# %% [markdown]
# ### NLP Assignment 2
# #### January 2020
#
# ###### Name:
# ###### Index No.:

# %% [markdown]
# ### Answer (a)
#
# This sention will load the dataset, remove symbols and filter alphanumeric words, tokenize, identify singlish or not and finally create 2 different CSV files for each

# %%
import pandas as pd

# %%
#importing the dataset
df = pd.read_csv("./Sinhala_Singlish_Hate_Speech.csv/Sinhala_Singlish_Hate_Speech.csv")
df.head()
# Out:
#    PhraseNo                                             Phrase IsHateSpeech
# 0         1  මේ බැල්ලි කොටින්ගේ ගු කනකොට අපහසුවක් දැනුනෙ නැ...          YES
# 1         2  මන් ඊයේ මුස්ලිම් ඩෑල් එකක් එක්ක සෙල්ෆියක් ගත්ත...          YES
# 2         3                           සංහිදියාවට අවුලක් වෙයි ද           NO
# 3         4  .කටින් පුරසාරම් දොඩන අපි සිංහලයො විදියට ලැජ්ජා...          YES
# 4         5  මචන් ඔය මගුල නවත්තලා කොන්දක් තියෙනවානම් පුලුවන...          YES

# %%
#function to remove non-alphanumeric characters
symbols = ["~", "`", "!", "@", "#", "$", "%", "^", "&", "*", "(", ")", "_", "-", "+", "=", ";", ":", '\"', "\'", "<", ",", ">", ".", "?", "/", "{", "[", "}", "]", "|", "\\"]
def removeNonAlphaNumeric(string):
    formattedStr = string
    for symbol in symbols:
        formattedStr = formattedStr.replace(symbol, ' ')
    return formattedStr

# %%
df["cleaned_phrase"] = df.Phrase.apply(removeNonAlphaNumeric)

# %% [markdown]
# ### Note: Did not filtered html tags since they were not present in the dataset. Only the symbols were removed

# %%
# function to tokenize a string using spaces since symbols are removed
def tokenize(string):
    tokens = string.split(" ")
    finalizedTokens = []
    for t in tokens:
        if(len(t) != 0):
            finalizedTokens.append(t)
    return finalizedTokens

# %%
tokens = []

# %%
# generate tokens
for index, row in df.iterrows():
    tokens.append(tokenize(row['cleaned_phrase']))

# %%
tokens
# Out:
# [['මේ',
#   'බැල්ලි',
#   'කොටින්ගේ',
#   'ගු',
#   'කනකොට',
#   'අපහසුවක්',
#   'දැනුනෙ',
#   'නැද්ද',
#   'දන්',
#   'නැහැ',
#   'ඔකිට',
#   'මිනිහා',
#   'මැරුනම',
#   'දැනුන',
#   'දුකට',
#   'වඩා',
#   'දහස්',
#   'ගුනයක',
#   'දුකක්',
#   'දැනෙනවා',
#   'ඉස්සරහට',
#   'උපසම්පදාව',
#   'තියන',
#   'භික්සුවක්',
#   'හිරේ',
#   'යැවුවට',
#   'ඔකි',
#   'වැඩියෙන්ම',
#   'ආදරේ',
#   'කෙනෙක්',
#   'ඔකිට',
#   'නැති',
#   'වෙනවා',
#   'වැඩි',
#   'කල්',
#   'නොගිහින්'],
#  ['මන්',
#   'ඊයේ',
#   'මුස්ලිම්',
#   'ඩෑල්',
#   'එකක්',
#   'එක්ක',
#   'සෙල්ෆියක්',
#   'ගත්තා',
#   'සහජීවනේ',
#   'රැකගෙන',
#   'ඉදිරියට',
#   'යන්න',
#   'ඌ',
#   'ඒක',
#   'තාම',
#   'දාලා',
#   'නෑ',
#   'පරයා'],
#  ['සංහිදියාවට', 'අවුලක්', 'වෙයි', 'ද'],
#  ['කටින්',
#   'පුරසාරම්',
#   'දොඩන',
#   'අපි',
#   'සිංහලයො',
#   'විදියට',
#   'ලැජ්ජා',
#   'විය',
#   'යුතුයි'],
#  ['මචන්',
#   'ඔය',
#   'මගුල',
#   'නවත්තලා',
#   'කොන්දක්',
#   'තියෙනවානම්',
#   'පුලුවන්නම්',
#   'කරලා',
#   'පෙන්නපන්',
#   'ඔය',
#   'දෙසපාලනය',
#   'කරන',
#   'අයගෙන්',
#   'මෙ',
#   'රටට',
#   'මොකක්ද',
#   'වෙලාතියෙන්නෙ',
#   'කියලා',
#   'අන්න',
#   'එදාට',
#   'උබ',
#   'නියම',
#   'කොල්ලෙක්',
#   'පුලුවන්නම්',
#   'කරලා',
#   'පෙන්නනවාද'],
#  ['හැබැයි',
#   'ඒ',
#   'මේ',
#   'ආණ්ඩුවේ',
#   'විතරක්',
#   'නෙවෙයි',
#   'රට',
#   'හූරාගෙන',
#   'තමන්ගෙ',
#   'බූදලය',
#   'කියල',
#   'හිතාගෙන',
#   'රට',
#   'උගස්',
#   'තියල',
#   'සල්ලි',
#   'නයට',
#   'අරගෙන',
#   'තමතමන්ගෙ',
#   'පරම්පරාවෙ',
#   'එවුන්ටයි',
#   'හිතවත්',
#   'එවුන්ටයි',
#   'බෙදාගෙන',
#   'කන',
#   'සියලුම',
#   'දේශපාලකයන්',
#   'දුටු',
#   'දුටු',
#   'තැන',
#   'මරලා',
#   'දාන',
#   'දිනය',
#   'වැඩි',
#   'ඈතක',
#   'නෑ'],
#  ['ලංකාව',
#   'මොකක්ද',
#   'මෙිකෙ',
#   'ඉන්නෙ',
#   'වාහනයක්',
#   'ගත්තම',
#   'අලි',
#   'ඔලුවෙන්',
#   'ඉන්න',
#   'පාරෙ',
#   'යන',
#   'වෙන',
#   'එකෙක්',
#   'ගැන',
#   'හිතන්නැති',
#   'නිරැවත්',
#   'පිංපියො',
#   'වගෙ',
#   'එවුන්',
#   'ටිකක්',
#   'නෙ'],
#  ['Menna',
#   'ratawal',
#   'menna',
#   'minissu',
#   'ape',
#   'ratawal',
#   'wala',
#   'inna',
#   'jathin',
#   'thunema',
#   'gothrikayo',
#   'tika',
#   'manussayo',
#   'karala',
#   'inna',
#   'wenawa'],
#  ['උඹ',
#   'ලෝකයක්',
#   'ඉස්සරහ',
#   'හදාගත්ත',
#   'නම්බුව',
#   'ලංකාවේ',
#   'කාලකණ්ණි',
#   'එක',
#   'විනාඩියේන්',
#   'නැති',
#   'කරයි',
#   'බන්',
#   'ඒ',
#   'හන්ද',
#   'දේශපාලනය',
#   'කරන්ට',
#   'එන්ට',
#   'එපා',
#   'මචංංංංං',
#   'ගුඩ්ලක්'],
#  ['පල්ලියකට',
#   'ගලක්',
#   'වැදුනත්',
#   'පරසක්වල',
#   'ගහන',
#   'මූ',
#   'පන්සල්',
#   'බිමට',
#   'සමතලා',
#   'කරද්දී',
#   'සද්ද',
#   'නෑ',
#   'මූට',
#   'කොහොමත්',
#   'ඡන්දෙ',
#   'නම්',
#   'දෙන්නෙ',
#   'නෑ'],
#  ['පංසල්',
#   'විනාශ',
#   'කරද්දී',
#   'ඇරෙන්නේ',
#   'නැති',
#   'සංගාගේ',
#   'කට',
#   'පල්ලියට',
#   'ගල්',
#   'ගහද්දි',
#   'ඇරුණා',
#   'එහෙම',
#   'නායකත්වයක්',
#   'සිංහල',
#   'රට',
#   'ජාතිය',
#   'හදයිද'],
#  ['paduway',
#   'hitahan',
#   'beri',
#   'weda',
#   'nokaran',
#   'bat',
#   'eka',
#   'gaththada',
#   'bole',
#   'elluwada',
#   'oka',
#   'karagena',
#   'inna',
#   'oyala',
#   'desapalanayata',
#   'atha',
#   'daruwan',
#   'therum',
#   'ganna',
#   'nikan',
#   'thiyena',
#   'prrsiddath',
#   'nethi',
#   'karanna',
#   'epa'],
#  ['muth',
#   'kata',
#   'arinne',
#   'anik',
#   'unta',
#   'witharai',
#   'jathiyata',
#   'agamata',
#   'sadda',
#   'na',
#   'endiyawata',
#   'koti',
#   'ganan',
#   'denawa',
#   'ahinsakayant',
#   'ape',
#   'rate',
#   'unta',
#   'mukuth',
#   'na'],
#  ['songs',
#   'kanna',
#   'epa',
#   'buruwo',
#   'kochchara',
#   'lassana',
#   'sindu',
#   'kanna',
#   'epa',
#   'ubalata',
#   'song',
#   'karanna',
#   'barinam',
#   'nikan',
#   'edapan',
#   'thiyana',
#   'ewa',
#   'kanna',
#   'epa'],
#  ['Muth',
#   'nanna',
#   'yanne',
#   'kridakayanta',
#   'ground',
#   'walata',
#   'wena',
#   'asadaranakam',
#   'walata',
#   'wachanayak',
#   'eliyata',
#   'danne',
#   'nathi',
#   'aka',
#   'rata',
#   'hadanna',
#   'yanawa',
#   'Mahela',
#   'karanam',
#   'api',
#   'akenma',
#   'set'],
#  ['Ai',
#   'mahinda',
#   'gen',
#   'polonnaruve',
#   'valikande',
#   'hmbawnaAkkara',
#   '1800',
#   'maddida',
#   'sanga',
#   'den',
#   'unp',
#   'yen',
#   'akkara',
#   'kiyak',
#   'onida',
#   'Apita',
#   'ogama',
#   'danna',
#   'kaururh',
#   'nane',
#   'dun',
#   'noth',
#   'apith',
#   'dannava',
#   'karan',
#   'naoni',
#   'vada'],
#  ['ජයසූරිය',
#   'mathakada',
#   'ow',
#   'ow',
#   'sanath',
#   'ජයසූරිය',
#   'thama',
#   'eyatath',
#   'wada',
#   'KUJITHA',
#   'wela',
#   'yannai',
#   'sangata',
#   'wenne'],
#  ['රට',
#   'හදන්න',
#   'ඕනේ',
#   'නම්',
#   'එන්ජීඕ',
#   'ගැට',
#   'වලින්',
#   'මිදී',
#   'ගෙදරට',
#   'වී',
#   'ඉන්න'],
#  ['Dana', 'reddak', 'sinhalen', 'danna', 'kiyanna', 'meka', 'lankawa'],
#  ['කියන්න',
#   'වැඩ',
#   'හොදනම්',
#   'හදවතින්ම',
#   'සපෝර්ට්',
#   'හැබැයි',
#   'පොහොට්ටුව',
#   'samaga',
#   'නොවී',
#   'U',
#   'N',
#   'p',
#   'nam',
#   'නම්',
#   'හුරේ'],
#  ['President',
#   'wenna',
#   'puluwan',
#   'bauddayekuta',
#   'witharai',
#   'Me',
#   'yaka',
#   'Croatian'],
#  ['රට',
#   'හදන්න',
#   'කලින්',
#   'මිනිසුන්',
#   'රවටන',
#   'ප්\u200dරචාරක',
#   'දැන්විම්',
#   'වලින්',
#   'මුදල්',
#   'හම්බ',
#   'කරන',
#   'එක',
#   'නවත්වා',
#   'සමාජයට',
#   'සේවයක්',
#   'කරන්න'],
#  ['ජයසූරියත්',
#   'ආවෙ',
#   'කෝ',
#   'රට',
#   'හැදුවද',
#   'හැදුවද',
#   'නෑ',
#   'නෙ',
#   'නෑ',
#   'නෙ',
#   'ඌ',
#   'ලමයි',
#   'හැදුවා'],
#  ['ආ', 'එතකොට', 'අපිටත්', 'ඇඩ්', 'එකක', 'ඉන්න', 'පුළුවන්', 'වෙයි', 'නේ'],
#  ['පොන්නයො',
#   'රට',
#   'පලනය',
#   'කරනකොට',
#   'ඔහොම',
#   'තමා',
#   'ජිවිතේ',
#   'අසාවෙන්',
#   'බලපු',
#   'එකම',
#   'දේ',
#   'ක්\u200dරිකට්',
#   'එකත්',
#   'නැති',
#   'කරා',
#   'මේ',
#   'පොන්නයො'],
#  ['ඔය',
#   'කාරනය',
#   'හරියට',
#   'විග්\u200dරහ',
#   'කරන්න',
#   'ඩුප්ලිකේට්',
#   'මහමෙව්නාවේ',
#   'ඩුප්ලිකේට්',
#   'කල්\u200dයාණ',
#   'මිතුරන්ට',
#   'පුලුවන්',
#   'නම්',
#   'දිව්\u200dය',
#   'ලෝක',
#   'promote',
#   'කරයි\u200d',
#   'ද'],
#  ['ස්ට්\u200dරයික්', 'කරන', 'ඔක්කොටම', 'ගහන්න', 'ඕන', 'දෝස්තරලාත්', 'ඇතුලු'],
#  ['Aka',
#   'satha',
#   '5k',
#   'wadi',
#   'karanna',
#   'epa',
#   'okunta',
#   'wada',
#   'karanna',
#   'bai',
#   'nam',
#   'job',
#   'eken',
#   'elawanna',
#   'eliye',
#   'job',
#   'nathi',
#   'ewun',
#   'oni',
#   'tharam',
#   'ennawa'],
#  ['ගිය',
#   'ආන්ඩුව',
#   'කාලෙ',
#   'ඔහොම',
#   'නැටුවේ',
#   'නෑ',
#   'මුන්ගෙ',
#   'කොන්ද',
#   'පන',
#   'නෑ'],
#  ['ඉතිං',
#   'බං',
#   'උබලා',
#   'පිස්සු',
#   'නටලා',
#   'ඊට',
#   'වඩා',
#   'පඩි',
#   'ගන්නෙ',
#   'ඕක',
#   'මොකක්ද'],
#  ['කල්ලතෝනි', 'පකෙක්'],
#  ['අැත්තටම',
#   'හරිම',
#   'සතුටුයි',
#   'එ්',
#   'මනුස්සකමට',
#   'එ්',
#   'වගේම',
#   'අරාබියට',
#   'ගිහින්එන',
#   'අපේ',
#   'මුස්ලිමි',
#   'කාන්තාවන්',
#   'මුන',
#   'වහගෙන',
#   'බිල්ලෝ',
#   'වගේ',
#   'එනකොට',
#   'මේ',
#   'නෝනා',
#   'හරිම',
#   'සුන්දර',
#   'විදියට',
#   'අැවිත්',
#   'ඉන්නවා'],
#  ['kisi', 'quality', 'ekak', 'nathi', 'apatayek'],
#  ['Munta', 'chande', 'Dena', 'buruwo', 'innawane', 'thawath', 'me', 'rate'],
#  ['මේ',
#   'කැරිවේසිග',
#   'පුතාල',
#   'ඉන්නකල්',
#   'රටට',
#   'කෙලවෙන',
#   'එක',
#   'අහන්නත්',
#   'දෙයක්ද',
#   'බන්',
#   'කාලකන්නි',
#   'හැත්ත',
#   'බල්ලො',
#   'රටේ',
#   'ලොක්කො',
#   'වෙනකොට',
#   'රට',
#   'බල්ලට',
#   'යන',
#   'එක',
#   'අහන්නත්',
#   'දෙයක්ද'],
#  ['thota',
#   'henagapiya',
#   'kadaya',
#   'thilangayawa',
#   'hurathal',
#   'karapan',
#   'esige',
#   'putha'],
#  ['cricket',
#   'kridawa',
#   'kawe',
#   'oi',
#   'thirisana',
#   'oi',
#   'putuwa',
#   'deehan',
#   'sangata',
#   'Un',
#   'dawiwaru',
#   'yakooo'],
#  ['kwda',
#   'me',
#   'lat',
#   'roy',
#   'kiyana',
#   'ekaa',
#   'lat',
#   'hoodana',
#   'ekek',
#   'da'],
#  ['ekata', 'ape', 'eka', 'thuuu'],
#  ['තොපි',
#   'වගේ',
#   'නාහෙන්',
#   'අඩන',
#   'කාලකන්නි',
#   'පොන්නයො',
#   'නිසා',
#   'තමයි',
#   'අපේ',
#   'සංගීතයට',
#   'අද',
#   'කණ',
#   'කොකා',
#   'හඩලා',
#   'තියෙන්නෙ',
#   'ලැජ්ජයි',
#   'යකෝ',
#   'තෝ',
#   'වගේ',
#   'එකෙක්',
#   'ආයෙ',
#   'මුණ',
#   'ගැහුනා',
#   'නම්',
#   'ඌත්',
#   'තෝ',
#   'වගේම',
#   'අඩයිනෙ',
#   'දවසක'],
#  ['dakuna', 'menessuu', 'harema', 'arthmarthakameeeeeeeeeeee'],
#  ['sinhalayo', 'kuhakayo'],
#  ['අපොයි',
#   '2020',
#   'ජනාධිපති',
#   'නෙද',
#   'හුත්තෝ',
#   'උබ',
#   'උබ',
#   'හොදයි',
#   'නගරසභාවේ',
#   'toilet',
#   'සුද්ද',
#   'කරන්න',
#   'හිකුණ්ඨික',
#   'සක්කිලියා'],
#  ['මොනව', 'උනත්', 'පොලිසියෙ', 'ඉන්නෙ', 'බල්ලො'],
#  ['Lankawe',
#   'wage',
#   'political',
#   'majarayo',
#   'innakam',
#   'police',
#   'quality',
#   'eka',
#   'wadi',
#   'karanna',
#   'baha'],
#  ['තෝ',
#   'වගෙ',
#   'එකෙක්',
#   'අනේ',
#   'මන්ද',
#   'යකෝ',
#   'වැදගත්',
#   'දෙයක්',
#   'කරපිය',
#   'ගොන්',
#   'වස්සෙක්',
#   'ඉදකින්',
#   'හුත්තො'],
#  ['Lanka',
#   'we',
#   'inne',
#   'labba',
#   'bahapu',
#   'naki',
#   'police',
#   'karayo',
#   'ne',
#   'bulath',
#   'wite',
#   'kagena',
#   'ahisaka',
#   'bike',
#   'ekak',
#   'nawath',
#   'wala',
#   'ugen',
#   'rs',
#   '500',
#   'aragena',
#   'lami',
#   'ta',
#   'ganun',
#   'ta',
#   'kanna',
#   'dena'],
#  ['kasippu',
#   'karayagen',
#   'ganja',
#   'karayagen',
#   'keeyak',
#   'hari',
#   'aragena',
#   'unge',
#   'bothalayata',
#   'yata',
#   'una',
#   'kisima',
#   'puhunuwak',
#   'nathi',
#   'gon',
#   'harak',
#   'tikak',
#   'ne',
#   'police',
#   'office',
#   'ekak',
#   'paththata',
#   'nikamata',
#   'gihilla',
#   'blapalla',
#   'ali',
#   'wrdi',
#   'walatath',
#   'duwana',
#   'un',
#   'inne',
#   'gam',
#   'walin',
#   'apu',
#   'rilau'],
#  ['ඇයි',
#   'යකෝ',
#   'ලංකාවේ',
#   'පොලිසිය',
#   'නිරායුධ',
#   'මිනිසුන්ට',
#   'ගහන්නේ',
#   'එලවා',
#   'එලවා'],
#  ['Ape', 'polisiya', 'atule', 'tmai', 'wadiyenma', 'horu', 'inne'],
#  ['arawa', 'kanno', 'echchari', 'danne', 'policeya', 'gena'],
#  ['පොලිස්සිය',
#   'තාමත්',
#   'කැද',
#   'හැලි',
#   'වගේ',
#   'තරැන',
#   'කොල්ලොන්ට',
#   'ජීවිතෙන්',
#   'වන්දි',
#   'ගෙවන්න',
#   'වෙන්නෙ',
#   'නාකි',
#   'පප්පල',
#   'බුලත්විටක්',
#   'කාගෙන',
#   'අඩි',
#   'දහයක්',
#   'දුවා',
#   'ගන්න',
#   'බැරි',
#   'නිසා'],
#  ['තුවක්කු',
#   'පුහුනුව',
#   'දෙන්නෙ',
#   'training',
#   'එකේ',
#   'විතරයි',
#   'ඉලක්කයක්',
#   'අරන්',
#   'වෙඩි',
#   'තියන්න',
#   'කී',
#   'දෙනාද',
#   'දක්ෂ',
#   'නාකි',
#   'පප්පල',
#   'ටික',
#   'ගහල',
#   'පන්නන්න',
#   'ඕන',
#   'ජරාව',
#   'කකා',
#   'ඉන්නන්',
#   'වාලේ',
#   'ඉන්නවට',
#   'අනිත්',
#   'එක',
#   'සාමාන්\u200dය',
#   'මිනිස්සු',
#   'ඉන්න',
#   'තත්වයකදි',
#   'මේ',
#   'විදියට',
#   'වෙඩි',
#   'තැබීම',
#   'අනුමත',
#   'කරන්න',
#   'බැ'],
#  ['පාතාල',
#   'කාරයන්ට',
#   'මනුස්සකමක්',
#   'නැනේ',
#   'මුන්',
#   'බයික්',
#   'වලට',
#   'නගිනකන්',
#   'ඉවසන්න',
#   'තිබුනේ',
#   'නැත්තන්',
#   'තත්වය',
#   'බලල',
#   'stf',
#   'ගෙනන්න',
#   'තිබුනේ',
#   'කොහේද',
#   'ලොක්කො',
#   'දෙන',
#   'අණ',
#   'නේ',
#   'අපරාදෙ',
#   'වටින',
#   'ජීවිතයක්'],
#  ['ගිහින්',
#   'ඔය',
#   'එකෙක්ටවත්',
#   'ආපහු',
#   'මේ',
#   'ලෝකේ',
#   'දකින්න',
#   'ඉඩ',
#   'තියන්න',
#   'එපා',
#   'මුන්ව',
#   'හිරේ',
#   'යවන්නනම්',
#   'එපා',
#   'මරලා',
#   'දානවා',
#   'මිසක්'],
#  ['අනේ', 'මෙහෙමත්', 'කුහක', 'මිනිස්සු'],
#  ['මෙතන',
#   'හොරු',
#   'හොදට',
#   'තුවක්කුවලින්',
#   'වෙඩි',
#   'තියනවා',
#   'පොලිසිය',
#   'අත',
#   'වන',
#   'වන',
#   'ඇවිත්',
#   'හොරුන්ගෙන්',
#   'වෙඩි',
#   'කනවා',
#   'ගුටි',
#   'කනවා'],
#  ['මෙලෝ', 'රහක්', 'නැති', 'උන්', 'ඉන්න', 'ටවුන්', 'එකක්'],
#  ['මන්නම්',
#   'කියන්නෙ',
#   'පොලිසියෙ',
#   'උන්නැහැලා',
#   'ටිකටත්',
#   'stf',
#   'පුහුණුවක්',
#   'අවශයයි',
#   'මොකද',
#   'හොරාට',
#   'පන්න',
#   'ගන්න',
#   'බැ',
#   'මොලෙ',
#   'පාවිච්චි',
#   'කරලා',
#   'හොරා',
#   'කොටු',
#   'කරගන්නෙ',
#   'නැ',
#   'ගොන්',
#   'වැඩ',
#   'ගොඩක්',
#   'තියෙනව'],
#  ['කතා',
#   'කරෝත්',
#   'මහ',
#   'ලොකුවට',
#   'අපි',
#   'දකුණේ',
#   'කෝන්දක්',
#   'තීයන1',
#   'කේනේක්',
#   'නෑ',
#   'පොලිසිය',
#   'අයියව',
#   'උස්සන්න',
#   'ඔය',
#   'උස්සපු',
#   'අයියා',
#   'විතරයි',
#   'පිරිමි',
#   'යේක්',
#   'කියලා'],
#  ['මමනං',
#   'දැක්කේ',
#   'අනිත්',
#   'ඔක්කෝම',
#   'පිරිමී',
#   'අපි',
#   'අදින',
#   'ගවුම්',
#   'වලට',
#   'වඩා',
#   'හෝද',
#   'නයිටි',
#   'ටිකක්',
#   'ඇදගන්න',
#   'ලැජ්ජයි',
#   'මට',
#   'නම්',
#   'මාතර',
#   'අයට',
#   'පිරිමි',
#   'කියන්න',
#   'දැක්ක',
#   'හොදම',
#   'නපුංසකයෝ',
#   'නම්',
#   'මාතර',
#   'තමා',
#   'අනේ',
#   'ප්ලීස්',
#   'ඔය',
#   'මංකොල්ල',
#   'කාරයෝ'],
#  ['ඔක්කෝම',
#   'කෝහෝම',
#   'හරි',
#   'වෙඩිතියල',
#   'මරලා',
#   'දාන්න',
#   'පොලිස්පති',
#   'තුමනි',
#   'අයේත්',
#   'මේවැනි',
#   'දේ',
#   'නොවෙන්න'],
#  ['මව්',
#   'බිම',
#   'නැති',
#   'නම්',
#   'මරණය',
#   'මෙයයි',
#   'තේමා',
#   'පාටය',
#   'විය',
#   'යුත්තේ',
#   'ඔය',
#   'පෝන්',
#   'කෝල්',
#   'වලට',
#   'බයේ',
#   'රාජකාරි',
#   'කරන',
#   'කාලය',
#   'ඇත',
#   'හැරි',
#   'යුතුයි'],
#  ['ratakata',
#   'giya',
#   'kalak',
#   'vahane',
#   'dora',
#   'arinna',
#   'ekek',
#   'help',
#   'kare',
#   'ne',
#   'ara',
#   'manussayata',
#   'me',
#   'aparade',
#   'karapu',
#   'un',
#   'tama',
#   'nidalle',
#   'rate',
#   'maha',
#   'un',
#   'ponnayo',
#   'ekai',
#   'me',
#   'serama',
#   'dewal',
#   'okunat',
#   'chance',
#   'denna',
#   'epa',
#   'tatwat'],
#  ['Pathali',
#   'para',
#   'haththa',
#   'akekwath',
#   'ethuru',
#   'karanna',
#   'epa',
#   'okunge',
#   'daruwanta',
#   'edala',
#   'hena',
#   'gahanawa',
#   'para',
#   'ballo'],
#  ['තුවක්කුවක්',
#   'නැත්තං',
#   'පැත්තකට',
#   'වෙලා',
#   'ඉදපංකො',
#   'විහිං',
#   'මැරැම්කන්නැතිව',
#   'තුවක්කු',
#   'තියං',
#   'ඉන්න',
#   'මංකොලල',
#   'කාරයන්ට',
#   'බැටන්පොල්ලෙන්',
#   'ගහන්න',
#   'ගියාම',
#   'මැරැංකන',
#   'එක',
#   'අහන්නත්',
#   'දෙයක්ද',
#   'මේක',
#   'මහ',
#   'මෝඩයෙක්'],
#  ['Ashi',
#   'Hashi',
#   'ඔවාට',
#   'දකුණේ',
#   'එකෙක්',
#   'ඒක',
#   'කෙලින්',
#   'කියන්න',
#   'වෙන',
#   'වෙන',
#   'සීන්',
#   'ගැන',
#   'කියල',
#   'මඩ',
#   'ගහන්නෙ',
#   'නැතුව'],
#  ['Ahama',
#   'kiyana',
#   'apa',
#   'natara',
#   'kiyann',
#   'apa',
#   'gama',
#   'policya',
#   'wada',
#   'waradagan',
#   'tiyana',
#   'nisai',
#   'minusu',
#   'ahka',
#   'baluwa',
#   'nikaruna',
#   'kollo',
#   'maranawa',
#   'horu',
#   'maragann',
#   'ba',
#   'bayta',
#   'akada',
#   'yahpalan',
#   'ahinsa',
#   'amm',
#   'adanwa',
#   'ada',
#   'puta',
#   'batuwa',
#   'oya',
#   'sakilli',
#   'bollonga',
#   'oluwata',
#   'waditiyala',
#   'danna',
#   'ona'],
#  ['මත්ද්\u200dරව්\u200dයවලට',
#   'ඇබ්බැහි',
#   'වෙලා',
#   'මිනිස්සු',
#   'මරලා',
#   'හරි',
#   'සල්ලි',
#   'ඔිිනි',
#   'පොලිසියට',
#   'පෙර',
#   'පුහුණුවක්',
#   'නැති',
#   'විම',
#   'පුජිත',
#   'දේසපාලකන්ගේ',
#   'කකුල්',
#   'ලේවකනවා',
#   'කොල්ලා',
#   'නිකන්',
#   'මැරැැනා'],
#  ['යකෝ',
#   'හරිහමන්',
#   'තුවක්කුවක්',
#   'දෙන්න',
#   'බැරිද',
#   'බන්',
#   'ඇමති',
#   'අයගේ',
#   'වාහන',
#   'වලට',
#   'කෝටි',
#   'ප්\u200dරකෝටි',
#   'ගනන්',
#   'නාස්ති',
#   'කරනවා',
#   'ඕන',
#   'දේකට',
#   'වියදම්',
#   'කරන්නේ',
#   'නෑ'],
#  ['Me', 'horu', 'training', 'une', 'koheda'],
#  ['Thattayaa',
#   'mokek',
#   'daa',
#   'uuu',
#   'karikii',
#   'karikii',
#   'innee',
#   'pissek',
#   'wagee',
#   'udauu',
#   'karannee',
#   'nathywaa',
#   'mona',
#   'pissek',
#   'daa',
#   'mandaa'],
#  ['Maraladanna',
#   'thiyenne',
#   'okunwa',
#   'mathara',
#   'un',
#   'dakune',
#   'kiyala',
#   'kehegahuwata',
#   'bayagullo',
#   'inne'],
#  ['අර',
#   'දිවියව',
#   'මරපු',
#   'මිනිස්සු',
#   'තරම්',
#   'අපරාධ',
#   'කාරයෝ',
#   'නෙමේ',
#   'වෙන්න',
#   'ඇති',
#   'මේ',
#   'පොලිස්',
#   'නිලධාරියාව',
#   'මරපු',
#   'මිනිමරුවෝ',
#   'එකනේ',
#   'ඒ',
#   'තරම්',
#   'දරුණු',
#   'වචන',
#   'නැත්තේ',
#   'මේ',
#   'මිනි',
#   'මරුවන්ට',
#   'එරෙහිව'],
#  ['Oya',
#   'jatika',
#   'arakahawa',
#   'sambanda',
#   'inna',
#   'uda',
#   'pena',
#   'pena',
#   'kata',
#   'meta',
#   'dodawana',
#   'amatio',
#   'dipan',
#   'polisiata',
#   'hoda',
#   'wepan',
#   'mesinngan',
#   'arun',
#   'ottu',
#   'sellam',
#   'karanawa',
#   'maha',
#   'pare',
#   'hat',
#   'denek',
#   'duwanawa',
#   'lejjai',
#   'dipan',
#   'oya',
#   'pattama',
#   'Patalema',
#   'Tawa',
#   'ekekuta',
#   'palayan',
#   'paw',
#   'nodi',
#   'gedara'],
#  ['Lankawe',
#   'inna',
#   'samahara',
#   'pirimi',
#   'napunsakayo',
#   'ara',
#   'manussayata',
#   'wahane',
#   'dora',
#   'arala',
#   'dennawat',
#   'kenek',
#   'enne',
#   'ne',
#   'mun',
#   'pirimida',
#   'ane',
#   'e',
#   'manussaya',
#   'veerayek',
#   'attatama'],
#  ['තවත්', 'එක්', 'සෝමාලියාවක්', 'වගේ', 'ශිට්'],
#  ['Meyata',
#   'aydayak',
#   'tibbanam',
#   'aniwa',
#   'dennekwath',
#   'bawanawa',
#   'aprade'],
#  ['පාතාලයේ', 'කියන', 'හැම', 'එකාවම', 'මරල', 'දාන්න', 'ඕනා'],
#  ['Hospital',
#   'inna',
#   'ewun',
#   'tikath',
#   'wada',
#   'deela',
#   'maranda',
#   'thiyenne'],
#  ['ත්\u200dරිවිධ',
#   'හමුදාවට',
#   'පොලිසිය',
#   'අසරණ',
#   'කරන්න',
#   'තහංචි',
#   'පනවා',
#   'හොරුන්ට',
#   'නීති',
#   'රීති',
#   'ලිහිල්වුන',
#   'රටක්',
#   'ලංකාව'],
#  ['කියන්න', 'නම්', 'එපා', 'අපි', 'දකුනේ', 'කියලා', 'විලි', 'ලැජ්ජයි', 'යකෝ'],
#  ['ඕකුන්වත්',
#   'පෝලිමට',
#   'තියලා',
#   'මරලා',
#   'දාපල්ලා',
#   'අර',
#   'අහිංසකයට',
#   'වුනා',
#   'වගේම'],
#  ['Shit', 'ara', 'ekek', 'dakalat', 'dakke', 'na', 'wage', 'yanawa'],
#  ['Waha', 'palane', 'raga', 'tamai', 'oya'],
#  ['වෙනසෙ', 'සැප', 'පේනවනේ', 'මෙි', 'රටෙි', 'නිතිය', 'බල්ලට', 'ගිහින්'],
#  ['ලංකාවේ',
#   'hema',
#   'tanama',
#   'oya',
#   'wage',
#   'tamai',
#   'R',
#   'D',
#   'A',
#   'නිලධාරීන්',
#   'owa',
#   'දකින්නේ',
#   'nati',
#   'එක',
#   'හරිම',
#   'කනගාටුදායක',
#   'අපෙන්',
#   'බඳු',
#   'ගහන',
#   'සල්ලිවලින්',
#   'කරන',
#   'අපරාධ',
#   'Henaghanawa',
#   'munta',
#   'tu'],
#  ['Ape',
#   'peththeth',
#   'oya',
#   'wede',
#   'mai',
#   'කරන්නේ',
#   'මහින්ද',
#   'මහත්තයා',
#   'නැතිකම',
#   'දැනෙනවා',
#   'hitiyanam',
#   'අපිත්',
#   'ගොඩ'],
#  ['දැන්',
#   'බැන',
#   'බැන',
#   'මේකෙ',
#   'පෝස්ට්',
#   'දැම්මට',
#   'මේවා',
#   'පිලිවෙලට',
#   'මහින්දගෙ',
#   'කාලෙ',
#   'සිද්ධ',
#   'උනා',
#   'ඒවාට',
#   'අසංවේදී',
#   'උන',
#   'මෝඩ',
#   'උද්ධච්ඡ',
#   'මිනිස්සුන්ගෙ',
#   'ඡන්ද',
#   'වල',
#   'පිහිටෙන්',
#   'ලැබුනු',
#   'වෙනස',
#   'තමයි',
#   'මේ',
#   'තියෙන්න්නේ'],
#  ['තුවාල',
#   'වලට',
#   'බේත්',
#   'දානවා',
#   'වගේ',
#   'කියන්න',
#   'දුකයි',
#   'සිංහල',
#   'ජාතිය',
#   'කාළකණ්නි',
#   'ජාතියක්',
#   'බවට',
#   'පත්',
#   'වී',
#   'හමාරයි'],
#  ['mewata',
#   'loku',
#   'baladarin',
#   'waga',
#   'kiyanna',
#   'ona',
#   'mun',
#   'okkoma',
#   'ekai',
#   'mahajana',
#   'mudal',
#   'nasthi',
#   'karana',
#   'kalakanni',
#   'balu',
#   'heththa'],
#  ['ඇත්තම', 'කියනවනම්', 'ලංකාව', 'හරිම', 'කාලකන්නි', 'රටක්'],
#  ['කාලකන්නි',
#   'හැතිකරය',
#   'අපේ',
#   'සල්ලි',
#   'වලින්',
#   'ලබු',
#   'කන',
#   'මෙි',
#   'වාගේ',
#   'රජයේ',
#   'අයතන',
#   'වලට',
#   'හන',
#   'හගන්න',
#   'ඔන'],
#  ['akke', 'aewa', 'loku', 'unge', 'weradi'],
#  ['mun', 'wage', 'kalakanni', 'innakan', 'ratawal', 'diunukarana', 'be'],
#  ['මුන්', 'ඔක්කොම', 'රට', 'කනවා', 'අනේ', 'අපේ', 'බදු', 'ගන්න', 'සල්ලි'],
#  ['ඒත්',
#   'උඹ',
#   'අර',
#   'හොටු',
#   'පෙරං',
#   'අඬන',
#   'හෙලු',
#   'කෙල්ලොංගෙ',
#   'videosui',
#   'අනික්',
#   'ලබ්බවල්',
#   'වලට',
#   'වඩා',
#   'මේ',
#   'කරපු',
#   'වැඩේනම්',
#   'great',
#   'බං'],
#  ['Api',
#   'thathala',
#   'nathuwa',
#   'duk',
#   'wenwa',
#   'me',
#   'kalaknni',
#   'thaththala',
#   'idala',
#   'salakanne'],
#  ['මොනතරම්',
#   'ගින්දරක්',
#   'පපු',
#   'ඇතුලේ',
#   'පත්තු',
#   'වෙනවා',
#   'අැද්ද',
#   'තාත්තා',
#   'මේ',
#   'අත්',
#   'පා',
#   'උස්මහත්',
#   'කරපු',
#   'තාත්තා',
#   'දෙයියනේ',
#   'ශාප',
#   'වෙයි',
#   'උඹලට',
#   'මේ',
#   'ආත්මෙම'],
#  ['thopi', 'wage', 'lamainta', 'me', 'athmedi', 'hena', 'wadina', 'ona'],
#  ['උගෙ',
#   'අප්පගෙ',
#   'නීතියක්නෙ',
#   'යකො',
#   'එක',
#   'අර',
#   'රංගෙ',
#   'බන්ඩාරගෙ',
#   'පුතා',
#   '3',
#   'පාරක්',
#   'වාහනෙ',
#   'හප්පලා',
#   'එක',
#   'මිනිහෙක්',
#   'මරලා',
#   'පවුලක්',
#   'අබ්බගාතයො',
#   'කරා',
#   'කො',
#   'නිතිය',
#   'මෙපාර',
#   'ගෙයක්',
#   'කුඩු',
#   'කරලා',
#   'හොදටම',
#   'බීලා',
#   'වාහනෙ',
#   'ඇතුලෙ',
#   'කඩු',
#   'පොලු',
#   'තියෙද්දිත්',
#   'කොහොමද',
#   'යකො',
#   'ඌට',
#   'ඇප',
#   'දෙන්නෙ'],
#  ['NGO',
#   'වලින්ද',
#   'එතකොට',
#   'ලංකාවෙ',
#   'නිතිය',
#   'ක්රියාත්මක',
#   'කරන්නෙ',
#   'නොදකිං',
#   'කලකිරෙනවා',
#   'මෙවා',
#   'දැක්කම',
#   'මොනද',
#   'මෙ',
#   'අපෙ',
#   'රටට',
#   'වෙන්නෙ'],
#  ['Henama',
#   'gahapiya',
#   'okita',
#   'NGO',
#   'karayanta',
#   'puka',
#   'dipan',
#   'thawath',
#   'wesi',
#   'tho',
#   'marunu',
#   'data',
#   'pansukule',
#   'denneth',
#   'අපේ',
#   'හාමුදුරුවෝ',
#   'mthaka',
#   'thiya',
#   'ganin',
#   'thota',
#   'sapa',
#   'wenawa',
#   'shinhalaya',
#   'gana',
#   'ktha',
#   'krapu',
#   'අපේ',
#   'හාමුදුරුවන්ට',
#   'මෙහෙම',
#   'කරාට'],
#  ['Mewata',
#   'katha',
#   'karanna',
#   'wachana',
#   'ne',
#   'hithe',
#   'wairaya',
#   'athi',
#   'karanawata',
#   'wada',
#   'wadath',
#   'hidama',
#   'de',
#   'munta',
#   'swabadahama',
#   'thulin',
#   'lebena',
#   'දඬුවම',
#   'diha',
#   'nihathamaniwa',
#   'balasitimai',
#   'sandya',
#   'kiyana',
#   'wesa',
#   'genita',
#   'hidata',
#   'ninda',
#   'yanawa',
#   'athi',
#   'den'],
#  ['Gon',
#   'genita',
#   'saapa',
#   'වේවා',
#   'me',
#   'athmedima',
#   'palisan',
#   'දේවා',
#   'හාමුදුරුවෝ',
#   'namak',
#   'hireta',
#   'yeuwata'],
#  ['Hamudurowo',
#   'kiwe',
#   'aththak',
#   'ube',
#   'miniha',
#   'KOtiyek',
#   'LTTE',
#   'eken',
#   'salli',
#   'gaththa',
#   'oththu',
#   'karayek',
#   'apith',
#   '2020',
#   'passe',
#   'me',
#   'kalakanni',
#   'anduwa',
#   'gedara',
#   'yawala',
#   'sahimakata',
#   'path',
#   'wenawa'],
#  ['Oyage',
#   'thawakalika',
#   'sathuta',
#   'uparima',
#   'winda',
#   'ganna',
#   'okata',
#   'windawanna',
#   'weddi',
#   'daraganna',
#   'bari',
#   'wei'],
#  ['ගොං', 'හුත්තී', 'හැමිනියන්', 'වෙසී', 'තොට', 'සාප', 'වේනවා', 'බැල්ලීයේ'],
#  ['කියන්න',
#   'දුකයි',
#   'අපෙ',
#   'රටේ',
#   'ලොකු',
#   'තැන්වල',
#   'උන්',
#   'පිරිහිලා',
#   'ඉවරයි',
#   'බලයට',
#   'ධනයට',
#   'ආගම',
#   'ජාතිය',
#   'විකුණනවා',
#   'උන්',
#   'දන්නෙ',
#   'නැ',
#   'උන්ට',
#   'වෙන්නේ',
#   'මොකක්ද',
#   'කියල',
#   'මෙවට',
#   'වගකිවයුතු',
#   'වන්නේ',
#   'ඉහළ',
#   'පෙලෙ',
#   'ඉන්න',
#   'උන්',
#   'අපෙ',
#   'ආගම',
#   'ජාතිය',
#   'විනාස',
#   'කරන',
#   'සක්කිලින්ට',
#   'කන්න',
#   'ගූත්',
#   'නැතිවෙනව',
#   'කාලකන්නි'],
#  ['මේ',
#   'බැල්ලි',
#   'කොටින්ගේ',
#   'ගු',
#   'කනකොට',
#   'අපහසුවක්',
#   'දැනුනෙ',
#   'නැද්ද',
#   'දන්',
#   'නැහැ',
#   'ඔකිට',
#   'මිනිහා',
#   'මැරුනම',
#   'දැනුන',
#   'දුකට',
#   'වඩා',
#   'දහස්',
#   'ගුනයක',
#   'දුකක්',
#   'දැනෙනවා',
#   'ඉස්සරහට',
#   'උපසම්පදාව',
#   'තියන',
#   'භික්සුවක්',
#   'හිරේ',
#   'යැවුවට',
#   'ඔකි',
#   'වැඩියෙන්ම',
#   'ආදරේ',
#   'කෙනෙක්',
#   'ඔකිට',
#   'නැති',
#   'වෙනවා',
#   'වැඩි',
#   'කල්',
#   'නොගිහින්'],
#  ['Cari',
#   'wesi',
#   'Me',
#   'cari',
#   'wesige',
#   'puke',
#   'arinna',
#   'one',
#   'miriskudu',
#   'daala',
#   'balu',
#   'wesita',
#   'Katu',
#   'kohila',
#   'alayak',
#   'bessuwanam',
#   'kakul',
#   '2ka',
#   'depeththata',
#   'karala',
#   'huththa',
#   'athulata',
#   'me',
#   'huththita',
#   'mita',
#   'wada',
#   'sathutak',
#   'lebei'],
#  ['අපේ',
#   'හමුදාව',
#   'බර',
#   'අවි',
#   'කෙමිකල්',
#   'මිසයිල',
#   'පාවිච්චි',
#   'කරලා',
#   'සමූලඝාතන',
#   'සිදුකලා',
#   'කියලා',
#   'මේ',
#   'හුත්තිගෙ',
#   'මිනිහා',
#   'කිව්වා',
#   'ඒකම',
#   'මේ',
#   'හුත්තිත්',
#   'කියනවා',
#   'එහෙම',
#   'එකේ',
#   'මේ',
#   'කැරි',
#   'වේසිට',
#   'දඩුවම්',
#   'දෙන්නෙ',
#   'එකෙක්',
#   'නැද්ද',
#   'මේ',
#   'බල්ලන්ට',
#   'අල්ලන',
#   'කැරි',
#   'වේසි',
#   'හමගහන්න',
#   'ඕනි',
#   'පනපිටින්'],
#  ['Tho',
#   'ganu',
#   'jatiyatama',
#   'nindawak',
#   'lake',
#   'wadi',
#   'dawasak',
#   'Yamaha',
#   'thota',
#   'sapa',
#   'wenawamai'],
#  ['මෙිි',
#   'හුත්තිට',
#   'සතුටුයිලු',
#   'අපේ',
#   'රටහරක්ටිකටත්',
#   'සතුටුඇති',
#   'අපේ',
#   'හාමුදුරැන්\u2063ට',
#   'දුන්න',
#   'දඩුවමට',
#   'දුකයි',
#   'ඊටත්වැඩිය',
#   'මරාගන',
#   'මැරෙන්න',
#   'හිතෙන්නෙ',
#   'අපෙහාමුදුරැවන්ට',
#   'ජමිිබරේ',
#   'අන්දපුඑකට',
#   'යකෝ'],
#  ['සංඝා',
#   'වහන්සේ',
#   'නමකට',
#   'විශේෂයෙන්',
#   'බුද්ධ',
#   'චිවරයට',
#   'අගෞරව',
#   'කල',
#   'පාපයට',
#   'නුඹට',
#   'මතු',
#   'මතුත්',
#   'සාප',
#   'වෙිවා'],
#  ['Meki',
#   'lankawe',
#   'janadi',
#   'pathinitakda',
#   'budu',
#   'dahama',
#   'winasa',
#   'karana',
#   'hethiriyak',
#   'ne'],
#  ['Podi',
#   'daruwo',
#   'dusanaya',
#   'karala',
#   'maranawa',
#   'ewata',
#   'mokuth',
#   'na',
#   'ane',
#   'pau',
#   'apahasa',
#   'neme',
#   'karanna',
#   'thibbe',
#   'kumarihamita',
#   'bella',
#   'mirikala',
#   'maranna'],
#  ['Tigae',
#   'miha',
#   'marapuuna',
#   'hiyanna',
#   'amruwak',
#   'na',
#   'katin',
#   'kiyapu',
#   'wacanata',
#   'uda',
#   'painawa',
#   'ubda',
#   'kada',
#   'hari',
#   'dittadamna',
#   'wadaniya',
#   'karumae',
#   'padisan',
#   'danawamai',
#   'budu',
#   'ciwarayanata',
#   'nigaru',
#   'kirimata'],
#  ['Oita',
#   'wada',
#   'hinsa',
#   'appa',
#   'rata',
#   'wanawa',
#   'podi',
#   'daruwo',
#   'antha',
#   'karanawa',
#   'apra',
#   'karayo',
#   'koha',
#   'baluwah',
#   'ma',
#   'gani',
#   'matharamma',
#   'sundara',
#   'wasthuwakda',
#   'balla',
#   'giya',
#   'ratak',
#   'apa',
#   'buddha',
#   'cjiwaraya',
#   'gana',
#   'harima',
#   'dukai'],
#  ['To',
#   'wage',
#   'balu',
#   'wesiyek',
#   'wadapu',
#   'toge',
#   'ammage',
#   'to',
#   'wadapu',
#   'tenatath',
#   'henagahannaona'],
#  ['Kanthawakata',
#   'hirihara',
#   'kireema',
#   'waradei',
#   'habai',
#   'me',
#   'wage',
#   'kotiyekuge',
#   'geniyekuta',
#   'banna',
#   'newei',
#   'maruwath',
#   'pau',
#   'na'],
#  ['Ape',
#   'ratata',
#   'mokadda',
#   'me',
#   'wenne',
#   'mun',
#   'alawanna',
#   'hadamu',
#   'mahindata',
#   'rata',
#   'barademu',
#   'okkoma',
#   'akathuwemu',
#   'me',
#   'sinhalayage',
#   'rata'],
#  ['කැරි', 'වේසි', 'හෙනගහපිය'],
#  ['Thambiyelta', 'kiyala', 'hukaganna', 'kiyahan', 'keri', 'wesita'],
#  ['මේ', 'වගේ', 'ගැනු', 'මේ', 'රටේන්', 'එලවන්න', 'ඔන', 'නොදකින්', 'ශාපවේවා'],
#  ['Okege', 'sathuta', 'As', 'panapitama', 'padesan', 'denna', 'one'],
#  ['අපේ', 'අමන', 'පාලකයොන්ගේ', 'වැරදි'],
#  ['ගොන්', 'වේසී', 'මිනිහා', 'ගිය', 'තැනටම', 'යන්න', 'දගලනවා', 'වගේ'],
#  ['පල',
#   'වේසියෙ',
#   'යන්න',
#   'මේ',
#   'ලෝකෙන්ම',
#   'තොලොන්චි',
#   'වෙලා',
#   'හැප්පිය',
#   'වාහනේකට',
#   'මැරෙන්නම',
#   'බැල්ලිව'],
#  ['මුස්ලිම්',
#   'රටක',
#   'ආගමික',
#   'නායකයකු',
#   'මෙ',
#   'දෙ',
#   'කලානම්',
#   'රාජ්\u200dය',
#   'ගෙෘරව',
#   'ජනතාවට',
#   'දෙවියෝ'],
#  ['හෙන', 'හත', 'ගහපන්'],
#  ['මේ',
#   'කල',
#   'දේට',
#   'තෝනමි',
#   'විඳවලා',
#   'මැරෙන්න',
#   'ඕන',
#   'තොට',
#   'හෙන',
#   'හතම',
#   'වැදියන්'],
#  ['Patta',
#   'wesi',
#   'tota',
#   'henama',
#   'gahapan',
#   'totai',
#   'toge',
#   'anduwatai',
#   'lagadima',
#   'redi',
#   'netuwa',
#   'pare',
#   'duwanna',
#   'wei',
#   'edata',
#   'toge',
#   'hinsanayata',
#   'api',
#   'gal',
#   'gahanawa'],
#  ['හෙන', 'ගහනවා', 'කැරි', 'වෙසිට'],
#  ['අපරාද', 'කාරයෝ', 'රට', 'පාවලා', 'දෙන', 'උන්', 'රකින', 'සක්කිලි', 'ආන්ඩුව'],
#  ['සාප', 'වේවා', 'තිට', 'හෙන', 'හතම', 'වැදියන්'],
#  ['Tho', 'sathutu', 'unaawagema', 'duk', 'wendath', 'wenawa'],
#  ['hotai',
#   'thindu',
#   'karapu',
#   'ekatai',
#   'me',
#   'rajayatai',
#   'henama',
#   'gahapiya'],
#  ['Kotinge',
#   'ata',
#   'deka',
#   'suppu',
#   'karapan',
#   'gihin',
#   'cari',
#   'wesi',
#   'Me',
#   'wesitanm',
#   'hodak',
#   'sidda',
#   'wenne',
#   'nehe',
#   'Hena',
#   'gahapan'],
#  ['පට්ට', 'බැල්ලි', 'බල්ලො', 'දම්මලා', 'හුකන්න', 'ඉනී'],
#  ['Huththa', 'lokuda', 'danne', 'neeee'],
#  ['Usawiyeth', 'desapalana', 'theendu'],
#  ['Balu', 'huttita', 'hana', 'hatama', 'gahapiya'],
#  ['Hitan',
#   'magenguti',
#   'kanna',
#   'nethiwa',
#   'oya',
#   'unansewa',
#   'nidahas',
#   'karapan',
#   'hodaekaawage'],
#  ['ජම්පරේ', 'ගස්සන්ඩ', 'ඕනී', 'ආයේ', 'චීවරේ', 'නොදාන්නම'],
#  ['Karumeta', 'gahala', 'akalata', 'haduna', 'wesiyo'],
#  ['LTTE',
#   'එකට',
#   'කඩේ',
#   'යන',
#   'NGO',
#   'සල්ලි',
#   'වලට',
#   'රට',
#   'පාවා',
#   'දෙන',
#   'හැත්ත'],
#  ['මෙි', 'ගැනිට', 'සාප', 'වෙිවා'],
#  ['hora', 'ganayonta', 'kade', 'yana', 'gonnu', 'inna', 'ratak', 'meka'],
#  ['Me', 'genige', 'geta', 'gal', 'gahanna', 'lasthiweyalla'],
#  ['පනපිටින්', 'අපායෙ', 'පල', 'කොටිදෙන'],
#  ['Puka',
#   'diyan',
#   'noel',
#   'mona',
#   'paiye',
#   'sinduda',
#   'hutto',
#   'me',
#   'සමාජෙට',
#   'හොද',
#   'දෙයක්',
#   'කරපන්'],
#  ['Mun', 'Rata', 'winasa', 'karalla', 'ewarayi'],
#  ['Ponna', 'wasi'],
#  ['Aknali', 'goda', 'maruna', 'aka', 'gana', 'api', 'sathutu', 'wenawa'],
#  ['කොටි', 'දෙනක්'],
#  ['Wesa',
#   'genita',
#   'hena',
#   'gahapiya',
#   'rate',
#   'nayakaya',
#   'ponnayek',
#   'unama',
#   'ohoma',
#   'tamai'],
#  ['හම්පඩ', 'පඩංගු', 'දෙමළු', 'වේසාවි'],
#  ['ako',
#   'ratama',
#   'ltte',
#   'eke',
#   'salli',
#   'walata',
#   'wikka',
#   'munta',
#   'ira',
#   'hada',
#   'payanawaneeee'],
#  ['Nadukarayage',
#   'mulu',
#   'engema',
#   'gedidapn',
#   'okage',
#   'paaulama',
#   'hedigeviyan'],
#  ['Koti', 'gani', 'shapa', 'wewa', 'ubata'],
#  ['එහෙමද', 'ආස', 'කැරී', 'wecii'],
#  ['Makabawilama', 'pala', 'paduru', 'wesi'],
#  ['බලු',
#   'වෙසි',
#   'තොගෙ',
#   'අම්මා',
#   'බල්ලොත්',
#   'ලැගලා',
#   'තොව',
#   'ජාතක',
#   'කරලා',
#   'තියෙන්නේ'],
#  ['Meeka', 'pada', 'show', 'ekak'],
#  ['Thota', 'hena', 'gahapan', 'thoge', 'balu', 'patawuntath', 'Balu', 'weesi'],
#  ['Henama', 'gahapiya', 'wesa', 'ballita'],
#  ['Tope', 'anduwa', 'tiyana', 'an', 'hodai'],
#  ['Mekita', 'dan', 'miniha', 'nathuwa', 'aduwak', 'wena', 'ekak', 'ne'],
#  ['SATHUTU', 'NAM', 'PUKA', 'DEEPAN', 'WESA', 'BADUWA'],
#  ['Me', 'genige', 'jathae', 'kalwam', 'ekak'],
#  ['Yadamin',
#   'benda',
#   'vilangu',
#   'la',
#   'Mage',
#   'putha',
#   'regena',
#   'yanna',
#   'Idikatu',
#   'weni',
#   'engili',
#   'thala',
#   'Dethis',
#   'wadaya',
#   'pamunuwanna',
#   'Aluth',
#   'lowak',
#   'gena',
#   'sithima',
#   'Danduwam',
#   'dena',
#   'warada',
#   'nam',
#   'Kumata',
#   'erata',
#   'adhikaranaya',
#   'Neethiya',
#   'saha',
#   'vinisuran'],
#  ['Bona',
#   'unta',
#   'bus',
#   'eke',
#   'megala',
#   'gihin',
#   'bol',
#   'gahanna',
#   'thamai',
#   'tiyenne'],
#  ['තෙවරප්පෙරැමට', 'අහුඋනොත්', 'ඔක්කොම', 'ගුටි', 'කනවා', 'යකෝ'],
#  ['ලංකාවෙි',
#   'මිනිස්සුන්ට',
#   'මොනතරමි',
#   'හොද',
#   'කලත්',
#   'වැඩක්',
#   'නැ',
#   'ඒ',
#   'අයගේ',
#   'ආකල්ප',
#   'වෙනස්කරන්න',
#   'බැ',
#   'මෙි',
#   'කමෙන්ටි',
#   'වලින්',
#   'ඒදේ',
#   'වැටහෙනවා',
#   'මහා',
#   'මෝඩ',
#   'මිනිස්සු',
#   'බහුතරයක්'],
#  ['Ponnayo',
#   'danne',
#   'kellek',
#   'aduwa',
#   'gaman',
#   'laga',
#   'inna',
#   'kollekta',
#   'Allan',
#   'gahanna',
#   'witharai'],
#  ['Ape', 'harak', 'samjeta', 'eka', 'honda', 'adrshyak'],
#  ['පොලීසිය', 'ගොං', 'ආතල්', 'දෙනවා', 'පූජිතයෝ', 'උබට', 'තියෙන', 'වැඩ', 'මේවද'],
#  ['Tpita', 'pisuda', 'yako', 'man', 'htuwe', 'atta', 'kiyala', 'aiyo'],
#  ['Kimbak', 'eduwoth', 'ape', 'untath', 'amma', 'thaththawath', 'penne', 'n'],
#  ['Lisan',
#   'nathawa',
#   'yanna',
#   'puluwan',
#   'yako',
#   'api',
#   'dannawa',
#   'oka',
#   'veede',
#   'nattiyak',
#   'kiyala'],
#  ['මේ',
#   'යුද්ධයේ',
#   'සැබෑම',
#   'අවසානය',
#   'වෙන්න',
#   'ඕන',
#   'මේකයි',
#   'දැන්වත්',
#   'කඩප්පුලි',
#   'විග්නේෂ්වරන්',
#   'සිවාජිලිංගම්',
#   'සම්බන්ධන්',
#   'සුමන්තිරන්',
#   'වැනි',
#   'කාළක්නි',
#   'දේශපාලකයින්',
#   'දේශපාලනයෙන්',
#   'අතුගා',
#   'දැමිය',
#   'යුතුයි'],
#  ['මෙතන',
#   'දී',
#   'අර',
#   'පාර්ලිමේන්තුවේ',
#   'ඉන්න',
#   'කක්කූසි',
#   'කටා',
#   'නොහොත්',
#   'දත්',
#   'දොස්තර',
#   'කාල',
#   'කන්නි',
#   'රාජිතයා',
#   'මතක්',
#   'වෙනකොට',
#   'මගේ',
#   'මාළු',
#   'නටනවා'],
#  ['කෝ',
#   'අපේ',
#   'නානසාර',
#   'ස්වාමීන්',
#   'වහන්සේ',
#   'ඒ',
#   'හිමියනට',
#   'පුළුවන්',
#   'මේ',
#   'වගේ',
#   'සෙබළුන්ගෙන්',
#   'ආදර්ශ',
#   'එහෙම',
#   'ලබාගන්න',
#   'බුදුන්ගෙන්',
#   'ආදර්ශ',
#   'ලබාගත්තේ',
#   'නැතිකොට',
#   'ඉතින්',
#   'මොකෙක්ගෙන්වත්',
#   'ආදර්ශ',
#   'ගනීද'],
#  ['Samanya',
#   'minasata',
#   'danena',
#   'de',
#   'me',
#   'kalakanni',
#   'desapalakayanta',
#   'penne',
#   'nathi',
#   'eka',
#   'thama',
#   'karume'],
#  ['ලංකාවේ', 'තම', 'හරක්', 'ඉන්න', 'නිසා', 'ඕවා', 'හොඳට', 'පිළිගන්නවා'],
#  ['අපේ',
#   'හරකුන්ට',
#   'ගහක්',
#   'හිටවන්න',
#   'ගියත්',
#   'කුඩයක්',
#   'අල්ලන්න',
#   'ඔනේ',
#   'බහින්න',
#   'වලකුත්',
#   'හාරලා',
#   'දෙන්න',
#   'ඔනේ',
#   'අපි',
#   'හරි',
#   'පවු',
#   'නේ'],
#  ['දැන්',
#   'ටික',
#   'කාලෙකට',
#   'කලින්',
#   'පාලත්',
#   'සභා',
#   'මන්ත්\u200dරී',
#   'ජුන්ඩේක්',
#   'පොලිස්',
#   'මහතෙක්',
#   'හැදුලුම්',
#   'පත',
#   'ඉල්ලූවා',
#   'කියලා',
#   'දාපු',
#   'ගෙම්බර්',
#   'මතක්',
#   'වුනා'],
#  ['Shampoo',
#   'එකක්',
#   'promote',
#   'කරන්න',
#   'දාපු',
#   'ලස්සන',
#   'මුට්ටියක්',
#   'කියලයි',
#   'මටනම්',
#   'හිතෙන්නෙ',
#   'බලපං',
#   'නැද්ද',
#   'කියලා',
#   'තා',
#   'ටික',
#   'දවසකින්'],
#  ['අම්මෝ', 'ඒක', 'හොදයි', 'ඒත්', 'දාගෙන', 'යන්නේ', 'පාරෙ', 'නේද'],
#  ['Dakune', 'shampoo', 'nadda'],
#  ['මූ', 'ජයරත්නගෙ', 'නෑදෑයෙක්ද', 'කොහෙද'],
#  ['වැස්සොත්', 'ශොට්', 'වෙල', 'මැරෙන්නෙ'],
#  ['muladi',
#   'hinawey',
#   'digatama',
#   'karoth',
#   'devole',
#   'karala',
#   'hoda',
#   'idea',
#   'ekak'],
#  ['Hadannanam',
#   'puluvan',
#   'eth',
#   'oka',
#   'reddak',
#   'adan',
#   'dagena',
#   'yanne',
#   'kohomai',
#   'ape',
#   'handuruvane'],
#  ['Police', 'yen', 'navatthana', 'ekkak', 'na'],
#  ['Mathakane',
#   'kalayak',
#   'ape',
#   'un',
#   'fite',
#   'fan',
#   'ellan',
#   'gihin',
#   'rexona',
#   'market',
#   'kala'],
#  ['Pahadili', 'madi', 'visthara', 'karapu', 'hati'],
#  ['Me', 'mokkakda', 'bn', 'eka', 'dapuwahama', 'mahasona', 'wagene'],
#  ['ඇඩ්',
#   'නම්',
#   'ඇඩ්',
#   'ලංකාව',
#   'දියුනු',
#   'නෑ',
#   'කියන',
#   'වුන්',
#   'ට',
#   'කනට',
#   'ගහලා',
#   'මෙක',
#   'පෙන්නපල්ලා'],
#  ['ela', 'ela', 'thawa', 'thawath', 'mede', 'wadidinu', 'karanna'],
#  ['Game', 'gahapan', 'aiya', 'api', 'gannaw'],
#  ['මේක', 'දියුණුවක්', 'කියලා', 'හිතනවා', 'නම්', 'උබට', 'වැරදිලා', 'සහෝදරයා'],
#  ['ගෙදරට', 'වෙලා', 'පාඩම්', 'කරපල්ලකෝ', 'පැය', 'ගනන්', 'පෝලීමේ', 'ඉන්නේ'],
#  ['Lankawen',
#   'desapalakayo',
#   'tikak',
#   'yawala',
#   'balamu',
#   'poster',
#   'gahana',
#   'widihata',
#   'thama',
#   'ita',
#   'passe'],
#  ['මෙච්චර',
#   'අමාරුවෙන්',
#   'පුටුවක්',
#   'අල්ලගන්න',
#   'ඕනිද',
#   'ගහක්',
#   'යට',
#   'වාඩිවෙලා',
#   'පාඩම්',
#   'කරන්න',
#   'පුළුවන්'],
#  ['Comments',
#   'බලන්න',
#   'ආපු',
#   'අය',
#   'මෙතනින්',
#   'පොඩි',
#   'Like',
#   'එකක්',
#   'ඕනේ',
#   'Bro'],
#  ['විඩීයෝ', 'එක', 'අප්සට්', 'පේන්නේ', 'නෑ', 'හරියට'],
#  ['paadam',
#   'karanawa',
#   'kese',
#   'wethath',
#   'putuwak',
#   'nan',
#   'aniwa',
#   'allagannawa',
#   'mama',
#   'puluwannan',
#   'putu',
#   'tikak',
#   'allala',
#   'business',
#   'line',
#   'ekakuth',
#   'gahagannawa',
#   'shape',
#   'eke'],
#  ['යක්කුන්ට', 'ලජ්ජා', 'කරන්න', 'එපා', 'මුන්ට', 'සමානකරලා'],
#  ['ඒකෙන්',
#   'මේකෙන්',
#   'උනේ',
#   'ගීතට',
#   'නමටහරි',
#   'හිටිය',
#   'මිනිහ',
#   'නැතිවුන',
#   'එක',
#   'විතරයි'],
#  ['මුන්',
#   'ගෙන්',
#   'ඇති',
#   'වැඩක්',
#   'නැ',
#   'තමයි',
#   'ඒ',
#   'උනාට',
#   'ඉඩල',
#   'හිටලා',
#   'වැදගත්',
#   'දෙවලුත්',
#   'නොකියන',
#   'වම',
#   'නෙවෙයි'],
#  ['E', 'karpu', 'kathwa', 'nm', 'wedagth', 'm', 'kiuwath', 'oyala'],
#  ['Oshadhi', 'adui', 'Hama', 'gahapu', 'issek', 'wage'],
#  ['බයිසන්ලට', 'ඉතින්', 'සුරංගනාවියන්', 'තමයි'],
#  ['මීට', 'කලින්', 'දැකලැ', 'නැ'],
#  ['මටනම්', 'හිතෙන්නේ', 'මේ', 'මිනිහා', 'තමයි', 'ඇත්ත', 'ඩයල්', 'එක', 'කියලා'],
#  ['දුප්පත්',
#   'මිනිසුන්',
#   'සියගනනකට',
#   'පැල්පතක්',
#   'තනාදෙන්න',
#   'තීබු',
#   'අපුරුව',
#   'නේද'],
#  ['Oka', 'light', 'bala', 'bala', 'cheeneta', 'naya', 'gewamu'],
#  ['පිහි',
#   'ඇනුම්',
#   'ගුටි',
#   'කෙලි',
#   'ඇතුලු',
#   'විනෝද',
#   'ක්\u200dරීඩා',
#   'රැසකුත්',
#   'ඇති',
#   'නෙහ්'],
#  ['කෑමකඩත්',
#   'තියෙනවද',
#   'tomorrowland',
#   'වගේද',
#   'festival',
#   'එක',
#   'තව',
#   'hardwell',
#   'mashmellow',
#   'එනවද',
#   'edm',
#   'කරන්න'],
#  ['මෙක',
#   'ගෑන',
#   'දන්න',
#   'එකෙක්',
#   'කියපන්',
#   'හරියටම',
#   'දන්න',
#   'එකෙක්',
#   'කන්ටැක්',
#   'කර',
#   'ගන්න',
#   'ඔනී'],
#  ['ඊළඟට',
#   'මේවල',
#   'සාමාන්\u200dය',
#   'මිනිස්සුන්ට',
#   'යන්න',
#   'බැරි',
#   'වෙන',
#   'විදිහට',
#   'ගණන්',
#   'වැඩි',
#   'විශේෂ',
#   'ටිකට්',
#   'එකක්',
#   'නිකුත්',
#   'කරන්න',
#   'ඕනේ'],
#  ['දවස',
#   'අන්තිමේ',
#   'යාඩ්',
#   'එකට',
#   'ගෙනල්ලා',
#   'නැවැත්තුවාම',
#   'එතන',
#   'ආරක්ෂාවත්',
#   'වැඩි',
#   'කරන්න',
#   'වෙනවා',
#   'රෑට',
#   'ෆෑන්',
#   'පන්නන',
#   'අයත්',
#   'ඉන්න',
#   'පුළුවන්',
#   'නේ'],
#  ['තව',
#   'මේවා',
#   'ඇතුල',
#   'සතියකට',
#   'දෙසැරයක්',
#   'වත්',
#   'පිරිසිදු',
#   'කරන්න',
#   'ඕනේ',
#   'විශේෂයෙන්ම',
#   'ටොයිලට්',
#   'තව',
#   'පිටත',
#   'මසෙට',
#   'දෙසැරයක්',
#   'වත්',
#   'ක්ලීන්',
#   'කරන්න',
#   'ඕනේ',
#   'එහෙම',
#   'කලොත්',
#   'ඔන්න',
#   'අවුරුදු',
#   '5ක්',
#   'වත්',
#   'ලස්සනට',
#   'තියාගතහැකි'],
#  ['ලංකාවට',
#   'ඕව',
#   'හරියන්නෙ',
#   'නෑ',
#   'බන්',
#   'අපි',
#   'සුපෝකබෝගී',
#   'දේවල්',
#   'විදින්න',
#   'කලින්',
#   'අපේ',
#   'මනස',
#   'හුරුකරගන්න',
#   'ඕන',
#   'අනිත්',
#   'උන්ටත්',
#   'ඒක',
#   'විදින්න',
#   'ඉතුරුකරල',
#   'යන්න',
#   'අපි',
#   'සිංහලනෙ',
#   'සිංහයන්ගෙන්ලුනෙ',
#   'පැවතගෙන',
#   'එන්නෙ',
#   'අපිට',
#   'බෑ',
#   'ප්\u200dරෙන්',
#   'අපිට',
#   'වනන්තර',
#   'වගේ',
#   'ඒව',
#   'ගෙනත්',
#   'දෙන්න',
#   'ඒවනම්',
#   'හරි',
#   'යනව',
#   'මම',
#   'දැකල',
#   'තියනවනෙ',
#   'අලුතින්ම',
#   'ගෙනාපු',
#   'කෝච්චි',
#   'වලට',
#   'අපේ',
#   'ඔපිස්',
#   'යන',
#   'සෙට්',
#   'ට්\u200dරිප්',
#   'යන',
#   'සෙට්',
#   'සිගිති',
#   'පාතාල',
#   'කාරයො',
#   'කරන',
#   'වැඩ',
#   'බොකක්',
#   'ලෝඩ්වෙලා',
#   'කෝච්චියෙ',
#   'ටොයිලට්',
#   'එකට',
#   'ගියොත්',
#   'පුදුම',
#   'හාස්කමක්',
#   'වෙන්නෙ',
#   'බොක',
#   'නැතිවෙනව',
#   'එක්කෝ',
#   'බොක',
#   'කටින්',
#   'යන්න',
#   'එනව'],
#  ['ඒකටනම්',
#   'දුම්\u200dරිය',
#   'දෙපාර්තුමේන්තුවත්',
#   'වගකියන්න',
#   'ඕන',
#   'කෝච්චිය',
#   'රෑ',
#   'අවසාන',
#   'ට්\u200dරිප්',
#   'එක',
#   'ගිහින්',
#   'ආවහම',
#   'කිසිම',
#   'නඩත්තුවක්',
#   'නැතුව',
#   'ආපහු',
#   'පහුවදා',
#   'උදේට',
#   'එන්ජිම',
#   'අනිත්',
#   'පැත්තට',
#   'අමුනල',
#   'ඇදගෙන',
#   'එනව',
#   'වගේ',
#   'මටනම්',
#   'පේන්නෙ',
#   'ඒකට',
#   'වරදක්',
#   'කියන්නත්',
#   'බෑ',
#   'බං',
#   'හරියට',
#   'maintenance',
#   'කරන්න',
#   'හරියට',
#   'සේවකයො',
#   'ගන්න',
#   'ඕන',
#   'උන්ට',
#   'පඩියක්',
#   'ගෙවන්න',
#   'ඕන',
#   'ඒව',
#   'කොරන්න',
#   'කොහෙඩ',
#   'රටට',
#   'සල්ලි',
#   'රටින්',
#   'ගන්න',
#   'ණය',
#   'අදාර',
#   'ඔක්කොම',
#   'ගිහිනුත්',
#   'මදි',
#   'පාර්ලිමේන්තුව',
#   'නඩත්තු',
#   'කරන්න',
#   'මට',
#   'තේරෙන්නෙ',
#   'නෑ',
#   'කතා',
#   'කරල',
#   'වැඩක්',
#   'නෑ',
#   'මේ',
#   'කෝච්චියෙ',
#   'යන්න',
#   'ටයි',
#   'කරන්න',
#   'එපා',
#   'ප්\u200dරෙන්',
#   'තෙප්පමක්',
#   'හදාගෙන',
#   'හරි',
#   'කමක්',
#   'නෑ',
#   'ජීවත්',
#   'වෙන්න',
#   'පුලුවන්',
#   'රටකට',
#   'පලයල්ල'],
#  ['මේ',
#   'comment',
#   'වල',
#   'තියෙන',
#   'අදහස්',
#   'Facebook',
#   'එක',
#   'ඇතුලේම',
#   'පල්',
#   'නොකර',
#   'ස්ටේෂන්',
#   'වලයි',
#   'දුම්රිය',
#   'මැදිරි',
#   'ඇතුලෙයි',
#   'මිනිස්සුන්ට',
#   'දැනෙන',
#   'විදිහට',
#   'Display',
#   'කළා',
#   'නම්',
#   'භාෂා',
#   '3න්ම',
#   'පින්තූරත්',
#   'එක්ක',
#   'පොඩි',
#   'වෙනසක්',
#   'හරි',
#   'දකින්න',
#   'පුළුවන්'],
#  ['ඔය',
#   'පොටෝ',
#   'ටිකම',
#   'තව',
#   'මාසයකින්',
#   'අරන්',
#   'බලන්න',
#   'සීට්',
#   'ටිකයි',
#   'එන්ජිමයි',
#   'විතරයි',
#   'ඉතුරු',
#   'අනිත්',
#   'ඔක්කොම',
#   'ගලවනවා',
#   'සත්තයි',
#   'අපේ',
#   'එඋන්'],
#  ['සාමාන්\u200dය',
#   'මිනිස්සුන්ගෙන්',
#   'පරිස්සම්',
#   'කරගන්න',
#   'පුලුවන්',
#   'ඒත්',
#   'කෝච්චි',
#   'වල',
#   'යන',
#   'ඔෆිස්',
#   'සෙට්',
#   'එක',
#   'කියලා',
#   'අමුතුම',
#   'සත්තු',
#   'ජාතියක්',
#   'උන්',
#   'කන',
#   'දේ',
#   'එකෙම',
#   'දානවා',
#   'හොර',
#   'ගෑනු',
#   'එක්ක',
#   'එකතු',
#   'වෙලා',
#   'සීට්',
#   'හුරනවා',
#   'ගොඩක්ම',
#   'කෝච්චි',
#   'විනස',
#   'කරන්නේ',
#   'ඒ',
#   'අහිගුන්ටකයෝ'],
#  ['විනයක්',
#   'නැති',
#   'පිරහෙමින්',
#   'තිබෙන',
#   'ජාතිය',
#   'බදු',
#   'මුදල්',
#   'වලින්',
#   'ගන්නා',
#   'මේවා',
#   'කොපමන',
#   'කල්',
#   'රැකගනීවිද',
#   'මන්දා',
#   'මිනිසුනේ',
#   'පොදු',
#   'දේපල',
#   'රැකගනිව්',
#   'බලි',
#   'කුරුටු',
#   'ගා',
#   'අපවිත්\u200dර',
#   'නොකරව්'],
#  ['ෂීට්',
#   'කඩලා',
#   'ජරා',
#   'කරන',
#   'එකෙක්',
#   'දැක්කොත්',
#   'පොන්නයෝ',
#   'වගේ',
#   'බලන්',
#   'ඉන්නැතුව',
#   'අත',
#   'පුරෝල',
#   'කන',
#   'පැලෙන්න',
#   'ගහපන්',
#   'අනිත්',
#   'උන්ටත්',
#   'පෙන්න'],
#  ['මගිජනතාව',
#   'වගේම',
#   'දුමිරිය',
#   'දෙපාර්තමේන්තු',
#   'සේවකයන්',
#   'තුත්',
#   'මෙය',
#   'රැකගන්න',
#   'කටයුතු',
#   'කලයුතුයි',
#   'මොකද',
#   'ගමන්',
#   'වාරයක්',
#   'අවසන',
#   'මෙම',
#   'දුමිරිය',
#   'මැදිරි',
#   'ඉතා',
#   'හොදින්',
#   'පිරිසිදු',
#   'කර',
#   'අඩුපාඩු',
#   'සැකසිය',
#   'යුතුයිි',
#   'දැන්',
#   'බලන්න',
#   'රැහුනු',
#   'කුමාරි',
#   'ගාලුකුමාරි',
#   'ෆැන්',
#   'වැඩ',
#   'නැ',
#   'මකුනුදැල්',
#   'බැදිල',
#   'හුඩි',
#   'එක',
#   'දුවිලිවලින්',
#   'පිරිල',
#   'මෙව',
#   'රැකගන්න',
#   'දෙගොල්ල',
#   'ම',
#   'දායක',
#   'වියයුතුමයි'],
#  ['Dubai',
#   'wala',
#   'thiyana',
#   'awaga',
#   'kama',
#   'kana',
#   'ak',
#   'thahanam',
#   'aduma',
#   'tharama',
#   'chuingam',
#   'wath',
#   'kanda',
#   'ba',
#   'aka',
#   'hama',
#   'thama',
#   'camara',
#   'thiyanawa',
#   'lagatama',
#   'avith',
#   'dada',
#   'gahanakn',
#   'danna',
#   'na',
#   'apa',
#   'minissu',
#   'wanas',
#   'karanda',
#   'amarui',
#   'akata',
#   'hodama',
#   'da',
#   'hariyata',
#   'nithi',
#   'hadanda',
#   'ona',
#   'owata',
#   'athokota',
#   'nikamma',
#   'purudu',
#   'wanawa'],
#  ['අපේ',
#   'එවුන්ට',
#   'ලියන්න',
#   'සිට්',
#   'ඉරන්න',
#   'කඩල',
#   'කන්න',
#   'බඩ',
#   'ඉරුගු',
#   'කන්න',
#   'එ',
#   'කාපු',
#   'එවා',
#   'එතන',
#   'ම',
#   'දලා',
#   'යන්න',
#   'ට්\u200dර්ප්',
#   'ගිහිල්ලා',
#   'බොක',
#   'කරලා',
#   'එන්න',
#   'ආපු',
#   'අලුත්',
#   'භාන්ඩේ',
#   'දැන්',
#   'කියන්න',
#   'එපා',
#   'අපො',
#   'ඉංදියන්',
#   'ජාරාව',
#   'කියලා',
#   'ඉස්සල්ලා',
#   'පුරුදු',
#   'වේයල්ලා',
#   'කඩල',
#   'ගොටු',
#   'කුනු',
#   'මල',
#   'ජාරාව',
#   'මානසික',
#   'ලෙඩ්ඩු',
#   'වගේ',
#   'ලියන',
#   'එවා',
#   'නවත්තන්න',
#   'පස්සේ',
#   'හොයපල්ලා',
#   'ඇද',
#   'කුද'],
#  ['ඔය',
#   'කොච්චිය',
#   'අගුලාන',
#   'කොරලවෙල්ල',
#   'මොරටුව',
#   'එ',
#   'දුම්රිය',
#   'ස්තාන',
#   'වල',
#   'නවත්තන්න',
#   'එපා',
#   'ඔය',
#   'කොච්චියේ',
#   'තියන',
#   'සෙප',
#   'පහසුකම්',
#   'ටික',
#   'මාසයක්',
#   'යනකොට',
#   'එ',
#   'පෙත්තේ',
#   'ගෙවල්',
#   'වල',
#   'තියෙයි'],
#  ['යන',
#   'එවුන්ටයි',
#   'මේ',
#   'කියන්නේ',
#   'මොන',
#   'තරම්',
#   'options',
#   'අවත්',
#   'කමක්',
#   'නෑ',
#   'එවගේ',
#   'ඒ',
#   'විදිහිට',
#   'ගිහින්',
#   'එක',
#   'පරිස්සමෙන්',
#   'පාවිච්චි',
#   'කරන්න',
#   'අපේ',
#   'දෙවල්',
#   'රැක',
#   'ගන්න'],
#  ['යකෝ',
#   'හැම',
#   'එකාම',
#   'කියන්නෙ',
#   'සතියෙන්',
#   'කයි',
#   'කියලා',
#   'බලන්',
#   'යද්දි',
#   'මෙව්වා',
#   'කන්ඩ',
#   'එකෙක්',
#   'නෑනෙ'],
#  ['Usb',
#   'port',
#   'එකෙ',
#   'චුයින්ගම්',
#   'අලවාවි',
#   'වඩේ',
#   'කාල',
#   'කර්ටන්',
#   'එකේ',
#   'අත',
#   'පිහිදලා',
#   'කම්මැලිකමට',
#   'sheet',
#   'එක',
#   'කුශන්',
#   'කෑලි',
#   'කඩලා',
#   'tv',
#   'එක',
#   'කැඩුන',
#   'කියල',
#   'පොඩි',
#   'අව්ලක්',
#   'හදල',
#   'රෙපයාර්',
#   'කරන',
#   'එඋන්',
#   'ගෙදර',
#   'ගෙනියලා',
#   'fan',
#   'ගලවල',
#   'ටිකට්',
#   'කවුන්ටරෙට',
#   'සෙට්',
#   'කරලා',
#   'ටොයිලට්',
#   'ටික',
#   'වටේට',
#   'ජරා',
#   'කරලා',
#   'අර',
#   'ස්ටෙසමේ',
#   'නවත්තනකොටම',
#   'සුද්ද',
#   'කරන්න',
#   'නගින',
#   'සෙට්',
#   'එකක්',
#   'ඉන්නොනෙ',
#   'බූමිතෙල්',
#   'වැදිච්ච',
#   'ගැරඩි',
#   'වගේ',
#   'cleaners',
#   'ලා',
#   'උන්',
#   'තමයි',
#   'ඕකෙ',
#   'තීන',
#   'කුනු',
#   'පේන',
#   'ටික',
#   'අතුගාල',
#   'අනිත්ව',
#   'ශීටඅස්සට',
#   'තල්ලු',
#   'කරල',
#   'ලොකුම',
#   'සේවය',
#   'කරන්නෙ'],
#  ['ඕක',
#   'සතියයි',
#   'ඉවරයි',
#   'ගාගා',
#   'කමෙන්ට්',
#   'දාන්නේ',
#   'පිටරට',
#   'උන්',
#   'වෙන්නැති',
#   'දැන්'],
#  ['අපේ',
#   'මහින්ද',
#   'මහත්තයා',
#   'ඇවිත්',
#   'මාසයයි',
#   'කොහොමද',
#   'එයාගෙ',
#   'වැඩ',
#   'ටොයියොන්ට',
#   'ජෙප්පොන්ට',
#   'පේන්න',
#   'ලයික්',
#   'එකක්',
#   'දාන්න'],
#  ['මට',
#   'තියෙන',
#   'ප්\u200dරශ්නේ',
#   'අර',
#   'ටීවි',
#   'එක',
#   'අඩු',
#   'වැඩි',
#   'කරන',
#   'සුවිච්',
#   'එකෙන්',
#   'අපේ',
#   'උන්',
#   'ආතල්',
#   'ගනීද',
#   'කියලා'],
#  ['Mewa',
#   'thiyana',
#   'widiyata',
#   'keedawasak',
#   'thiyaganna',
#   'puluwan',
#   'weida',
#   'ape',
#   'moda',
#   'noogathun',
#   'ekka'],
#  ['Wadenam',
#   'hondai',
#   'eth',
#   'ape',
#   'minisunge',
#   'winayath',
#   'ekka',
#   'mewa',
#   'araksha',
#   'karaganida'],
#  ['අපේ',
#   'රටට',
#   'ඕව',
#   'හරියන්',
#   'නෑ',
#   'මොකද',
#   'මිනිස්සු',
#   'අඩුයි',
#   'දැන්',
#   'ඒ',
#   'වගේම',
#   'සමහරුන්ට',
#   'මොලයක්',
#   'නෑ',
#   'මේක',
#   'නඩත්තු',
#   'වෙන්නෙ',
#   'අපේ',
#   'බදු',
#   'මුදලින්',
#   'කියල',
#   'ඒක',
#   'නිසා',
#   'මේව',
#   'උපරිම',
#   'මාසයයි',
#   'පිලිවෙලට',
#   'තියෙන්නෙ'],
#  ['මාස',
#   'කීයක්',
#   'මේ',
#   'පිලිවෙලට',
#   'තියෙයිද',
#   'දන්නෙ',
#   'නෑ',
#   'ඕක',
#   'ඇතුලේ',
#   'කෑලි',
#   'ටිකත්',
#   'ගලවගෙන',
#   'නොගියොත්',
#   'තමයි',
#   'පුදුම'],
#  ['ඕවා',
#   'සාමාන්\u200dය',
#   'මගී',
#   'ජනතාවට',
#   'යන්න',
#   'ගෙන්නපුව',
#   'නෙවෙයි',
#   'මේවා',
#   'ගෙන්නන',
#   'එවුන්ව',
#   'කාර්\u200dයාල',
#   'දුම්\u200d',
#   'රියක',
#   'ටික',
#   'දවසක්',
#   'යවන්න',
#   'ඕන',
#   'දුම්',
#   'රිය',
#   'ගාස්තු',
#   'නහුතෙට',
#   'වැඩි',
#   'කරලා',
#   'ඒ',
#   'සල්ලිවලින්',
#   'වෙලාවට',
#   'දෙපැත්තට',
#   'පැද්දෙන්නෙ',
#   'නැතුව',
#   'ඉල',
#   'ඇට',
#   'කඩා',
#   'ගන්නෙ',
#   'නැතුව',
#   'යන්න',
#   'පුලුවන්',
#   'විදිහෙ',
#   'දුම්',
#   'රිය',
#   'සේවයක්',
#   'හදපල්ලා'],
#  ['Ape',
#   'ratata',
#   'genna',
#   'ona',
#   'owa',
#   'newe',
#   'hoda',
#   'hadichcha',
#   'silachara',
#   'minissu',
#   'tikak',
#   'dan',
#   'inna',
#   'un',
#   'tikawa',
#   'koheta',
#   'hari',
#   'aduwata',
#   'vikunala',
#   'dala'],
#  ['ඉහල',
#   'සියට',
#   'පහලට',
#   'ආදර්ශයක්',
#   'නොදී',
#   'රටක',
#   'විනයක්',
#   'ඇති',
#   'කල',
#   'නොහැක',
#   'සිංගප්පූරුව',
#   'එයට',
#   'හොදම',
#   'ආදර්ශයයි',
#   'ලංකාවෙ',
#   'ඉහලින්',
#   'පහලට',
#   'දෙන',
#   'යහපත්',
#   'ආදර්ශය',
#   'කුමක්ද'],
#  ['Ehenm',
#   'palaweni',
#   'dawasema',
#   'train',
#   'ride',
#   'ekak',
#   'yanda',
#   'onee',
#   'mokada',
#   'dawas',
#   'deka',
#   'thunak',
#   'giyata',
#   'passe',
#   'owwa',
#   'mukuth',
#   'nee',
#   'ne'],
#  ['Hamadama',
#   'ithin',
#   'ahanna',
#   'wenne',
#   'kohen',
#   'hari',
#   'genapu',
#   'ekak',
#   'gana',
#   'thamai',
#   'Ape',
#   'rate',
#   'nispadanayak',
#   'kiyala',
#   'ahanna',
#   'wena',
#   'ekak',
#   'naha'],
#  ['Indiawen',
#   'genna',
#   'oneda',
#   'oowa',
#   'lankawe',
#   'ennawa',
#   'onnataran',
#   'weddo',
#   'oitawada',
#   'hodata',
#   'haganna',
#   'puluwan',
#   'kutti',
#   'pitin',
#   'ekapara',
#   'gasaganna',
#   'project',
#   'oowa'],
#  ['Owa',
#   'ta',
#   'army',
#   'eken',
#   'dala',
#   'arawage',
#   'pissu',
#   'natana',
#   'unge',
#   'kana',
#   'paluwa',
#   'nam',
#   'nikan',
#   'ma',
#   'hadeyi'],
#  ['Badulla',
#   'Jaffna',
#   'Kandy',
#   'yana',
#   'train',
#   'me',
#   'wage',
#   'Api',
#   'dawasawala',
#   'hondai',
#   'Dan',
#   'kohomada'],
#  ['රැකගනිල්ලා',
#   'ඇහැවගේ',
#   'නැත්නම්',
#   'වවුලෝ',
#   'වගේ',
#   'තමයි',
#   'හැමදාම',
#   'තොපිට',
#   'යන්න',
#   'වෙන්නේ',
#   'වනසන',
#   'එකෙක්',
#   'දැක්කොත්',
#   'හැමෝම',
#   'එකාවගේ',
#   'නැගීහිටපල්ලා',
#   'මට',
#   'අදාල',
#   'නෑනේ',
#   'කියලා',
#   'නොහිතා',
#   'ජනතාව',
#   'හැටියට',
#   'අපි',
#   'අපේ',
#   'වගකීමවත්',
#   'හරියට',
#   'ඉෂ්ඨ',
#   'කරමු'],
#  ['මේ',
#   'දුම්රියේ',
#   'ගමන්වාර',
#   'අවසානයේදී',
#   'දුම්රියේ',
#   'මැදිරි',
#   'අපේ',
#   'ජනතාව',
#   'පාවිච්චි',
#   'කරලා',
#   'තියෙන',
#   'විදිය',
#   'රටටම',
#   'පෙන්වන්න',
#   'ඕනේ',
#   'කියලා',
#   'යෝජනා',
#   'කරනවා'],
#  ['Unp',
#   'ආන්ඩුව',
#   'මොකුත්',
#   'කලේ',
#   'නෑ',
#   'කියන',
#   'එවුන්',
#   'බලා',
#   'ගනිල්ල',
#   'unp',
#   'ආන්ඩුවක්',
#   'පලක්',
#   'නැති',
#   'දේවල්',
#   'වෙනුවෙන',
#   'කවදාවත්',
#   'ලෝකෙට',
#   'රට',
#   'ණයකලේ',
#   'නෑ',
#   'නෙළුම්',
#   'පොකුනු',
#   'නෙළුම්',
#   'පොකුනු',
#   'වෙනුවෙන්',
#   'රට',
#   'ණයකරපු',
#   'සල්ලිවල',
#   'මේ',
#   'වගේ',
#   'දෙයක්',
#   'කලානම්',
#   'කොච්චර',
#   'වටිනවද'],
#  ['සතියයි',
#   'බං',
#   'ඕවා',
#   'ඕවට',
#   'cctv',
#   'camera',
#   'system',
#   'එකක්',
#   'දාන්න',
#   'ඕනෙ'],
#  ['මෙක',
#   'දකිද්දී',
#   'මට',
#   'හිතෙන්නේ',
#   'ඉන්දියාව',
#   'කොච්චර',
#   'ඉස්සරහින්ද',
#   'අපිට',
#   'වඩා'],
#  ['Okko', 'keli', 'galawan', 'yanawa', 'ape', 'un'],
#  ['ඔකෙ',
#   'යන්නෙ',
#   'පරණ',
#   'එව්න්',
#   'ටිකමනෙ',
#   'මාස',
#   'තුනක්',
#   'යද්දී',
#   'කහල',
#   'ගොඩක්',
#   'වගේ',
#   'තියේවි'],
#  ['Oya',
#   'thathwen',
#   'tyenne',
#   'eka',
#   'dwsai',
#   'ape',
#   'minisunt',
#   'kohed',
#   'owge',
#   'wtinakamak'],
#  ['ඉන්දීය',
#   'දුම්රියන්',
#   'එන්න',
#   'එන්නම',
#   'අසාර්තකයි',
#   'ඇයි',
#   'ඒවම',
#   'ගෙන්වන්නෙ',
#   'මේකෙනුත්',
#   'කොමිස්',
#   'කුට්ටි',
#   'එන',
#   'නිසාද'],
#  ['ලංකාව',
#   'ඉන්දියාවේ',
#   'කොලනියක්',
#   'වෙන',
#   'රටවල',
#   'නැතිද',
#   'කොහොමත්',
#   'ඉන්දියාවේ',
#   'බයික්',
#   'වගේ',
#   'ඇති'],
#  ['ඔකොම',
#   'තිබිලා',
#   'අන්තිමට',
#   'කලින්',
#   'එවගේ',
#   'වගේ',
#   'බ්\u200dරේක්',
#   'අවුලක්',
#   'උනොත්',
#   'තමා',
#   'අවුල'],
#  ['මේ',
#   'ලංකාවටද',
#   'ඕක',
#   'ගේන්නෙ',
#   'පලවෙනි',
#   'දවසෙම',
#   'ඕකේ',
#   'ෆෑන්',
#   'TV',
#   'ටික',
#   'ගලවන්',
#   'යයි'],
#  ['gothrika',
#   'ratakata',
#   'me',
#   'wage',
#   'dewal',
#   'dunnata',
#   'reka',
#   'ganne',
#   'ne',
#   'kiyala',
#   'sure'],
#  ['විදේශ',
#   'රටවල',
#   'මේ',
#   'වගේ',
#   'කෝච්චි',
#   'වල',
#   'ආහාර',
#   'හා',
#   'කෑම',
#   'ගැනීම',
#   'තහනම්',
#   'ඒකයි',
#   'ඒව',
#   'පිරිසිදුවට',
#   'තියෙන්නෙ'],
#  ['Ki', 'dawasak', 'ohoma', 'lassanata', 'thiyaida'],
#  ['Cctv',
#   'gahala',
#   'genna',
#   'nathnm',
#   'dawsai',
#   'dekaii',
#   'okkoma',
#   'kala',
#   'daweee'],
#  ['මේවායේ',
#   'ගමන්',
#   'කරන',
#   'සහ',
#   'පාවිච්චි',
#   'කරන',
#   'විදියත්',
#   'ලංකාවේ',
#   'මිනිස්සුන්ට',
#   'කියල',
#   'දෙන්න',
#   'වෙයි'],
#  ['Ape',
#   'unta',
#   'oke',
#   'yanna',
#   'uganna',
#   'wenawa',
#   'neth',
#   'nam',
#   'kala',
#   'dawi'],
#  ['විශේෂයෙන්',
#   'නිතර',
#   'දුම්රිය',
#   'ගමන්',
#   'කරන',
#   'මගින්',
#   'මේ',
#   'ගැන',
#   'සැලකිලිමත්',
#   'විය',
#   'යුතුයි',
#   'කරුනා',
#   'කරලා',
#   'පරෙස්සම්',
#   'කරන්න'],
#  ['Ape', 'rilawu', 'tika', 'okatath', 'wade', 'deyi'],
#  ['balamu',
#   'mekawath',
#   'hariyata',
#   'thiya',
#   'ganida',
#   'kiyala',
#   'badulle',
#   'train',
#   'eke',
#   'toilat',
#   'eken',
#   'eleyata',
#   'patta',
#   'chu',
#   'gadai'],
#  ['දාපු',
#   'ඔස්තාර්ල',
#   'ටික',
#   'ඕකෙ',
#   'නග්ගල',
#   'යවන්න',
#   'ඕන',
#   'බලන්න',
#   'වැඩ',
#   'ටික'],
#  ['Hoda', 'wagayma', 'wanasana', 'ewungayn', 'bayraganna', 'watina', 'Badu'],
#  ['රත්තරන්',
#   'අපේක්ෂකයා',
#   'කවුද',
#   'කියලා',
#   'දැනගන්න',
#   'දැන්ම',
#   'මිස්',
#   'කෝල්',
#   'එකක්',
#   'දෙන්න'],
#  ['Raththaran',
#   'newei',
#   'diyamanthi',
#   'hari',
#   'kamak',
#   'na',
#   'ape',
#   'gedara',
#   'chandayaka',
#   'watinakama',
#   'laksha',
#   'dekai'],
#  ['me',
#   'mama',
#   'nemei',
#   'ane',
#   'danne',
#   'nadda',
#   'mata',
#   'naya',
#   'gahala',
#   'mama',
#   'malane',
#   'a',
#   'unata',
#   'balannako',
#   'parcy',
#   'aiyata',
#   'kellek',
#   'akka',
#   'sapak',
#   'ganna',
#   'ona',
#   'unama',
#   'mama',
#   'thamai',
#   'set',
#   'karala',
#   'denne',
#   'parcy',
#   'aiya',
#   'katha',
#   'kaloth',
#   'witharai',
#   'mata',
#   'pana',
#   'Anne'],
#  ['මංගල',
#   'මුදු',
#   'මාල',
#   'වළලු',
#   'රන්',
#   'අභරණ',
#   'ලබාගන්න',
#   'විශ්වාසයි',
#   'කල්',
#   'පවතියි',
#   'වගකීමට',
#   'බැඳී',
#   'සිටියි'],
#  ['Mehema',
#   'poster',
#   'gahana',
#   'ekeknam',
#   'raththaran',
#   'ekek',
#   'wenna',
#   'ba'],
#  ['ඇයි', 'බ්\u200dරෝ', 'ස්පොන්සර්', 'ගහලා', 'සල්ලි', 'වැඩිවෙලාද'],
#  ['එනකම්',
#   'මගබලන්',
#   'ඉන්නෙ',
#   'කවුද',
#   'බන්',
#   'මූ',
#   'කිය්ලා',
#   'ලංකාවෙ',
#   'නෙමේද',
#   'දන්නෑ',
#   'හිටියෙ',
#   'මූ'],
#  ['පිරිත',
#   'බුදුන්',
#   'වහන්සේගේ',
#   'දේශනා',
#   'කොට',
#   'ඇත්තේ',
#   'සමුද්\u200dරඝෝෂ',
#   'විරිතට',
#   'අනුකූලවයි',
#   'පිරිතේ',
#   'අක්ෂර',
#   'ලියා',
#   'ඇත්තේ',
#   'ඒ',
#   'අනුවමයි',
#   'පිරිත',
#   'තුළින්',
#   'ඒ',
#   'සෙත්',
#   'ශක්තිය',
#   'ලබාගැනිමට',
#   'ඒ',
#   'ආකාරයෙන්',
#   'ම',
#   'සජ්ජායනය',
#   'කලයුතුයි'],
#  ['මෝඩ',
#   'මිනිස්සු',
#   'ටිකක්',
#   'නම්',
#   'මේක',
#   'අහල',
#   'තෙරුවනේ',
#   'ගුණ',
#   'කෙරෙහි',
#   'සිත',
#   'පහදවා',
#   'ගන්නෙ',
#   'නැතිව',
#   'තාලයයි',
#   'භාෂාවයි',
#   'ගැන',
#   'වාද',
#   'කර',
#   'කර',
#   'ඉන්නවා',
#   'අනේ',
#   'මේ',
#   'මිනිස්සු',
#   'කවදානම්',
#   'මේ',
#   'සංසාරයෙන්',
#   'එතෙර',
#   'වෙන්න',
#   'උත්සාහයක්',
#   'ගනීද'],
#  ['පිස්සො',
#   'පිස්සු',
#   'කතා',
#   'කියයි',
#   'සුනකයි',
#   'සුනක',
#   'කතා',
#   'කියයි',
#   'නරි',
#   'හූ',
#   'කිය',
#   'කිය',
#   'නටයි',
#   'මහමෙව්නා',
#   'වාසි',
#   'පිරිසයට',
#   'ඒ',
#   'සත්ව',
#   'කොට්ඨාසය',
#   'අදාලම',
#   'නැ',
#   'අපිට',
#   'නරි',
#   'නාවන්ඩ',
#   'වෙලාවකුත්',
#   'නැ',
#   'ඔබ',
#   'වහන්සේලා',
#   'කරන',
#   'දේ',
#   'අපිට',
#   'මහ',
#   'මෙරක්',
#   'වගේ',
#   'මේ',
#   'ලොකු',
#   'ස්වාමින්වහන්සේගේ',
#   'යුගයයි',
#   'අපේ',
#   'ලොකු',
#   'ස්වාමින්වහන්සේගෙ',
#   'මාර්ගයේ',
#   'අපි',
#   'යනවා',
#   'මේවැනි',
#   'පින්වත්',
#   'ස්වාමින්වහන්සේලා',
#   'මේ',
#   'මිහිමත',
#   'තව',
#   'තවත්',
#   'පහල',
#   'වේවා'],
#  ['මේ',
#   'වන්දනාවට',
#   'දොස්',
#   'නගන',
#   'සියලු',
#   'දෙනාටයි',
#   'නිකන්',
#   'බොරුවට',
#   'ආර්\u200dය',
#   'උපවාදයට',
#   'ලක්',
#   'වෙන්න',
#   'එපා',
#   'කිරිබත්ගොඩ',
#   'මා',
#   'හිමිගේ',
#   'බන',
#   'පදයක්වත්',
#   'නො',
#   'අසා',
#   'මේ',
#   'විදිහට',
#   'උන්',
#   'වහසේගේ',
#   'පිලිවෙතට',
#   'දොස්',
#   'නගන්න',
#   'එපා',
#   'වැරදි',
#   'ඇති',
#   'කා',
#   'ලගත්',
#   'ඒත්',
#   'කිරිබත්ගොඩ',
#   'හිමියන්ගේ',
#   'සීලයටවත්',
#   'ගුනයටවත්',
#   'අපිට',
#   'ලගටවත්',
#   'යන්න',
#   'බෑ',
#   'උන්',
#   'වහන්සේ',
#   'සිදු',
#   'කරන',
#   'සේවය',
#   'අති',
#   'මහත්',
#   'ස්\u200dරද්දාව',
#   'වැඩෙනවා'],
#  ['හැකි',
#   'සෑම',
#   'විටම',
#   'ත්\u200dරිවිධ',
#   'රත්නයේ',
#   'ගුණ',
#   'සිහිපත්',
#   'කිරීමයි',
#   'වැදගත්',
#   'මේ',
#   'ස්වාමීන්',
#   'වහන්සේලාගේ',
#   'දේශනාවෙන්',
#   'මම',
#   'සුවපත්',
#   'වුනෙමි',
#   'ඒ',
#   'කුසලය',
#   'උන්',
#   'වහන්සේලා',
#   'අනුමෝදන්',
#   'වේවා',
#   'බල්ලො',
#   'බිරුවට',
#   'කදු',
#   'පාත්',
#   'වෙන්නෙ',
#   'නෑනෙ',
#   'බුදු',
#   'සසුන',
#   'බැබලේවා'],
#  ['දහම්පාසලකට',
#   'ගියේ',
#   'නැති',
#   'එකාලාට',
#   'මේ',
#   'බණ',
#   'නම්',
#   'සෝක්',
#   'ඊයේ',
#   'පෙරේදා',
#   'ෂෝ',
#   'එකට',
#   'ධර්මය',
#   'පස්සෙ',
# ...
#   'කරන',
#   'එක',
#   'මිනිස්සුන්ට',
#   'හිතන්න',
#   'හුඟක්ම',
#   'හුඟක්',
#   'දේවල්',
#   'මේ',
#   'තුල',
#   'අන්තර්',
#   'ගතයි',
#   'හොන්ඳ',
#   'පණිවිඩයක්',
#   'මිනිසුන්ගේ',
#   'හිත්',
#   'තුලට'],
#  ['හැමෝම',
#   'එක',
#   'වගේ',
#   'නෑ',
#   'හැම',
#   'ජාතියකම',
#   'හොද',
#   'මිනිස්සු',
#   'ඉන්නවා',
#   'සිංහල',
#   'ජාතීයේ',
#   'තමයි',
#   'හොයන්න',
#   'අමාරූ'],
#  ['Me',
#   'wage',
#   'minisu',
#   'dekkama',
#   'loku',
#   'satutak',
#   'denenawa',
#   'arabi',
#   'kiyanne',
#   'darunu',
#   'minisu',
#   'inne',
#   'ratak',
#   'ath',
#   'meyala',
#   'ehema',
#   'ne'],
#  ['Pin',
#   'athwai',
#   'mahathayo',
#   'ubala',
#   'dan',
#   'pawul',
#   '7kata',
#   'athiwenna',
#   'hambakaragaththane',
#   'oi',
#   'putuwe',
#   'edan',
#   'Sumathipalata',
#   'nam',
#   'lajjawak',
#   'na',
#   'perethaya'],
#  ['කොහේ',
#   'හරි',
#   'කාට',
#   'හෝ',
#   'අවශ්\u200dය',
#   'කෙනෙක්',
#   'හමුවන',
#   'තුරු',
#   'හැකිතාක්',
#   'ශෙයා',
#   'කරන්න',
#   'අපි',
#   'ජීවිතයක්',
#   'බේරාගත',
#   'හැකිය'],
#  ['මෙ',
#   'ලගදි',
#   'ෂෙයා',
#   'කරලා',
#   'තිබ්බා',
#   'පෙඡ්',
#   'එකකින්',
#   'මතක',
#   'නැ',
#   'දැන්'],
#  ['උදව්වක්', 'one'],
#  ['රට',
#   'දැය',
#   'වෙනුවෙන්',
#   'උරදුන්නට',
#   'පක්ශ',
#   'පාට',
#   'බේදයකින්',
#   'තොරව',
#   'අපි',
#   'සහය',
#   'දෙන්නමු',
#   'ජයවේවා',
#   'ලොක්ක'],
#  ['පස්වන',
#   'විධායක',
#   'ජානාධිපති',
#   'මහින්ද',
#   'රාජපක්ෂ',
#   'මැතිඳුන්',
#   'මේ',
#   'රට',
#   'පාලනය',
#   'නොකරන්න',
#   'මේ',
#   'ඉංජිනේරු',
#   'මහත්තයගේ',
#   'නම',
#   'තියන්න',
#   'තිබ්බේ',
#   'කොහෙද',
#   'කියලා',
#   'අද',
#   'රටේ',
#   'ජනතාව',
#   'දන්නවා'],
#  ['කොහොමත්',
#   'උබේ',
#   'නම',
#   'හිතට',
#   'එකගව',
#   'දාන්න',
#   'බෑ',
#   'මහින්දගේ',
#   'නම',
#   'දාන්න',
#   'බෑ',
#   'තොපි',
#   'කුහකයි',
#   'ඉතිං',
#   'ඉංජිනේරුවගේ',
#   'නම',
#   'දාපිය',
#   'කව්රුවත්',
#   'නෙමෙයි',
#   'ඕක',
#   'හැදුවේ',
#   'අපි'],
#  ['අපි',
#   'ණය',
#   'ගෙවනවනම්',
#   'ඒක',
#   'වෙන',
#   'උන්',
#   'හදන්න',
#   'බෑනේ',
#   'තොපිකාලා',
#   'ඇදලා',
#   'ඉන්නෙත්',
#   'අපේ',
#   'සල්ලි',
#   'ලැජ්ජයි',
#   'තොපි',
#   'ගැන'],
#  ['මහින්ද', 'හදපුවගෙ', 'නම්', 'මාරු', 'කර', 'කර', 'හිටපං', 'හිටං'],
#  ['මහින්ද',
#   'කළා',
#   'කියන',
#   'වහල්ලු',
#   'මොරගහකන්ද',
#   'ජලාශය',
#   'ඉදි',
#   'කරන්න',
#   'මහින්ද',
#   'කළ',
#   'ටික',
#   'කියනවද'],
#  ['දැං',
#   'මං',
#   'අහන්නෙ',
#   'මොනවම',
#   'හරි',
#   'දෙයක්',
#   'ජනතාවගේ',
#   'සල්ලි',
#   'වැය',
#   'කරල',
#   'හැදුවම',
#   'ඒකට',
#   'කාගෙ',
#   'හරි',
#   'නමක්',
#   'දාන්නම',
#   'ඕනෙද'],
#  ['නම්',
#   'තැබිමනම්',
#   'ඉතා',
#   'හොද',
#   'ආදර්ශයක්',
#   'ගාල්ලෙත්',
#   'ඕකයි',
#   'කරන්ඩ',
#   'තිබ්බේ'],
#  ['Oka',
#   'hadanna',
#   'patagannkota',
#   'epa',
#   'kiyala',
#   'natapu',
#   'aya',
#   'akka',
#   'inna',
#   'hoda',
#   'porata'],
#  ['ලැජ්ජයි', 'රටේ', 'පාලකය', 'විධියට', 'මෙවැනි', 'ගජබින්න', 'කෙලිනඑකගැන'],
#  ['Arabi', 'walin', 'higa', 'kapu', 'salli'],
#  ['අප',
#   'ළඟ',
#   'පුහු',
#   'ආඩම්බරයක්',
#   'ඇත',
#   'තාත්තා',
#   'දරුවන්ට',
#   'ගුරුවරයා',
#   'ගෝලයින්ට',
#   'කොන්දොස්තර',
#   'මගීන්ට',
#   'දේශපාලකයා',
#   'ඡන්ද',
#   'දායකයන්ට',
#   'සිංහලයා',
#   'මුස්ලිම්',
#   'අයට',
#   'පමණක්',
#   'නොවෙයි',
#   'ගෙදර',
#   'ඉන්න',
#   'බල්ලාට',
#   'පවා',
#   'පුහු',
#   'ආඩම්බරකම',
#   'පෙන්වමින්',
#   'ඉන්නා',
#   'නිසා',
#   'තමයි',
#   'අපේ',
#   'නොදියුණු',
#   'භාවය',
#   'ඇති',
#   'වෙලා',
#   'තියෙන්නේ'],
#  ['උන්',
#   'නැමෙනවා',
#   'වැඩියි',
#   'බං',
#   'බැරි',
#   'වෙලාවත්',
#   'ලංකාවෙ',
#   'ඔහොම',
#   'නැවෙන්න',
#   'ගියොත්'],
#  ['ස්වාභාවික', 'විපත්', 'නිසා', 'උන්', 'මොකටද', 'සමාව', 'ඉල්ලන්නේ'],
#  ['අපේ', 'දුම්රිය', 'සේවය', 'වගේ'],
#  ['ලංකාවට',
#   'කිසිම',
#   'පාලනයක්',
#   'අවශ්\u200dය',
#   'නැ',
#   'මිනිස්සු',
#   'තමන්ගේ',
#   'පාඩුවේ',
#   'හැමදේම',
#   'කරද්දි',
#   'කාලකන්නි',
#   'අපේම',
#   'සල්ලි',
#   'වලින්',
#   'අපිට',
#   'අරිනවා',
#   'දකින',
#   'තැන',
#   'ගහලා',
#   'එලවන',
#   'සමාජයක්',
#   'බිහිෙවනකන්',
#   'මෙව්වා',
#   'මෙහෙම',
#   'තමයි'],
#  ['Malinga',
#   'chande',
#   'ellapan',
#   'uba',
#   'dinanawa',
#   'me',
#   'rate',
#   'niliyo',
#   'chande',
#   'ellala',
#   'dinuwa',
#   'nam',
#   'ubata',
#   'gamakma',
#   'ne',
#   'hoda',
#   'pakshekin',
#   'ellala',
#   'uba',
#   'oya',
#   'ubata',
#   'kenehilikam',
#   'karapu',
#   'unta',
#   'pennapan',
#   'me',
#   'rate',
#   'minissu',
#   'ubata',
#   'ennawa',
#   'kiyala',
#   'pennapan'],
#  ['උන්ට', 'බම්බු', 'ගහන්න', 'කියලා', 'අපි', 'ඌට', 'farewell', 'එකක්', 'දෙමු'],
#  ['ඇත්තටම',
#   'ඌ',
#   'ඒම',
#   'කියල',
#   'ද',
#   'කළින්',
#   'මාලි',
#   'වන්ඩේ',
#   'වලට',
#   'නම්',
#   'විමේ',
#   'ඉඩක්',
#   'තියනව',
#   'කිව',
#   'නේද'],
#  ['ලැබ්රඩොග්', 'ගැන', 'අපි', 'දැක්කනේ'],
#  ['ලැබ්\u200dරෝයි', 'කරන්නෙ', 'බුකි', 'සුමතිට', 'වෙච්ච', 'පොරොන්දුවක්'],
#  ['Hena',
#   'hathama',
#   'Gahapuya',
#   'LEBAROY',
#   'thota',
#   'මාලිංග',
#   'ta',
#   'wagema',
#   'ධනුෂ්ක',
#   'yata',
#   'karapu',
#   'ewataaa'],
#  ['සීනි', 'කොහෙ', 'තිබ්බත්', 'කූබි', 'වහනවා'],
#  ['හෙන', 'ගහන්නෙත්', 'නෑ', 'බන්', 'ඕකුන්ට'],
#  ['ඔට්ටුපාලයා',
#   'ඕකත්',
#   'මේ',
#   'ගේම්',
#   'එකේ',
#   'යට',
#   'ඉන්නවා',
#   'ඉන්දියන්කාරයෝ',
#   'එක්ක',
#   'ඉන්දියාව',
#   'ඉස්සරහා',
#   'අපි',
#   'පීචන්',
#   'කරන',
#   'බ්\u200dරෝකර්',
#   'තමා',
#   'ඕකා'],
#  ['Maharagama',
#   'Christian',
#   'sambawayak',
#   'tiyena',
#   'godak',
#   'minnssu',
#   'inna',
#   'sinhala',
#   'burger',
#   'oya',
#   'dasun',
#   'meeta',
#   'awurudu',
#   '30',
#   'kata',
#   'kalin',
#   'sulabai'],
#  ['Mewa',
#   'dekkahama',
#   'mage',
#   'papuwa',
#   'pelenawa',
#   'gage',
#   'sansara',
#   'gamanata',
#   'yanna',
#   'kauruth',
#   'kemati',
#   'nehe'],
#  ['කව්රුත්', 'නොදකින', 'සැබැ', 'ආදරේ'],
#  ['ඇඩුන', 'ඒකට', 'දෙය්යනේ'],
#  ['Mamath',
#   'dekka',
#   'meyalawa',
#   'godak',
#   'sathutu',
#   'hithuna',
#   'meyalage',
#   'adare',
#   'gena'],
#  ['Ehema', 'thamai', 'wenna', 'one'],
#  ['ඔහොම',
#   'කිඋවයි',
#   'කියල',
#   'අපේ',
#   'උන්',
#   'රටේ',
#   'තිබෙන',
#   'දේශපාලන',
#   'ක්\u200dරමය',
#   'වෙනස්',
#   'කරන්වද',
#   'නෑනේ',
#   'බොරුවට',
#   'කෑගහනව',
#   'විතරනේ',
#   'තව',
#   'ටික',
#   'දවසකින්',
#   'මේ',
#   'කතාව',
#   'මතකවත්',
#   'නෑනේ'],
#  ['කවදාවත්',
#   'සිංහල',
#   'එකෙක්',
#   'මේ',
#   'රට',
#   'හදන්නේ',
#   'නෑ',
#   'අනුකම්පා',
#   'කරලා',
#   'සුද්දෙක්',
#   'ලංකාවේ',
#   'පුරවැසි',
#   'භාවය',
#   'හිමිකරගෙන',
#   'ඌ',
#   'ජන්දේ',
#   'ඉල්ලුවොත්',
#   'මම',
#   'අනිවාර්යයෙන්',
#   'ඌට',
#   'ජන්දේ',
#   'දෙනවා'],
#  ['එහෙනම්',
#   'ලංකාව',
#   'අතෑරලා',
#   'යන්න',
#   'ඕන',
#   'පෙන්',
#   'ලංකාවෙ',
#   'ඉදන්',
#   'ක්\u200dරීඩවකින්',
#   'උඩට',
#   'යන්න',
#   'බෑ'],
#  ['ලංකාවේ',
#   'ජාතික',
#   'මට්ටමේ',
#   'ජාත්\u200dයන්තර',
#   'මට්ටමේ',
#   'ඉන්න',
#   'ක්\u200dරිඩකයන්',
#   'කවදා',
#   'අලවි',
#   'වෙයිද',
#   'මන්දා'],
#  ['පලමුවත්', 'මව්බිම', 'දෙවනුවත්', 'මව්බිම', 'තෙවනුවත්', 'මව්බිම'],
#  ['මම', 'දන්නෑ', 'හාමුදුරුවනේ'],
#  ['උන්',
#   'කැද',
#   'බීල',
#   'වගෙ',
#   'සෙල්ලම්',
#   'කරේ',
#   'නෑ',
#   'නේ',
#   'කීඩා',
#   'සමාජ',
#   'වලට',
#   'සිලෙක්ට්',
#   'වෙන්න',
#   'බලාගෙන',
#   'සෙල්ලම්',
#   'කරෙත්',
#   'නෑ'],
#  ['ඒ', 'තමා', 'මිනිස්සු'],
#  ['Iwarayak', 'nadda', 'oii', 'මේ', 'මගුල'],
#  ['දිනුවත්', 'නෑ', 'පැරදුනත්', 'නෑ'],
#  ['මීට', 'කලින්', 'දැකලා', 'නෑ', 'තමයි'],
#  ['Ape', 'vahallunta', 'Honda', 'padam'],
#  ['Final', 'ආපු', 'එක', 'වගේද', 'බං', 'හැමදාම', 'පරාද', 'වෙන', 'එක'],
#  ['කොඩිය',
#   'විතරක්',
#   'ගිහින්',
#   'වැඩක්',
#   'නැතෝ',
#   'Team',
#   'eka',
#   'ගිහිල්ලා',
#   'අපිට',
#   'වනන්න',
#   'අවස්ථාවක්',
#   'තමයි',
#   'ඕනා'],
#  ['ටීම්',
#   'එකක්',
#   'world',
#   'cup',
#   'එකට',
#   'නොගියට',
#   'මොක්ද',
#   'කොඩිය',
#   'අරං',
#   'හරි',
#   'එකෙක්',
#   'යනවනෙ',
#   'ඒත්',
#   'මිනිස්සු',
#   'බලනවා',
#   'ඇති',
#   'මේ',
#   'මොන',
#   'රටක',
#   'කොඩියක්ද',
#   'කියලා'],
#  ['ඔහොම',
#   'කරන්න',
#   'ඕනේ',
#   'නෑ',
#   'බන්',
#   'රටේ',
#   'නම',
#   'ජාත්\u200dයන්තරයට',
#   'ගෙනියන්න',
#   'තව',
#   'ටික',
#   'කාලයක්',
#   'බලන්',
#   'හිටපන්කෝ',
#   'අපේ',
#   'මයිත්\u200dරී',
#   'මාමා',
#   'අපේ',
#   'රටේ',
#   'නම',
#   'ලෝකේම',
#   'බබලවන',
#   'විදිහ'],
#  ['Kodiya',
#   'aelluvata',
#   'ජාත්\u200dයන්තරyata',
#   'yanna',
#   'be',
#   'ne',
#   'ahenam',
#   'apee',
#   'team',
#   'akak',
#   'fifa',
#   'gahanna',
#   'harinona'],
#  ['අනිවා', 'කොහේ', 'ගියත්', 'අපේ', 'එකෙක්', 'ඉන්නවමයි'],
#  ['එලකිරී', 'මචෝ'],
#  ['Attamai', 'adambarai', 'kohoma', 'haduwath', 'Rata', 'gana', 'kakkuma'],
#  ['Cricket',
#   'Board',
#   'eka',
#   'ewun',
#   'hithagena',
#   'inne',
#   'unta',
#   'eka',
#   'paramparawen',
#   'labunu',
#   'deyak',
#   'kiyala',
#   'Sellan',
#   'karanne',
#   'wena',
#   'ewun',
#   'lakunu',
#   'daganne',
#   'un',
#   'Hariyata',
#   'lankawe',
#   'udde',
#   'dinuwa',
#   'wage'],
#  ['කමක්', 'නැහැ', 'ඔහොම', 'හරි', 'කරලා', 'හිත', 'හදාගමුකෝ'],
#  ['ලංකාවේ', 'අය', '6', 'දෙනෙක්', 'විතරයි', 'ඉන්නෙ'],
#  ['මූ', 'කොහොමත්', 'අක්කලටනෙ', 'කැමති'],
#  ['අපේ', 'රටේ', 'නායකයෝ', 'මැච්', 'බලන්න', 'ගියොත්', 'එදාට', 'එක', 'පරාදයි'],
#  ['ඒකට', 'මෙහෙ', 'ඉන්න', '225', 'නොදකින්'],
#  ['දැං', 'එතකොට', 'මෙයාට', 'ජනාධිපති', 'ධූරයේ', 'වැඩ', 'නැද්ද'],
#  ['aperate', 'wagemai', 'budu', 'amboo'],
#  ['අපේ', 'පව', 'බන්'],
#  ['Ane',
#   'manda',
#   'mewa',
#   'balala',
#   'ape',
#   'aya',
#   'kohoma',
#   'react',
#   'karaida',
#   'kiyala'],
#  ['Ape', 'eka', 'mewa', 'dakinneth', 'paththaren'],
#  ['අපේ',
#   'අය',
#   'අපිව',
#   'මීට',
#   'වඩා',
#   'සප්\u200dරයිස්',
#   'කරයි',
#   'ඒ',
#   'නිසා',
#   'ඒ',
#   'ගැන',
#   'වැඩිය',
#   'හිතන්න',
#   'හොඳ',
#   'නෑ'],
#  ['මෙයත්',
#   'අතීතයට',
#   'එක',
#   'වන',
#   'එක',
#   'දවසකට',
#   'පමනක්',
#   'සෙයා',
#   'ව',
#   'එක්',
#   'පෝස්ටුවක්',
#   'පමනයි',
#   'සිස්ටම්',
#   'එක',
#   'වෙනස්වන',
#   'බවක්',
#   'පේනතෙක්',
#   'මානෙක',
#   'වත්',
#   'නෑ'],
#  ['Konda',
#   'kelin',
#   'warada',
#   'warada',
#   'vidiyata',
#   'penwana',
#   'minissu',
#   'balu',
#   'karala',
#   'sutikko',
#   'legendsla',
#   'karana',
#   'mediane',
#   'ape',
#   'minissu',
#   'illane',
#   'Malinga',
#   'hamadamath',
#   'adarei',
#   'kelin',
#   'kathakarana',
#   'obata'],
#  ['ඒ', 'තත්පර', 'දෙක', 'ඉඳලා', 'බලල', 'යන්නත්', 'තිබ්බා'],
#  ['යකෝ', 'උන්', 'දන්නවද', 'තව', 'ටිකකින්', 'goal', 'එකක්', 'ගහනව', 'කියලා'],
#  ['දෙයක්',
#   'කියන්නේ',
#   'ව්\u200dයංග්\u200dයර්ථයෙන්',
#   'වැදගත්',
#   'විදිහට',
#   'ඒක',
#   'තේරුම්',
#   'ගන්න',
#   'බැරි',
#   'මිනිසුන්',
#   'ඉන්න',
#   'රටක්',
#   'දියුණු',
#   'වෙයිද'],
#  ['මල',
#   'සමයං',
#   'හ්ම්',
#   'අපි',
#   'ඒ',
#   'වගේ',
#   'නොවේ',
#   'එලාම්',
#   'එක',
#   'ඔෆ්',
#   'කරලයි',
#   'අපි',
#   'මැච්',
#   'එක',
#   'බලන්නේ',
#   'ගින්දර',
#   'වගේද',
#   'මැච්',
#   'මෙයා'],
#  ['තමන්ගේ',
#   'ජොබ්',
#   'එක',
#   'හරියටම',
#   'කල',
#   'මිනිස්සු',
#   'ලන්කාවේ',
#   'රාජ්\u200dය',
#   'සේවකයන්ට',
#   'ලොකු',
#   'ආදර්ශයක්',
#   'රාජ්\u200dය',
#   'සේවක',
#   'බූවල්ලගෙන්',
#   'රට',
#   'නිදහස්',
#   'කර',
#   'නොගත්තොත්',
#   'කොයි',
#   'නායකයා',
#   'ආවත්',
#   'අපේ',
#   'රට',
#   'හදන්න',
#   'බෑ'],
#  ['ඇත්ත',
#   'බොරුව',
#   'ගෝල්',
#   'එක',
#   'ගහනවද',
#   'මොන',
#   'රටේද',
#   'කොහෙද',
#   'වැඩ',
#   'කරන්නෙ',
#   'මොන',
#   'ජාතියේද',
#   'මොන',
#   'ආගමේද',
#   'වැඩක්',
#   'නෑ',
#   'ගෙදර',
#   'වුනත්',
#   'ඉන්න',
#   'තැනක',
#   'කරන',
#   'පැවරෙන',
#   'වැඩක්',
#   'හරියට',
#   'කරනව',
#   'නම්',
#   'එච්චරයි'],
#  ['නැහැ',
#   'මෙි',
#   'විඩියෝ',
#   'එක',
#   'අපි',
#   'කාටත්',
#   'හෝද',
#   'ආදර්ශයක්',
#   'විඩියෝවේ',
#   'අදහස්',
#   'හිතට',
#   'ගන්න',
#   'ලංකාවටත්',
#   'දැන්',
#   'ඹිනේ',
#   'මෙිහේම',
#   'ඡනතාවක්'],
#  ['කවුද',
#   'යකෝ',
#   'තමන්ගෙ',
#   'රට',
#   'සෙමි',
#   'ෆයිනල්',
#   'ගහද්දි',
#   'ගිණි',
#   'තියපු',
#   'එකා'],
#  ['Lakawa',
#   'dawasen',
#   'dawasa',
#   'wala',
#   'pallata',
#   'yanne',
#   'mewan',
#   'akalpa',
#   'athi',
#   'minisun',
#   'bihi',
#   'nowena',
#   'nisa'],
#  ['Hari',
#   'ithin',
#   'ehe',
#   'wage',
#   'president',
#   'ekenk',
#   'innawanam',
#   'akuratama',
#   'raja',
#   'kari',
#   'karanna',
#   'eka',
#   'mokakda'],
#  ['අපේ',
#   'උන්',
#   'හිටියා',
#   'නම්',
#   'අනිවා',
#   'කියනවා',
#   'කලින්ම',
#   'ගිනි',
#   'නිවන',
#   'ඇදුම්',
#   'ඇදගෙන',
#   'නොහිටපු',
#   'එකට',
#   'විනය',
#   'පරීක්ෂණයක්',
#   'ඕනේ',
#   'කියලා'],
#  ['එපේ',
#   'උන්',
#   'නම්',
#   'මැච්',
#   'එකත්',
#   'බලලා',
#   'සතුටට',
#   'අඩියකුත්',
#   'ගහලා',
#   'තමා',
#   'යන්නේ'],
#  ['Dan', 'ithin', 'උන්', 'ගැන', 'එක', 'එක', 'සී', 'පද', 'කියයි'],
#  ['ජිවිතයේ', 'ඒසුන්දර', 'අත්දැකීම', 'අවදිකලා'],
#  ['Ape',
#   'minissu',
#   'nm',
#   'ithin',
#   'match',
#   'eka',
#   'balala',
#   'ginna',
#   'niunatath',
#   'passe',
#   'ethanata',
#   'yanne'],
#  ['Meka', 'sira', 'ada', 'news', 'walatat', 'pennuwa'],
#  ['හැම',
#   'දේටම',
#   'වඩා',
#   'රාජකාරිය',
#   'උතුම්',
#   'ලෙස',
#   'ලෝකෙටම',
#   'ආදර්ශ',
#   'දෙන',
#   'උතුම්',
#   'මිනිස්සු'],
#  ['මිලියන',
#   '4',
#   'යි',
#   'ජනගහනය',
#   'අපට',
#   'මිලියන',
#   '20',
#   'යි',
#   'රටක්',
#   'හැදෙනව',
#   'නම්',
#   'හැදෙන්නෙ',
#   'මෙහෙමයි'],
#  ['සුදු',
#   'ඇදගෙන',
#   'අන්තිමට',
#   'එන',
#   'කෙනාව',
#   'බලන්න',
#   'මෙක',
#   'තනිකර',
#   'බොරුවක්',
#   'බොරුවට',
#   'කෙරවලට',
#   'දුවලා',
#   'නිකම්',
#   'එනවා'],
#  ['ඒකට',
#   'ලංකාවේ',
#   'ගින්න',
#   'තියන',
#   'තැනට',
#   'ගහින්',
#   'තමා',
#   'වතුර',
#   'තියනවද',
#   'කියල',
#   'බලන්නේ'],
#  ['අෙප්',
#   'ර',
#   'ෙට්',
#   'තරුණ',
#   'පිරිසකට',
#   'ෙම',
#   'ෙහම',
#   'වුණා',
#   'නම්',
#   'අැෙග්',
#   'ශක්තිය',
#   'තියා',
#   'ගන්න',
#   'භාවනාවක්',
#   'වත්',
#   'දන්නවාද'],
#  ['Me',
#   'manssayek',
#   'karapu',
#   'wade',
#   'nisa',
#   'ara',
#   'lamai',
#   'මැරෙන්නට',
#   'tibba',
#   'ratak',
#   'lowak',
#   'duk',
#   'una',
#   'oya',
#   'wage',
#   'dura',
#   'dakin',
#   'nathi',
#   'modayo',
#   'ekka',
#   'තමන්ගෙ',
#   'pana',
#   'wage',
#   'lamai',
#   'yawan',
#   'epa',
#   'දෙමව්පියන්',
#   'ta',
#   'hoda',
#   'පාඩමක්',
#   'මේකෙන්',
#   'ගත්තම',
#   'ඉවරයි'],
#  ['Mama',
#   'adambarawanawa',
#   'magana',
#   'nodanna',
#   'tawa',
#   'ayata',
#   'makadi',
#   'lankawat',
#   '2',
#   'wani',
#   'tana',
#   'innawa',
#   'gugal',
#   'walin',
#   '1',
#   'Singapore',
#   'anith',
#   'waddo',
#   'apita',
#   'passa'],
#  ['Mole',
#   'tikak',
#   'thiyanava',
#   'neda',
#   'aulak',
#   'okkoma',
#   'pili',
#   'gani',
#   'add',
#   'akak',
#   'kiyala',
#   'arakath'],
#  ['Ane',
#   'ithin',
#   'mewa',
#   'hodai',
#   'mole',
#   'nethi',
#   'unta',
#   'viswasa',
#   'karanna'],
#  ['Metharam', 'hodata', 'avith', 'awasaane', 'sarame', 'giyanew'],
#  ['මේක',
#   'තමයි',
#   'අපේ',
#   'රටේ',
#   'රත්තරන්',
#   'මිනිස්සුන්',
#   'ගේ',
#   'සැගවෙලා',
#   'තියන',
#   'DN',
#   'එක'],
#  ['මොකක්දෝ',
#   'කරැම',
#   'සල්ලි',
#   'වලට',
#   'වහ',
#   'වැටිලා',
#   'ඒ',
#   'දේ',
#   'සැගවිලා',
#   'ගිහින්',
#   'ඒත්',
#   'මෙහෙම',
#   'අවස්ථා',
#   'වල',
#   'ඉබේම',
#   'ඒක',
#   'එලියට',
#   'එනවා',
#   'ඒ',
#   'දේ',
#   'මොන',
#   'සක්කරයටවත්',
#   'බෑ',
#   'නවත්වන්න'],
#  ['කරදරේකදි',
#   'වගේම',
#   'අනිත්',
#   'හැම',
#   'වෙලාවෙමත්',
#   'ඔය',
#   'මනුස්සකම',
#   'ඔය',
#   'විදියට',
#   'තියේ',
#   'නම්',
#   'ගොඩක්',
#   'ලස්සන',
#   'රටක්',
#   'මේ',
#   'රට',
#   'Respect'],
#  ['කොච්චර',
#   'කාලකන්නි',
#   'හිටියත්',
#   'තාමත්',
#   'මෙහෙම',
#   'මිනිස්සු',
#   'ඉතුරු',
#   'වෙලා',
#   'ඉන්න',
#   'එක',
#   'ගැන',
#   'දැනෙන්නේ',
#   'පුදුම',
#   'ආඩම්බරයක්',
#   'මේක',
#   'තමයි',
#   'ශ්\u200dරි',
#   'ලාංකීක',
#   'කම'],
#  ['winayak',
#   'athuwa',
#   'wahana',
#   'elawana',
#   'magra',
#   'neethi',
#   'pilipadina',
#   'riyaduran',
#   'pirisak',
#   'bihikireemay',
#   'yugaye',
#   'awashyathawaya',
#   'nathuwa',
#   'murandu',
#   'awadanam',
#   'nosalakilimath',
#   'kalakanni',
#   'kiyanna',
#   'wachana',
#   'nahe',
#   'happala',
#   'atha',
#   'paya',
#   'kkadala',
#   'jeewitha',
#   'paligaththama',
#   'ane',
#   'apoy',
#   'kiyala',
#   'duk',
#   'wela',
#   'wadak',
#   'nahe'],
#  ['mowunta',
#   'uparima',
#   'danduwam',
#   'dena',
#   'thada',
#   'neethi',
#   'hadanna',
#   'ona',
#   'kenek',
#   'maruwama',
#   'miniya',
#   'nochariyen',
#   'eliyata',
#   'ganna',
#   'issella',
#   'happapu',
#   'eka',
#   'epa',
#   'pita',
#   'eliyata',
#   'daalaa'],
#  ['ithin',
#   'minissu',
#   'bayanahe',
#   'diyunu',
#   'ratawalwala',
#   'wage',
#   'neethi',
#   'thadin',
#   'kriyath',
#   'maka',
#   'karala',
#   'dadi',
#   'danduwam',
#   'denna',
#   'ona'],
#  ['ape',
#   'ayata',
#   'thama',
#   'happunama',
#   'nidahasata',
#   'karu',
#   'daahak',
#   'thiyenne',
#   'break',
#   'nathiwuna',
#   'lissuwaa',
#   'dakke',
#   'nahe',
#   'eka',
#   'para',
#   'panna'],
#  ['Malinga',
#   'labana',
#   'mase',
#   'candawta',
#   'gihin',
#   'golble',
#   't20',
#   'tournament',
#   'eka',
#   'sellan',
#   'karanawa'],
#  ['Sumathipala',
#   'pamanak',
#   'iwath',
#   'kalata',
#   'wedak',
#   'Naha',
#   'Ekata',
#   'manapa',
#   'un',
#   'hatagananak',
#   'withara',
#   'innawa',
#   'unuth',
#   'me',
#   'game',
#   'wala',
#   'Kota',
#   's',
#   'karayo'],
#  ['Mewage',
#   'manussakamak',
#   'thiyana',
#   'ratharam',
#   'minissun',
#   'lankawe',
#   'Inna',
#   'eka',
#   'gana',
#   'proud',
#   'wenawa',
#   'respected',
#   'you',
#   'd',
#   'work',
#   'me',
#   'wage',
#   'ashinsaka',
#   'dupath',
#   'minissunta',
#   'thama',
#   'lankawe',
#   'manussakamak',
#   'thiyana',
#   'anith',
#   'kalakani',
#   'loku',
#   'add',
#   'damata',
#   'appreciate',
#   'you',
#   'services',
#   'Budun',
#   'wadiya',
#   'rate',
#   'inne',
#   'deviwaru',
#   'mewage',
#   'ayata',
#   'thanks',
#   'pin',
#   'labend',
#   'blessings',
#   'themselves',
#   'to',
#   'have',
#   'better',
#   'lifestyle',
#   'Salli',
#   'wasiyata',
#   'manussakamak',
#   'thiyana',
#   'kalakani',
#   'Inna',
#   'society',
#   'eka',
#   'mewage',
#   'deviwawaru',
#   'wage',
#   'Aya',
#   'Inna',
#   'ekath',
#   'proud',
#   'of',
#   'Sri',
#   'Lanka'],
#  ['Buki',
#   'karayonta',
#   'owa',
#   'dunnma',
#   'u',
#   'ekath',
#   'wikunagena',
#   'kanawa',
#   'mokada',
#   'munta',
#   'ona',
#   'kohomahari',
#   'salli'],
#  ['කවුරු',
#   'මොනා',
#   'කිව්වත්',
#   'කරදරයකදි',
#   'අපේ',
#   'මිනිස්සු',
#   'ලංකාවේ',
#   'මිනිස්සු',
#   'දෙවිවරු',
#   'අත්දැකීමෙන්',
#   'කියන්නේ',
#   'ජාතිබේද',
#   'නැති',
#   'මනුස්සකම'],
#  ...]

# %%
# function to identify a given string is english or not
def isEnglish(s):
    if(str.isdigit(s)):
        return False
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# %%
# function to identify a given list of tokens are singlish or  not
def isSinglish(tokens):
    for token in tokens:
        if(isEnglish(token)):
            return True
    return False

# %%
# function to get the unique token of a given singlish token
def getUniqueSinglishTokens(token):
    convertedToken = token.lower()
    # get the root version
    return convertedToken

# %%
cleaned_tokens = []
for sentTokens in tokens:
    if(isSinglish(sentTokens)):
        temp = []
        for token in sentTokens:
            if(isEnglish(token)):
                temp.append(getUniqueSinglishTokens(token))
            else:
                temp.append(token)
        cleaned_tokens.append(temp)
    else:
        cleaned_tokens.append(sentTokens)

# %%
cleaned_tokens
# Out:
# [['මේ',
#   'බැල්ලි',
#   'කොටින්ගේ',
#   'ගු',
#   'කනකොට',
#   'අපහසුවක්',
#   'දැනුනෙ',
#   'නැද්ද',
#   'දන්',
#   'නැහැ',
#   'ඔකිට',
#   'මිනිහා',
#   'මැරුනම',
#   'දැනුන',
#   'දුකට',
#   'වඩා',
#   'දහස්',
#   'ගුනයක',
#   'දුකක්',
#   'දැනෙනවා',
#   'ඉස්සරහට',
#   'උපසම්පදාව',
#   'තියන',
#   'භික්සුවක්',
#   'හිරේ',
#   'යැවුවට',
#   'ඔකි',
#   'වැඩියෙන්ම',
#   'ආදරේ',
#   'කෙනෙක්',
#   'ඔකිට',
#   'නැති',
#   'වෙනවා',
#   'වැඩි',
#   'කල්',
#   'නොගිහින්'],
#  ['මන්',
#   'ඊයේ',
#   'මුස්ලිම්',
#   'ඩෑල්',
#   'එකක්',
#   'එක්ක',
#   'සෙල්ෆියක්',
#   'ගත්තා',
#   'සහජීවනේ',
#   'රැකගෙන',
#   'ඉදිරියට',
#   'යන්න',
#   'ඌ',
#   'ඒක',
#   'තාම',
#   'දාලා',
#   'නෑ',
#   'පරයා'],
#  ['සංහිදියාවට', 'අවුලක්', 'වෙයි', 'ද'],
#  ['කටින්',
#   'පුරසාරම්',
#   'දොඩන',
#   'අපි',
#   'සිංහලයො',
#   'විදියට',
#   'ලැජ්ජා',
#   'විය',
#   'යුතුයි'],
#  ['මචන්',
#   'ඔය',
#   'මගුල',
#   'නවත්තලා',
#   'කොන්දක්',
#   'තියෙනවානම්',
#   'පුලුවන්නම්',
#   'කරලා',
#   'පෙන්නපන්',
#   'ඔය',
#   'දෙසපාලනය',
#   'කරන',
#   'අයගෙන්',
#   'මෙ',
#   'රටට',
#   'මොකක්ද',
#   'වෙලාතියෙන්නෙ',
#   'කියලා',
#   'අන්න',
#   'එදාට',
#   'උබ',
#   'නියම',
#   'කොල්ලෙක්',
#   'පුලුවන්නම්',
#   'කරලා',
#   'පෙන්නනවාද'],
#  ['හැබැයි',
#   'ඒ',
#   'මේ',
#   'ආණ්ඩුවේ',
#   'විතරක්',
#   'නෙවෙයි',
#   'රට',
#   'හූරාගෙන',
#   'තමන්ගෙ',
#   'බූදලය',
#   'කියල',
#   'හිතාගෙන',
#   'රට',
#   'උගස්',
#   'තියල',
#   'සල්ලි',
#   'නයට',
#   'අරගෙන',
#   'තමතමන්ගෙ',
#   'පරම්පරාවෙ',
#   'එවුන්ටයි',
#   'හිතවත්',
#   'එවුන්ටයි',
#   'බෙදාගෙන',
#   'කන',
#   'සියලුම',
#   'දේශපාලකයන්',
#   'දුටු',
#   'දුටු',
#   'තැන',
#   'මරලා',
#   'දාන',
#   'දිනය',
#   'වැඩි',
#   'ඈතක',
#   'නෑ'],
#  ['ලංකාව',
#   'මොකක්ද',
#   'මෙිකෙ',
#   'ඉන්නෙ',
#   'වාහනයක්',
#   'ගත්තම',
#   'අලි',
#   'ඔලුවෙන්',
#   'ඉන්න',
#   'පාරෙ',
#   'යන',
#   'වෙන',
#   'එකෙක්',
#   'ගැන',
#   'හිතන්නැති',
#   'නිරැවත්',
#   'පිංපියො',
#   'වගෙ',
#   'එවුන්',
#   'ටිකක්',
#   'නෙ'],
#  ['menna',
#   'ratawal',
#   'menna',
#   'minissu',
#   'ape',
#   'ratawal',
#   'wala',
#   'inna',
#   'jathin',
#   'thunema',
#   'gothrikayo',
#   'tika',
#   'manussayo',
#   'karala',
#   'inna',
#   'wenawa'],
#  ['උඹ',
#   'ලෝකයක්',
#   'ඉස්සරහ',
#   'හදාගත්ත',
#   'නම්බුව',
#   'ලංකාවේ',
#   'කාලකණ්ණි',
#   'එක',
#   'විනාඩියේන්',
#   'නැති',
#   'කරයි',
#   'බන්',
#   'ඒ',
#   'හන්ද',
#   'දේශපාලනය',
#   'කරන්ට',
#   'එන්ට',
#   'එපා',
#   'මචංංංංං',
#   'ගුඩ්ලක්'],
#  ['පල්ලියකට',
#   'ගලක්',
#   'වැදුනත්',
#   'පරසක්වල',
#   'ගහන',
#   'මූ',
#   'පන්සල්',
#   'බිමට',
#   'සමතලා',
#   'කරද්දී',
#   'සද්ද',
#   'නෑ',
#   'මූට',
#   'කොහොමත්',
#   'ඡන්දෙ',
#   'නම්',
#   'දෙන්නෙ',
#   'නෑ'],
#  ['පංසල්',
#   'විනාශ',
#   'කරද්දී',
#   'ඇරෙන්නේ',
#   'නැති',
#   'සංගාගේ',
#   'කට',
#   'පල්ලියට',
#   'ගල්',
#   'ගහද්දි',
#   'ඇරුණා',
#   'එහෙම',
#   'නායකත්වයක්',
#   'සිංහල',
#   'රට',
#   'ජාතිය',
#   'හදයිද'],
#  ['paduway',
#   'hitahan',
#   'beri',
#   'weda',
#   'nokaran',
#   'bat',
#   'eka',
#   'gaththada',
#   'bole',
#   'elluwada',
#   'oka',
#   'karagena',
#   'inna',
#   'oyala',
#   'desapalanayata',
#   'atha',
#   'daruwan',
#   'therum',
#   'ganna',
#   'nikan',
#   'thiyena',
#   'prrsiddath',
#   'nethi',
#   'karanna',
#   'epa'],
#  ['muth',
#   'kata',
#   'arinne',
#   'anik',
#   'unta',
#   'witharai',
#   'jathiyata',
#   'agamata',
#   'sadda',
#   'na',
#   'endiyawata',
#   'koti',
#   'ganan',
#   'denawa',
#   'ahinsakayant',
#   'ape',
#   'rate',
#   'unta',
#   'mukuth',
#   'na'],
#  ['songs',
#   'kanna',
#   'epa',
#   'buruwo',
#   'kochchara',
#   'lassana',
#   'sindu',
#   'kanna',
#   'epa',
#   'ubalata',
#   'song',
#   'karanna',
#   'barinam',
#   'nikan',
#   'edapan',
#   'thiyana',
#   'ewa',
#   'kanna',
#   'epa'],
#  ['muth',
#   'nanna',
#   'yanne',
#   'kridakayanta',
#   'ground',
#   'walata',
#   'wena',
#   'asadaranakam',
#   'walata',
#   'wachanayak',
#   'eliyata',
#   'danne',
#   'nathi',
#   'aka',
#   'rata',
#   'hadanna',
#   'yanawa',
#   'mahela',
#   'karanam',
#   'api',
#   'akenma',
#   'set'],
#  ['ai',
#   'mahinda',
#   'gen',
#   'polonnaruve',
#   'valikande',
#   'hmbawnaakkara',
#   '1800',
#   'maddida',
#   'sanga',
#   'den',
#   'unp',
#   'yen',
#   'akkara',
#   'kiyak',
#   'onida',
#   'apita',
#   'ogama',
#   'danna',
#   'kaururh',
#   'nane',
#   'dun',
#   'noth',
#   'apith',
#   'dannava',
#   'karan',
#   'naoni',
#   'vada'],
#  ['ජයසූරිය',
#   'mathakada',
#   'ow',
#   'ow',
#   'sanath',
#   'ජයසූරිය',
#   'thama',
#   'eyatath',
#   'wada',
#   'kujitha',
#   'wela',
#   'yannai',
#   'sangata',
#   'wenne'],
#  ['රට',
#   'හදන්න',
#   'ඕනේ',
#   'නම්',
#   'එන්ජීඕ',
#   'ගැට',
#   'වලින්',
#   'මිදී',
#   'ගෙදරට',
#   'වී',
#   'ඉන්න'],
#  ['dana', 'reddak', 'sinhalen', 'danna', 'kiyanna', 'meka', 'lankawa'],
#  ['කියන්න',
#   'වැඩ',
#   'හොදනම්',
#   'හදවතින්ම',
#   'සපෝර්ට්',
#   'හැබැයි',
#   'පොහොට්ටුව',
#   'samaga',
#   'නොවී',
#   'u',
#   'n',
#   'p',
#   'nam',
#   'නම්',
#   'හුරේ'],
#  ['president',
#   'wenna',
#   'puluwan',
#   'bauddayekuta',
#   'witharai',
#   'me',
#   'yaka',
#   'croatian'],
#  ['රට',
#   'හදන්න',
#   'කලින්',
#   'මිනිසුන්',
#   'රවටන',
#   'ප්\u200dරචාරක',
#   'දැන්විම්',
#   'වලින්',
#   'මුදල්',
#   'හම්බ',
#   'කරන',
#   'එක',
#   'නවත්වා',
#   'සමාජයට',
#   'සේවයක්',
#   'කරන්න'],
#  ['ජයසූරියත්',
#   'ආවෙ',
#   'කෝ',
#   'රට',
#   'හැදුවද',
#   'හැදුවද',
#   'නෑ',
#   'නෙ',
#   'නෑ',
#   'නෙ',
#   'ඌ',
#   'ලමයි',
#   'හැදුවා'],
#  ['ආ', 'එතකොට', 'අපිටත්', 'ඇඩ්', 'එකක', 'ඉන්න', 'පුළුවන්', 'වෙයි', 'නේ'],
#  ['පොන්නයො',
#   'රට',
#   'පලනය',
#   'කරනකොට',
#   'ඔහොම',
#   'තමා',
#   'ජිවිතේ',
#   'අසාවෙන්',
#   'බලපු',
#   'එකම',
#   'දේ',
#   'ක්\u200dරිකට්',
#   'එකත්',
#   'නැති',
#   'කරා',
#   'මේ',
#   'පොන්නයො'],
#  ['ඔය',
#   'කාරනය',
#   'හරියට',
#   'විග්\u200dරහ',
#   'කරන්න',
#   'ඩුප්ලිකේට්',
#   'මහමෙව්නාවේ',
#   'ඩුප්ලිකේට්',
#   'කල්\u200dයාණ',
#   'මිතුරන්ට',
#   'පුලුවන්',
#   'නම්',
#   'දිව්\u200dය',
#   'ලෝක',
#   'promote',
#   'කරයි\u200d',
#   'ද'],
#  ['ස්ට්\u200dරයික්', 'කරන', 'ඔක්කොටම', 'ගහන්න', 'ඕන', 'දෝස්තරලාත්', 'ඇතුලු'],
#  ['aka',
#   'satha',
#   '5k',
#   'wadi',
#   'karanna',
#   'epa',
#   'okunta',
#   'wada',
#   'karanna',
#   'bai',
#   'nam',
#   'job',
#   'eken',
#   'elawanna',
#   'eliye',
#   'job',
#   'nathi',
#   'ewun',
#   'oni',
#   'tharam',
#   'ennawa'],
#  ['ගිය',
#   'ආන්ඩුව',
#   'කාලෙ',
#   'ඔහොම',
#   'නැටුවේ',
#   'නෑ',
#   'මුන්ගෙ',
#   'කොන්ද',
#   'පන',
#   'නෑ'],
#  ['ඉතිං',
#   'බං',
#   'උබලා',
#   'පිස්සු',
#   'නටලා',
#   'ඊට',
#   'වඩා',
#   'පඩි',
#   'ගන්නෙ',
#   'ඕක',
#   'මොකක්ද'],
#  ['කල්ලතෝනි', 'පකෙක්'],
#  ['අැත්තටම',
#   'හරිම',
#   'සතුටුයි',
#   'එ්',
#   'මනුස්සකමට',
#   'එ්',
#   'වගේම',
#   'අරාබියට',
#   'ගිහින්එන',
#   'අපේ',
#   'මුස්ලිමි',
#   'කාන්තාවන්',
#   'මුන',
#   'වහගෙන',
#   'බිල්ලෝ',
#   'වගේ',
#   'එනකොට',
#   'මේ',
#   'නෝනා',
#   'හරිම',
#   'සුන්දර',
#   'විදියට',
#   'අැවිත්',
#   'ඉන්නවා'],
#  ['kisi', 'quality', 'ekak', 'nathi', 'apatayek'],
#  ['munta', 'chande', 'dena', 'buruwo', 'innawane', 'thawath', 'me', 'rate'],
#  ['මේ',
#   'කැරිවේසිග',
#   'පුතාල',
#   'ඉන්නකල්',
#   'රටට',
#   'කෙලවෙන',
#   'එක',
#   'අහන්නත්',
#   'දෙයක්ද',
#   'බන්',
#   'කාලකන්නි',
#   'හැත්ත',
#   'බල්ලො',
#   'රටේ',
#   'ලොක්කො',
#   'වෙනකොට',
#   'රට',
#   'බල්ලට',
#   'යන',
#   'එක',
#   'අහන්නත්',
#   'දෙයක්ද'],
#  ['thota',
#   'henagapiya',
#   'kadaya',
#   'thilangayawa',
#   'hurathal',
#   'karapan',
#   'esige',
#   'putha'],
#  ['cricket',
#   'kridawa',
#   'kawe',
#   'oi',
#   'thirisana',
#   'oi',
#   'putuwa',
#   'deehan',
#   'sangata',
#   'un',
#   'dawiwaru',
#   'yakooo'],
#  ['kwda',
#   'me',
#   'lat',
#   'roy',
#   'kiyana',
#   'ekaa',
#   'lat',
#   'hoodana',
#   'ekek',
#   'da'],
#  ['ekata', 'ape', 'eka', 'thuuu'],
#  ['තොපි',
#   'වගේ',
#   'නාහෙන්',
#   'අඩන',
#   'කාලකන්නි',
#   'පොන්නයො',
#   'නිසා',
#   'තමයි',
#   'අපේ',
#   'සංගීතයට',
#   'අද',
#   'කණ',
#   'කොකා',
#   'හඩලා',
#   'තියෙන්නෙ',
#   'ලැජ්ජයි',
#   'යකෝ',
#   'තෝ',
#   'වගේ',
#   'එකෙක්',
#   'ආයෙ',
#   'මුණ',
#   'ගැහුනා',
#   'නම්',
#   'ඌත්',
#   'තෝ',
#   'වගේම',
#   'අඩයිනෙ',
#   'දවසක'],
#  ['dakuna', 'menessuu', 'harema', 'arthmarthakameeeeeeeeeeee'],
#  ['sinhalayo', 'kuhakayo'],
#  ['අපොයි',
#   '2020',
#   'ජනාධිපති',
#   'නෙද',
#   'හුත්තෝ',
#   'උබ',
#   'උබ',
#   'හොදයි',
#   'නගරසභාවේ',
#   'toilet',
#   'සුද්ද',
#   'කරන්න',
#   'හිකුණ්ඨික',
#   'සක්කිලියා'],
#  ['මොනව', 'උනත්', 'පොලිසියෙ', 'ඉන්නෙ', 'බල්ලො'],
#  ['lankawe',
#   'wage',
#   'political',
#   'majarayo',
#   'innakam',
#   'police',
#   'quality',
#   'eka',
#   'wadi',
#   'karanna',
#   'baha'],
#  ['තෝ',
#   'වගෙ',
#   'එකෙක්',
#   'අනේ',
#   'මන්ද',
#   'යකෝ',
#   'වැදගත්',
#   'දෙයක්',
#   'කරපිය',
#   'ගොන්',
#   'වස්සෙක්',
#   'ඉදකින්',
#   'හුත්තො'],
#  ['lanka',
#   'we',
#   'inne',
#   'labba',
#   'bahapu',
#   'naki',
#   'police',
#   'karayo',
#   'ne',
#   'bulath',
#   'wite',
#   'kagena',
#   'ahisaka',
#   'bike',
#   'ekak',
#   'nawath',
#   'wala',
#   'ugen',
#   'rs',
#   '500',
#   'aragena',
#   'lami',
#   'ta',
#   'ganun',
#   'ta',
#   'kanna',
#   'dena'],
#  ['kasippu',
#   'karayagen',
#   'ganja',
#   'karayagen',
#   'keeyak',
#   'hari',
#   'aragena',
#   'unge',
#   'bothalayata',
#   'yata',
#   'una',
#   'kisima',
#   'puhunuwak',
#   'nathi',
#   'gon',
#   'harak',
#   'tikak',
#   'ne',
#   'police',
#   'office',
#   'ekak',
#   'paththata',
#   'nikamata',
#   'gihilla',
#   'blapalla',
#   'ali',
#   'wrdi',
#   'walatath',
#   'duwana',
#   'un',
#   'inne',
#   'gam',
#   'walin',
#   'apu',
#   'rilau'],
#  ['ඇයි',
#   'යකෝ',
#   'ලංකාවේ',
#   'පොලිසිය',
#   'නිරායුධ',
#   'මිනිසුන්ට',
#   'ගහන්නේ',
#   'එලවා',
#   'එලවා'],
#  ['ape', 'polisiya', 'atule', 'tmai', 'wadiyenma', 'horu', 'inne'],
#  ['arawa', 'kanno', 'echchari', 'danne', 'policeya', 'gena'],
#  ['පොලිස්සිය',
#   'තාමත්',
#   'කැද',
#   'හැලි',
#   'වගේ',
#   'තරැන',
#   'කොල්ලොන්ට',
#   'ජීවිතෙන්',
#   'වන්දි',
#   'ගෙවන්න',
#   'වෙන්නෙ',
#   'නාකි',
#   'පප්පල',
#   'බුලත්විටක්',
#   'කාගෙන',
#   'අඩි',
#   'දහයක්',
#   'දුවා',
#   'ගන්න',
#   'බැරි',
#   'නිසා'],
#  ['තුවක්කු',
#   'පුහුනුව',
#   'දෙන්නෙ',
#   'training',
#   'එකේ',
#   'විතරයි',
#   'ඉලක්කයක්',
#   'අරන්',
#   'වෙඩි',
#   'තියන්න',
#   'කී',
#   'දෙනාද',
#   'දක්ෂ',
#   'නාකි',
#   'පප්පල',
#   'ටික',
#   'ගහල',
#   'පන්නන්න',
#   'ඕන',
#   'ජරාව',
#   'කකා',
#   'ඉන්නන්',
#   'වාලේ',
#   'ඉන්නවට',
#   'අනිත්',
#   'එක',
#   'සාමාන්\u200dය',
#   'මිනිස්සු',
#   'ඉන්න',
#   'තත්වයකදි',
#   'මේ',
#   'විදියට',
#   'වෙඩි',
#   'තැබීම',
#   'අනුමත',
#   'කරන්න',
#   'බැ'],
#  ['පාතාල',
#   'කාරයන්ට',
#   'මනුස්සකමක්',
#   'නැනේ',
#   'මුන්',
#   'බයික්',
#   'වලට',
#   'නගිනකන්',
#   'ඉවසන්න',
#   'තිබුනේ',
#   'නැත්තන්',
#   'තත්වය',
#   'බලල',
#   'stf',
#   'ගෙනන්න',
#   'තිබුනේ',
#   'කොහේද',
#   'ලොක්කො',
#   'දෙන',
#   'අණ',
#   'නේ',
#   'අපරාදෙ',
#   'වටින',
#   'ජීවිතයක්'],
#  ['ගිහින්',
#   'ඔය',
#   'එකෙක්ටවත්',
#   'ආපහු',
#   'මේ',
#   'ලෝකේ',
#   'දකින්න',
#   'ඉඩ',
#   'තියන්න',
#   'එපා',
#   'මුන්ව',
#   'හිරේ',
#   'යවන්නනම්',
#   'එපා',
#   'මරලා',
#   'දානවා',
#   'මිසක්'],
#  ['අනේ', 'මෙහෙමත්', 'කුහක', 'මිනිස්සු'],
#  ['මෙතන',
#   'හොරු',
#   'හොදට',
#   'තුවක්කුවලින්',
#   'වෙඩි',
#   'තියනවා',
#   'පොලිසිය',
#   'අත',
#   'වන',
#   'වන',
#   'ඇවිත්',
#   'හොරුන්ගෙන්',
#   'වෙඩි',
#   'කනවා',
#   'ගුටි',
#   'කනවා'],
#  ['මෙලෝ', 'රහක්', 'නැති', 'උන්', 'ඉන්න', 'ටවුන්', 'එකක්'],
#  ['මන්නම්',
#   'කියන්නෙ',
#   'පොලිසියෙ',
#   'උන්නැහැලා',
#   'ටිකටත්',
#   'stf',
#   'පුහුණුවක්',
#   'අවශයයි',
#   'මොකද',
#   'හොරාට',
#   'පන්න',
#   'ගන්න',
#   'බැ',
#   'මොලෙ',
#   'පාවිච්චි',
#   'කරලා',
#   'හොරා',
#   'කොටු',
#   'කරගන්නෙ',
#   'නැ',
#   'ගොන්',
#   'වැඩ',
#   'ගොඩක්',
#   'තියෙනව'],
#  ['කතා',
#   'කරෝත්',
#   'මහ',
#   'ලොකුවට',
#   'අපි',
#   'දකුණේ',
#   'කෝන්දක්',
#   'තීයන1',
#   'කේනේක්',
#   'නෑ',
#   'පොලිසිය',
#   'අයියව',
#   'උස්සන්න',
#   'ඔය',
#   'උස්සපු',
#   'අයියා',
#   'විතරයි',
#   'පිරිමි',
#   'යේක්',
#   'කියලා'],
#  ['මමනං',
#   'දැක්කේ',
#   'අනිත්',
#   'ඔක්කෝම',
#   'පිරිමී',
#   'අපි',
#   'අදින',
#   'ගවුම්',
#   'වලට',
#   'වඩා',
#   'හෝද',
#   'නයිටි',
#   'ටිකක්',
#   'ඇදගන්න',
#   'ලැජ්ජයි',
#   'මට',
#   'නම්',
#   'මාතර',
#   'අයට',
#   'පිරිමි',
#   'කියන්න',
#   'දැක්ක',
#   'හොදම',
#   'නපුංසකයෝ',
#   'නම්',
#   'මාතර',
#   'තමා',
#   'අනේ',
#   'ප්ලීස්',
#   'ඔය',
#   'මංකොල්ල',
#   'කාරයෝ'],
#  ['ඔක්කෝම',
#   'කෝහෝම',
#   'හරි',
#   'වෙඩිතියල',
#   'මරලා',
#   'දාන්න',
#   'පොලිස්පති',
#   'තුමනි',
#   'අයේත්',
#   'මේවැනි',
#   'දේ',
#   'නොවෙන්න'],
#  ['මව්',
#   'බිම',
#   'නැති',
#   'නම්',
#   'මරණය',
#   'මෙයයි',
#   'තේමා',
#   'පාටය',
#   'විය',
#   'යුත්තේ',
#   'ඔය',
#   'පෝන්',
#   'කෝල්',
#   'වලට',
#   'බයේ',
#   'රාජකාරි',
#   'කරන',
#   'කාලය',
#   'ඇත',
#   'හැරි',
#   'යුතුයි'],
#  ['ratakata',
#   'giya',
#   'kalak',
#   'vahane',
#   'dora',
#   'arinna',
#   'ekek',
#   'help',
#   'kare',
#   'ne',
#   'ara',
#   'manussayata',
#   'me',
#   'aparade',
#   'karapu',
#   'un',
#   'tama',
#   'nidalle',
#   'rate',
#   'maha',
#   'un',
#   'ponnayo',
#   'ekai',
#   'me',
#   'serama',
#   'dewal',
#   'okunat',
#   'chance',
#   'denna',
#   'epa',
#   'tatwat'],
#  ['pathali',
#   'para',
#   'haththa',
#   'akekwath',
#   'ethuru',
#   'karanna',
#   'epa',
#   'okunge',
#   'daruwanta',
#   'edala',
#   'hena',
#   'gahanawa',
#   'para',
#   'ballo'],
#  ['තුවක්කුවක්',
#   'නැත්තං',
#   'පැත්තකට',
#   'වෙලා',
#   'ඉදපංකො',
#   'විහිං',
#   'මැරැම්කන්නැතිව',
#   'තුවක්කු',
#   'තියං',
#   'ඉන්න',
#   'මංකොලල',
#   'කාරයන්ට',
#   'බැටන්පොල්ලෙන්',
#   'ගහන්න',
#   'ගියාම',
#   'මැරැංකන',
#   'එක',
#   'අහන්නත්',
#   'දෙයක්ද',
#   'මේක',
#   'මහ',
#   'මෝඩයෙක්'],
#  ['ashi',
#   'hashi',
#   'ඔවාට',
#   'දකුණේ',
#   'එකෙක්',
#   'ඒක',
#   'කෙලින්',
#   'කියන්න',
#   'වෙන',
#   'වෙන',
#   'සීන්',
#   'ගැන',
#   'කියල',
#   'මඩ',
#   'ගහන්නෙ',
#   'නැතුව'],
#  ['ahama',
#   'kiyana',
#   'apa',
#   'natara',
#   'kiyann',
#   'apa',
#   'gama',
#   'policya',
#   'wada',
#   'waradagan',
#   'tiyana',
#   'nisai',
#   'minusu',
#   'ahka',
#   'baluwa',
#   'nikaruna',
#   'kollo',
#   'maranawa',
#   'horu',
#   'maragann',
#   'ba',
#   'bayta',
#   'akada',
#   'yahpalan',
#   'ahinsa',
#   'amm',
#   'adanwa',
#   'ada',
#   'puta',
#   'batuwa',
#   'oya',
#   'sakilli',
#   'bollonga',
#   'oluwata',
#   'waditiyala',
#   'danna',
#   'ona'],
#  ['මත්ද්\u200dරව්\u200dයවලට',
#   'ඇබ්බැහි',
#   'වෙලා',
#   'මිනිස්සු',
#   'මරලා',
#   'හරි',
#   'සල්ලි',
#   'ඔිිනි',
#   'පොලිසියට',
#   'පෙර',
#   'පුහුණුවක්',
#   'නැති',
#   'විම',
#   'පුජිත',
#   'දේසපාලකන්ගේ',
#   'කකුල්',
#   'ලේවකනවා',
#   'කොල්ලා',
#   'නිකන්',
#   'මැරැැනා'],
#  ['යකෝ',
#   'හරිහමන්',
#   'තුවක්කුවක්',
#   'දෙන්න',
#   'බැරිද',
#   'බන්',
#   'ඇමති',
#   'අයගේ',
#   'වාහන',
#   'වලට',
#   'කෝටි',
#   'ප්\u200dරකෝටි',
#   'ගනන්',
#   'නාස්ති',
#   'කරනවා',
#   'ඕන',
#   'දේකට',
#   'වියදම්',
#   'කරන්නේ',
#   'නෑ'],
#  ['me', 'horu', 'training', 'une', 'koheda'],
#  ['thattayaa',
#   'mokek',
#   'daa',
#   'uuu',
#   'karikii',
#   'karikii',
#   'innee',
#   'pissek',
#   'wagee',
#   'udauu',
#   'karannee',
#   'nathywaa',
#   'mona',
#   'pissek',
#   'daa',
#   'mandaa'],
#  ['maraladanna',
#   'thiyenne',
#   'okunwa',
#   'mathara',
#   'un',
#   'dakune',
#   'kiyala',
#   'kehegahuwata',
#   'bayagullo',
#   'inne'],
#  ['අර',
#   'දිවියව',
#   'මරපු',
#   'මිනිස්සු',
#   'තරම්',
#   'අපරාධ',
#   'කාරයෝ',
#   'නෙමේ',
#   'වෙන්න',
#   'ඇති',
#   'මේ',
#   'පොලිස්',
#   'නිලධාරියාව',
#   'මරපු',
#   'මිනිමරුවෝ',
#   'එකනේ',
#   'ඒ',
#   'තරම්',
#   'දරුණු',
#   'වචන',
#   'නැත්තේ',
#   'මේ',
#   'මිනි',
#   'මරුවන්ට',
#   'එරෙහිව'],
#  ['oya',
#   'jatika',
#   'arakahawa',
#   'sambanda',
#   'inna',
#   'uda',
#   'pena',
#   'pena',
#   'kata',
#   'meta',
#   'dodawana',
#   'amatio',
#   'dipan',
#   'polisiata',
#   'hoda',
#   'wepan',
#   'mesinngan',
#   'arun',
#   'ottu',
#   'sellam',
#   'karanawa',
#   'maha',
#   'pare',
#   'hat',
#   'denek',
#   'duwanawa',
#   'lejjai',
#   'dipan',
#   'oya',
#   'pattama',
#   'patalema',
#   'tawa',
#   'ekekuta',
#   'palayan',
#   'paw',
#   'nodi',
#   'gedara'],
#  ['lankawe',
#   'inna',
#   'samahara',
#   'pirimi',
#   'napunsakayo',
#   'ara',
#   'manussayata',
#   'wahane',
#   'dora',
#   'arala',
#   'dennawat',
#   'kenek',
#   'enne',
#   'ne',
#   'mun',
#   'pirimida',
#   'ane',
#   'e',
#   'manussaya',
#   'veerayek',
#   'attatama'],
#  ['තවත්', 'එක්', 'සෝමාලියාවක්', 'වගේ', 'ශිට්'],
#  ['meyata',
#   'aydayak',
#   'tibbanam',
#   'aniwa',
#   'dennekwath',
#   'bawanawa',
#   'aprade'],
#  ['පාතාලයේ', 'කියන', 'හැම', 'එකාවම', 'මරල', 'දාන්න', 'ඕනා'],
#  ['hospital',
#   'inna',
#   'ewun',
#   'tikath',
#   'wada',
#   'deela',
#   'maranda',
#   'thiyenne'],
#  ['ත්\u200dරිවිධ',
#   'හමුදාවට',
#   'පොලිසිය',
#   'අසරණ',
#   'කරන්න',
#   'තහංචි',
#   'පනවා',
#   'හොරුන්ට',
#   'නීති',
#   'රීති',
#   'ලිහිල්වුන',
#   'රටක්',
#   'ලංකාව'],
#  ['කියන්න', 'නම්', 'එපා', 'අපි', 'දකුනේ', 'කියලා', 'විලි', 'ලැජ්ජයි', 'යකෝ'],
#  ['ඕකුන්වත්',
#   'පෝලිමට',
#   'තියලා',
#   'මරලා',
#   'දාපල්ලා',
#   'අර',
#   'අහිංසකයට',
#   'වුනා',
#   'වගේම'],
#  ['shit', 'ara', 'ekek', 'dakalat', 'dakke', 'na', 'wage', 'yanawa'],
#  ['waha', 'palane', 'raga', 'tamai', 'oya'],
#  ['වෙනසෙ', 'සැප', 'පේනවනේ', 'මෙි', 'රටෙි', 'නිතිය', 'බල්ලට', 'ගිහින්'],
#  ['ලංකාවේ',
#   'hema',
#   'tanama',
#   'oya',
#   'wage',
#   'tamai',
#   'r',
#   'd',
#   'a',
#   'නිලධාරීන්',
#   'owa',
#   'දකින්නේ',
#   'nati',
#   'එක',
#   'හරිම',
#   'කනගාටුදායක',
#   'අපෙන්',
#   'බඳු',
#   'ගහන',
#   'සල්ලිවලින්',
#   'කරන',
#   'අපරාධ',
#   'henaghanawa',
#   'munta',
#   'tu'],
#  ['ape',
#   'peththeth',
#   'oya',
#   'wede',
#   'mai',
#   'කරන්නේ',
#   'මහින්ද',
#   'මහත්තයා',
#   'නැතිකම',
#   'දැනෙනවා',
#   'hitiyanam',
#   'අපිත්',
#   'ගොඩ'],
#  ['දැන්',
#   'බැන',
#   'බැන',
#   'මේකෙ',
#   'පෝස්ට්',
#   'දැම්මට',
#   'මේවා',
#   'පිලිවෙලට',
#   'මහින්දගෙ',
#   'කාලෙ',
#   'සිද්ධ',
#   'උනා',
#   'ඒවාට',
#   'අසංවේදී',
#   'උන',
#   'මෝඩ',
#   'උද්ධච්ඡ',
#   'මිනිස්සුන්ගෙ',
#   'ඡන්ද',
#   'වල',
#   'පිහිටෙන්',
#   'ලැබුනු',
#   'වෙනස',
#   'තමයි',
#   'මේ',
#   'තියෙන්න්නේ'],
#  ['තුවාල',
#   'වලට',
#   'බේත්',
#   'දානවා',
#   'වගේ',
#   'කියන්න',
#   'දුකයි',
#   'සිංහල',
#   'ජාතිය',
#   'කාළකණ්නි',
#   'ජාතියක්',
#   'බවට',
#   'පත්',
#   'වී',
#   'හමාරයි'],
#  ['mewata',
#   'loku',
#   'baladarin',
#   'waga',
#   'kiyanna',
#   'ona',
#   'mun',
#   'okkoma',
#   'ekai',
#   'mahajana',
#   'mudal',
#   'nasthi',
#   'karana',
#   'kalakanni',
#   'balu',
#   'heththa'],
#  ['ඇත්තම', 'කියනවනම්', 'ලංකාව', 'හරිම', 'කාලකන්නි', 'රටක්'],
#  ['කාලකන්නි',
#   'හැතිකරය',
#   'අපේ',
#   'සල්ලි',
#   'වලින්',
#   'ලබු',
#   'කන',
#   'මෙි',
#   'වාගේ',
#   'රජයේ',
#   'අයතන',
#   'වලට',
#   'හන',
#   'හගන්න',
#   'ඔන'],
#  ['akke', 'aewa', 'loku', 'unge', 'weradi'],
#  ['mun', 'wage', 'kalakanni', 'innakan', 'ratawal', 'diunukarana', 'be'],
#  ['මුන්', 'ඔක්කොම', 'රට', 'කනවා', 'අනේ', 'අපේ', 'බදු', 'ගන්න', 'සල්ලි'],
#  ['ඒත්',
#   'උඹ',
#   'අර',
#   'හොටු',
#   'පෙරං',
#   'අඬන',
#   'හෙලු',
#   'කෙල්ලොංගෙ',
#   'videosui',
#   'අනික්',
#   'ලබ්බවල්',
#   'වලට',
#   'වඩා',
#   'මේ',
#   'කරපු',
#   'වැඩේනම්',
#   'great',
#   'බං'],
#  ['api',
#   'thathala',
#   'nathuwa',
#   'duk',
#   'wenwa',
#   'me',
#   'kalaknni',
#   'thaththala',
#   'idala',
#   'salakanne'],
#  ['මොනතරම්',
#   'ගින්දරක්',
#   'පපු',
#   'ඇතුලේ',
#   'පත්තු',
#   'වෙනවා',
#   'අැද්ද',
#   'තාත්තා',
#   'මේ',
#   'අත්',
#   'පා',
#   'උස්මහත්',
#   'කරපු',
#   'තාත්තා',
#   'දෙයියනේ',
#   'ශාප',
#   'වෙයි',
#   'උඹලට',
#   'මේ',
#   'ආත්මෙම'],
#  ['thopi', 'wage', 'lamainta', 'me', 'athmedi', 'hena', 'wadina', 'ona'],
#  ['උගෙ',
#   'අප්පගෙ',
#   'නීතියක්නෙ',
#   'යකො',
#   'එක',
#   'අර',
#   'රංගෙ',
#   'බන්ඩාරගෙ',
#   'පුතා',
#   '3',
#   'පාරක්',
#   'වාහනෙ',
#   'හප්පලා',
#   'එක',
#   'මිනිහෙක්',
#   'මරලා',
#   'පවුලක්',
#   'අබ්බගාතයො',
#   'කරා',
#   'කො',
#   'නිතිය',
#   'මෙපාර',
#   'ගෙයක්',
#   'කුඩු',
#   'කරලා',
#   'හොදටම',
#   'බීලා',
#   'වාහනෙ',
#   'ඇතුලෙ',
#   'කඩු',
#   'පොලු',
#   'තියෙද්දිත්',
#   'කොහොමද',
#   'යකො',
#   'ඌට',
#   'ඇප',
#   'දෙන්නෙ'],
#  ['ngo',
#   'වලින්ද',
#   'එතකොට',
#   'ලංකාවෙ',
#   'නිතිය',
#   'ක්රියාත්මක',
#   'කරන්නෙ',
#   'නොදකිං',
#   'කලකිරෙනවා',
#   'මෙවා',
#   'දැක්කම',
#   'මොනද',
#   'මෙ',
#   'අපෙ',
#   'රටට',
#   'වෙන්නෙ'],
#  ['henama',
#   'gahapiya',
#   'okita',
#   'ngo',
#   'karayanta',
#   'puka',
#   'dipan',
#   'thawath',
#   'wesi',
#   'tho',
#   'marunu',
#   'data',
#   'pansukule',
#   'denneth',
#   'අපේ',
#   'හාමුදුරුවෝ',
#   'mthaka',
#   'thiya',
#   'ganin',
#   'thota',
#   'sapa',
#   'wenawa',
#   'shinhalaya',
#   'gana',
#   'ktha',
#   'krapu',
#   'අපේ',
#   'හාමුදුරුවන්ට',
#   'මෙහෙම',
#   'කරාට'],
#  ['mewata',
#   'katha',
#   'karanna',
#   'wachana',
#   'ne',
#   'hithe',
#   'wairaya',
#   'athi',
#   'karanawata',
#   'wada',
#   'wadath',
#   'hidama',
#   'de',
#   'munta',
#   'swabadahama',
#   'thulin',
#   'lebena',
#   'දඬුවම',
#   'diha',
#   'nihathamaniwa',
#   'balasitimai',
#   'sandya',
#   'kiyana',
#   'wesa',
#   'genita',
#   'hidata',
#   'ninda',
#   'yanawa',
#   'athi',
#   'den'],
#  ['gon',
#   'genita',
#   'saapa',
#   'වේවා',
#   'me',
#   'athmedima',
#   'palisan',
#   'දේවා',
#   'හාමුදුරුවෝ',
#   'namak',
#   'hireta',
#   'yeuwata'],
#  ['hamudurowo',
#   'kiwe',
#   'aththak',
#   'ube',
#   'miniha',
#   'kotiyek',
#   'ltte',
#   'eken',
#   'salli',
#   'gaththa',
#   'oththu',
#   'karayek',
#   'apith',
#   '2020',
#   'passe',
#   'me',
#   'kalakanni',
#   'anduwa',
#   'gedara',
#   'yawala',
#   'sahimakata',
#   'path',
#   'wenawa'],
#  ['oyage',
#   'thawakalika',
#   'sathuta',
#   'uparima',
#   'winda',
#   'ganna',
#   'okata',
#   'windawanna',
#   'weddi',
#   'daraganna',
#   'bari',
#   'wei'],
#  ['ගොං', 'හුත්තී', 'හැමිනියන්', 'වෙසී', 'තොට', 'සාප', 'වේනවා', 'බැල්ලීයේ'],
#  ['කියන්න',
#   'දුකයි',
#   'අපෙ',
#   'රටේ',
#   'ලොකු',
#   'තැන්වල',
#   'උන්',
#   'පිරිහිලා',
#   'ඉවරයි',
#   'බලයට',
#   'ධනයට',
#   'ආගම',
#   'ජාතිය',
#   'විකුණනවා',
#   'උන්',
#   'දන්නෙ',
#   'නැ',
#   'උන්ට',
#   'වෙන්නේ',
#   'මොකක්ද',
#   'කියල',
#   'මෙවට',
#   'වගකිවයුතු',
#   'වන්නේ',
#   'ඉහළ',
#   'පෙලෙ',
#   'ඉන්න',
#   'උන්',
#   'අපෙ',
#   'ආගම',
#   'ජාතිය',
#   'විනාස',
#   'කරන',
#   'සක්කිලින්ට',
#   'කන්න',
#   'ගූත්',
#   'නැතිවෙනව',
#   'කාලකන්නි'],
#  ['මේ',
#   'බැල්ලි',
#   'කොටින්ගේ',
#   'ගු',
#   'කනකොට',
#   'අපහසුවක්',
#   'දැනුනෙ',
#   'නැද්ද',
#   'දන්',
#   'නැහැ',
#   'ඔකිට',
#   'මිනිහා',
#   'මැරුනම',
#   'දැනුන',
#   'දුකට',
#   'වඩා',
#   'දහස්',
#   'ගුනයක',
#   'දුකක්',
#   'දැනෙනවා',
#   'ඉස්සරහට',
#   'උපසම්පදාව',
#   'තියන',
#   'භික්සුවක්',
#   'හිරේ',
#   'යැවුවට',
#   'ඔකි',
#   'වැඩියෙන්ම',
#   'ආදරේ',
#   'කෙනෙක්',
#   'ඔකිට',
#   'නැති',
#   'වෙනවා',
#   'වැඩි',
#   'කල්',
#   'නොගිහින්'],
#  ['cari',
#   'wesi',
#   'me',
#   'cari',
#   'wesige',
#   'puke',
#   'arinna',
#   'one',
#   'miriskudu',
#   'daala',
#   'balu',
#   'wesita',
#   'katu',
#   'kohila',
#   'alayak',
#   'bessuwanam',
#   'kakul',
#   '2ka',
#   'depeththata',
#   'karala',
#   'huththa',
#   'athulata',
#   'me',
#   'huththita',
#   'mita',
#   'wada',
#   'sathutak',
#   'lebei'],
#  ['අපේ',
#   'හමුදාව',
#   'බර',
#   'අවි',
#   'කෙමිකල්',
#   'මිසයිල',
#   'පාවිච්චි',
#   'කරලා',
#   'සමූලඝාතන',
#   'සිදුකලා',
#   'කියලා',
#   'මේ',
#   'හුත්තිගෙ',
#   'මිනිහා',
#   'කිව්වා',
#   'ඒකම',
#   'මේ',
#   'හුත්තිත්',
#   'කියනවා',
#   'එහෙම',
#   'එකේ',
#   'මේ',
#   'කැරි',
#   'වේසිට',
#   'දඩුවම්',
#   'දෙන්නෙ',
#   'එකෙක්',
#   'නැද්ද',
#   'මේ',
#   'බල්ලන්ට',
#   'අල්ලන',
#   'කැරි',
#   'වේසි',
#   'හමගහන්න',
#   'ඕනි',
#   'පනපිටින්'],
#  ['tho',
#   'ganu',
#   'jatiyatama',
#   'nindawak',
#   'lake',
#   'wadi',
#   'dawasak',
#   'yamaha',
#   'thota',
#   'sapa',
#   'wenawamai'],
#  ['මෙිි',
#   'හුත්තිට',
#   'සතුටුයිලු',
#   'අපේ',
#   'රටහරක්ටිකටත්',
#   'සතුටුඇති',
#   'අපේ',
#   'හාමුදුරැන්\u2063ට',
#   'දුන්න',
#   'දඩුවමට',
#   'දුකයි',
#   'ඊටත්වැඩිය',
#   'මරාගන',
#   'මැරෙන්න',
#   'හිතෙන්නෙ',
#   'අපෙහාමුදුරැවන්ට',
#   'ජමිිබරේ',
#   'අන්දපුඑකට',
#   'යකෝ'],
#  ['සංඝා',
#   'වහන්සේ',
#   'නමකට',
#   'විශේෂයෙන්',
#   'බුද්ධ',
#   'චිවරයට',
#   'අගෞරව',
#   'කල',
#   'පාපයට',
#   'නුඹට',
#   'මතු',
#   'මතුත්',
#   'සාප',
#   'වෙිවා'],
#  ['meki',
#   'lankawe',
#   'janadi',
#   'pathinitakda',
#   'budu',
#   'dahama',
#   'winasa',
#   'karana',
#   'hethiriyak',
#   'ne'],
#  ['podi',
#   'daruwo',
#   'dusanaya',
#   'karala',
#   'maranawa',
#   'ewata',
#   'mokuth',
#   'na',
#   'ane',
#   'pau',
#   'apahasa',
#   'neme',
#   'karanna',
#   'thibbe',
#   'kumarihamita',
#   'bella',
#   'mirikala',
#   'maranna'],
#  ['tigae',
#   'miha',
#   'marapuuna',
#   'hiyanna',
#   'amruwak',
#   'na',
#   'katin',
#   'kiyapu',
#   'wacanata',
#   'uda',
#   'painawa',
#   'ubda',
#   'kada',
#   'hari',
#   'dittadamna',
#   'wadaniya',
#   'karumae',
#   'padisan',
#   'danawamai',
#   'budu',
#   'ciwarayanata',
#   'nigaru',
#   'kirimata'],
#  ['oita',
#   'wada',
#   'hinsa',
#   'appa',
#   'rata',
#   'wanawa',
#   'podi',
#   'daruwo',
#   'antha',
#   'karanawa',
#   'apra',
#   'karayo',
#   'koha',
#   'baluwah',
#   'ma',
#   'gani',
#   'matharamma',
#   'sundara',
#   'wasthuwakda',
#   'balla',
#   'giya',
#   'ratak',
#   'apa',
#   'buddha',
#   'cjiwaraya',
#   'gana',
#   'harima',
#   'dukai'],
#  ['to',
#   'wage',
#   'balu',
#   'wesiyek',
#   'wadapu',
#   'toge',
#   'ammage',
#   'to',
#   'wadapu',
#   'tenatath',
#   'henagahannaona'],
#  ['kanthawakata',
#   'hirihara',
#   'kireema',
#   'waradei',
#   'habai',
#   'me',
#   'wage',
#   'kotiyekuge',
#   'geniyekuta',
#   'banna',
#   'newei',
#   'maruwath',
#   'pau',
#   'na'],
#  ['ape',
#   'ratata',
#   'mokadda',
#   'me',
#   'wenne',
#   'mun',
#   'alawanna',
#   'hadamu',
#   'mahindata',
#   'rata',
#   'barademu',
#   'okkoma',
#   'akathuwemu',
#   'me',
#   'sinhalayage',
#   'rata'],
#  ['කැරි', 'වේසි', 'හෙනගහපිය'],
#  ['thambiyelta', 'kiyala', 'hukaganna', 'kiyahan', 'keri', 'wesita'],
#  ['මේ', 'වගේ', 'ගැනු', 'මේ', 'රටේන්', 'එලවන්න', 'ඔන', 'නොදකින්', 'ශාපවේවා'],
#  ['okege', 'sathuta', 'as', 'panapitama', 'padesan', 'denna', 'one'],
#  ['අපේ', 'අමන', 'පාලකයොන්ගේ', 'වැරදි'],
#  ['ගොන්', 'වේසී', 'මිනිහා', 'ගිය', 'තැනටම', 'යන්න', 'දගලනවා', 'වගේ'],
#  ['පල',
#   'වේසියෙ',
#   'යන්න',
#   'මේ',
#   'ලෝකෙන්ම',
#   'තොලොන්චි',
#   'වෙලා',
#   'හැප්පිය',
#   'වාහනේකට',
#   'මැරෙන්නම',
#   'බැල්ලිව'],
#  ['මුස්ලිම්',
#   'රටක',
#   'ආගමික',
#   'නායකයකු',
#   'මෙ',
#   'දෙ',
#   'කලානම්',
#   'රාජ්\u200dය',
#   'ගෙෘරව',
#   'ජනතාවට',
#   'දෙවියෝ'],
#  ['හෙන', 'හත', 'ගහපන්'],
#  ['මේ',
#   'කල',
#   'දේට',
#   'තෝනමි',
#   'විඳවලා',
#   'මැරෙන්න',
#   'ඕන',
#   'තොට',
#   'හෙන',
#   'හතම',
#   'වැදියන්'],
#  ['patta',
#   'wesi',
#   'tota',
#   'henama',
#   'gahapan',
#   'totai',
#   'toge',
#   'anduwatai',
#   'lagadima',
#   'redi',
#   'netuwa',
#   'pare',
#   'duwanna',
#   'wei',
#   'edata',
#   'toge',
#   'hinsanayata',
#   'api',
#   'gal',
#   'gahanawa'],
#  ['හෙන', 'ගහනවා', 'කැරි', 'වෙසිට'],
#  ['අපරාද', 'කාරයෝ', 'රට', 'පාවලා', 'දෙන', 'උන්', 'රකින', 'සක්කිලි', 'ආන්ඩුව'],
#  ['සාප', 'වේවා', 'තිට', 'හෙන', 'හතම', 'වැදියන්'],
#  ['tho', 'sathutu', 'unaawagema', 'duk', 'wendath', 'wenawa'],
#  ['hotai',
#   'thindu',
#   'karapu',
#   'ekatai',
#   'me',
#   'rajayatai',
#   'henama',
#   'gahapiya'],
#  ['kotinge',
#   'ata',
#   'deka',
#   'suppu',
#   'karapan',
#   'gihin',
#   'cari',
#   'wesi',
#   'me',
#   'wesitanm',
#   'hodak',
#   'sidda',
#   'wenne',
#   'nehe',
#   'hena',
#   'gahapan'],
#  ['පට්ට', 'බැල්ලි', 'බල්ලො', 'දම්මලා', 'හුකන්න', 'ඉනී'],
#  ['huththa', 'lokuda', 'danne', 'neeee'],
#  ['usawiyeth', 'desapalana', 'theendu'],
#  ['balu', 'huttita', 'hana', 'hatama', 'gahapiya'],
#  ['hitan',
#   'magenguti',
#   'kanna',
#   'nethiwa',
#   'oya',
#   'unansewa',
#   'nidahas',
#   'karapan',
#   'hodaekaawage'],
#  ['ජම්පරේ', 'ගස්සන්ඩ', 'ඕනී', 'ආයේ', 'චීවරේ', 'නොදාන්නම'],
#  ['karumeta', 'gahala', 'akalata', 'haduna', 'wesiyo'],
#  ['ltte',
#   'එකට',
#   'කඩේ',
#   'යන',
#   'ngo',
#   'සල්ලි',
#   'වලට',
#   'රට',
#   'පාවා',
#   'දෙන',
#   'හැත්ත'],
#  ['මෙි', 'ගැනිට', 'සාප', 'වෙිවා'],
#  ['hora', 'ganayonta', 'kade', 'yana', 'gonnu', 'inna', 'ratak', 'meka'],
#  ['me', 'genige', 'geta', 'gal', 'gahanna', 'lasthiweyalla'],
#  ['පනපිටින්', 'අපායෙ', 'පල', 'කොටිදෙන'],
#  ['puka',
#   'diyan',
#   'noel',
#   'mona',
#   'paiye',
#   'sinduda',
#   'hutto',
#   'me',
#   'සමාජෙට',
#   'හොද',
#   'දෙයක්',
#   'කරපන්'],
#  ['mun', 'rata', 'winasa', 'karalla', 'ewarayi'],
#  ['ponna', 'wasi'],
#  ['aknali', 'goda', 'maruna', 'aka', 'gana', 'api', 'sathutu', 'wenawa'],
#  ['කොටි', 'දෙනක්'],
#  ['wesa',
#   'genita',
#   'hena',
#   'gahapiya',
#   'rate',
#   'nayakaya',
#   'ponnayek',
#   'unama',
#   'ohoma',
#   'tamai'],
#  ['හම්පඩ', 'පඩංගු', 'දෙමළු', 'වේසාවි'],
#  ['ako',
#   'ratama',
#   'ltte',
#   'eke',
#   'salli',
#   'walata',
#   'wikka',
#   'munta',
#   'ira',
#   'hada',
#   'payanawaneeee'],
#  ['nadukarayage',
#   'mulu',
#   'engema',
#   'gedidapn',
#   'okage',
#   'paaulama',
#   'hedigeviyan'],
#  ['koti', 'gani', 'shapa', 'wewa', 'ubata'],
#  ['එහෙමද', 'ආස', 'කැරී', 'wecii'],
#  ['makabawilama', 'pala', 'paduru', 'wesi'],
#  ['බලු',
#   'වෙසි',
#   'තොගෙ',
#   'අම්මා',
#   'බල්ලොත්',
#   'ලැගලා',
#   'තොව',
#   'ජාතක',
#   'කරලා',
#   'තියෙන්නේ'],
#  ['meeka', 'pada', 'show', 'ekak'],
#  ['thota', 'hena', 'gahapan', 'thoge', 'balu', 'patawuntath', 'balu', 'weesi'],
#  ['henama', 'gahapiya', 'wesa', 'ballita'],
#  ['tope', 'anduwa', 'tiyana', 'an', 'hodai'],
#  ['mekita', 'dan', 'miniha', 'nathuwa', 'aduwak', 'wena', 'ekak', 'ne'],
#  ['sathutu', 'nam', 'puka', 'deepan', 'wesa', 'baduwa'],
#  ['me', 'genige', 'jathae', 'kalwam', 'ekak'],
#  ['yadamin',
#   'benda',
#   'vilangu',
#   'la',
#   'mage',
#   'putha',
#   'regena',
#   'yanna',
#   'idikatu',
#   'weni',
#   'engili',
#   'thala',
#   'dethis',
#   'wadaya',
#   'pamunuwanna',
#   'aluth',
#   'lowak',
#   'gena',
#   'sithima',
#   'danduwam',
#   'dena',
#   'warada',
#   'nam',
#   'kumata',
#   'erata',
#   'adhikaranaya',
#   'neethiya',
#   'saha',
#   'vinisuran'],
#  ['bona',
#   'unta',
#   'bus',
#   'eke',
#   'megala',
#   'gihin',
#   'bol',
#   'gahanna',
#   'thamai',
#   'tiyenne'],
#  ['තෙවරප්පෙරැමට', 'අහුඋනොත්', 'ඔක්කොම', 'ගුටි', 'කනවා', 'යකෝ'],
#  ['ලංකාවෙි',
#   'මිනිස්සුන්ට',
#   'මොනතරමි',
#   'හොද',
#   'කලත්',
#   'වැඩක්',
#   'නැ',
#   'ඒ',
#   'අයගේ',
#   'ආකල්ප',
#   'වෙනස්කරන්න',
#   'බැ',
#   'මෙි',
#   'කමෙන්ටි',
#   'වලින්',
#   'ඒදේ',
#   'වැටහෙනවා',
#   'මහා',
#   'මෝඩ',
#   'මිනිස්සු',
#   'බහුතරයක්'],
#  ['ponnayo',
#   'danne',
#   'kellek',
#   'aduwa',
#   'gaman',
#   'laga',
#   'inna',
#   'kollekta',
#   'allan',
#   'gahanna',
#   'witharai'],
#  ['ape', 'harak', 'samjeta', 'eka', 'honda', 'adrshyak'],
#  ['පොලීසිය', 'ගොං', 'ආතල්', 'දෙනවා', 'පූජිතයෝ', 'උබට', 'තියෙන', 'වැඩ', 'මේවද'],
#  ['tpita', 'pisuda', 'yako', 'man', 'htuwe', 'atta', 'kiyala', 'aiyo'],
#  ['kimbak', 'eduwoth', 'ape', 'untath', 'amma', 'thaththawath', 'penne', 'n'],
#  ['lisan',
#   'nathawa',
#   'yanna',
#   'puluwan',
#   'yako',
#   'api',
#   'dannawa',
#   'oka',
#   'veede',
#   'nattiyak',
#   'kiyala'],
#  ['මේ',
#   'යුද්ධයේ',
#   'සැබෑම',
#   'අවසානය',
#   'වෙන්න',
#   'ඕන',
#   'මේකයි',
#   'දැන්වත්',
#   'කඩප්පුලි',
#   'විග්නේෂ්වරන්',
#   'සිවාජිලිංගම්',
#   'සම්බන්ධන්',
#   'සුමන්තිරන්',
#   'වැනි',
#   'කාළක්නි',
#   'දේශපාලකයින්',
#   'දේශපාලනයෙන්',
#   'අතුගා',
#   'දැමිය',
#   'යුතුයි'],
#  ['මෙතන',
#   'දී',
#   'අර',
#   'පාර්ලිමේන්තුවේ',
#   'ඉන්න',
#   'කක්කූසි',
#   'කටා',
#   'නොහොත්',
#   'දත්',
#   'දොස්තර',
#   'කාල',
#   'කන්නි',
#   'රාජිතයා',
#   'මතක්',
#   'වෙනකොට',
#   'මගේ',
#   'මාළු',
#   'නටනවා'],
#  ['කෝ',
#   'අපේ',
#   'නානසාර',
#   'ස්වාමීන්',
#   'වහන්සේ',
#   'ඒ',
#   'හිමියනට',
#   'පුළුවන්',
#   'මේ',
#   'වගේ',
#   'සෙබළුන්ගෙන්',
#   'ආදර්ශ',
#   'එහෙම',
#   'ලබාගන්න',
#   'බුදුන්ගෙන්',
#   'ආදර්ශ',
#   'ලබාගත්තේ',
#   'නැතිකොට',
#   'ඉතින්',
#   'මොකෙක්ගෙන්වත්',
#   'ආදර්ශ',
#   'ගනීද'],
#  ['samanya',
#   'minasata',
#   'danena',
#   'de',
#   'me',
#   'kalakanni',
#   'desapalakayanta',
#   'penne',
#   'nathi',
#   'eka',
#   'thama',
#   'karume'],
#  ['ලංකාවේ', 'තම', 'හරක්', 'ඉන්න', 'නිසා', 'ඕවා', 'හොඳට', 'පිළිගන්නවා'],
#  ['අපේ',
#   'හරකුන්ට',
#   'ගහක්',
#   'හිටවන්න',
#   'ගියත්',
#   'කුඩයක්',
#   'අල්ලන්න',
#   'ඔනේ',
#   'බහින්න',
#   'වලකුත්',
#   'හාරලා',
#   'දෙන්න',
#   'ඔනේ',
#   'අපි',
#   'හරි',
#   'පවු',
#   'නේ'],
#  ['දැන්',
#   'ටික',
#   'කාලෙකට',
#   'කලින්',
#   'පාලත්',
#   'සභා',
#   'මන්ත්\u200dරී',
#   'ජුන්ඩේක්',
#   'පොලිස්',
#   'මහතෙක්',
#   'හැදුලුම්',
#   'පත',
#   'ඉල්ලූවා',
#   'කියලා',
#   'දාපු',
#   'ගෙම්බර්',
#   'මතක්',
#   'වුනා'],
#  ['shampoo',
#   'එකක්',
#   'promote',
#   'කරන්න',
#   'දාපු',
#   'ලස්සන',
#   'මුට්ටියක්',
#   'කියලයි',
#   'මටනම්',
#   'හිතෙන්නෙ',
#   'බලපං',
#   'නැද්ද',
#   'කියලා',
#   'තා',
#   'ටික',
#   'දවසකින්'],
#  ['අම්මෝ', 'ඒක', 'හොදයි', 'ඒත්', 'දාගෙන', 'යන්නේ', 'පාරෙ', 'නේද'],
#  ['dakune', 'shampoo', 'nadda'],
#  ['මූ', 'ජයරත්නගෙ', 'නෑදෑයෙක්ද', 'කොහෙද'],
#  ['වැස්සොත්', 'ශොට්', 'වෙල', 'මැරෙන්නෙ'],
#  ['muladi',
#   'hinawey',
#   'digatama',
#   'karoth',
#   'devole',
#   'karala',
#   'hoda',
#   'idea',
#   'ekak'],
#  ['hadannanam',
#   'puluvan',
#   'eth',
#   'oka',
#   'reddak',
#   'adan',
#   'dagena',
#   'yanne',
#   'kohomai',
#   'ape',
#   'handuruvane'],
#  ['police', 'yen', 'navatthana', 'ekkak', 'na'],
#  ['mathakane',
#   'kalayak',
#   'ape',
#   'un',
#   'fite',
#   'fan',
#   'ellan',
#   'gihin',
#   'rexona',
#   'market',
#   'kala'],
#  ['pahadili', 'madi', 'visthara', 'karapu', 'hati'],
#  ['me', 'mokkakda', 'bn', 'eka', 'dapuwahama', 'mahasona', 'wagene'],
#  ['ඇඩ්',
#   'නම්',
#   'ඇඩ්',
#   'ලංකාව',
#   'දියුනු',
#   'නෑ',
#   'කියන',
#   'වුන්',
#   'ට',
#   'කනට',
#   'ගහලා',
#   'මෙක',
#   'පෙන්නපල්ලා'],
#  ['ela', 'ela', 'thawa', 'thawath', 'mede', 'wadidinu', 'karanna'],
#  ['game', 'gahapan', 'aiya', 'api', 'gannaw'],
#  ['මේක', 'දියුණුවක්', 'කියලා', 'හිතනවා', 'නම්', 'උබට', 'වැරදිලා', 'සහෝදරයා'],
#  ['ගෙදරට', 'වෙලා', 'පාඩම්', 'කරපල්ලකෝ', 'පැය', 'ගනන්', 'පෝලීමේ', 'ඉන්නේ'],
#  ['lankawen',
#   'desapalakayo',
#   'tikak',
#   'yawala',
#   'balamu',
#   'poster',
#   'gahana',
#   'widihata',
#   'thama',
#   'ita',
#   'passe'],
#  ['මෙච්චර',
#   'අමාරුවෙන්',
#   'පුටුවක්',
#   'අල්ලගන්න',
#   'ඕනිද',
#   'ගහක්',
#   'යට',
#   'වාඩිවෙලා',
#   'පාඩම්',
#   'කරන්න',
#   'පුළුවන්'],
#  ['comments',
#   'බලන්න',
#   'ආපු',
#   'අය',
#   'මෙතනින්',
#   'පොඩි',
#   'like',
#   'එකක්',
#   'ඕනේ',
#   'bro'],
#  ['විඩීයෝ', 'එක', 'අප්සට්', 'පේන්නේ', 'නෑ', 'හරියට'],
#  ['paadam',
#   'karanawa',
#   'kese',
#   'wethath',
#   'putuwak',
#   'nan',
#   'aniwa',
#   'allagannawa',
#   'mama',
#   'puluwannan',
#   'putu',
#   'tikak',
#   'allala',
#   'business',
#   'line',
#   'ekakuth',
#   'gahagannawa',
#   'shape',
#   'eke'],
#  ['යක්කුන්ට', 'ලජ්ජා', 'කරන්න', 'එපා', 'මුන්ට', 'සමානකරලා'],
#  ['ඒකෙන්',
#   'මේකෙන්',
#   'උනේ',
#   'ගීතට',
#   'නමටහරි',
#   'හිටිය',
#   'මිනිහ',
#   'නැතිවුන',
#   'එක',
#   'විතරයි'],
#  ['මුන්',
#   'ගෙන්',
#   'ඇති',
#   'වැඩක්',
#   'නැ',
#   'තමයි',
#   'ඒ',
#   'උනාට',
#   'ඉඩල',
#   'හිටලා',
#   'වැදගත්',
#   'දෙවලුත්',
#   'නොකියන',
#   'වම',
#   'නෙවෙයි'],
#  ['e', 'karpu', 'kathwa', 'nm', 'wedagth', 'm', 'kiuwath', 'oyala'],
#  ['oshadhi', 'adui', 'hama', 'gahapu', 'issek', 'wage'],
#  ['බයිසන්ලට', 'ඉතින්', 'සුරංගනාවියන්', 'තමයි'],
#  ['මීට', 'කලින්', 'දැකලැ', 'නැ'],
#  ['මටනම්', 'හිතෙන්නේ', 'මේ', 'මිනිහා', 'තමයි', 'ඇත්ත', 'ඩයල්', 'එක', 'කියලා'],
#  ['දුප්පත්',
#   'මිනිසුන්',
#   'සියගනනකට',
#   'පැල්පතක්',
#   'තනාදෙන්න',
#   'තීබු',
#   'අපුරුව',
#   'නේද'],
#  ['oka', 'light', 'bala', 'bala', 'cheeneta', 'naya', 'gewamu'],
#  ['පිහි',
#   'ඇනුම්',
#   'ගුටි',
#   'කෙලි',
#   'ඇතුලු',
#   'විනෝද',
#   'ක්\u200dරීඩා',
#   'රැසකුත්',
#   'ඇති',
#   'නෙහ්'],
#  ['කෑමකඩත්',
#   'තියෙනවද',
#   'tomorrowland',
#   'වගේද',
#   'festival',
#   'එක',
#   'තව',
#   'hardwell',
#   'mashmellow',
#   'එනවද',
#   'edm',
#   'කරන්න'],
#  ['මෙක',
#   'ගෑන',
#   'දන්න',
#   'එකෙක්',
#   'කියපන්',
#   'හරියටම',
#   'දන්න',
#   'එකෙක්',
#   'කන්ටැක්',
#   'කර',
#   'ගන්න',
#   'ඔනී'],
#  ['ඊළඟට',
#   'මේවල',
#   'සාමාන්\u200dය',
#   'මිනිස්සුන්ට',
#   'යන්න',
#   'බැරි',
#   'වෙන',
#   'විදිහට',
#   'ගණන්',
#   'වැඩි',
#   'විශේෂ',
#   'ටිකට්',
#   'එකක්',
#   'නිකුත්',
#   'කරන්න',
#   'ඕනේ'],
#  ['දවස',
#   'අන්තිමේ',
#   'යාඩ්',
#   'එකට',
#   'ගෙනල්ලා',
#   'නැවැත්තුවාම',
#   'එතන',
#   'ආරක්ෂාවත්',
#   'වැඩි',
#   'කරන්න',
#   'වෙනවා',
#   'රෑට',
#   'ෆෑන්',
#   'පන්නන',
#   'අයත්',
#   'ඉන්න',
#   'පුළුවන්',
#   'නේ'],
#  ['තව',
#   'මේවා',
#   'ඇතුල',
#   'සතියකට',
#   'දෙසැරයක්',
#   'වත්',
#   'පිරිසිදු',
#   'කරන්න',
#   'ඕනේ',
#   'විශේෂයෙන්ම',
#   'ටොයිලට්',
#   'තව',
#   'පිටත',
#   'මසෙට',
#   'දෙසැරයක්',
#   'වත්',
#   'ක්ලීන්',
#   'කරන්න',
#   'ඕනේ',
#   'එහෙම',
#   'කලොත්',
#   'ඔන්න',
#   'අවුරුදු',
#   '5ක්',
#   'වත්',
#   'ලස්සනට',
#   'තියාගතහැකි'],
#  ['ලංකාවට',
#   'ඕව',
#   'හරියන්නෙ',
#   'නෑ',
#   'බන්',
#   'අපි',
#   'සුපෝකබෝගී',
#   'දේවල්',
#   'විදින්න',
#   'කලින්',
#   'අපේ',
#   'මනස',
#   'හුරුකරගන්න',
#   'ඕන',
#   'අනිත්',
#   'උන්ටත්',
#   'ඒක',
#   'විදින්න',
#   'ඉතුරුකරල',
#   'යන්න',
#   'අපි',
#   'සිංහලනෙ',
#   'සිංහයන්ගෙන්ලුනෙ',
#   'පැවතගෙන',
#   'එන්නෙ',
#   'අපිට',
#   'බෑ',
#   'ප්\u200dරෙන්',
#   'අපිට',
#   'වනන්තර',
#   'වගේ',
#   'ඒව',
#   'ගෙනත්',
#   'දෙන්න',
#   'ඒවනම්',
#   'හරි',
#   'යනව',
#   'මම',
#   'දැකල',
#   'තියනවනෙ',
#   'අලුතින්ම',
#   'ගෙනාපු',
#   'කෝච්චි',
#   'වලට',
#   'අපේ',
#   'ඔපිස්',
#   'යන',
#   'සෙට්',
#   'ට්\u200dරිප්',
#   'යන',
#   'සෙට්',
#   'සිගිති',
#   'පාතාල',
#   'කාරයො',
#   'කරන',
#   'වැඩ',
#   'බොකක්',
#   'ලෝඩ්වෙලා',
#   'කෝච්චියෙ',
#   'ටොයිලට්',
#   'එකට',
#   'ගියොත්',
#   'පුදුම',
#   'හාස්කමක්',
#   'වෙන්නෙ',
#   'බොක',
#   'නැතිවෙනව',
#   'එක්කෝ',
#   'බොක',
#   'කටින්',
#   'යන්න',
#   'එනව'],
#  ['ඒකටනම්',
#   'දුම්\u200dරිය',
#   'දෙපාර්තුමේන්තුවත්',
#   'වගකියන්න',
#   'ඕන',
#   'කෝච්චිය',
#   'රෑ',
#   'අවසාන',
#   'ට්\u200dරිප්',
#   'එක',
#   'ගිහින්',
#   'ආවහම',
#   'කිසිම',
#   'නඩත්තුවක්',
#   'නැතුව',
#   'ආපහු',
#   'පහුවදා',
#   'උදේට',
#   'එන්ජිම',
#   'අනිත්',
#   'පැත්තට',
#   'අමුනල',
#   'ඇදගෙන',
#   'එනව',
#   'වගේ',
#   'මටනම්',
#   'පේන්නෙ',
#   'ඒකට',
#   'වරදක්',
#   'කියන්නත්',
#   'බෑ',
#   'බං',
#   'හරියට',
#   'maintenance',
#   'කරන්න',
#   'හරියට',
#   'සේවකයො',
#   'ගන්න',
#   'ඕන',
#   'උන්ට',
#   'පඩියක්',
#   'ගෙවන්න',
#   'ඕන',
#   'ඒව',
#   'කොරන්න',
#   'කොහෙඩ',
#   'රටට',
#   'සල්ලි',
#   'රටින්',
#   'ගන්න',
#   'ණය',
#   'අදාර',
#   'ඔක්කොම',
#   'ගිහිනුත්',
#   'මදි',
#   'පාර්ලිමේන්තුව',
#   'නඩත්තු',
#   'කරන්න',
#   'මට',
#   'තේරෙන්නෙ',
#   'නෑ',
#   'කතා',
#   'කරල',
#   'වැඩක්',
#   'නෑ',
#   'මේ',
#   'කෝච්චියෙ',
#   'යන්න',
#   'ටයි',
#   'කරන්න',
#   'එපා',
#   'ප්\u200dරෙන්',
#   'තෙප්පමක්',
#   'හදාගෙන',
#   'හරි',
#   'කමක්',
#   'නෑ',
#   'ජීවත්',
#   'වෙන්න',
#   'පුලුවන්',
#   'රටකට',
#   'පලයල්ල'],
#  ['මේ',
#   'comment',
#   'වල',
#   'තියෙන',
#   'අදහස්',
#   'facebook',
#   'එක',
#   'ඇතුලේම',
#   'පල්',
#   'නොකර',
#   'ස්ටේෂන්',
#   'වලයි',
#   'දුම්රිය',
#   'මැදිරි',
#   'ඇතුලෙයි',
#   'මිනිස්සුන්ට',
#   'දැනෙන',
#   'විදිහට',
#   'display',
#   'කළා',
#   'නම්',
#   'භාෂා',
#   '3න්ම',
#   'පින්තූරත්',
#   'එක්ක',
#   'පොඩි',
#   'වෙනසක්',
#   'හරි',
#   'දකින්න',
#   'පුළුවන්'],
#  ['ඔය',
#   'පොටෝ',
#   'ටිකම',
#   'තව',
#   'මාසයකින්',
#   'අරන්',
#   'බලන්න',
#   'සීට්',
#   'ටිකයි',
#   'එන්ජිමයි',
#   'විතරයි',
#   'ඉතුරු',
#   'අනිත්',
#   'ඔක්කොම',
#   'ගලවනවා',
#   'සත්තයි',
#   'අපේ',
#   'එඋන්'],
#  ['සාමාන්\u200dය',
#   'මිනිස්සුන්ගෙන්',
#   'පරිස්සම්',
#   'කරගන්න',
#   'පුලුවන්',
#   'ඒත්',
#   'කෝච්චි',
#   'වල',
#   'යන',
#   'ඔෆිස්',
#   'සෙට්',
#   'එක',
#   'කියලා',
#   'අමුතුම',
#   'සත්තු',
#   'ජාතියක්',
#   'උන්',
#   'කන',
#   'දේ',
#   'එකෙම',
#   'දානවා',
#   'හොර',
#   'ගෑනු',
#   'එක්ක',
#   'එකතු',
#   'වෙලා',
#   'සීට්',
#   'හුරනවා',
#   'ගොඩක්ම',
#   'කෝච්චි',
#   'විනස',
#   'කරන්නේ',
#   'ඒ',
#   'අහිගුන්ටකයෝ'],
#  ['විනයක්',
#   'නැති',
#   'පිරහෙමින්',
#   'තිබෙන',
#   'ජාතිය',
#   'බදු',
#   'මුදල්',
#   'වලින්',
#   'ගන්නා',
#   'මේවා',
#   'කොපමන',
#   'කල්',
#   'රැකගනීවිද',
#   'මන්දා',
#   'මිනිසුනේ',
#   'පොදු',
#   'දේපල',
#   'රැකගනිව්',
#   'බලි',
#   'කුරුටු',
#   'ගා',
#   'අපවිත්\u200dර',
#   'නොකරව්'],
#  ['ෂීට්',
#   'කඩලා',
#   'ජරා',
#   'කරන',
#   'එකෙක්',
#   'දැක්කොත්',
#   'පොන්නයෝ',
#   'වගේ',
#   'බලන්',
#   'ඉන්නැතුව',
#   'අත',
#   'පුරෝල',
#   'කන',
#   'පැලෙන්න',
#   'ගහපන්',
#   'අනිත්',
#   'උන්ටත්',
#   'පෙන්න'],
#  ['මගිජනතාව',
#   'වගේම',
#   'දුමිරිය',
#   'දෙපාර්තමේන්තු',
#   'සේවකයන්',
#   'තුත්',
#   'මෙය',
#   'රැකගන්න',
#   'කටයුතු',
#   'කලයුතුයි',
#   'මොකද',
#   'ගමන්',
#   'වාරයක්',
#   'අවසන',
#   'මෙම',
#   'දුමිරිය',
#   'මැදිරි',
#   'ඉතා',
#   'හොදින්',
#   'පිරිසිදු',
#   'කර',
#   'අඩුපාඩු',
#   'සැකසිය',
#   'යුතුයිි',
#   'දැන්',
#   'බලන්න',
#   'රැහුනු',
#   'කුමාරි',
#   'ගාලුකුමාරි',
#   'ෆැන්',
#   'වැඩ',
#   'නැ',
#   'මකුනුදැල්',
#   'බැදිල',
#   'හුඩි',
#   'එක',
#   'දුවිලිවලින්',
#   'පිරිල',
#   'මෙව',
#   'රැකගන්න',
#   'දෙගොල්ල',
#   'ම',
#   'දායක',
#   'වියයුතුමයි'],
#  ['dubai',
#   'wala',
#   'thiyana',
#   'awaga',
#   'kama',
#   'kana',
#   'ak',
#   'thahanam',
#   'aduma',
#   'tharama',
#   'chuingam',
#   'wath',
#   'kanda',
#   'ba',
#   'aka',
#   'hama',
#   'thama',
#   'camara',
#   'thiyanawa',
#   'lagatama',
#   'avith',
#   'dada',
#   'gahanakn',
#   'danna',
#   'na',
#   'apa',
#   'minissu',
#   'wanas',
#   'karanda',
#   'amarui',
#   'akata',
#   'hodama',
#   'da',
#   'hariyata',
#   'nithi',
#   'hadanda',
#   'ona',
#   'owata',
#   'athokota',
#   'nikamma',
#   'purudu',
#   'wanawa'],
#  ['අපේ',
#   'එවුන්ට',
#   'ලියන්න',
#   'සිට්',
#   'ඉරන්න',
#   'කඩල',
#   'කන්න',
#   'බඩ',
#   'ඉරුගු',
#   'කන්න',
#   'එ',
#   'කාපු',
#   'එවා',
#   'එතන',
#   'ම',
#   'දලා',
#   'යන්න',
#   'ට්\u200dර්ප්',
#   'ගිහිල්ලා',
#   'බොක',
#   'කරලා',
#   'එන්න',
#   'ආපු',
#   'අලුත්',
#   'භාන්ඩේ',
#   'දැන්',
#   'කියන්න',
#   'එපා',
#   'අපො',
#   'ඉංදියන්',
#   'ජාරාව',
#   'කියලා',
#   'ඉස්සල්ලා',
#   'පුරුදු',
#   'වේයල්ලා',
#   'කඩල',
#   'ගොටු',
#   'කුනු',
#   'මල',
#   'ජාරාව',
#   'මානසික',
#   'ලෙඩ්ඩු',
#   'වගේ',
#   'ලියන',
#   'එවා',
#   'නවත්තන්න',
#   'පස්සේ',
#   'හොයපල්ලා',
#   'ඇද',
#   'කුද'],
#  ['ඔය',
#   'කොච්චිය',
#   'අගුලාන',
#   'කොරලවෙල්ල',
#   'මොරටුව',
#   'එ',
#   'දුම්රිය',
#   'ස්තාන',
#   'වල',
#   'නවත්තන්න',
#   'එපා',
#   'ඔය',
#   'කොච්චියේ',
#   'තියන',
#   'සෙප',
#   'පහසුකම්',
#   'ටික',
#   'මාසයක්',
#   'යනකොට',
#   'එ',
#   'පෙත්තේ',
#   'ගෙවල්',
#   'වල',
#   'තියෙයි'],
#  ['යන',
#   'එවුන්ටයි',
#   'මේ',
#   'කියන්නේ',
#   'මොන',
#   'තරම්',
#   'options',
#   'අවත්',
#   'කමක්',
#   'නෑ',
#   'එවගේ',
#   'ඒ',
#   'විදිහිට',
#   'ගිහින්',
#   'එක',
#   'පරිස්සමෙන්',
#   'පාවිච්චි',
#   'කරන්න',
#   'අපේ',
#   'දෙවල්',
#   'රැක',
#   'ගන්න'],
#  ['යකෝ',
#   'හැම',
#   'එකාම',
#   'කියන්නෙ',
#   'සතියෙන්',
#   'කයි',
#   'කියලා',
#   'බලන්',
#   'යද්දි',
#   'මෙව්වා',
#   'කන්ඩ',
#   'එකෙක්',
#   'නෑනෙ'],
#  ['usb',
#   'port',
#   'එකෙ',
#   'චුයින්ගම්',
#   'අලවාවි',
#   'වඩේ',
#   'කාල',
#   'කර්ටන්',
#   'එකේ',
#   'අත',
#   'පිහිදලා',
#   'කම්මැලිකමට',
#   'sheet',
#   'එක',
#   'කුශන්',
#   'කෑලි',
#   'කඩලා',
#   'tv',
#   'එක',
#   'කැඩුන',
#   'කියල',
#   'පොඩි',
#   'අව්ලක්',
#   'හදල',
#   'රෙපයාර්',
#   'කරන',
#   'එඋන්',
#   'ගෙදර',
#   'ගෙනියලා',
#   'fan',
#   'ගලවල',
#   'ටිකට්',
#   'කවුන්ටරෙට',
#   'සෙට්',
#   'කරලා',
#   'ටොයිලට්',
#   'ටික',
#   'වටේට',
#   'ජරා',
#   'කරලා',
#   'අර',
#   'ස්ටෙසමේ',
#   'නවත්තනකොටම',
#   'සුද්ද',
#   'කරන්න',
#   'නගින',
#   'සෙට්',
#   'එකක්',
#   'ඉන්නොනෙ',
#   'බූමිතෙල්',
#   'වැදිච්ච',
#   'ගැරඩි',
#   'වගේ',
#   'cleaners',
#   'ලා',
#   'උන්',
#   'තමයි',
#   'ඕකෙ',
#   'තීන',
#   'කුනු',
#   'පේන',
#   'ටික',
#   'අතුගාල',
#   'අනිත්ව',
#   'ශීටඅස්සට',
#   'තල්ලු',
#   'කරල',
#   'ලොකුම',
#   'සේවය',
#   'කරන්නෙ'],
#  ['ඕක',
#   'සතියයි',
#   'ඉවරයි',
#   'ගාගා',
#   'කමෙන්ට්',
#   'දාන්නේ',
#   'පිටරට',
#   'උන්',
#   'වෙන්නැති',
#   'දැන්'],
#  ['අපේ',
#   'මහින්ද',
#   'මහත්තයා',
#   'ඇවිත්',
#   'මාසයයි',
#   'කොහොමද',
#   'එයාගෙ',
#   'වැඩ',
#   'ටොයියොන්ට',
#   'ජෙප්පොන්ට',
#   'පේන්න',
#   'ලයික්',
#   'එකක්',
#   'දාන්න'],
#  ['මට',
#   'තියෙන',
#   'ප්\u200dරශ්නේ',
#   'අර',
#   'ටීවි',
#   'එක',
#   'අඩු',
#   'වැඩි',
#   'කරන',
#   'සුවිච්',
#   'එකෙන්',
#   'අපේ',
#   'උන්',
#   'ආතල්',
#   'ගනීද',
#   'කියලා'],
#  ['mewa',
#   'thiyana',
#   'widiyata',
#   'keedawasak',
#   'thiyaganna',
#   'puluwan',
#   'weida',
#   'ape',
#   'moda',
#   'noogathun',
#   'ekka'],
#  ['wadenam',
#   'hondai',
#   'eth',
#   'ape',
#   'minisunge',
#   'winayath',
#   'ekka',
#   'mewa',
#   'araksha',
#   'karaganida'],
#  ['අපේ',
#   'රටට',
#   'ඕව',
#   'හරියන්',
#   'නෑ',
#   'මොකද',
#   'මිනිස්සු',
#   'අඩුයි',
#   'දැන්',
#   'ඒ',
#   'වගේම',
#   'සමහරුන්ට',
#   'මොලයක්',
#   'නෑ',
#   'මේක',
#   'නඩත්තු',
#   'වෙන්නෙ',
#   'අපේ',
#   'බදු',
#   'මුදලින්',
#   'කියල',
#   'ඒක',
#   'නිසා',
#   'මේව',
#   'උපරිම',
#   'මාසයයි',
#   'පිලිවෙලට',
#   'තියෙන්නෙ'],
#  ['මාස',
#   'කීයක්',
#   'මේ',
#   'පිලිවෙලට',
#   'තියෙයිද',
#   'දන්නෙ',
#   'නෑ',
#   'ඕක',
#   'ඇතුලේ',
#   'කෑලි',
#   'ටිකත්',
#   'ගලවගෙන',
#   'නොගියොත්',
#   'තමයි',
#   'පුදුම'],
#  ['ඕවා',
#   'සාමාන්\u200dය',
#   'මගී',
#   'ජනතාවට',
#   'යන්න',
#   'ගෙන්නපුව',
#   'නෙවෙයි',
#   'මේවා',
#   'ගෙන්නන',
#   'එවුන්ව',
#   'කාර්\u200dයාල',
#   'දුම්\u200d',
#   'රියක',
#   'ටික',
#   'දවසක්',
#   'යවන්න',
#   'ඕන',
#   'දුම්',
#   'රිය',
#   'ගාස්තු',
#   'නහුතෙට',
#   'වැඩි',
#   'කරලා',
#   'ඒ',
#   'සල්ලිවලින්',
#   'වෙලාවට',
#   'දෙපැත්තට',
#   'පැද්දෙන්නෙ',
#   'නැතුව',
#   'ඉල',
#   'ඇට',
#   'කඩා',
#   'ගන්නෙ',
#   'නැතුව',
#   'යන්න',
#   'පුලුවන්',
#   'විදිහෙ',
#   'දුම්',
#   'රිය',
#   'සේවයක්',
#   'හදපල්ලා'],
#  ['ape',
#   'ratata',
#   'genna',
#   'ona',
#   'owa',
#   'newe',
#   'hoda',
#   'hadichcha',
#   'silachara',
#   'minissu',
#   'tikak',
#   'dan',
#   'inna',
#   'un',
#   'tikawa',
#   'koheta',
#   'hari',
#   'aduwata',
#   'vikunala',
#   'dala'],
#  ['ඉහල',
#   'සියට',
#   'පහලට',
#   'ආදර්ශයක්',
#   'නොදී',
#   'රටක',
#   'විනයක්',
#   'ඇති',
#   'කල',
#   'නොහැක',
#   'සිංගප්පූරුව',
#   'එයට',
#   'හොදම',
#   'ආදර්ශයයි',
#   'ලංකාවෙ',
#   'ඉහලින්',
#   'පහලට',
#   'දෙන',
#   'යහපත්',
#   'ආදර්ශය',
#   'කුමක්ද'],
#  ['ehenm',
#   'palaweni',
#   'dawasema',
#   'train',
#   'ride',
#   'ekak',
#   'yanda',
#   'onee',
#   'mokada',
#   'dawas',
#   'deka',
#   'thunak',
#   'giyata',
#   'passe',
#   'owwa',
#   'mukuth',
#   'nee',
#   'ne'],
#  ['hamadama',
#   'ithin',
#   'ahanna',
#   'wenne',
#   'kohen',
#   'hari',
#   'genapu',
#   'ekak',
#   'gana',
#   'thamai',
#   'ape',
#   'rate',
#   'nispadanayak',
#   'kiyala',
#   'ahanna',
#   'wena',
#   'ekak',
#   'naha'],
#  ['indiawen',
#   'genna',
#   'oneda',
#   'oowa',
#   'lankawe',
#   'ennawa',
#   'onnataran',
#   'weddo',
#   'oitawada',
#   'hodata',
#   'haganna',
#   'puluwan',
#   'kutti',
#   'pitin',
#   'ekapara',
#   'gasaganna',
#   'project',
#   'oowa'],
#  ['owa',
#   'ta',
#   'army',
#   'eken',
#   'dala',
#   'arawage',
#   'pissu',
#   'natana',
#   'unge',
#   'kana',
#   'paluwa',
#   'nam',
#   'nikan',
#   'ma',
#   'hadeyi'],
#  ['badulla',
#   'jaffna',
#   'kandy',
#   'yana',
#   'train',
#   'me',
#   'wage',
#   'api',
#   'dawasawala',
#   'hondai',
#   'dan',
#   'kohomada'],
#  ['රැකගනිල්ලා',
#   'ඇහැවගේ',
#   'නැත්නම්',
#   'වවුලෝ',
#   'වගේ',
#   'තමයි',
#   'හැමදාම',
#   'තොපිට',
#   'යන්න',
#   'වෙන්නේ',
#   'වනසන',
#   'එකෙක්',
#   'දැක්කොත්',
#   'හැමෝම',
#   'එකාවගේ',
#   'නැගීහිටපල්ලා',
#   'මට',
#   'අදාල',
#   'නෑනේ',
#   'කියලා',
#   'නොහිතා',
#   'ජනතාව',
#   'හැටියට',
#   'අපි',
#   'අපේ',
#   'වගකීමවත්',
#   'හරියට',
#   'ඉෂ්ඨ',
#   'කරමු'],
#  ['මේ',
#   'දුම්රියේ',
#   'ගමන්වාර',
#   'අවසානයේදී',
#   'දුම්රියේ',
#   'මැදිරි',
#   'අපේ',
#   'ජනතාව',
#   'පාවිච්චි',
#   'කරලා',
#   'තියෙන',
#   'විදිය',
#   'රටටම',
#   'පෙන්වන්න',
#   'ඕනේ',
#   'කියලා',
#   'යෝජනා',
#   'කරනවා'],
#  ['unp',
#   'ආන්ඩුව',
#   'මොකුත්',
#   'කලේ',
#   'නෑ',
#   'කියන',
#   'එවුන්',
#   'බලා',
#   'ගනිල්ල',
#   'unp',
#   'ආන්ඩුවක්',
#   'පලක්',
#   'නැති',
#   'දේවල්',
#   'වෙනුවෙන',
#   'කවදාවත්',
#   'ලෝකෙට',
#   'රට',
#   'ණයකලේ',
#   'නෑ',
#   'නෙළුම්',
#   'පොකුනු',
#   'නෙළුම්',
#   'පොකුනු',
#   'වෙනුවෙන්',
#   'රට',
#   'ණයකරපු',
#   'සල්ලිවල',
#   'මේ',
#   'වගේ',
#   'දෙයක්',
#   'කලානම්',
#   'කොච්චර',
#   'වටිනවද'],
#  ['සතියයි',
#   'බං',
#   'ඕවා',
#   'ඕවට',
#   'cctv',
#   'camera',
#   'system',
#   'එකක්',
#   'දාන්න',
#   'ඕනෙ'],
#  ['මෙක',
#   'දකිද්දී',
#   'මට',
#   'හිතෙන්නේ',
#   'ඉන්දියාව',
#   'කොච්චර',
#   'ඉස්සරහින්ද',
#   'අපිට',
#   'වඩා'],
#  ['okko', 'keli', 'galawan', 'yanawa', 'ape', 'un'],
#  ['ඔකෙ',
#   'යන්නෙ',
#   'පරණ',
#   'එව්න්',
#   'ටිකමනෙ',
#   'මාස',
#   'තුනක්',
#   'යද්දී',
#   'කහල',
#   'ගොඩක්',
#   'වගේ',
#   'තියේවි'],
#  ['oya',
#   'thathwen',
#   'tyenne',
#   'eka',
#   'dwsai',
#   'ape',
#   'minisunt',
#   'kohed',
#   'owge',
#   'wtinakamak'],
#  ['ඉන්දීය',
#   'දුම්රියන්',
#   'එන්න',
#   'එන්නම',
#   'අසාර්තකයි',
#   'ඇයි',
#   'ඒවම',
#   'ගෙන්වන්නෙ',
#   'මේකෙනුත්',
#   'කොමිස්',
#   'කුට්ටි',
#   'එන',
#   'නිසාද'],
#  ['ලංකාව',
#   'ඉන්දියාවේ',
#   'කොලනියක්',
#   'වෙන',
#   'රටවල',
#   'නැතිද',
#   'කොහොමත්',
#   'ඉන්දියාවේ',
#   'බයික්',
#   'වගේ',
#   'ඇති'],
#  ['ඔකොම',
#   'තිබිලා',
#   'අන්තිමට',
#   'කලින්',
#   'එවගේ',
#   'වගේ',
#   'බ්\u200dරේක්',
#   'අවුලක්',
#   'උනොත්',
#   'තමා',
#   'අවුල'],
#  ['මේ',
#   'ලංකාවටද',
#   'ඕක',
#   'ගේන්නෙ',
#   'පලවෙනි',
#   'දවසෙම',
#   'ඕකේ',
#   'ෆෑන්',
#   'tv',
#   'ටික',
#   'ගලවන්',
#   'යයි'],
#  ['gothrika',
#   'ratakata',
#   'me',
#   'wage',
#   'dewal',
#   'dunnata',
#   'reka',
#   'ganne',
#   'ne',
#   'kiyala',
#   'sure'],
#  ['විදේශ',
#   'රටවල',
#   'මේ',
#   'වගේ',
#   'කෝච්චි',
#   'වල',
#   'ආහාර',
#   'හා',
#   'කෑම',
#   'ගැනීම',
#   'තහනම්',
#   'ඒකයි',
#   'ඒව',
#   'පිරිසිදුවට',
#   'තියෙන්නෙ'],
#  ['ki', 'dawasak', 'ohoma', 'lassanata', 'thiyaida'],
#  ['cctv',
#   'gahala',
#   'genna',
#   'nathnm',
#   'dawsai',
#   'dekaii',
#   'okkoma',
#   'kala',
#   'daweee'],
#  ['මේවායේ',
#   'ගමන්',
#   'කරන',
#   'සහ',
#   'පාවිච්චි',
#   'කරන',
#   'විදියත්',
#   'ලංකාවේ',
#   'මිනිස්සුන්ට',
#   'කියල',
#   'දෙන්න',
#   'වෙයි'],
#  ['ape',
#   'unta',
#   'oke',
#   'yanna',
#   'uganna',
#   'wenawa',
#   'neth',
#   'nam',
#   'kala',
#   'dawi'],
#  ['විශේෂයෙන්',
#   'නිතර',
#   'දුම්රිය',
#   'ගමන්',
#   'කරන',
#   'මගින්',
#   'මේ',
#   'ගැන',
#   'සැලකිලිමත්',
#   'විය',
#   'යුතුයි',
#   'කරුනා',
#   'කරලා',
#   'පරෙස්සම්',
#   'කරන්න'],
#  ['ape', 'rilawu', 'tika', 'okatath', 'wade', 'deyi'],
#  ['balamu',
#   'mekawath',
#   'hariyata',
#   'thiya',
#   'ganida',
#   'kiyala',
#   'badulle',
#   'train',
#   'eke',
#   'toilat',
#   'eken',
#   'eleyata',
#   'patta',
#   'chu',
#   'gadai'],
#  ['දාපු',
#   'ඔස්තාර්ල',
#   'ටික',
#   'ඕකෙ',
#   'නග්ගල',
#   'යවන්න',
#   'ඕන',
#   'බලන්න',
#   'වැඩ',
#   'ටික'],
#  ['hoda', 'wagayma', 'wanasana', 'ewungayn', 'bayraganna', 'watina', 'badu'],
#  ['රත්තරන්',
#   'අපේක්ෂකයා',
#   'කවුද',
#   'කියලා',
#   'දැනගන්න',
#   'දැන්ම',
#   'මිස්',
#   'කෝල්',
#   'එකක්',
#   'දෙන්න'],
#  ['raththaran',
#   'newei',
#   'diyamanthi',
#   'hari',
#   'kamak',
#   'na',
#   'ape',
#   'gedara',
#   'chandayaka',
#   'watinakama',
#   'laksha',
#   'dekai'],
#  ['me',
#   'mama',
#   'nemei',
#   'ane',
#   'danne',
#   'nadda',
#   'mata',
#   'naya',
#   'gahala',
#   'mama',
#   'malane',
#   'a',
#   'unata',
#   'balannako',
#   'parcy',
#   'aiyata',
#   'kellek',
#   'akka',
#   'sapak',
#   'ganna',
#   'ona',
#   'unama',
#   'mama',
#   'thamai',
#   'set',
#   'karala',
#   'denne',
#   'parcy',
#   'aiya',
#   'katha',
#   'kaloth',
#   'witharai',
#   'mata',
#   'pana',
#   'anne'],
#  ['මංගල',
#   'මුදු',
#   'මාල',
#   'වළලු',
#   'රන්',
#   'අභරණ',
#   'ලබාගන්න',
#   'විශ්වාසයි',
#   'කල්',
#   'පවතියි',
#   'වගකීමට',
#   'බැඳී',
#   'සිටියි'],
#  ['mehema',
#   'poster',
#   'gahana',
#   'ekeknam',
#   'raththaran',
#   'ekek',
#   'wenna',
#   'ba'],
#  ['ඇයි', 'බ්\u200dරෝ', 'ස්පොන්සර්', 'ගහලා', 'සල්ලි', 'වැඩිවෙලාද'],
#  ['එනකම්',
#   'මගබලන්',
#   'ඉන්නෙ',
#   'කවුද',
#   'බන්',
#   'මූ',
#   'කිය්ලා',
#   'ලංකාවෙ',
#   'නෙමේද',
#   'දන්නෑ',
#   'හිටියෙ',
#   'මූ'],
#  ['පිරිත',
#   'බුදුන්',
#   'වහන්සේගේ',
#   'දේශනා',
#   'කොට',
#   'ඇත්තේ',
#   'සමුද්\u200dරඝෝෂ',
#   'විරිතට',
#   'අනුකූලවයි',
#   'පිරිතේ',
#   'අක්ෂර',
#   'ලියා',
#   'ඇත්තේ',
#   'ඒ',
#   'අනුවමයි',
#   'පිරිත',
#   'තුළින්',
#   'ඒ',
#   'සෙත්',
#   'ශක්තිය',
#   'ලබාගැනිමට',
#   'ඒ',
#   'ආකාරයෙන්',
#   'ම',
#   'සජ්ජායනය',
#   'කලයුතුයි'],
#  ['මෝඩ',
#   'මිනිස්සු',
#   'ටිකක්',
#   'නම්',
#   'මේක',
#   'අහල',
#   'තෙරුවනේ',
#   'ගුණ',
#   'කෙරෙහි',
#   'සිත',
#   'පහදවා',
#   'ගන්නෙ',
#   'නැතිව',
#   'තාලයයි',
#   'භාෂාවයි',
#   'ගැන',
#   'වාද',
#   'කර',
#   'කර',
#   'ඉන්නවා',
#   'අනේ',
#   'මේ',
#   'මිනිස්සු',
#   'කවදානම්',
#   'මේ',
#   'සංසාරයෙන්',
#   'එතෙර',
#   'වෙන්න',
#   'උත්සාහයක්',
#   'ගනීද'],
#  ['පිස්සො',
#   'පිස්සු',
#   'කතා',
#   'කියයි',
#   'සුනකයි',
#   'සුනක',
#   'කතා',
#   'කියයි',
#   'නරි',
#   'හූ',
#   'කිය',
#   'කිය',
#   'නටයි',
#   'මහමෙව්නා',
#   'වාසි',
#   'පිරිසයට',
#   'ඒ',
#   'සත්ව',
#   'කොට්ඨාසය',
#   'අදාලම',
#   'නැ',
#   'අපිට',
#   'නරි',
#   'නාවන්ඩ',
#   'වෙලාවකුත්',
#   'නැ',
#   'ඔබ',
#   'වහන්සේලා',
#   'කරන',
#   'දේ',
#   'අපිට',
#   'මහ',
#   'මෙරක්',
#   'වගේ',
#   'මේ',
#   'ලොකු',
#   'ස්වාමින්වහන්සේගේ',
#   'යුගයයි',
#   'අපේ',
#   'ලොකු',
#   'ස්වාමින්වහන්සේගෙ',
#   'මාර්ගයේ',
#   'අපි',
#   'යනවා',
#   'මේවැනි',
#   'පින්වත්',
#   'ස්වාමින්වහන්සේලා',
#   'මේ',
#   'මිහිමත',
#   'තව',
#   'තවත්',
#   'පහල',
#   'වේවා'],
#  ['මේ',
#   'වන්දනාවට',
#   'දොස්',
#   'නගන',
#   'සියලු',
#   'දෙනාටයි',
#   'නිකන්',
#   'බොරුවට',
#   'ආර්\u200dය',
#   'උපවාදයට',
#   'ලක්',
#   'වෙන්න',
#   'එපා',
#   'කිරිබත්ගොඩ',
#   'මා',
#   'හිමිගේ',
#   'බන',
#   'පදයක්වත්',
#   'නො',
#   'අසා',
#   'මේ',
#   'විදිහට',
#   'උන්',
#   'වහසේගේ',
#   'පිලිවෙතට',
#   'දොස්',
#   'නගන්න',
#   'එපා',
#   'වැරදි',
#   'ඇති',
#   'කා',
#   'ලගත්',
#   'ඒත්',
#   'කිරිබත්ගොඩ',
#   'හිමියන්ගේ',
#   'සීලයටවත්',
#   'ගුනයටවත්',
#   'අපිට',
#   'ලගටවත්',
#   'යන්න',
#   'බෑ',
#   'උන්',
#   'වහන්සේ',
#   'සිදු',
#   'කරන',
#   'සේවය',
#   'අති',
#   'මහත්',
#   'ස්\u200dරද්දාව',
#   'වැඩෙනවා'],
#  ['හැකි',
#   'සෑම',
#   'විටම',
#   'ත්\u200dරිවිධ',
#   'රත්නයේ',
#   'ගුණ',
#   'සිහිපත්',
#   'කිරීමයි',
#   'වැදගත්',
#   'මේ',
#   'ස්වාමීන්',
#   'වහන්සේලාගේ',
#   'දේශනාවෙන්',
#   'මම',
#   'සුවපත්',
#   'වුනෙමි',
#   'ඒ',
#   'කුසලය',
#   'උන්',
#   'වහන්සේලා',
#   'අනුමෝදන්',
#   'වේවා',
#   'බල්ලො',
#   'බිරුවට',
#   'කදු',
#   'පාත්',
#   'වෙන්නෙ',
#   'නෑනෙ',
#   'බුදු',
#   'සසුන',
#   'බැබලේවා'],
#  ['දහම්පාසලකට',
#   'ගියේ',
#   'නැති',
#   'එකාලාට',
#   'මේ',
#   'බණ',
#   'නම්',
#   'සෝක්',
#   'ඊයේ',
#   'පෙරේදා',
#   'ෂෝ',
#   'එකට',
#   'ධර්මය',
#   'පස්සෙ',
# ...
#   'කරන',
#   'එක',
#   'මිනිස්සුන්ට',
#   'හිතන්න',
#   'හුඟක්ම',
#   'හුඟක්',
#   'දේවල්',
#   'මේ',
#   'තුල',
#   'අන්තර්',
#   'ගතයි',
#   'හොන්ඳ',
#   'පණිවිඩයක්',
#   'මිනිසුන්ගේ',
#   'හිත්',
#   'තුලට'],
#  ['හැමෝම',
#   'එක',
#   'වගේ',
#   'නෑ',
#   'හැම',
#   'ජාතියකම',
#   'හොද',
#   'මිනිස්සු',
#   'ඉන්නවා',
#   'සිංහල',
#   'ජාතීයේ',
#   'තමයි',
#   'හොයන්න',
#   'අමාරූ'],
#  ['me',
#   'wage',
#   'minisu',
#   'dekkama',
#   'loku',
#   'satutak',
#   'denenawa',
#   'arabi',
#   'kiyanne',
#   'darunu',
#   'minisu',
#   'inne',
#   'ratak',
#   'ath',
#   'meyala',
#   'ehema',
#   'ne'],
#  ['pin',
#   'athwai',
#   'mahathayo',
#   'ubala',
#   'dan',
#   'pawul',
#   '7kata',
#   'athiwenna',
#   'hambakaragaththane',
#   'oi',
#   'putuwe',
#   'edan',
#   'sumathipalata',
#   'nam',
#   'lajjawak',
#   'na',
#   'perethaya'],
#  ['කොහේ',
#   'හරි',
#   'කාට',
#   'හෝ',
#   'අවශ්\u200dය',
#   'කෙනෙක්',
#   'හමුවන',
#   'තුරු',
#   'හැකිතාක්',
#   'ශෙයා',
#   'කරන්න',
#   'අපි',
#   'ජීවිතයක්',
#   'බේරාගත',
#   'හැකිය'],
#  ['මෙ',
#   'ලගදි',
#   'ෂෙයා',
#   'කරලා',
#   'තිබ්බා',
#   'පෙඡ්',
#   'එකකින්',
#   'මතක',
#   'නැ',
#   'දැන්'],
#  ['උදව්වක්', 'one'],
#  ['රට',
#   'දැය',
#   'වෙනුවෙන්',
#   'උරදුන්නට',
#   'පක්ශ',
#   'පාට',
#   'බේදයකින්',
#   'තොරව',
#   'අපි',
#   'සහය',
#   'දෙන්නමු',
#   'ජයවේවා',
#   'ලොක්ක'],
#  ['පස්වන',
#   'විධායක',
#   'ජානාධිපති',
#   'මහින්ද',
#   'රාජපක්ෂ',
#   'මැතිඳුන්',
#   'මේ',
#   'රට',
#   'පාලනය',
#   'නොකරන්න',
#   'මේ',
#   'ඉංජිනේරු',
#   'මහත්තයගේ',
#   'නම',
#   'තියන්න',
#   'තිබ්බේ',
#   'කොහෙද',
#   'කියලා',
#   'අද',
#   'රටේ',
#   'ජනතාව',
#   'දන්නවා'],
#  ['කොහොමත්',
#   'උබේ',
#   'නම',
#   'හිතට',
#   'එකගව',
#   'දාන්න',
#   'බෑ',
#   'මහින්දගේ',
#   'නම',
#   'දාන්න',
#   'බෑ',
#   'තොපි',
#   'කුහකයි',
#   'ඉතිං',
#   'ඉංජිනේරුවගේ',
#   'නම',
#   'දාපිය',
#   'කව්රුවත්',
#   'නෙමෙයි',
#   'ඕක',
#   'හැදුවේ',
#   'අපි'],
#  ['අපි',
#   'ණය',
#   'ගෙවනවනම්',
#   'ඒක',
#   'වෙන',
#   'උන්',
#   'හදන්න',
#   'බෑනේ',
#   'තොපිකාලා',
#   'ඇදලා',
#   'ඉන්නෙත්',
#   'අපේ',
#   'සල්ලි',
#   'ලැජ්ජයි',
#   'තොපි',
#   'ගැන'],
#  ['මහින්ද', 'හදපුවගෙ', 'නම්', 'මාරු', 'කර', 'කර', 'හිටපං', 'හිටං'],
#  ['මහින්ද',
#   'කළා',
#   'කියන',
#   'වහල්ලු',
#   'මොරගහකන්ද',
#   'ජලාශය',
#   'ඉදි',
#   'කරන්න',
#   'මහින්ද',
#   'කළ',
#   'ටික',
#   'කියනවද'],
#  ['දැං',
#   'මං',
#   'අහන්නෙ',
#   'මොනවම',
#   'හරි',
#   'දෙයක්',
#   'ජනතාවගේ',
#   'සල්ලි',
#   'වැය',
#   'කරල',
#   'හැදුවම',
#   'ඒකට',
#   'කාගෙ',
#   'හරි',
#   'නමක්',
#   'දාන්නම',
#   'ඕනෙද'],
#  ['නම්',
#   'තැබිමනම්',
#   'ඉතා',
#   'හොද',
#   'ආදර්ශයක්',
#   'ගාල්ලෙත්',
#   'ඕකයි',
#   'කරන්ඩ',
#   'තිබ්බේ'],
#  ['oka',
#   'hadanna',
#   'patagannkota',
#   'epa',
#   'kiyala',
#   'natapu',
#   'aya',
#   'akka',
#   'inna',
#   'hoda',
#   'porata'],
#  ['ලැජ්ජයි', 'රටේ', 'පාලකය', 'විධියට', 'මෙවැනි', 'ගජබින්න', 'කෙලිනඑකගැන'],
#  ['arabi', 'walin', 'higa', 'kapu', 'salli'],
#  ['අප',
#   'ළඟ',
#   'පුහු',
#   'ආඩම්බරයක්',
#   'ඇත',
#   'තාත්තා',
#   'දරුවන්ට',
#   'ගුරුවරයා',
#   'ගෝලයින්ට',
#   'කොන්දොස්තර',
#   'මගීන්ට',
#   'දේශපාලකයා',
#   'ඡන්ද',
#   'දායකයන්ට',
#   'සිංහලයා',
#   'මුස්ලිම්',
#   'අයට',
#   'පමණක්',
#   'නොවෙයි',
#   'ගෙදර',
#   'ඉන්න',
#   'බල්ලාට',
#   'පවා',
#   'පුහු',
#   'ආඩම්බරකම',
#   'පෙන්වමින්',
#   'ඉන්නා',
#   'නිසා',
#   'තමයි',
#   'අපේ',
#   'නොදියුණු',
#   'භාවය',
#   'ඇති',
#   'වෙලා',
#   'තියෙන්නේ'],
#  ['උන්',
#   'නැමෙනවා',
#   'වැඩියි',
#   'බං',
#   'බැරි',
#   'වෙලාවත්',
#   'ලංකාවෙ',
#   'ඔහොම',
#   'නැවෙන්න',
#   'ගියොත්'],
#  ['ස්වාභාවික', 'විපත්', 'නිසා', 'උන්', 'මොකටද', 'සමාව', 'ඉල්ලන්නේ'],
#  ['අපේ', 'දුම්රිය', 'සේවය', 'වගේ'],
#  ['ලංකාවට',
#   'කිසිම',
#   'පාලනයක්',
#   'අවශ්\u200dය',
#   'නැ',
#   'මිනිස්සු',
#   'තමන්ගේ',
#   'පාඩුවේ',
#   'හැමදේම',
#   'කරද්දි',
#   'කාලකන්නි',
#   'අපේම',
#   'සල්ලි',
#   'වලින්',
#   'අපිට',
#   'අරිනවා',
#   'දකින',
#   'තැන',
#   'ගහලා',
#   'එලවන',
#   'සමාජයක්',
#   'බිහිෙවනකන්',
#   'මෙව්වා',
#   'මෙහෙම',
#   'තමයි'],
#  ['malinga',
#   'chande',
#   'ellapan',
#   'uba',
#   'dinanawa',
#   'me',
#   'rate',
#   'niliyo',
#   'chande',
#   'ellala',
#   'dinuwa',
#   'nam',
#   'ubata',
#   'gamakma',
#   'ne',
#   'hoda',
#   'pakshekin',
#   'ellala',
#   'uba',
#   'oya',
#   'ubata',
#   'kenehilikam',
#   'karapu',
#   'unta',
#   'pennapan',
#   'me',
#   'rate',
#   'minissu',
#   'ubata',
#   'ennawa',
#   'kiyala',
#   'pennapan'],
#  ['උන්ට', 'බම්බු', 'ගහන්න', 'කියලා', 'අපි', 'ඌට', 'farewell', 'එකක්', 'දෙමු'],
#  ['ඇත්තටම',
#   'ඌ',
#   'ඒම',
#   'කියල',
#   'ද',
#   'කළින්',
#   'මාලි',
#   'වන්ඩේ',
#   'වලට',
#   'නම්',
#   'විමේ',
#   'ඉඩක්',
#   'තියනව',
#   'කිව',
#   'නේද'],
#  ['ලැබ්රඩොග්', 'ගැන', 'අපි', 'දැක්කනේ'],
#  ['ලැබ්\u200dරෝයි', 'කරන්නෙ', 'බුකි', 'සුමතිට', 'වෙච්ච', 'පොරොන්දුවක්'],
#  ['hena',
#   'hathama',
#   'gahapuya',
#   'lebaroy',
#   'thota',
#   'මාලිංග',
#   'ta',
#   'wagema',
#   'ධනුෂ්ක',
#   'yata',
#   'karapu',
#   'ewataaa'],
#  ['සීනි', 'කොහෙ', 'තිබ්බත්', 'කූබි', 'වහනවා'],
#  ['හෙන', 'ගහන්නෙත්', 'නෑ', 'බන්', 'ඕකුන්ට'],
#  ['ඔට්ටුපාලයා',
#   'ඕකත්',
#   'මේ',
#   'ගේම්',
#   'එකේ',
#   'යට',
#   'ඉන්නවා',
#   'ඉන්දියන්කාරයෝ',
#   'එක්ක',
#   'ඉන්දියාව',
#   'ඉස්සරහා',
#   'අපි',
#   'පීචන්',
#   'කරන',
#   'බ්\u200dරෝකර්',
#   'තමා',
#   'ඕකා'],
#  ['maharagama',
#   'christian',
#   'sambawayak',
#   'tiyena',
#   'godak',
#   'minnssu',
#   'inna',
#   'sinhala',
#   'burger',
#   'oya',
#   'dasun',
#   'meeta',
#   'awurudu',
#   '30',
#   'kata',
#   'kalin',
#   'sulabai'],
#  ['mewa',
#   'dekkahama',
#   'mage',
#   'papuwa',
#   'pelenawa',
#   'gage',
#   'sansara',
#   'gamanata',
#   'yanna',
#   'kauruth',
#   'kemati',
#   'nehe'],
#  ['කව්රුත්', 'නොදකින', 'සැබැ', 'ආදරේ'],
#  ['ඇඩුන', 'ඒකට', 'දෙය්යනේ'],
#  ['mamath',
#   'dekka',
#   'meyalawa',
#   'godak',
#   'sathutu',
#   'hithuna',
#   'meyalage',
#   'adare',
#   'gena'],
#  ['ehema', 'thamai', 'wenna', 'one'],
#  ['ඔහොම',
#   'කිඋවයි',
#   'කියල',
#   'අපේ',
#   'උන්',
#   'රටේ',
#   'තිබෙන',
#   'දේශපාලන',
#   'ක්\u200dරමය',
#   'වෙනස්',
#   'කරන්වද',
#   'නෑනේ',
#   'බොරුවට',
#   'කෑගහනව',
#   'විතරනේ',
#   'තව',
#   'ටික',
#   'දවසකින්',
#   'මේ',
#   'කතාව',
#   'මතකවත්',
#   'නෑනේ'],
#  ['කවදාවත්',
#   'සිංහල',
#   'එකෙක්',
#   'මේ',
#   'රට',
#   'හදන්නේ',
#   'නෑ',
#   'අනුකම්පා',
#   'කරලා',
#   'සුද්දෙක්',
#   'ලංකාවේ',
#   'පුරවැසි',
#   'භාවය',
#   'හිමිකරගෙන',
#   'ඌ',
#   'ජන්දේ',
#   'ඉල්ලුවොත්',
#   'මම',
#   'අනිවාර්යයෙන්',
#   'ඌට',
#   'ජන්දේ',
#   'දෙනවා'],
#  ['එහෙනම්',
#   'ලංකාව',
#   'අතෑරලා',
#   'යන්න',
#   'ඕන',
#   'පෙන්',
#   'ලංකාවෙ',
#   'ඉදන්',
#   'ක්\u200dරීඩවකින්',
#   'උඩට',
#   'යන්න',
#   'බෑ'],
#  ['ලංකාවේ',
#   'ජාතික',
#   'මට්ටමේ',
#   'ජාත්\u200dයන්තර',
#   'මට්ටමේ',
#   'ඉන්න',
#   'ක්\u200dරිඩකයන්',
#   'කවදා',
#   'අලවි',
#   'වෙයිද',
#   'මන්දා'],
#  ['පලමුවත්', 'මව්බිම', 'දෙවනුවත්', 'මව්බිම', 'තෙවනුවත්', 'මව්බිම'],
#  ['මම', 'දන්නෑ', 'හාමුදුරුවනේ'],
#  ['උන්',
#   'කැද',
#   'බීල',
#   'වගෙ',
#   'සෙල්ලම්',
#   'කරේ',
#   'නෑ',
#   'නේ',
#   'කීඩා',
#   'සමාජ',
#   'වලට',
#   'සිලෙක්ට්',
#   'වෙන්න',
#   'බලාගෙන',
#   'සෙල්ලම්',
#   'කරෙත්',
#   'නෑ'],
#  ['ඒ', 'තමා', 'මිනිස්සු'],
#  ['iwarayak', 'nadda', 'oii', 'මේ', 'මගුල'],
#  ['දිනුවත්', 'නෑ', 'පැරදුනත්', 'නෑ'],
#  ['මීට', 'කලින්', 'දැකලා', 'නෑ', 'තමයි'],
#  ['ape', 'vahallunta', 'honda', 'padam'],
#  ['final', 'ආපු', 'එක', 'වගේද', 'බං', 'හැමදාම', 'පරාද', 'වෙන', 'එක'],
#  ['කොඩිය',
#   'විතරක්',
#   'ගිහින්',
#   'වැඩක්',
#   'නැතෝ',
#   'team',
#   'eka',
#   'ගිහිල්ලා',
#   'අපිට',
#   'වනන්න',
#   'අවස්ථාවක්',
#   'තමයි',
#   'ඕනා'],
#  ['ටීම්',
#   'එකක්',
#   'world',
#   'cup',
#   'එකට',
#   'නොගියට',
#   'මොක්ද',
#   'කොඩිය',
#   'අරං',
#   'හරි',
#   'එකෙක්',
#   'යනවනෙ',
#   'ඒත්',
#   'මිනිස්සු',
#   'බලනවා',
#   'ඇති',
#   'මේ',
#   'මොන',
#   'රටක',
#   'කොඩියක්ද',
#   'කියලා'],
#  ['ඔහොම',
#   'කරන්න',
#   'ඕනේ',
#   'නෑ',
#   'බන්',
#   'රටේ',
#   'නම',
#   'ජාත්\u200dයන්තරයට',
#   'ගෙනියන්න',
#   'තව',
#   'ටික',
#   'කාලයක්',
#   'බලන්',
#   'හිටපන්කෝ',
#   'අපේ',
#   'මයිත්\u200dරී',
#   'මාමා',
#   'අපේ',
#   'රටේ',
#   'නම',
#   'ලෝකේම',
#   'බබලවන',
#   'විදිහ'],
#  ['kodiya',
#   'aelluvata',
#   'ජාත්\u200dයන්තරyata',
#   'yanna',
#   'be',
#   'ne',
#   'ahenam',
#   'apee',
#   'team',
#   'akak',
#   'fifa',
#   'gahanna',
#   'harinona'],
#  ['අනිවා', 'කොහේ', 'ගියත්', 'අපේ', 'එකෙක්', 'ඉන්නවමයි'],
#  ['එලකිරී', 'මචෝ'],
#  ['attamai', 'adambarai', 'kohoma', 'haduwath', 'rata', 'gana', 'kakkuma'],
#  ['cricket',
#   'board',
#   'eka',
#   'ewun',
#   'hithagena',
#   'inne',
#   'unta',
#   'eka',
#   'paramparawen',
#   'labunu',
#   'deyak',
#   'kiyala',
#   'sellan',
#   'karanne',
#   'wena',
#   'ewun',
#   'lakunu',
#   'daganne',
#   'un',
#   'hariyata',
#   'lankawe',
#   'udde',
#   'dinuwa',
#   'wage'],
#  ['කමක්', 'නැහැ', 'ඔහොම', 'හරි', 'කරලා', 'හිත', 'හදාගමුකෝ'],
#  ['ලංකාවේ', 'අය', '6', 'දෙනෙක්', 'විතරයි', 'ඉන්නෙ'],
#  ['මූ', 'කොහොමත්', 'අක්කලටනෙ', 'කැමති'],
#  ['අපේ', 'රටේ', 'නායකයෝ', 'මැච්', 'බලන්න', 'ගියොත්', 'එදාට', 'එක', 'පරාදයි'],
#  ['ඒකට', 'මෙහෙ', 'ඉන්න', '225', 'නොදකින්'],
#  ['දැං', 'එතකොට', 'මෙයාට', 'ජනාධිපති', 'ධූරයේ', 'වැඩ', 'නැද්ද'],
#  ['aperate', 'wagemai', 'budu', 'amboo'],
#  ['අපේ', 'පව', 'බන්'],
#  ['ane',
#   'manda',
#   'mewa',
#   'balala',
#   'ape',
#   'aya',
#   'kohoma',
#   'react',
#   'karaida',
#   'kiyala'],
#  ['ape', 'eka', 'mewa', 'dakinneth', 'paththaren'],
#  ['අපේ',
#   'අය',
#   'අපිව',
#   'මීට',
#   'වඩා',
#   'සප්\u200dරයිස්',
#   'කරයි',
#   'ඒ',
#   'නිසා',
#   'ඒ',
#   'ගැන',
#   'වැඩිය',
#   'හිතන්න',
#   'හොඳ',
#   'නෑ'],
#  ['මෙයත්',
#   'අතීතයට',
#   'එක',
#   'වන',
#   'එක',
#   'දවසකට',
#   'පමනක්',
#   'සෙයා',
#   'ව',
#   'එක්',
#   'පෝස්ටුවක්',
#   'පමනයි',
#   'සිස්ටම්',
#   'එක',
#   'වෙනස්වන',
#   'බවක්',
#   'පේනතෙක්',
#   'මානෙක',
#   'වත්',
#   'නෑ'],
#  ['konda',
#   'kelin',
#   'warada',
#   'warada',
#   'vidiyata',
#   'penwana',
#   'minissu',
#   'balu',
#   'karala',
#   'sutikko',
#   'legendsla',
#   'karana',
#   'mediane',
#   'ape',
#   'minissu',
#   'illane',
#   'malinga',
#   'hamadamath',
#   'adarei',
#   'kelin',
#   'kathakarana',
#   'obata'],
#  ['ඒ', 'තත්පර', 'දෙක', 'ඉඳලා', 'බලල', 'යන්නත්', 'තිබ්බා'],
#  ['යකෝ', 'උන්', 'දන්නවද', 'තව', 'ටිකකින්', 'goal', 'එකක්', 'ගහනව', 'කියලා'],
#  ['දෙයක්',
#   'කියන්නේ',
#   'ව්\u200dයංග්\u200dයර්ථයෙන්',
#   'වැදගත්',
#   'විදිහට',
#   'ඒක',
#   'තේරුම්',
#   'ගන්න',
#   'බැරි',
#   'මිනිසුන්',
#   'ඉන්න',
#   'රටක්',
#   'දියුණු',
#   'වෙයිද'],
#  ['මල',
#   'සමයං',
#   'හ්ම්',
#   'අපි',
#   'ඒ',
#   'වගේ',
#   'නොවේ',
#   'එලාම්',
#   'එක',
#   'ඔෆ්',
#   'කරලයි',
#   'අපි',
#   'මැච්',
#   'එක',
#   'බලන්නේ',
#   'ගින්දර',
#   'වගේද',
#   'මැච්',
#   'මෙයා'],
#  ['තමන්ගේ',
#   'ජොබ්',
#   'එක',
#   'හරියටම',
#   'කල',
#   'මිනිස්සු',
#   'ලන්කාවේ',
#   'රාජ්\u200dය',
#   'සේවකයන්ට',
#   'ලොකු',
#   'ආදර්ශයක්',
#   'රාජ්\u200dය',
#   'සේවක',
#   'බූවල්ලගෙන්',
#   'රට',
#   'නිදහස්',
#   'කර',
#   'නොගත්තොත්',
#   'කොයි',
#   'නායකයා',
#   'ආවත්',
#   'අපේ',
#   'රට',
#   'හදන්න',
#   'බෑ'],
#  ['ඇත්ත',
#   'බොරුව',
#   'ගෝල්',
#   'එක',
#   'ගහනවද',
#   'මොන',
#   'රටේද',
#   'කොහෙද',
#   'වැඩ',
#   'කරන්නෙ',
#   'මොන',
#   'ජාතියේද',
#   'මොන',
#   'ආගමේද',
#   'වැඩක්',
#   'නෑ',
#   'ගෙදර',
#   'වුනත්',
#   'ඉන්න',
#   'තැනක',
#   'කරන',
#   'පැවරෙන',
#   'වැඩක්',
#   'හරියට',
#   'කරනව',
#   'නම්',
#   'එච්චරයි'],
#  ['නැහැ',
#   'මෙි',
#   'විඩියෝ',
#   'එක',
#   'අපි',
#   'කාටත්',
#   'හෝද',
#   'ආදර්ශයක්',
#   'විඩියෝවේ',
#   'අදහස්',
#   'හිතට',
#   'ගන්න',
#   'ලංකාවටත්',
#   'දැන්',
#   'ඹිනේ',
#   'මෙිහේම',
#   'ඡනතාවක්'],
#  ['කවුද',
#   'යකෝ',
#   'තමන්ගෙ',
#   'රට',
#   'සෙමි',
#   'ෆයිනල්',
#   'ගහද්දි',
#   'ගිණි',
#   'තියපු',
#   'එකා'],
#  ['lakawa',
#   'dawasen',
#   'dawasa',
#   'wala',
#   'pallata',
#   'yanne',
#   'mewan',
#   'akalpa',
#   'athi',
#   'minisun',
#   'bihi',
#   'nowena',
#   'nisa'],
#  ['hari',
#   'ithin',
#   'ehe',
#   'wage',
#   'president',
#   'ekenk',
#   'innawanam',
#   'akuratama',
#   'raja',
#   'kari',
#   'karanna',
#   'eka',
#   'mokakda'],
#  ['අපේ',
#   'උන්',
#   'හිටියා',
#   'නම්',
#   'අනිවා',
#   'කියනවා',
#   'කලින්ම',
#   'ගිනි',
#   'නිවන',
#   'ඇදුම්',
#   'ඇදගෙන',
#   'නොහිටපු',
#   'එකට',
#   'විනය',
#   'පරීක්ෂණයක්',
#   'ඕනේ',
#   'කියලා'],
#  ['එපේ',
#   'උන්',
#   'නම්',
#   'මැච්',
#   'එකත්',
#   'බලලා',
#   'සතුටට',
#   'අඩියකුත්',
#   'ගහලා',
#   'තමා',
#   'යන්නේ'],
#  ['dan', 'ithin', 'උන්', 'ගැන', 'එක', 'එක', 'සී', 'පද', 'කියයි'],
#  ['ජිවිතයේ', 'ඒසුන්දර', 'අත්දැකීම', 'අවදිකලා'],
#  ['ape',
#   'minissu',
#   'nm',
#   'ithin',
#   'match',
#   'eka',
#   'balala',
#   'ginna',
#   'niunatath',
#   'passe',
#   'ethanata',
#   'yanne'],
#  ['meka', 'sira', 'ada', 'news', 'walatat', 'pennuwa'],
#  ['හැම',
#   'දේටම',
#   'වඩා',
#   'රාජකාරිය',
#   'උතුම්',
#   'ලෙස',
#   'ලෝකෙටම',
#   'ආදර්ශ',
#   'දෙන',
#   'උතුම්',
#   'මිනිස්සු'],
#  ['මිලියන',
#   '4',
#   'යි',
#   'ජනගහනය',
#   'අපට',
#   'මිලියන',
#   '20',
#   'යි',
#   'රටක්',
#   'හැදෙනව',
#   'නම්',
#   'හැදෙන්නෙ',
#   'මෙහෙමයි'],
#  ['සුදු',
#   'ඇදගෙන',
#   'අන්තිමට',
#   'එන',
#   'කෙනාව',
#   'බලන්න',
#   'මෙක',
#   'තනිකර',
#   'බොරුවක්',
#   'බොරුවට',
#   'කෙරවලට',
#   'දුවලා',
#   'නිකම්',
#   'එනවා'],
#  ['ඒකට',
#   'ලංකාවේ',
#   'ගින්න',
#   'තියන',
#   'තැනට',
#   'ගහින්',
#   'තමා',
#   'වතුර',
#   'තියනවද',
#   'කියල',
#   'බලන්නේ'],
#  ['අෙප්',
#   'ර',
#   'ෙට්',
#   'තරුණ',
#   'පිරිසකට',
#   'ෙම',
#   'ෙහම',
#   'වුණා',
#   'නම්',
#   'අැෙග්',
#   'ශක්තිය',
#   'තියා',
#   'ගන්න',
#   'භාවනාවක්',
#   'වත්',
#   'දන්නවාද'],
#  ['me',
#   'manssayek',
#   'karapu',
#   'wade',
#   'nisa',
#   'ara',
#   'lamai',
#   'මැරෙන්නට',
#   'tibba',
#   'ratak',
#   'lowak',
#   'duk',
#   'una',
#   'oya',
#   'wage',
#   'dura',
#   'dakin',
#   'nathi',
#   'modayo',
#   'ekka',
#   'තමන්ගෙ',
#   'pana',
#   'wage',
#   'lamai',
#   'yawan',
#   'epa',
#   'දෙමව්පියන්',
#   'ta',
#   'hoda',
#   'පාඩමක්',
#   'මේකෙන්',
#   'ගත්තම',
#   'ඉවරයි'],
#  ['mama',
#   'adambarawanawa',
#   'magana',
#   'nodanna',
#   'tawa',
#   'ayata',
#   'makadi',
#   'lankawat',
#   '2',
#   'wani',
#   'tana',
#   'innawa',
#   'gugal',
#   'walin',
#   '1',
#   'singapore',
#   'anith',
#   'waddo',
#   'apita',
#   'passa'],
#  ['mole',
#   'tikak',
#   'thiyanava',
#   'neda',
#   'aulak',
#   'okkoma',
#   'pili',
#   'gani',
#   'add',
#   'akak',
#   'kiyala',
#   'arakath'],
#  ['ane',
#   'ithin',
#   'mewa',
#   'hodai',
#   'mole',
#   'nethi',
#   'unta',
#   'viswasa',
#   'karanna'],
#  ['metharam', 'hodata', 'avith', 'awasaane', 'sarame', 'giyanew'],
#  ['මේක',
#   'තමයි',
#   'අපේ',
#   'රටේ',
#   'රත්තරන්',
#   'මිනිස්සුන්',
#   'ගේ',
#   'සැගවෙලා',
#   'තියන',
#   'dn',
#   'එක'],
#  ['මොකක්දෝ',
#   'කරැම',
#   'සල්ලි',
#   'වලට',
#   'වහ',
#   'වැටිලා',
#   'ඒ',
#   'දේ',
#   'සැගවිලා',
#   'ගිහින්',
#   'ඒත්',
#   'මෙහෙම',
#   'අවස්ථා',
#   'වල',
#   'ඉබේම',
#   'ඒක',
#   'එලියට',
#   'එනවා',
#   'ඒ',
#   'දේ',
#   'මොන',
#   'සක්කරයටවත්',
#   'බෑ',
#   'නවත්වන්න'],
#  ['කරදරේකදි',
#   'වගේම',
#   'අනිත්',
#   'හැම',
#   'වෙලාවෙමත්',
#   'ඔය',
#   'මනුස්සකම',
#   'ඔය',
#   'විදියට',
#   'තියේ',
#   'නම්',
#   'ගොඩක්',
#   'ලස්සන',
#   'රටක්',
#   'මේ',
#   'රට',
#   'respect'],
#  ['කොච්චර',
#   'කාලකන්නි',
#   'හිටියත්',
#   'තාමත්',
#   'මෙහෙම',
#   'මිනිස්සු',
#   'ඉතුරු',
#   'වෙලා',
#   'ඉන්න',
#   'එක',
#   'ගැන',
#   'දැනෙන්නේ',
#   'පුදුම',
#   'ආඩම්බරයක්',
#   'මේක',
#   'තමයි',
#   'ශ්\u200dරි',
#   'ලාංකීක',
#   'කම'],
#  ['winayak',
#   'athuwa',
#   'wahana',
#   'elawana',
#   'magra',
#   'neethi',
#   'pilipadina',
#   'riyaduran',
#   'pirisak',
#   'bihikireemay',
#   'yugaye',
#   'awashyathawaya',
#   'nathuwa',
#   'murandu',
#   'awadanam',
#   'nosalakilimath',
#   'kalakanni',
#   'kiyanna',
#   'wachana',
#   'nahe',
#   'happala',
#   'atha',
#   'paya',
#   'kkadala',
#   'jeewitha',
#   'paligaththama',
#   'ane',
#   'apoy',
#   'kiyala',
#   'duk',
#   'wela',
#   'wadak',
#   'nahe'],
#  ['mowunta',
#   'uparima',
#   'danduwam',
#   'dena',
#   'thada',
#   'neethi',
#   'hadanna',
#   'ona',
#   'kenek',
#   'maruwama',
#   'miniya',
#   'nochariyen',
#   'eliyata',
#   'ganna',
#   'issella',
#   'happapu',
#   'eka',
#   'epa',
#   'pita',
#   'eliyata',
#   'daalaa'],
#  ['ithin',
#   'minissu',
#   'bayanahe',
#   'diyunu',
#   'ratawalwala',
#   'wage',
#   'neethi',
#   'thadin',
#   'kriyath',
#   'maka',
#   'karala',
#   'dadi',
#   'danduwam',
#   'denna',
#   'ona'],
#  ['ape',
#   'ayata',
#   'thama',
#   'happunama',
#   'nidahasata',
#   'karu',
#   'daahak',
#   'thiyenne',
#   'break',
#   'nathiwuna',
#   'lissuwaa',
#   'dakke',
#   'nahe',
#   'eka',
#   'para',
#   'panna'],
#  ['malinga',
#   'labana',
#   'mase',
#   'candawta',
#   'gihin',
#   'golble',
#   't20',
#   'tournament',
#   'eka',
#   'sellan',
#   'karanawa'],
#  ['sumathipala',
#   'pamanak',
#   'iwath',
#   'kalata',
#   'wedak',
#   'naha',
#   'ekata',
#   'manapa',
#   'un',
#   'hatagananak',
#   'withara',
#   'innawa',
#   'unuth',
#   'me',
#   'game',
#   'wala',
#   'kota',
#   's',
#   'karayo'],
#  ['mewage',
#   'manussakamak',
#   'thiyana',
#   'ratharam',
#   'minissun',
#   'lankawe',
#   'inna',
#   'eka',
#   'gana',
#   'proud',
#   'wenawa',
#   'respected',
#   'you',
#   'd',
#   'work',
#   'me',
#   'wage',
#   'ashinsaka',
#   'dupath',
#   'minissunta',
#   'thama',
#   'lankawe',
#   'manussakamak',
#   'thiyana',
#   'anith',
#   'kalakani',
#   'loku',
#   'add',
#   'damata',
#   'appreciate',
#   'you',
#   'services',
#   'budun',
#   'wadiya',
#   'rate',
#   'inne',
#   'deviwaru',
#   'mewage',
#   'ayata',
#   'thanks',
#   'pin',
#   'labend',
#   'blessings',
#   'themselves',
#   'to',
#   'have',
#   'better',
#   'lifestyle',
#   'salli',
#   'wasiyata',
#   'manussakamak',
#   'thiyana',
#   'kalakani',
#   'inna',
#   'society',
#   'eka',
#   'mewage',
#   'deviwawaru',
#   'wage',
#   'aya',
#   'inna',
#   'ekath',
#   'proud',
#   'of',
#   'sri',
#   'lanka'],
#  ['buki',
#   'karayonta',
#   'owa',
#   'dunnma',
#   'u',
#   'ekath',
#   'wikunagena',
#   'kanawa',
#   'mokada',
#   'munta',
#   'ona',
#   'kohomahari',
#   'salli'],
#  ['කවුරු',
#   'මොනා',
#   'කිව්වත්',
#   'කරදරයකදි',
#   'අපේ',
#   'මිනිස්සු',
#   'ලංකාවේ',
#   'මිනිස්සු',
#   'දෙවිවරු',
#   'අත්දැකීමෙන්',
#   'කියන්නේ',
#   'ජාතිබේද',
#   'නැති',
#   'මනුස්සකම'],
#  ...]

# %%
sinhala_tokens_set = []
singlish_tokens_set = []

# %%
for tokenSet in cleaned_tokens:
    if(isSinglish(tokenSet)):
        singlish_tokens_set.append(tokenSet)
    else:
        sinhala_tokens_set.append(tokenSet)

# %%
sinhala_tokens_set
# Out:
# [['මේ',
#   'බැල්ලි',
#   'කොටින්ගේ',
#   'ගු',
#   'කනකොට',
#   'අපහසුවක්',
#   'දැනුනෙ',
#   'නැද්ද',
#   'දන්',
#   'නැහැ',
#   'ඔකිට',
#   'මිනිහා',
#   'මැරුනම',
#   'දැනුන',
#   'දුකට',
#   'වඩා',
#   'දහස්',
#   'ගුනයක',
#   'දුකක්',
#   'දැනෙනවා',
#   'ඉස්සරහට',
#   'උපසම්පදාව',
#   'තියන',
#   'භික්සුවක්',
#   'හිරේ',
#   'යැවුවට',
#   'ඔකි',
#   'වැඩියෙන්ම',
#   'ආදරේ',
#   'කෙනෙක්',
#   'ඔකිට',
#   'නැති',
#   'වෙනවා',
#   'වැඩි',
#   'කල්',
#   'නොගිහින්'],
#  ['මන්',
#   'ඊයේ',
#   'මුස්ලිම්',
#   'ඩෑල්',
#   'එකක්',
#   'එක්ක',
#   'සෙල්ෆියක්',
#   'ගත්තා',
#   'සහජීවනේ',
#   'රැකගෙන',
#   'ඉදිරියට',
#   'යන්න',
#   'ඌ',
#   'ඒක',
#   'තාම',
#   'දාලා',
#   'නෑ',
#   'පරයා'],
#  ['සංහිදියාවට', 'අවුලක්', 'වෙයි', 'ද'],
#  ['කටින්',
#   'පුරසාරම්',
#   'දොඩන',
#   'අපි',
#   'සිංහලයො',
#   'විදියට',
#   'ලැජ්ජා',
#   'විය',
#   'යුතුයි'],
#  ['මචන්',
#   'ඔය',
#   'මගුල',
#   'නවත්තලා',
#   'කොන්දක්',
#   'තියෙනවානම්',
#   'පුලුවන්නම්',
#   'කරලා',
#   'පෙන්නපන්',
#   'ඔය',
#   'දෙසපාලනය',
#   'කරන',
#   'අයගෙන්',
#   'මෙ',
#   'රටට',
#   'මොකක්ද',
#   'වෙලාතියෙන්නෙ',
#   'කියලා',
#   'අන්න',
#   'එදාට',
#   'උබ',
#   'නියම',
#   'කොල්ලෙක්',
#   'පුලුවන්නම්',
#   'කරලා',
#   'පෙන්නනවාද'],
#  ['හැබැයි',
#   'ඒ',
#   'මේ',
#   'ආණ්ඩුවේ',
#   'විතරක්',
#   'නෙවෙයි',
#   'රට',
#   'හූරාගෙන',
#   'තමන්ගෙ',
#   'බූදලය',
#   'කියල',
#   'හිතාගෙන',
#   'රට',
#   'උගස්',
#   'තියල',
#   'සල්ලි',
#   'නයට',
#   'අරගෙන',
#   'තමතමන්ගෙ',
#   'පරම්පරාවෙ',
#   'එවුන්ටයි',
#   'හිතවත්',
#   'එවුන්ටයි',
#   'බෙදාගෙන',
#   'කන',
#   'සියලුම',
#   'දේශපාලකයන්',
#   'දුටු',
#   'දුටු',
#   'තැන',
#   'මරලා',
#   'දාන',
#   'දිනය',
#   'වැඩි',
#   'ඈතක',
#   'නෑ'],
#  ['ලංකාව',
#   'මොකක්ද',
#   'මෙිකෙ',
#   'ඉන්නෙ',
#   'වාහනයක්',
#   'ගත්තම',
#   'අලි',
#   'ඔලුවෙන්',
#   'ඉන්න',
#   'පාරෙ',
#   'යන',
#   'වෙන',
#   'එකෙක්',
#   'ගැන',
#   'හිතන්නැති',
#   'නිරැවත්',
#   'පිංපියො',
#   'වගෙ',
#   'එවුන්',
#   'ටිකක්',
#   'නෙ'],
#  ['උඹ',
#   'ලෝකයක්',
#   'ඉස්සරහ',
#   'හදාගත්ත',
#   'නම්බුව',
#   'ලංකාවේ',
#   'කාලකණ්ණි',
#   'එක',
#   'විනාඩියේන්',
#   'නැති',
#   'කරයි',
#   'බන්',
#   'ඒ',
#   'හන්ද',
#   'දේශපාලනය',
#   'කරන්ට',
#   'එන්ට',
#   'එපා',
#   'මචංංංංං',
#   'ගුඩ්ලක්'],
#  ['පල්ලියකට',
#   'ගලක්',
#   'වැදුනත්',
#   'පරසක්වල',
#   'ගහන',
#   'මූ',
#   'පන්සල්',
#   'බිමට',
#   'සමතලා',
#   'කරද්දී',
#   'සද්ද',
#   'නෑ',
#   'මූට',
#   'කොහොමත්',
#   'ඡන්දෙ',
#   'නම්',
#   'දෙන්නෙ',
#   'නෑ'],
#  ['පංසල්',
#   'විනාශ',
#   'කරද්දී',
#   'ඇරෙන්නේ',
#   'නැති',
#   'සංගාගේ',
#   'කට',
#   'පල්ලියට',
#   'ගල්',
#   'ගහද්දි',
#   'ඇරුණා',
#   'එහෙම',
#   'නායකත්වයක්',
#   'සිංහල',
#   'රට',
#   'ජාතිය',
#   'හදයිද'],
#  ['රට',
#   'හදන්න',
#   'ඕනේ',
#   'නම්',
#   'එන්ජීඕ',
#   'ගැට',
#   'වලින්',
#   'මිදී',
#   'ගෙදරට',
#   'වී',
#   'ඉන්න'],
#  ['රට',
#   'හදන්න',
#   'කලින්',
#   'මිනිසුන්',
#   'රවටන',
#   'ප්\u200dරචාරක',
#   'දැන්විම්',
#   'වලින්',
#   'මුදල්',
#   'හම්බ',
#   'කරන',
#   'එක',
#   'නවත්වා',
#   'සමාජයට',
#   'සේවයක්',
#   'කරන්න'],
#  ['ජයසූරියත්',
#   'ආවෙ',
#   'කෝ',
#   'රට',
#   'හැදුවද',
#   'හැදුවද',
#   'නෑ',
#   'නෙ',
#   'නෑ',
#   'නෙ',
#   'ඌ',
#   'ලමයි',
#   'හැදුවා'],
#  ['ආ', 'එතකොට', 'අපිටත්', 'ඇඩ්', 'එකක', 'ඉන්න', 'පුළුවන්', 'වෙයි', 'නේ'],
#  ['පොන්නයො',
#   'රට',
#   'පලනය',
#   'කරනකොට',
#   'ඔහොම',
#   'තමා',
#   'ජිවිතේ',
#   'අසාවෙන්',
#   'බලපු',
#   'එකම',
#   'දේ',
#   'ක්\u200dරිකට්',
#   'එකත්',
#   'නැති',
#   'කරා',
#   'මේ',
#   'පොන්නයො'],
#  ['ස්ට්\u200dරයික්', 'කරන', 'ඔක්කොටම', 'ගහන්න', 'ඕන', 'දෝස්තරලාත්', 'ඇතුලු'],
#  ['ගිය',
#   'ආන්ඩුව',
#   'කාලෙ',
#   'ඔහොම',
#   'නැටුවේ',
#   'නෑ',
#   'මුන්ගෙ',
#   'කොන්ද',
#   'පන',
#   'නෑ'],
#  ['ඉතිං',
#   'බං',
#   'උබලා',
#   'පිස්සු',
#   'නටලා',
#   'ඊට',
#   'වඩා',
#   'පඩි',
#   'ගන්නෙ',
#   'ඕක',
#   'මොකක්ද'],
#  ['කල්ලතෝනි', 'පකෙක්'],
#  ['අැත්තටම',
#   'හරිම',
#   'සතුටුයි',
#   'එ්',
#   'මනුස්සකමට',
#   'එ්',
#   'වගේම',
#   'අරාබියට',
#   'ගිහින්එන',
#   'අපේ',
#   'මුස්ලිමි',
#   'කාන්තාවන්',
#   'මුන',
#   'වහගෙන',
#   'බිල්ලෝ',
#   'වගේ',
#   'එනකොට',
#   'මේ',
#   'නෝනා',
#   'හරිම',
#   'සුන්දර',
#   'විදියට',
#   'අැවිත්',
#   'ඉන්නවා'],
#  ['මේ',
#   'කැරිවේසිග',
#   'පුතාල',
#   'ඉන්නකල්',
#   'රටට',
#   'කෙලවෙන',
#   'එක',
#   'අහන්නත්',
#   'දෙයක්ද',
#   'බන්',
#   'කාලකන්නි',
#   'හැත්ත',
#   'බල්ලො',
#   'රටේ',
#   'ලොක්කො',
#   'වෙනකොට',
#   'රට',
#   'බල්ලට',
#   'යන',
#   'එක',
#   'අහන්නත්',
#   'දෙයක්ද'],
#  ['තොපි',
#   'වගේ',
#   'නාහෙන්',
#   'අඩන',
#   'කාලකන්නි',
#   'පොන්නයො',
#   'නිසා',
#   'තමයි',
#   'අපේ',
#   'සංගීතයට',
#   'අද',
#   'කණ',
#   'කොකා',
#   'හඩලා',
#   'තියෙන්නෙ',
#   'ලැජ්ජයි',
#   'යකෝ',
#   'තෝ',
#   'වගේ',
#   'එකෙක්',
#   'ආයෙ',
#   'මුණ',
#   'ගැහුනා',
#   'නම්',
#   'ඌත්',
#   'තෝ',
#   'වගේම',
#   'අඩයිනෙ',
#   'දවසක'],
#  ['මොනව', 'උනත්', 'පොලිසියෙ', 'ඉන්නෙ', 'බල්ලො'],
#  ['තෝ',
#   'වගෙ',
#   'එකෙක්',
#   'අනේ',
#   'මන්ද',
#   'යකෝ',
#   'වැදගත්',
#   'දෙයක්',
#   'කරපිය',
#   'ගොන්',
#   'වස්සෙක්',
#   'ඉදකින්',
#   'හුත්තො'],
#  ['ඇයි',
#   'යකෝ',
#   'ලංකාවේ',
#   'පොලිසිය',
#   'නිරායුධ',
#   'මිනිසුන්ට',
#   'ගහන්නේ',
#   'එලවා',
#   'එලවා'],
#  ['පොලිස්සිය',
#   'තාමත්',
#   'කැද',
#   'හැලි',
#   'වගේ',
#   'තරැන',
#   'කොල්ලොන්ට',
#   'ජීවිතෙන්',
#   'වන්දි',
#   'ගෙවන්න',
#   'වෙන්නෙ',
#   'නාකි',
#   'පප්පල',
#   'බුලත්විටක්',
#   'කාගෙන',
#   'අඩි',
#   'දහයක්',
#   'දුවා',
#   'ගන්න',
#   'බැරි',
#   'නිසා'],
#  ['ගිහින්',
#   'ඔය',
#   'එකෙක්ටවත්',
#   'ආපහු',
#   'මේ',
#   'ලෝකේ',
#   'දකින්න',
#   'ඉඩ',
#   'තියන්න',
#   'එපා',
#   'මුන්ව',
#   'හිරේ',
#   'යවන්නනම්',
#   'එපා',
#   'මරලා',
#   'දානවා',
#   'මිසක්'],
#  ['අනේ', 'මෙහෙමත්', 'කුහක', 'මිනිස්සු'],
#  ['මෙතන',
#   'හොරු',
#   'හොදට',
#   'තුවක්කුවලින්',
#   'වෙඩි',
#   'තියනවා',
#   'පොලිසිය',
#   'අත',
#   'වන',
#   'වන',
#   'ඇවිත්',
#   'හොරුන්ගෙන්',
#   'වෙඩි',
#   'කනවා',
#   'ගුටි',
#   'කනවා'],
#  ['මෙලෝ', 'රහක්', 'නැති', 'උන්', 'ඉන්න', 'ටවුන්', 'එකක්'],
#  ['කතා',
#   'කරෝත්',
#   'මහ',
#   'ලොකුවට',
#   'අපි',
#   'දකුණේ',
#   'කෝන්දක්',
#   'තීයන1',
#   'කේනේක්',
#   'නෑ',
#   'පොලිසිය',
#   'අයියව',
#   'උස්සන්න',
#   'ඔය',
#   'උස්සපු',
#   'අයියා',
#   'විතරයි',
#   'පිරිමි',
#   'යේක්',
#   'කියලා'],
#  ['මමනං',
#   'දැක්කේ',
#   'අනිත්',
#   'ඔක්කෝම',
#   'පිරිමී',
#   'අපි',
#   'අදින',
#   'ගවුම්',
#   'වලට',
#   'වඩා',
#   'හෝද',
#   'නයිටි',
#   'ටිකක්',
#   'ඇදගන්න',
#   'ලැජ්ජයි',
#   'මට',
#   'නම්',
#   'මාතර',
#   'අයට',
#   'පිරිමි',
#   'කියන්න',
#   'දැක්ක',
#   'හොදම',
#   'නපුංසකයෝ',
#   'නම්',
#   'මාතර',
#   'තමා',
#   'අනේ',
#   'ප්ලීස්',
#   'ඔය',
#   'මංකොල්ල',
#   'කාරයෝ'],
#  ['ඔක්කෝම',
#   'කෝහෝම',
#   'හරි',
#   'වෙඩිතියල',
#   'මරලා',
#   'දාන්න',
#   'පොලිස්පති',
#   'තුමනි',
#   'අයේත්',
#   'මේවැනි',
#   'දේ',
#   'නොවෙන්න'],
#  ['මව්',
#   'බිම',
#   'නැති',
#   'නම්',
#   'මරණය',
#   'මෙයයි',
#   'තේමා',
#   'පාටය',
#   'විය',
#   'යුත්තේ',
#   'ඔය',
#   'පෝන්',
#   'කෝල්',
#   'වලට',
#   'බයේ',
#   'රාජකාරි',
#   'කරන',
#   'කාලය',
#   'ඇත',
#   'හැරි',
#   'යුතුයි'],
#  ['තුවක්කුවක්',
#   'නැත්තං',
#   'පැත්තකට',
#   'වෙලා',
#   'ඉදපංකො',
#   'විහිං',
#   'මැරැම්කන්නැතිව',
#   'තුවක්කු',
#   'තියං',
#   'ඉන්න',
#   'මංකොලල',
#   'කාරයන්ට',
#   'බැටන්පොල්ලෙන්',
#   'ගහන්න',
#   'ගියාම',
#   'මැරැංකන',
#   'එක',
#   'අහන්නත්',
#   'දෙයක්ද',
#   'මේක',
#   'මහ',
#   'මෝඩයෙක්'],
#  ['මත්ද්\u200dරව්\u200dයවලට',
#   'ඇබ්බැහි',
#   'වෙලා',
#   'මිනිස්සු',
#   'මරලා',
#   'හරි',
#   'සල්ලි',
#   'ඔිිනි',
#   'පොලිසියට',
#   'පෙර',
#   'පුහුණුවක්',
#   'නැති',
#   'විම',
#   'පුජිත',
#   'දේසපාලකන්ගේ',
#   'කකුල්',
#   'ලේවකනවා',
#   'කොල්ලා',
#   'නිකන්',
#   'මැරැැනා'],
#  ['යකෝ',
#   'හරිහමන්',
#   'තුවක්කුවක්',
#   'දෙන්න',
#   'බැරිද',
#   'බන්',
#   'ඇමති',
#   'අයගේ',
#   'වාහන',
#   'වලට',
#   'කෝටි',
#   'ප්\u200dරකෝටි',
#   'ගනන්',
#   'නාස්ති',
#   'කරනවා',
#   'ඕන',
#   'දේකට',
#   'වියදම්',
#   'කරන්නේ',
#   'නෑ'],
#  ['අර',
#   'දිවියව',
#   'මරපු',
#   'මිනිස්සු',
#   'තරම්',
#   'අපරාධ',
#   'කාරයෝ',
#   'නෙමේ',
#   'වෙන්න',
#   'ඇති',
#   'මේ',
#   'පොලිස්',
#   'නිලධාරියාව',
#   'මරපු',
#   'මිනිමරුවෝ',
#   'එකනේ',
#   'ඒ',
#   'තරම්',
#   'දරුණු',
#   'වචන',
#   'නැත්තේ',
#   'මේ',
#   'මිනි',
#   'මරුවන්ට',
#   'එරෙහිව'],
#  ['තවත්', 'එක්', 'සෝමාලියාවක්', 'වගේ', 'ශිට්'],
#  ['පාතාලයේ', 'කියන', 'හැම', 'එකාවම', 'මරල', 'දාන්න', 'ඕනා'],
#  ['ත්\u200dරිවිධ',
#   'හමුදාවට',
#   'පොලිසිය',
#   'අසරණ',
#   'කරන්න',
#   'තහංචි',
#   'පනවා',
#   'හොරුන්ට',
#   'නීති',
#   'රීති',
#   'ලිහිල්වුන',
#   'රටක්',
#   'ලංකාව'],
#  ['කියන්න', 'නම්', 'එපා', 'අපි', 'දකුනේ', 'කියලා', 'විලි', 'ලැජ්ජයි', 'යකෝ'],
#  ['ඕකුන්වත්',
#   'පෝලිමට',
#   'තියලා',
#   'මරලා',
#   'දාපල්ලා',
#   'අර',
#   'අහිංසකයට',
#   'වුනා',
#   'වගේම'],
#  ['වෙනසෙ', 'සැප', 'පේනවනේ', 'මෙි', 'රටෙි', 'නිතිය', 'බල්ලට', 'ගිහින්'],
#  ['දැන්',
#   'බැන',
#   'බැන',
#   'මේකෙ',
#   'පෝස්ට්',
#   'දැම්මට',
#   'මේවා',
#   'පිලිවෙලට',
#   'මහින්දගෙ',
#   'කාලෙ',
#   'සිද්ධ',
#   'උනා',
#   'ඒවාට',
#   'අසංවේදී',
#   'උන',
#   'මෝඩ',
#   'උද්ධච්ඡ',
#   'මිනිස්සුන්ගෙ',
#   'ඡන්ද',
#   'වල',
#   'පිහිටෙන්',
#   'ලැබුනු',
#   'වෙනස',
#   'තමයි',
#   'මේ',
#   'තියෙන්න්නේ'],
#  ['තුවාල',
#   'වලට',
#   'බේත්',
#   'දානවා',
#   'වගේ',
#   'කියන්න',
#   'දුකයි',
#   'සිංහල',
#   'ජාතිය',
#   'කාළකණ්නි',
#   'ජාතියක්',
#   'බවට',
#   'පත්',
#   'වී',
#   'හමාරයි'],
#  ['ඇත්තම', 'කියනවනම්', 'ලංකාව', 'හරිම', 'කාලකන්නි', 'රටක්'],
#  ['කාලකන්නි',
#   'හැතිකරය',
#   'අපේ',
#   'සල්ලි',
#   'වලින්',
#   'ලබු',
#   'කන',
#   'මෙි',
#   'වාගේ',
#   'රජයේ',
#   'අයතන',
#   'වලට',
#   'හන',
#   'හගන්න',
#   'ඔන'],
#  ['මුන්', 'ඔක්කොම', 'රට', 'කනවා', 'අනේ', 'අපේ', 'බදු', 'ගන්න', 'සල්ලි'],
#  ['මොනතරම්',
#   'ගින්දරක්',
#   'පපු',
#   'ඇතුලේ',
#   'පත්තු',
#   'වෙනවා',
#   'අැද්ද',
#   'තාත්තා',
#   'මේ',
#   'අත්',
#   'පා',
#   'උස්මහත්',
#   'කරපු',
#   'තාත්තා',
#   'දෙයියනේ',
#   'ශාප',
#   'වෙයි',
#   'උඹලට',
#   'මේ',
#   'ආත්මෙම'],
#  ['උගෙ',
#   'අප්පගෙ',
#   'නීතියක්නෙ',
#   'යකො',
#   'එක',
#   'අර',
#   'රංගෙ',
#   'බන්ඩාරගෙ',
#   'පුතා',
#   '3',
#   'පාරක්',
#   'වාහනෙ',
#   'හප්පලා',
#   'එක',
#   'මිනිහෙක්',
#   'මරලා',
#   'පවුලක්',
#   'අබ්බගාතයො',
#   'කරා',
#   'කො',
#   'නිතිය',
#   'මෙපාර',
#   'ගෙයක්',
#   'කුඩු',
#   'කරලා',
#   'හොදටම',
#   'බීලා',
#   'වාහනෙ',
#   'ඇතුලෙ',
#   'කඩු',
#   'පොලු',
#   'තියෙද්දිත්',
#   'කොහොමද',
#   'යකො',
#   'ඌට',
#   'ඇප',
#   'දෙන්නෙ'],
#  ['ගොං', 'හුත්තී', 'හැමිනියන්', 'වෙසී', 'තොට', 'සාප', 'වේනවා', 'බැල්ලීයේ'],
#  ['කියන්න',
#   'දුකයි',
#   'අපෙ',
#   'රටේ',
#   'ලොකු',
#   'තැන්වල',
#   'උන්',
#   'පිරිහිලා',
#   'ඉවරයි',
#   'බලයට',
#   'ධනයට',
#   'ආගම',
#   'ජාතිය',
#   'විකුණනවා',
#   'උන්',
#   'දන්නෙ',
#   'නැ',
#   'උන්ට',
#   'වෙන්නේ',
#   'මොකක්ද',
#   'කියල',
#   'මෙවට',
#   'වගකිවයුතු',
#   'වන්නේ',
#   'ඉහළ',
#   'පෙලෙ',
#   'ඉන්න',
#   'උන්',
#   'අපෙ',
#   'ආගම',
#   'ජාතිය',
#   'විනාස',
#   'කරන',
#   'සක්කිලින්ට',
#   'කන්න',
#   'ගූත්',
#   'නැතිවෙනව',
#   'කාලකන්නි'],
#  ['මේ',
#   'බැල්ලි',
#   'කොටින්ගේ',
#   'ගු',
#   'කනකොට',
#   'අපහසුවක්',
#   'දැනුනෙ',
#   'නැද්ද',
#   'දන්',
#   'නැහැ',
#   'ඔකිට',
#   'මිනිහා',
#   'මැරුනම',
#   'දැනුන',
#   'දුකට',
#   'වඩා',
#   'දහස්',
#   'ගුනයක',
#   'දුකක්',
#   'දැනෙනවා',
#   'ඉස්සරහට',
#   'උපසම්පදාව',
#   'තියන',
#   'භික්සුවක්',
#   'හිරේ',
#   'යැවුවට',
#   'ඔකි',
#   'වැඩියෙන්ම',
#   'ආදරේ',
#   'කෙනෙක්',
#   'ඔකිට',
#   'නැති',
#   'වෙනවා',
#   'වැඩි',
#   'කල්',
#   'නොගිහින්'],
#  ['අපේ',
#   'හමුදාව',
#   'බර',
#   'අවි',
#   'කෙමිකල්',
#   'මිසයිල',
#   'පාවිච්චි',
#   'කරලා',
#   'සමූලඝාතන',
#   'සිදුකලා',
#   'කියලා',
#   'මේ',
#   'හුත්තිගෙ',
#   'මිනිහා',
#   'කිව්වා',
#   'ඒකම',
#   'මේ',
#   'හුත්තිත්',
#   'කියනවා',
#   'එහෙම',
#   'එකේ',
#   'මේ',
#   'කැරි',
#   'වේසිට',
#   'දඩුවම්',
#   'දෙන්නෙ',
#   'එකෙක්',
#   'නැද්ද',
#   'මේ',
#   'බල්ලන්ට',
#   'අල්ලන',
#   'කැරි',
#   'වේසි',
#   'හමගහන්න',
#   'ඕනි',
#   'පනපිටින්'],
#  ['මෙිි',
#   'හුත්තිට',
#   'සතුටුයිලු',
#   'අපේ',
#   'රටහරක්ටිකටත්',
#   'සතුටුඇති',
#   'අපේ',
#   'හාමුදුරැන්\u2063ට',
#   'දුන්න',
#   'දඩුවමට',
#   'දුකයි',
#   'ඊටත්වැඩිය',
#   'මරාගන',
#   'මැරෙන්න',
#   'හිතෙන්නෙ',
#   'අපෙහාමුදුරැවන්ට',
#   'ජමිිබරේ',
#   'අන්දපුඑකට',
#   'යකෝ'],
#  ['සංඝා',
#   'වහන්සේ',
#   'නමකට',
#   'විශේෂයෙන්',
#   'බුද්ධ',
#   'චිවරයට',
#   'අගෞරව',
#   'කල',
#   'පාපයට',
#   'නුඹට',
#   'මතු',
#   'මතුත්',
#   'සාප',
#   'වෙිවා'],
#  ['කැරි', 'වේසි', 'හෙනගහපිය'],
#  ['මේ', 'වගේ', 'ගැනු', 'මේ', 'රටේන්', 'එලවන්න', 'ඔන', 'නොදකින්', 'ශාපවේවා'],
#  ['අපේ', 'අමන', 'පාලකයොන්ගේ', 'වැරදි'],
#  ['ගොන්', 'වේසී', 'මිනිහා', 'ගිය', 'තැනටම', 'යන්න', 'දගලනවා', 'වගේ'],
#  ['පල',
#   'වේසියෙ',
#   'යන්න',
#   'මේ',
#   'ලෝකෙන්ම',
#   'තොලොන්චි',
#   'වෙලා',
#   'හැප්පිය',
#   'වාහනේකට',
#   'මැරෙන්නම',
#   'බැල්ලිව'],
#  ['මුස්ලිම්',
#   'රටක',
#   'ආගමික',
#   'නායකයකු',
#   'මෙ',
#   'දෙ',
#   'කලානම්',
#   'රාජ්\u200dය',
#   'ගෙෘරව',
#   'ජනතාවට',
#   'දෙවියෝ'],
#  ['හෙන', 'හත', 'ගහපන්'],
#  ['මේ',
#   'කල',
#   'දේට',
#   'තෝනමි',
#   'විඳවලා',
#   'මැරෙන්න',
#   'ඕන',
#   'තොට',
#   'හෙන',
#   'හතම',
#   'වැදියන්'],
#  ['හෙන', 'ගහනවා', 'කැරි', 'වෙසිට'],
#  ['අපරාද', 'කාරයෝ', 'රට', 'පාවලා', 'දෙන', 'උන්', 'රකින', 'සක්කිලි', 'ආන්ඩුව'],
#  ['සාප', 'වේවා', 'තිට', 'හෙන', 'හතම', 'වැදියන්'],
#  ['පට්ට', 'බැල්ලි', 'බල්ලො', 'දම්මලා', 'හුකන්න', 'ඉනී'],
#  ['ජම්පරේ', 'ගස්සන්ඩ', 'ඕනී', 'ආයේ', 'චීවරේ', 'නොදාන්නම'],
#  ['මෙි', 'ගැනිට', 'සාප', 'වෙිවා'],
#  ['පනපිටින්', 'අපායෙ', 'පල', 'කොටිදෙන'],
#  ['කොටි', 'දෙනක්'],
#  ['හම්පඩ', 'පඩංගු', 'දෙමළු', 'වේසාවි'],
#  ['බලු',
#   'වෙසි',
#   'තොගෙ',
#   'අම්මා',
#   'බල්ලොත්',
#   'ලැගලා',
#   'තොව',
#   'ජාතක',
#   'කරලා',
#   'තියෙන්නේ'],
#  ['තෙවරප්පෙරැමට', 'අහුඋනොත්', 'ඔක්කොම', 'ගුටි', 'කනවා', 'යකෝ'],
#  ['ලංකාවෙි',
#   'මිනිස්සුන්ට',
#   'මොනතරමි',
#   'හොද',
#   'කලත්',
#   'වැඩක්',
#   'නැ',
#   'ඒ',
#   'අයගේ',
#   'ආකල්ප',
#   'වෙනස්කරන්න',
#   'බැ',
#   'මෙි',
#   'කමෙන්ටි',
#   'වලින්',
#   'ඒදේ',
#   'වැටහෙනවා',
#   'මහා',
#   'මෝඩ',
#   'මිනිස්සු',
#   'බහුතරයක්'],
#  ['පොලීසිය', 'ගොං', 'ආතල්', 'දෙනවා', 'පූජිතයෝ', 'උබට', 'තියෙන', 'වැඩ', 'මේවද'],
#  ['මේ',
#   'යුද්ධයේ',
#   'සැබෑම',
#   'අවසානය',
#   'වෙන්න',
#   'ඕන',
#   'මේකයි',
#   'දැන්වත්',
#   'කඩප්පුලි',
#   'විග්නේෂ්වරන්',
#   'සිවාජිලිංගම්',
#   'සම්බන්ධන්',
#   'සුමන්තිරන්',
#   'වැනි',
#   'කාළක්නි',
#   'දේශපාලකයින්',
#   'දේශපාලනයෙන්',
#   'අතුගා',
#   'දැමිය',
#   'යුතුයි'],
#  ['මෙතන',
#   'දී',
#   'අර',
#   'පාර්ලිමේන්තුවේ',
#   'ඉන්න',
#   'කක්කූසි',
#   'කටා',
#   'නොහොත්',
#   'දත්',
#   'දොස්තර',
#   'කාල',
#   'කන්නි',
#   'රාජිතයා',
#   'මතක්',
#   'වෙනකොට',
#   'මගේ',
#   'මාළු',
#   'නටනවා'],
#  ['කෝ',
#   'අපේ',
#   'නානසාර',
#   'ස්වාමීන්',
#   'වහන්සේ',
#   'ඒ',
#   'හිමියනට',
#   'පුළුවන්',
#   'මේ',
#   'වගේ',
#   'සෙබළුන්ගෙන්',
#   'ආදර්ශ',
#   'එහෙම',
#   'ලබාගන්න',
#   'බුදුන්ගෙන්',
#   'ආදර්ශ',
#   'ලබාගත්තේ',
#   'නැතිකොට',
#   'ඉතින්',
#   'මොකෙක්ගෙන්වත්',
#   'ආදර්ශ',
#   'ගනීද'],
#  ['ලංකාවේ', 'තම', 'හරක්', 'ඉන්න', 'නිසා', 'ඕවා', 'හොඳට', 'පිළිගන්නවා'],
#  ['අපේ',
#   'හරකුන්ට',
#   'ගහක්',
#   'හිටවන්න',
#   'ගියත්',
#   'කුඩයක්',
#   'අල්ලන්න',
#   'ඔනේ',
#   'බහින්න',
#   'වලකුත්',
#   'හාරලා',
#   'දෙන්න',
#   'ඔනේ',
#   'අපි',
#   'හරි',
#   'පවු',
#   'නේ'],
#  ['දැන්',
#   'ටික',
#   'කාලෙකට',
#   'කලින්',
#   'පාලත්',
#   'සභා',
#   'මන්ත්\u200dරී',
#   'ජුන්ඩේක්',
#   'පොලිස්',
#   'මහතෙක්',
#   'හැදුලුම්',
#   'පත',
#   'ඉල්ලූවා',
#   'කියලා',
#   'දාපු',
#   'ගෙම්බර්',
#   'මතක්',
#   'වුනා'],
#  ['අම්මෝ', 'ඒක', 'හොදයි', 'ඒත්', 'දාගෙන', 'යන්නේ', 'පාරෙ', 'නේද'],
#  ['මූ', 'ජයරත්නගෙ', 'නෑදෑයෙක්ද', 'කොහෙද'],
#  ['වැස්සොත්', 'ශොට්', 'වෙල', 'මැරෙන්නෙ'],
#  ['ඇඩ්',
#   'නම්',
#   'ඇඩ්',
#   'ලංකාව',
#   'දියුනු',
#   'නෑ',
#   'කියන',
#   'වුන්',
#   'ට',
#   'කනට',
#   'ගහලා',
#   'මෙක',
#   'පෙන්නපල්ලා'],
#  ['මේක', 'දියුණුවක්', 'කියලා', 'හිතනවා', 'නම්', 'උබට', 'වැරදිලා', 'සහෝදරයා'],
#  ['ගෙදරට', 'වෙලා', 'පාඩම්', 'කරපල්ලකෝ', 'පැය', 'ගනන්', 'පෝලීමේ', 'ඉන්නේ'],
#  ['මෙච්චර',
#   'අමාරුවෙන්',
#   'පුටුවක්',
#   'අල්ලගන්න',
#   'ඕනිද',
#   'ගහක්',
#   'යට',
#   'වාඩිවෙලා',
#   'පාඩම්',
#   'කරන්න',
#   'පුළුවන්'],
#  ['විඩීයෝ', 'එක', 'අප්සට්', 'පේන්නේ', 'නෑ', 'හරියට'],
#  ['යක්කුන්ට', 'ලජ්ජා', 'කරන්න', 'එපා', 'මුන්ට', 'සමානකරලා'],
#  ['ඒකෙන්',
#   'මේකෙන්',
#   'උනේ',
#   'ගීතට',
#   'නමටහරි',
#   'හිටිය',
#   'මිනිහ',
#   'නැතිවුන',
#   'එක',
#   'විතරයි'],
#  ['මුන්',
#   'ගෙන්',
#   'ඇති',
#   'වැඩක්',
#   'නැ',
#   'තමයි',
#   'ඒ',
#   'උනාට',
#   'ඉඩල',
#   'හිටලා',
#   'වැදගත්',
#   'දෙවලුත්',
#   'නොකියන',
#   'වම',
#   'නෙවෙයි'],
#  ['බයිසන්ලට', 'ඉතින්', 'සුරංගනාවියන්', 'තමයි'],
#  ['මීට', 'කලින්', 'දැකලැ', 'නැ'],
#  ['මටනම්', 'හිතෙන්නේ', 'මේ', 'මිනිහා', 'තමයි', 'ඇත්ත', 'ඩයල්', 'එක', 'කියලා'],
#  ['දුප්පත්',
#   'මිනිසුන්',
#   'සියගනනකට',
#   'පැල්පතක්',
#   'තනාදෙන්න',
#   'තීබු',
#   'අපුරුව',
#   'නේද'],
#  ['පිහි',
#   'ඇනුම්',
#   'ගුටි',
#   'කෙලි',
#   'ඇතුලු',
#   'විනෝද',
#   'ක්\u200dරීඩා',
#   'රැසකුත්',
#   'ඇති',
#   'නෙහ්'],
#  ['මෙක',
#   'ගෑන',
#   'දන්න',
#   'එකෙක්',
#   'කියපන්',
#   'හරියටම',
#   'දන්න',
#   'එකෙක්',
#   'කන්ටැක්',
#   'කර',
#   'ගන්න',
#   'ඔනී'],
#  ['ඊළඟට',
#   'මේවල',
#   'සාමාන්\u200dය',
#   'මිනිස්සුන්ට',
#   'යන්න',
#   'බැරි',
#   'වෙන',
#   'විදිහට',
#   'ගණන්',
#   'වැඩි',
#   'විශේෂ',
#   'ටිකට්',
#   'එකක්',
#   'නිකුත්',
#   'කරන්න',
#   'ඕනේ'],
#  ['දවස',
#   'අන්තිමේ',
#   'යාඩ්',
#   'එකට',
#   'ගෙනල්ලා',
#   'නැවැත්තුවාම',
#   'එතන',
#   'ආරක්ෂාවත්',
#   'වැඩි',
#   'කරන්න',
#   'වෙනවා',
#   'රෑට',
#   'ෆෑන්',
#   'පන්නන',
#   'අයත්',
#   'ඉන්න',
#   'පුළුවන්',
#   'නේ'],
#  ['තව',
#   'මේවා',
#   'ඇතුල',
#   'සතියකට',
#   'දෙසැරයක්',
#   'වත්',
#   'පිරිසිදු',
#   'කරන්න',
#   'ඕනේ',
#   'විශේෂයෙන්ම',
#   'ටොයිලට්',
#   'තව',
#   'පිටත',
#   'මසෙට',
#   'දෙසැරයක්',
#   'වත්',
#   'ක්ලීන්',
#   'කරන්න',
#   'ඕනේ',
#   'එහෙම',
#   'කලොත්',
#   'ඔන්න',
#   'අවුරුදු',
#   '5ක්',
#   'වත්',
#   'ලස්සනට',
#   'තියාගතහැකි'],
#  ['ලංකාවට',
#   'ඕව',
#   'හරියන්නෙ',
#   'නෑ',
#   'බන්',
#   'අපි',
#   'සුපෝකබෝගී',
#   'දේවල්',
#   'විදින්න',
#   'කලින්',
#   'අපේ',
#   'මනස',
#   'හුරුකරගන්න',
#   'ඕන',
#   'අනිත්',
#   'උන්ටත්',
#   'ඒක',
#   'විදින්න',
#   'ඉතුරුකරල',
#   'යන්න',
#   'අපි',
#   'සිංහලනෙ',
#   'සිංහයන්ගෙන්ලුනෙ',
#   'පැවතගෙන',
#   'එන්නෙ',
#   'අපිට',
#   'බෑ',
#   'ප්\u200dරෙන්',
#   'අපිට',
#   'වනන්තර',
#   'වගේ',
#   'ඒව',
#   'ගෙනත්',
#   'දෙන්න',
#   'ඒවනම්',
#   'හරි',
#   'යනව',
#   'මම',
#   'දැකල',
#   'තියනවනෙ',
#   'අලුතින්ම',
#   'ගෙනාපු',
#   'කෝච්චි',
#   'වලට',
#   'අපේ',
#   'ඔපිස්',
#   'යන',
#   'සෙට්',
#   'ට්\u200dරිප්',
#   'යන',
#   'සෙට්',
#   'සිගිති',
#   'පාතාල',
#   'කාරයො',
#   'කරන',
#   'වැඩ',
#   'බොකක්',
#   'ලෝඩ්වෙලා',
#   'කෝච්චියෙ',
#   'ටොයිලට්',
#   'එකට',
#   'ගියොත්',
#   'පුදුම',
#   'හාස්කමක්',
#   'වෙන්නෙ',
#   'බොක',
#   'නැතිවෙනව',
#   'එක්කෝ',
#   'බොක',
#   'කටින්',
#   'යන්න',
#   'එනව'],
#  ['ඔය',
#   'පොටෝ',
#   'ටිකම',
#   'තව',
#   'මාසයකින්',
#   'අරන්',
#   'බලන්න',
#   'සීට්',
#   'ටිකයි',
#   'එන්ජිමයි',
#   'විතරයි',
#   'ඉතුරු',
#   'අනිත්',
#   'ඔක්කොම',
#   'ගලවනවා',
#   'සත්තයි',
#   'අපේ',
#   'එඋන්'],
#  ['සාමාන්\u200dය',
#   'මිනිස්සුන්ගෙන්',
#   'පරිස්සම්',
#   'කරගන්න',
#   'පුලුවන්',
#   'ඒත්',
#   'කෝච්චි',
#   'වල',
#   'යන',
#   'ඔෆිස්',
#   'සෙට්',
#   'එක',
#   'කියලා',
#   'අමුතුම',
#   'සත්තු',
#   'ජාතියක්',
#   'උන්',
#   'කන',
#   'දේ',
#   'එකෙම',
#   'දානවා',
#   'හොර',
#   'ගෑනු',
#   'එක්ක',
#   'එකතු',
#   'වෙලා',
#   'සීට්',
#   'හුරනවා',
#   'ගොඩක්ම',
#   'කෝච්චි',
#   'විනස',
#   'කරන්නේ',
#   'ඒ',
#   'අහිගුන්ටකයෝ'],
#  ['විනයක්',
#   'නැති',
#   'පිරහෙමින්',
#   'තිබෙන',
#   'ජාතිය',
#   'බදු',
#   'මුදල්',
#   'වලින්',
#   'ගන්නා',
#   'මේවා',
#   'කොපමන',
#   'කල්',
#   'රැකගනීවිද',
#   'මන්දා',
#   'මිනිසුනේ',
#   'පොදු',
#   'දේපල',
#   'රැකගනිව්',
#   'බලි',
#   'කුරුටු',
#   'ගා',
#   'අපවිත්\u200dර',
#   'නොකරව්'],
#  ['ෂීට්',
#   'කඩලා',
#   'ජරා',
#   'කරන',
#   'එකෙක්',
#   'දැක්කොත්',
#   'පොන්නයෝ',
#   'වගේ',
#   'බලන්',
#   'ඉන්නැතුව',
#   'අත',
#   'පුරෝල',
#   'කන',
#   'පැලෙන්න',
#   'ගහපන්',
#   'අනිත්',
#   'උන්ටත්',
#   'පෙන්න'],
#  ['මගිජනතාව',
#   'වගේම',
#   'දුමිරිය',
#   'දෙපාර්තමේන්තු',
#   'සේවකයන්',
#   'තුත්',
#   'මෙය',
#   'රැකගන්න',
#   'කටයුතු',
#   'කලයුතුයි',
#   'මොකද',
#   'ගමන්',
#   'වාරයක්',
#   'අවසන',
#   'මෙම',
#   'දුමිරිය',
#   'මැදිරි',
#   'ඉතා',
#   'හොදින්',
#   'පිරිසිදු',
#   'කර',
#   'අඩුපාඩු',
#   'සැකසිය',
#   'යුතුයිි',
#   'දැන්',
#   'බලන්න',
#   'රැහුනු',
#   'කුමාරි',
#   'ගාලුකුමාරි',
#   'ෆැන්',
#   'වැඩ',
#   'නැ',
#   'මකුනුදැල්',
#   'බැදිල',
#   'හුඩි',
#   'එක',
#   'දුවිලිවලින්',
#   'පිරිල',
#   'මෙව',
#   'රැකගන්න',
#   'දෙගොල්ල',
#   'ම',
#   'දායක',
#   'වියයුතුමයි'],
#  ['අපේ',
#   'එවුන්ට',
#   'ලියන්න',
#   'සිට්',
#   'ඉරන්න',
#   'කඩල',
#   'කන්න',
#   'බඩ',
#   'ඉරුගු',
#   'කන්න',
#   'එ',
#   'කාපු',
#   'එවා',
#   'එතන',
#   'ම',
#   'දලා',
#   'යන්න',
#   'ට්\u200dර්ප්',
#   'ගිහිල්ලා',
#   'බොක',
#   'කරලා',
#   'එන්න',
#   'ආපු',
#   'අලුත්',
#   'භාන්ඩේ',
#   'දැන්',
#   'කියන්න',
#   'එපා',
#   'අපො',
#   'ඉංදියන්',
#   'ජාරාව',
#   'කියලා',
#   'ඉස්සල්ලා',
#   'පුරුදු',
#   'වේයල්ලා',
#   'කඩල',
#   'ගොටු',
#   'කුනු',
#   'මල',
#   'ජාරාව',
#   'මානසික',
#   'ලෙඩ්ඩු',
#   'වගේ',
#   'ලියන',
#   'එවා',
#   'නවත්තන්න',
#   'පස්සේ',
#   'හොයපල්ලා',
#   'ඇද',
#   'කුද'],
#  ['ඔය',
#   'කොච්චිය',
#   'අගුලාන',
#   'කොරලවෙල්ල',
#   'මොරටුව',
#   'එ',
#   'දුම්රිය',
#   'ස්තාන',
#   'වල',
#   'නවත්තන්න',
#   'එපා',
#   'ඔය',
#   'කොච්චියේ',
#   'තියන',
#   'සෙප',
#   'පහසුකම්',
#   'ටික',
#   'මාසයක්',
#   'යනකොට',
#   'එ',
#   'පෙත්තේ',
#   'ගෙවල්',
#   'වල',
#   'තියෙයි'],
#  ['යකෝ',
#   'හැම',
#   'එකාම',
#   'කියන්නෙ',
#   'සතියෙන්',
#   'කයි',
#   'කියලා',
#   'බලන්',
#   'යද්දි',
#   'මෙව්වා',
#   'කන්ඩ',
#   'එකෙක්',
#   'නෑනෙ'],
#  ['ඕක',
#   'සතියයි',
#   'ඉවරයි',
#   'ගාගා',
#   'කමෙන්ට්',
#   'දාන්නේ',
#   'පිටරට',
#   'උන්',
#   'වෙන්නැති',
#   'දැන්'],
#  ['අපේ',
#   'මහින්ද',
#   'මහත්තයා',
#   'ඇවිත්',
#   'මාසයයි',
#   'කොහොමද',
#   'එයාගෙ',
#   'වැඩ',
#   'ටොයියොන්ට',
#   'ජෙප්පොන්ට',
#   'පේන්න',
#   'ලයික්',
#   'එකක්',
#   'දාන්න'],
#  ['මට',
#   'තියෙන',
#   'ප්\u200dරශ්නේ',
#   'අර',
#   'ටීවි',
#   'එක',
#   'අඩු',
#   'වැඩි',
#   'කරන',
#   'සුවිච්',
#   'එකෙන්',
#   'අපේ',
#   'උන්',
#   'ආතල්',
#   'ගනීද',
#   'කියලා'],
#  ['අපේ',
#   'රටට',
#   'ඕව',
#   'හරියන්',
#   'නෑ',
#   'මොකද',
#   'මිනිස්සු',
#   'අඩුයි',
#   'දැන්',
#   'ඒ',
#   'වගේම',
#   'සමහරුන්ට',
#   'මොලයක්',
#   'නෑ',
#   'මේක',
#   'නඩත්තු',
#   'වෙන්නෙ',
#   'අපේ',
#   'බදු',
#   'මුදලින්',
#   'කියල',
#   'ඒක',
#   'නිසා',
#   'මේව',
#   'උපරිම',
#   'මාසයයි',
#   'පිලිවෙලට',
#   'තියෙන්නෙ'],
#  ['මාස',
#   'කීයක්',
#   'මේ',
#   'පිලිවෙලට',
#   'තියෙයිද',
#   'දන්නෙ',
#   'නෑ',
#   'ඕක',
#   'ඇතුලේ',
#   'කෑලි',
#   'ටිකත්',
#   'ගලවගෙන',
#   'නොගියොත්',
#   'තමයි',
#   'පුදුම'],
#  ['ඕවා',
#   'සාමාන්\u200dය',
#   'මගී',
#   'ජනතාවට',
#   'යන්න',
#   'ගෙන්නපුව',
#   'නෙවෙයි',
#   'මේවා',
#   'ගෙන්නන',
#   'එවුන්ව',
#   'කාර්\u200dයාල',
#   'දුම්\u200d',
#   'රියක',
#   'ටික',
#   'දවසක්',
#   'යවන්න',
#   'ඕන',
#   'දුම්',
#   'රිය',
#   'ගාස්තු',
#   'නහුතෙට',
#   'වැඩි',
#   'කරලා',
#   'ඒ',
#   'සල්ලිවලින්',
#   'වෙලාවට',
#   'දෙපැත්තට',
#   'පැද්දෙන්නෙ',
#   'නැතුව',
#   'ඉල',
#   'ඇට',
#   'කඩා',
#   'ගන්නෙ',
#   'නැතුව',
#   'යන්න',
#   'පුලුවන්',
#   'විදිහෙ',
#   'දුම්',
#   'රිය',
#   'සේවයක්',
#   'හදපල්ලා'],
#  ['ඉහල',
#   'සියට',
#   'පහලට',
#   'ආදර්ශයක්',
#   'නොදී',
#   'රටක',
#   'විනයක්',
#   'ඇති',
#   'කල',
#   'නොහැක',
#   'සිංගප්පූරුව',
#   'එයට',
#   'හොදම',
#   'ආදර්ශයයි',
#   'ලංකාවෙ',
#   'ඉහලින්',
#   'පහලට',
#   'දෙන',
#   'යහපත්',
#   'ආදර්ශය',
#   'කුමක්ද'],
#  ['රැකගනිල්ලා',
#   'ඇහැවගේ',
#   'නැත්නම්',
#   'වවුලෝ',
#   'වගේ',
#   'තමයි',
#   'හැමදාම',
#   'තොපිට',
#   'යන්න',
#   'වෙන්නේ',
#   'වනසන',
#   'එකෙක්',
#   'දැක්කොත්',
#   'හැමෝම',
#   'එකාවගේ',
#   'නැගීහිටපල්ලා',
#   'මට',
#   'අදාල',
#   'නෑනේ',
#   'කියලා',
#   'නොහිතා',
#   'ජනතාව',
#   'හැටියට',
#   'අපි',
#   'අපේ',
#   'වගකීමවත්',
#   'හරියට',
#   'ඉෂ්ඨ',
#   'කරමු'],
#  ['මේ',
#   'දුම්රියේ',
#   'ගමන්වාර',
#   'අවසානයේදී',
#   'දුම්රියේ',
#   'මැදිරි',
#   'අපේ',
#   'ජනතාව',
#   'පාවිච්චි',
#   'කරලා',
#   'තියෙන',
#   'විදිය',
#   'රටටම',
#   'පෙන්වන්න',
#   'ඕනේ',
#   'කියලා',
#   'යෝජනා',
#   'කරනවා'],
#  ['මෙක',
#   'දකිද්දී',
#   'මට',
#   'හිතෙන්නේ',
#   'ඉන්දියාව',
#   'කොච්චර',
#   'ඉස්සරහින්ද',
#   'අපිට',
#   'වඩා'],
#  ['ඔකෙ',
#   'යන්නෙ',
#   'පරණ',
#   'එව්න්',
#   'ටිකමනෙ',
#   'මාස',
#   'තුනක්',
#   'යද්දී',
#   'කහල',
#   'ගොඩක්',
#   'වගේ',
#   'තියේවි'],
#  ['ඉන්දීය',
#   'දුම්රියන්',
#   'එන්න',
#   'එන්නම',
#   'අසාර්තකයි',
#   'ඇයි',
#   'ඒවම',
#   'ගෙන්වන්නෙ',
#   'මේකෙනුත්',
#   'කොමිස්',
#   'කුට්ටි',
#   'එන',
#   'නිසාද'],
#  ['ලංකාව',
#   'ඉන්දියාවේ',
#   'කොලනියක්',
#   'වෙන',
#   'රටවල',
#   'නැතිද',
#   'කොහොමත්',
#   'ඉන්දියාවේ',
#   'බයික්',
#   'වගේ',
#   'ඇති'],
#  ['ඔකොම',
#   'තිබිලා',
#   'අන්තිමට',
#   'කලින්',
#   'එවගේ',
#   'වගේ',
#   'බ්\u200dරේක්',
#   'අවුලක්',
#   'උනොත්',
#   'තමා',
#   'අවුල'],
#  ['විදේශ',
#   'රටවල',
#   'මේ',
#   'වගේ',
#   'කෝච්චි',
#   'වල',
#   'ආහාර',
#   'හා',
#   'කෑම',
#   'ගැනීම',
#   'තහනම්',
#   'ඒකයි',
#   'ඒව',
#   'පිරිසිදුවට',
#   'තියෙන්නෙ'],
#  ['මේවායේ',
#   'ගමන්',
#   'කරන',
#   'සහ',
#   'පාවිච්චි',
#   'කරන',
#   'විදියත්',
#   'ලංකාවේ',
#   'මිනිස්සුන්ට',
#   'කියල',
#   'දෙන්න',
#   'වෙයි'],
#  ['විශේෂයෙන්',
#   'නිතර',
#   'දුම්රිය',
#   'ගමන්',
#   'කරන',
#   'මගින්',
#   'මේ',
#   'ගැන',
#   'සැලකිලිමත්',
#   'විය',
#   'යුතුයි',
#   'කරුනා',
#   'කරලා',
#   'පරෙස්සම්',
#   'කරන්න'],
#  ['දාපු',
#   'ඔස්තාර්ල',
#   'ටික',
#   'ඕකෙ',
#   'නග්ගල',
#   'යවන්න',
#   'ඕන',
#   'බලන්න',
#   'වැඩ',
#   'ටික'],
#  ['රත්තරන්',
#   'අපේක්ෂකයා',
#   'කවුද',
#   'කියලා',
#   'දැනගන්න',
#   'දැන්ම',
#   'මිස්',
#   'කෝල්',
#   'එකක්',
#   'දෙන්න'],
#  ['මංගල',
#   'මුදු',
#   'මාල',
#   'වළලු',
#   'රන්',
#   'අභරණ',
#   'ලබාගන්න',
#   'විශ්වාසයි',
#   'කල්',
#   'පවතියි',
#   'වගකීමට',
#   'බැඳී',
#   'සිටියි'],
#  ['ඇයි', 'බ්\u200dරෝ', 'ස්පොන්සර්', 'ගහලා', 'සල්ලි', 'වැඩිවෙලාද'],
#  ['එනකම්',
#   'මගබලන්',
#   'ඉන්නෙ',
#   'කවුද',
#   'බන්',
#   'මූ',
#   'කිය්ලා',
#   'ලංකාවෙ',
#   'නෙමේද',
#   'දන්නෑ',
#   'හිටියෙ',
#   'මූ'],
#  ['පිරිත',
#   'බුදුන්',
#   'වහන්සේගේ',
#   'දේශනා',
#   'කොට',
#   'ඇත්තේ',
#   'සමුද්\u200dරඝෝෂ',
#   'විරිතට',
#   'අනුකූලවයි',
#   'පිරිතේ',
#   'අක්ෂර',
#   'ලියා',
#   'ඇත්තේ',
#   'ඒ',
#   'අනුවමයි',
#   'පිරිත',
#   'තුළින්',
#   'ඒ',
#   'සෙත්',
#   'ශක්තිය',
#   'ලබාගැනිමට',
#   'ඒ',
#   'ආකාරයෙන්',
#   'ම',
#   'සජ්ජායනය',
#   'කලයුතුයි'],
#  ['මෝඩ',
#   'මිනිස්සු',
#   'ටිකක්',
#   'නම්',
#   'මේක',
#   'අහල',
#   'තෙරුවනේ',
#   'ගුණ',
#   'කෙරෙහි',
#   'සිත',
#   'පහදවා',
#   'ගන්නෙ',
#   'නැතිව',
#   'තාලයයි',
#   'භාෂාවයි',
#   'ගැන',
#   'වාද',
#   'කර',
#   'කර',
#   'ඉන්නවා',
#   'අනේ',
#   'මේ',
#   'මිනිස්සු',
#   'කවදානම්',
#   'මේ',
#   'සංසාරයෙන්',
#   'එතෙර',
#   'වෙන්න',
#   'උත්සාහයක්',
#   'ගනීද'],
#  ['පිස්සො',
#   'පිස්සු',
#   'කතා',
#   'කියයි',
#   'සුනකයි',
#   'සුනක',
#   'කතා',
#   'කියයි',
#   'නරි',
#   'හූ',
#   'කිය',
#   'කිය',
#   'නටයි',
#   'මහමෙව්නා',
#   'වාසි',
#   'පිරිසයට',
#   'ඒ',
#   'සත්ව',
#   'කොට්ඨාසය',
#   'අදාලම',
#   'නැ',
#   'අපිට',
#   'නරි',
#   'නාවන්ඩ',
#   'වෙලාවකුත්',
#   'නැ',
#   'ඔබ',
#   'වහන්සේලා',
#   'කරන',
#   'දේ',
#   'අපිට',
#   'මහ',
#   'මෙරක්',
#   'වගේ',
#   'මේ',
#   'ලොකු',
#   'ස්වාමින්වහන්සේගේ',
#   'යුගයයි',
#   'අපේ',
#   'ලොකු',
#   'ස්වාමින්වහන්සේගෙ',
#   'මාර්ගයේ',
#   'අපි',
#   'යනවා',
#   'මේවැනි',
#   'පින්වත්',
#   'ස්වාමින්වහන්සේලා',
#   'මේ',
#   'මිහිමත',
#   'තව',
#   'තවත්',
#   'පහල',
#   'වේවා'],
#  ['මේ',
#   'වන්දනාවට',
#   'දොස්',
#   'නගන',
#   'සියලු',
#   'දෙනාටයි',
#   'නිකන්',
#   'බොරුවට',
#   'ආර්\u200dය',
#   'උපවාදයට',
#   'ලක්',
#   'වෙන්න',
#   'එපා',
#   'කිරිබත්ගොඩ',
#   'මා',
#   'හිමිගේ',
#   'බන',
#   'පදයක්වත්',
#   'නො',
#   'අසා',
#   'මේ',
#   'විදිහට',
#   'උන්',
#   'වහසේගේ',
#   'පිලිවෙතට',
#   'දොස්',
#   'නගන්න',
#   'එපා',
#   'වැරදි',
#   'ඇති',
#   'කා',
#   'ලගත්',
#   'ඒත්',
#   'කිරිබත්ගොඩ',
#   'හිමියන්ගේ',
#   'සීලයටවත්',
#   'ගුනයටවත්',
#   'අපිට',
#   'ලගටවත්',
#   'යන්න',
#   'බෑ',
#   'උන්',
#   'වහන්සේ',
#   'සිදු',
#   'කරන',
#   'සේවය',
#   'අති',
#   'මහත්',
#   'ස්\u200dරද්දාව',
#   'වැඩෙනවා'],
#  ['හැකි',
#   'සෑම',
#   'විටම',
#   'ත්\u200dරිවිධ',
#   'රත්නයේ',
#   'ගුණ',
#   'සිහිපත්',
#   'කිරීමයි',
#   'වැදගත්',
#   'මේ',
#   'ස්වාමීන්',
#   'වහන්සේලාගේ',
#   'දේශනාවෙන්',
#   'මම',
#   'සුවපත්',
#   'වුනෙමි',
#   'ඒ',
#   'කුසලය',
#   'උන්',
#   'වහන්සේලා',
#   'අනුමෝදන්',
#   'වේවා',
#   'බල්ලො',
#   'බිරුවට',
#   'කදු',
#   'පාත්',
#   'වෙන්නෙ',
#   'නෑනෙ',
#   'බුදු',
#   'සසුන',
#   'බැබලේවා'],
#  ['දහම්පාසලකට',
#   'ගියේ',
#   'නැති',
#   'එකාලාට',
#   'මේ',
#   'බණ',
#   'නම්',
#   'සෝක්',
#   'ඊයේ',
#   'පෙරේදා',
#   'ෂෝ',
#   'එකට',
#   'ධර්මය',
#   'පස්සෙ',
#   'යන',
#   'එකාලා',
#   'ට',
#   'මේ',
#   'විකුර්ති',
#   'හොදයි',
#   'බුදුහාමුදරුවෝ',
#   'කීව',
#   'දේ',
#   'හරි',
#   'සාසනේ',
#   'විනාස',
#   'කරන',
#   'අය',
#   'සාසනෙන්ම',
#   'බිහිවෙලා',
#   'ඉවරයි'],
#  ['වත්තල',
#   'සිලරතන',
#   'හාමුදුරුවෝ',
#   'පිරිත්',
#   'අහපන්',
#   'එතකොට',
#   'තෙරෙයි',
#   'මෙවා',
#   'ව්කුර්ති',
#   'එවා',
#   'බව',
#   'නියම',
#   'පිරිත්',
#   'දන්නෙ',
#   'නෙති',
#   'උන්ට',
#   'මේවාට',
#   'සිත',
#   'නිවෙනවා',
#   'ලු',
#   'අබුද්දස',
#   'කාලේ',
#   'මෙවා',
#   'ගීතිකා',
#   'ගන',
#   'ස්වර',
#   'කෝ'],
#  ['දර්මය',
#   'සැකවින්',
#   'සොයා',
#   'බලා',
#   'සත්\u200dය',
#   'කුමක්ද',
#   'යන්න',
#   'තමන්',
#   'අවබෝද',
#   'කරගන්න',
#   'බුදුරජාණන්වහන්සේගේ',
#   'දේශනාවයි',
#   'කියා',
#   'තමන්ගේ',
#   'මත',
#   'ඉදිරිපත්',
#   'කරන්නාවුන්',
#   'පිරි',
#   'දේශයක්',
#   'වෙලා',
#   'නිර්වානය',
#   'වසා',
#   'තමන්ගේ',
#   'ලාබ',
#   'ප්\u200dරයෝජන',
#   'තකා',
#   'වැඩකරන්නාවුන්',
#   'අදුන',
#   'ගන්න',
#   'පුද',
#   'පුජා',
#   'ක්\u200dරම',
#   'තුල',
#   'නිවනක්',
#   'නැත',
#   'ඇත්තේ',
#   'සසර',
#   'දිගු',
#   'කරගන්නා',
#   'මගක්',
#   'පමනි',
#   'එන',
#   'නිසා',
#   'නොපමාව',
#   'කුසල්',
#   'වඩා',
#   'නිර්වානය',
#   'සාක්ශාත්',
#   'කරගනිත්වා',
#   'මා',
#   'හටද',
#   'අවබෝදය',
#   'වේවා',
#   'මොලයක්',
#   'ඇත්තවුන්',
#   'තෙරුම්',
#   'ගත',
#   'යුතුයි',
#   'දර්මය',
#   'කුමක්ද',
#   'යන්න',
#   'කියා'],
#  ['ඒක',
#   'දරුවා',
#   'තිරණය',
#   'කරයි',
#   'පලවැනි',
#   'එකා',
#   'බෞද්ධ',
#   'දෙක',
#   'කතෝලික',
#   'අරකයි',
#   'මේකයි',
#   'දෙන්නවම',
#   'කැමතිනම්',
#   'බෞතීස්ම',
#   'කරන්න',
#   'ඒ',
#   'අය',
#   'අදාල',
#   'වයසේදි',
#   'කැමති',
#   'දෙයක්',
#   'කරයි'],
#  ['කොල්ලා',
#   'බෞද්ධ',
#   'කෙල්ල',
#   'කතෝලික',
#   'දෙන්නා',
#   'බැන්දයින්',
#   'පස්සෙ',
#   'ඉපදෙන',
#   'පලවෙනි',
#   'පිරිමි',
#   'ලමයා',
#   'බෞද්ධ',
#   'කරලා',
#   'ඊලගට',
#   'ඉපදෙන',
#   'ලමයා',
#   'කෙල්ලෙක්',
#   'උනත්',
#   'කොල්ලෙක්',
#   'උනත්',
#   'කතෝලික',
#   'කරන',
#   'එක',
#   'ප්\u200dරශ්නයක්ද',
#   'එක',
#   'ලමයෙක්',
#   'කතෝලික',
#   'කරන',
#   'එක',
#   'ප්\u200dරශ්නයක්ද'],
#  ['අන්න',
#   'අදත්',
#   'අපේ',
#   'කතෝලික',
#   'යාළුවෝ',
#   'ගරු',
#   'කාදිනල්',
#   'තුමාට',
#   'පළු',
#   'යන්න',
#   'බනිනවා',
#   'කාදිනල්',
#   'තුමා',
#   'ඔයාලගෙ',
#   'දකුණු',
#   'කම්මුලට',
#   'ගැහුවොත්',
#   'වම්',
#   'කම්මුලත්',
#   'පෙන්නන්න',
#   'මගේ',
#   'රත්තරන්',
#   'කතෝලික',
#   'යාළුවනේ'],
#  ['ඇයි',
#   'මේ',
#   'ආණ්ඩුව',
#   'වෙනරටවල්',
#   'වලින්',
#   'සල්ලි',
#   'එන',
#   'මුස්ලිම්',
#   'සහ',
#   'කතෝලික',
#   'පල්ලි',
#   'ගැන',
#   'පරීකෂන',
#   'කරන්නෙ',
#   'නැත්තෙ',
#   'බයේද'],
#  ['උප්පැන්නෙ',
#   'ජාතිය',
#   'සිංහල',
#   'ආගම',
#   'කතෝලික',
#   'කියල',
#   'නැතිව',
#   'ශ්\u200dරීලාංකික',
#   'කියන',
#   'එක',
#   'විතරක්',
#   'තිබ්බනම්',
#   'කොච්චර',
#   'හොදද'],
#  ['වැලන්ටයින්',
#   'කියන්නේ',
#   'කතෝලික',
#   'සාන්තුවරයෙක්ගේ',
#   'නමක්',
#   'කියල',
#   'ආගම්වාදියෝ',
#   'දැනගත්තොත්',
#   'මුන්',
#   'ඕකත්',
#   'ලංකාවේ',
#   'තහනං',
#   'කරලා',
#   'දායි',
#   'නේද'],
#  ['වෙසක්',
#   'වලට',
#   'අවුරුද්දට',
#   'වත්',
#   'මෙහෙම',
#   'සහන',
#   'නැහැනේ',
#   'නැහැනේ',
#   'කතෝලික',
#   'චන්දවලට',
#   'ආසාව',
#   'තමා'],
#  ['මේ',
#   'හදිස්සියේ',
#   'මට',
#   'මතක්',
#   'උනේ',
#   'කතෝලික',
#   'ගෑනු',
#   'ලමයෙක්',
#   'බැන්දනම්',
#   'කොහොමද',
#   'කියල',
#   'එතකොට',
#   'අවුරුදුත්',
#   'තියෙයි',
#   'නත්තලුත්',
#   'තියෙයි',
#   'එතකොට',
#   'දීපවාලි',
#   'සහ',
#   'හජ්ජි'],
#  ['ප්\u200dරතිසංස්කරණය',
#   'කරන',
#   'ලද',
#   'මුල්ලිකුලම',
#   'කතෝලික',
#   'දේවස්ථානය',
#   'ආරක්ෂක',
#   'ලේකම්තුමන්',
#   'අතින්',
#   'ජනතා',
#   'අයිතියට'],
#  ['ග්\u200dරෑන්ඩ්පාස්',
#   'අනවසර',
#   'මුස්ලිම්',
#   'පල්ලියට',
#   'ඔහොම',
#   'වුනා',
#   'කියල',
#   'සිංහල',
#   'බවුද්ධ',
#   'කතෝලික',
#   'දෙමල',
#   'මිනිස්සු',
#   'නාහෙන්',
#   'අඬනවා'],
#  ['මන්නාරමේ',
#   'මීසම',
#   'භාර',
#   'කතෝලික',
#   'පූජකතුමන්ලා',
#   'සහ',
#   'ප්\u200dරාදේශීය',
#   'දේශපාලනඥයින්',
#   'මීට',
#   'මොහොතකට',
#   'පෙර',
#   'කොළඹ',
#   'දී',
#   'ජනාධිපති',
#   'රාජපක්ෂ',
#   'මැතිතුමා',
#   'හමු',
#   'වූහ'],
#  ['මහාමෙව්නා',
#   'අසපුවට',
#   'ගියාම',
#   'දැනෙන',
#   'නිදහස',
#   'ගිහිල්ලම',
#   'බලන්න',
#   'ඕනේ',
#   'ලොකු',
#   'දැනුමක්',
#   'ලැබෙනවා',
#   'කරන',
#   'පව්',
#   'පිං',
#   'ඒ',
#   'වගේම',
#   'උතුම්',
#   'ධර්මය',
#   'ගැනත්'],
#  ['මෙහෙම',
#   'දෙපැත්තට',
#   'කාකොටා',
#   'ගන්න',
#   'මිනිස්සු',
#   'එදත්',
#   'හිටියා',
#   'අදත්',
#   'ඉන්නවා',
#   'ධර්මය',
#   'ගැන',
#   'වැලි',
#   'කැටයක',
#   'තරම්වත්',
#   'දෙයක්',
#   'නොදැන',
#   'හරි',
#   'වැරැද්ද',
#   'කතා',
#   'කරනවා'],
#  ['මේක',
#   'වැරදි',
#   'පූර්වාදර්ශයක්',
#   'ඔහු',
#   'අතට',
#   'අත',
#   'දෙන',
#   'අවස්ථාවෙදිවත්',
#   'එය',
#   'ප්\u200dරතික්ෂේප',
#   'කරනවා',
#   'ඒකෙන්',
#   'පෙන්නුම්',
#   'කරන්නේ',
#   'ඔහුගේ',
#   'උඩගු',
#   'කම',
#   'විනා',
#   'වෙනත්',
#   'දෙයක්',
#   'නොව'],
#  ['දුමින්ද',
#   'වගේ',
#   'කලාවට',
#   'සේවයක්',
#   'කරපු',
#   'කෙනෙක්',
#   'තවත්',
#   'නෑ',
#   'එක',
#   'කලාකාරිනියකට',
#   'මාසෙට',
#   'කෝටි',
#   '3ගානේ',
#   'ගෙවනවා',
#   'ගොඩනැගිල්ලට',
#   'යන්නත්',
#   'කලින්',
#   'ඉදලම'],
#  ['උදය',
#   'ගම්මන්පිල',
#   'කියන්නෙ',
#   'නිකමෙක්',
#   'නෙවෙයි',
#   'ඔහු',
#   '1989',
#   'වසරේ',
#   'උසස්',
#   'පෙළ',
#   'වාණිජ',
#   'අංශයෙන්',
#   'දිවයිනෙන්ම',
#   'ප්\u200dරථමස්ථානය',
#   'ලබා',
#   'ගත්',
#   'ශ්\u200dරී',
#   'ලංකා',
#   'දේශපාලනයට',
#   'විරල',
#   'උගතෙක්',
#   'මේ',
#   'සිදුවීම',
#   'හරිම',
#   'අස්භාවිකයි'],
#  ['කලාකරුවා',
#   'දේශපාලනේ',
#   'අතින්',
#   'මොන',
#   'මතය',
#   'දැරුවත්',
#   'මේ',
#   'වගේ',
#   'තැනක',
#   'නිහතමානි',
#   'නොවීම',
#   'කනගාටුවට',
#   'කාරනාවක්',
#   'සම්මානයේ',
#   'දක්වපු',
#   'ගෞරවය',
#   'එතැනින්ම',
#   'ඉවරයි'],
#  ['දැන්',
#   'තේරැමි',
#   'ගන්න',
#   'පුළුවන්',
#   'නේද',
#   'මහජනතාවගේ',
#   'තියෙන',
#   'පිලිකුල',
#   'ඔය',
#   'මහජන',
#   'සේවයට',
#   'කියල',
#   'ආපු',
#   'අයගේ',
#   'තව',
#   'තවත්',
#   'තරුණියන්',
#   'මෙිවගේ',
#   'සංවිධාන',
#   'වෙන්න',
#   'ඔින'],
#  ['හම්මෝ',
#   'මුන්',
#   'දෙන්න',
#   'මේ',
#   'ටිකට',
#   'ශාරුක්',
#   'කාන්ලටත්',
#   'එහා',
#   'ගිහින්',
#   'නේ',
#   'මොකුන්ද',
#   'මේ',
#   'සම්මාන',
#   'ගත්තෙ',
#   'නෑ',
#   'කියනකොට',
#   'දැනගත්තෙම',
#   'කොහොම',
#   'උනත්',
#   'මොවුන්',
#   'දෙදෙනා',
#   'හදවතින්',
#   'කලා',
#   'කරුවන්',
#   'නොවේ'],
#  ['පක්ෂ',
#   'වැඩක්',
#   'නැ',
#   'සමිමානේ',
#   'ගන්න',
#   'බැරි',
#   'නමි',
#   'අතට',
#   'අත',
#   'දෙන්න',
#   'තිබිබා',
#   '\u2063මිනිසෙකුට',
#   'අත',
#   'අත',
#   'දෙන්න',
#   'බැරි',
#   'නමි',
#   'වැඩක්',
#   'නැ',
#   'තරහ',
#   'කාරයෙක්',
#   'උනත්',
#   'තරහ',
#   'කාරයෙක්',
#   'උනත්',
#   'මිනිසෙක්',
#   'හිනා',
#   'උනොත්',
#   'හිනා',
#   'වෙන්නවත්',
#   'ඔනේ',
#   'අහක',
#   'බලන්',
#   'අනිත්',
#   'කෙනාට',
#   'අතට',
#   'අත',
#   'නොදි'],
#  ['මං',
#   'හිතන්නෙ',
#   'උන්ගෙන්',
#   'ඕක',
#   'ගත්තම',
#   'ඒ',
#   'සම්මානයට',
#   'වටිනා',
#   'කමක්',
#   'නෑ',
#   'මොකද',
#   'සම්මානයට',
#   'ප්\u200dරාත',
#   'නිර්මානයක්',
#   'කියන්නෙ',
#   'වටිනා',
#   'ලොකු',
#   'කමක්',
#   'තියෙන',
#   'දෙයක්',
#   'එහෙම',
#   'වටිනා',
#   'දෙයක්',
#   'කිසිම',
#   'වටිනාකමක්',
#   'නැති',
#   'නිර්ලජ්ජ',
#   'විශබීජයක්',
#   'අතිං',
#   'ලැබුනොත්',
#   'ඒකෙ',
#   'වටිනා',
#   'කමක්',
#   'නෑ',
#   'මොකක්ද',
#   'මේ',
#   'දෙන්නගෙ',
#   'තියෙන',
#   'රටට',
#   'සමාජයට',
#   'හොදේ'],
#  ['සමාජයට',
#   'විශබීජ',
#   'වපුරන',
#   'මේ',
#   'වගේ',
#   'ප්\u200dරතිපත්තියක්',
#   'නැති',
#   'පල්',
#   'හොරු',
#   'දෙන්නෙක්ට',
#   'ආරාධනය',
#   'කරන්න',
#   'තියෙන',
#   'සදාචාරාත්මක',
#   'අයිතිය',
#   'සම්මානයක්',
#   'කියන්නෙ',
#   'කලාකාරයෙකුට',
#   'තියෙන',
#   'උසස්ම',
#   'දෙයක්',
#   'එහෙම',
#   'දෙයක්',
#   'කිසි',
#   'වටිනාකමක්',
#   'නැති',
#   'පාදඩයෙක්ගෙ',
#   'අතිං',
#   'ගත්තම',
#   'නිසි',
#   'වටිනාකමක්',
#   'ලැබෙන්නෙ',
#   'නෑ',
#   'ඊටවඩා',
#   'සමාජයට',
#   'දීපු',
#   'පනිවිඩය',
#   'වැදගත්',
#   'ප්\u200dරතික්ෂේප',
#   'වියයුත්තේ',
#   'කොතනද',
#   'කියන',
#   'එක',
#   'නෙමෙයි',
#   'වැදගත්',
#   'ප්\u200dරතික්ෂේප',
#   'කිරීමයි',
#   'කශේරුකාවක්',
#   'තියෙන',
#   'මිනිහෙක්',
#   'රටේ',
#   'මිනිස්සුන්ට',
#   'පෙන්නුවා',
#   'මේ',
#   'ප්\u200dරතික්ශේප',
#   'විය',
#   'යුතු',
#   'මිනිස්සු',
#   'කියල'],
#  ['ඕක',
#   'තමයි',
#   'අපේ',
#   'කළාවට',
#   'හෙන',
#   'ගහලා',
#   'තියෙන්නේ',
#   'මුන්ගෙ',
#   'උද්දච්චකම',
#   'විතරයි',
#   'අර',
#   'ඉන්දියාවේ',
#   'ඉන්න',
#   'බොලිවුඩය',
#   'සහ',
#   'හොලිවුඩයෙ',
#   'නලු',
#   'නිළියන්',
#   'කොච්චර',
#   'නිහතමානී',
#   'ද',
#   'මුන්',
#   'දැන්',
#   'ඔය',
#   'මොකේද',
#   'රගපෑවෙ',
#   'උනුත්',
#   'මහජනයා',
#   'ප්\u200dරතිකේෂ්ප',
#   'කලොත්',
#   'ගෙදර',
#   'දේශපාලකයොත්',
#   'මහජන',
#   'තාව',
#   'ප්\u200dරතික්ෂේප',
#   'කලොත්',
#   'ගෙදර',
#   'කළාකරුවෙක්',
#   'කියන්නේ',
#   'විවේචනය',
#   'මගින්',
#   'ඕනෑම',
#   'කෙනෙක්',
#   'උපහාසයට',
#   'ලක්කර',
#   'මිනිස්සුන්ගෙ',
#   'හිත්',
#   'දිනාගැනීමට',
#   'හැකියාවක්',
#   'තියෙන',
#   'අය',
#   'ඒකට',
#   'මුන්',
#   'අනේ'],
#  ['කලාවට',
#   'දේෂපාලනයක්',
#   'ගාවගන්නෙ',
#   'ඇයි',
#   'හැකියාව',
#   'නිසයි',
#   'සම්මාන',
#   'දෙන්නෙ',
#   'ඒත්',
#   'මෙහෙම',
#   'කරපු',
#   'දේ',
#   'වැරදියි',
#   'අතට',
#   'අත',
#   'දෙන්න',
#   'තිබ්බා',
#   'අකමැති',
#   'දේ',
#   'වෙනයි',
#   'ඒ',
#   'වුනාට',
#   'ඔයිට',
#   'වඩා',
#   'ප්\u200dරවීන',
#   'කලාකාරයෝ',
#   'ඔහොම',
#   'නෑ',
#   'සමාජෙට',
#   'දෙන',
#   'ආදර්ෂය',
#   'මොකද්ද',
#   'දේෂපාලකයෝ',
#   'කලාවට',
#   'ගාවගන්නැතුව',
#   'ඉන්න',
#   'එකනම්',
#   'කලාකාරයෝ',
#   'දේෂපාලනයට',
#   'නොයා',
#   'සිටිය',
#   'යුතුයි'],
#  ['ඕක',
#   'ඔතන',
#   'ගන්න',
#   'තිබුණෙ',
#   'රණසිංහ',
#   'ප්\u200dරේමදාස',
#   'වගේ',
#   'කෙනෙක්',
#   'අතින්',
#   'එතනදි',
#   'ඔහොම',
#   'වුණානම්',
#   'ටයර්',
#   'දෙකකුත්',
#   'නොමිලෙම',
#   'හම්බෙනවා',
#   'බෙල්ල',
#   'වටේ',
#   'දාගන්න',
#   'පහුවෙනිදට'],
#  ['අපේ',
#   'රටේ',
#   'තරං',
#   'හැම',
#   'මගුලටම',
#   'දේසපාලුවො',
#   'ගාව',
#   'ගන්න',
#   'රටක්',
#   'නැ',
#   'කොහෙවත්',
#   'ඔස්කාර්',
#   'දෙන්න',
#   'බුෂ්',
#   'ඔබාමා',
#   'ට්රම්ප්',
#   'ආවද',
#   'ෆිල්ම්',
#   'ෆෙයාර්',
#   'දෙන්න',
#   'වජ්පායි',
#   'කලාම්',
#   'මෝදි',
#   'එනව',
#   'දැකල',
#   'තියනවද',
#   'කලාව',
#   'එකක්',
#   'දේශපාලනය',
#   'එකක්',
#   'ගමේ',
#   'ඡන්දෙ',
#   'ඉල්ලන්න',
#   'බලං',
#   'ඉන්න',
#   'එකෙක්ට',
#   'නොමිනේෂන්',
#   'දෙන්න',
#   'ඇමති',
#   'කෙනෙක්',
#   'ආවට',
#   'කමක්',
#   'නැ',
#   'ඒක',
#   'උන්ගෙ',
#   'ෆීල්ඩ්එක',
#   'කලාකරුවන්ට',
#   'සම්මාන',
#   'දෙන්න',
#   'ඕන',
#   'ඒ',
#   'ඒ',
#   'ක්ෂේත්\u200dර',
#   'වල',
#   'ප්\u200dරවීණයො',
#   'නෙවෙයි',
#   'ද',
#   'නිකමට',
#   'බලපං',
#   'ඔස්කාර්',
#   'සම්මානය',
#   'දෙන',
#   'එකක්',
#   'අපේ',
#   'රටේ',
#   'මිනිස්සු',
#   'මනින',
#   'මිම්මත්',
#   'මිනිස්සු',
#   'දිහා',
#   'බලන',
#   'කෝණයත්',
#   'දේශපාලන',
#   'වෙලා'],
#  ['හොදට',
#   'බලපං',
#   'යටම',
#   'ආදරේ',
#   'කරපු',
#   'කෙනෙක්',
#   'එක',
#   'පක්\u200dෂයකින්',
#   'ඡන්දෙ',
#   'ඉල්ලුවොත්',
#   'ඒ',
#   'ඕන',
#   'නැ',
#   'පක්ෂයක',
#   'රැස්වීමකට',
#   'ගියොත්',
#   'පහුවදා',
#   'ඉදන්',
#   'ඌ',
#   'ඉවරයි',
#   'අනික්',
#   'පක්ෂයේ',
#   'උන්',
#   'දෙශපාලනය',
#   'නිසා',
#   'අර',
#   'කෙනාට',
#   'මඩ',
#   'ගහනව',
#   'එක',
#   'බත්පත',
#   'බෙදං',
#   'කාපු',
#   'යාළුවො',
#   'කොච්චර',
#   'තරහ',
#   'වෙලා',
#   'ඇද්ද',
#   'මේ',
#   'රටේ',
#   'දේශපාලනය',
#   'නිසා',
#   'මේ',
#   'කමෙන්ට්',
#   'වලම',
#   'බලපං',
#   'ඒක',
#   'තේරෙයි',
#   'මම',
#   'කියන්නෙ',
#   'සියලුම',
#   'කලා',
#   'කටයුතු',
#   'වලට',
#   'නරඹන්නට',
#   'හැර',
#   'සම්මාන',
#   'ප්\u200dරදාන',
#   'වලට',
#   'දේශපාලනය',
#   'කරන',
#   'උන්',
#   'ඕන',
#   'නැ'],
#  ['උන්',
#   'බලන්නෙ',
#   'කාගෙන්හරි',
#   'උන්',
#   'ඡන්ද',
#   'අරන්',
#   'ගොඩ',
#   'යන්න',
#   'මිස',
#   'රට',
#   'හදන්න',
#   'නෙවෙ',
#   'කලාට',
#   'විතරක්',
#   'නෙවෙයි',
#   'මේක',
#   'අපේ',
#   'ක්\u200dරිඩාවටත්',
#   'අදාළයි',
#   'ඒකෙත්බලපං',
#   'දේශපාලනය',
#   'ගෑවෙන',
#   'ක්\u200dරිඩා',
#   'ඉවරයිනෙ',
#   'ඒ',
#   'නිසා',
#   'මං',
#   'හිතන්නෙ',
#   'දේශපාලන',
#   'ඒ',
#   'විදියට',
#   'තියන්න',
#   'ඔන',
#   'මේ',
#   'කරපු',
#   'වැඩේ',
#   'හරි',
#   'සම්මානනීය',
#   'ජේෂ්ඨ',
#   'කලාකරුවෙක්',
#   'ඉද්දි',
#   'ඇයි',
#   'මේ',
#   'ඇඩ්',
#   'එකකවත්',
#   'ඉදල',
#   'නැති',
#   'කෙනෙක්',
#   'ගෙන්',
#   'සම්මාන',
#   'ගන්නෙ',
#   'ශ්\u200dරීයන්ත',
#   'මෙන්ඩිස්',
#   'ඇමතිලට',
#   'අමාත්යාංශ',
#   'වැඩ',
#   'භාර',
#   'දෙන',
#   'ලිපි',
#   'දුන්නොත්',
#   'ඒක',
#   'කොහොමද',
#   'වැඩෙ',
#   'හොදයි'],
#  ['කළා',
#   'කරුවා',
#   'යනු',
#   'සහෘදයා',
#   'ඔහුන්',
#   'බොහෝසෙයින්',
#   'නිහතමානී',
#   'ආදරණීය',
#   'ප්\u200dරියයානයෙක්',
#   'විය',
#   'යුතු',
#   'බවයි',
#   'මගේ',
#   'අදහස',
#   'සරස්වතී',
#   'දේවින්ගෙන්',
#   'ආශීර්වාද',
#   'ලබාගෙන',
#   'තම',
#   'සෞම්\u200dය',
#   'සුන්දරත්වය',
#   'හදවතින්ම',
#   'පිළිබිඹු',
#   'කලා',
#   'නම්',
#   'කොච්චර',
#   'වටිනේද',
#   'හරි',
#   'හෝ',
#   'වැරදි',
#   'බව',
#   'නිර්දේශ',
#   'කිරීම',
#   'බුදු',
#   'දහම',
#   'සංස්කෘතිය',
#   'අප',
#   'ජීවත්වන',
#   'කල්ක්\u200dරියාව',
#   'අනුව',
#   'තීරණය',
#   'වේ'],
#  ['අන්න',
#   'නියම',
#   'මිනිස්සු',
#   'යන',
#   'යන',
#   'තැන',
#   'ඔය',
#   'පිස්සොන්ට',
#   'කරන්න',
#   'ඕනි',
#   'ඔය',
#   'ටික',
#   'තමයි',
#   'දැන්නම්',
#   'අපේ',
#   'මිනිස්සු',
#   'ටික',
#   'ටික',
#   'හැදීගෙන',
#   'එනව',
#   'වගේ',
#   'මේව',
#   'දැක්කම',
#   'පුදුම',
#   'සතුටක්',
#   'දැනෙන්නෙ',
#   'නියමයි',
#   'මරු'],
#  ['ගම්මන්පිල',
#   'මමත්',
#   'විශෙෂ',
#   'කැමත්තක්',
#   'නැති',
#   'කෙනෙක්',
#   'හැබැයි',
#   'අද',
#   'ඔහු',
#   'මහත්මයෙක්',
#   'කියන',
#   'එක',
#   'පෙන්නුවා',
#   'අර',
#   'සම්මානය',
#   'ශියන්ත',
#   'මෙන්ඩිස්',
#   'මහතාට',
#   'දිලා',
#   'ඉටපස්සෙ',
#   'අත්පුඩි',
#   'ගහපු',
#   'එකෙන්',
#   'අනේ',
#   'මන්දා',
#   'මම',
#   'නම්',
#   'අදමයි',
#   'දැක්කෙ',
#   'මොනවා',
#   'උනත්',
#   'කලාකරුවන්',
#   'දෙශපාලනය',
#   'අතකොලුවක්',
#   'වෙන',
#   'එක',
#   'නම්',
#   'පිළිකුලක්',
#   'දෙශපාලනය',
#   'පක්ෂ',
#   'කොකත්',
#   'එකයි',
#   'කවුරුත්',
#   'මහජනයාට',
#   'ආදරේ',
#   'නම්',
#   'නැහැ',
#   'හැබැයි',
#   'මහින්ද',
#   'රාජපක්ෂ',
#   'කියන',
#   'කෙනා',
#   'රටට',
#   'දෙයක්',
#   'කරා',
#   'එක',
#   'නැහැ',
#   'කියන්න',
#   'තරම්',
#   'මට',
#   'කුහක',
#   'වෙන්න',
#   'බැහැ',
#   'මොනවා',
#   'උනත්',
#   'මට',
#   'නම්',
#   'පෙනුනේ',
#   'එ',
#   'කලාකරුවන්',
#   'කියන',
#   'දෙන්නාගෙ',
#   'චන්ඩි',
#   'පාට්',
#   'එකක්',
#   'විතරයි',
#   'අඩු',
#   'ගානේ',
#   'කමිසේ',
#   'බොත්තම්',
#   'ටික',
#   'වත්',
#   'දාලා',
#   'තිබුණා',
#   'ද',
#   'අමු',
#   'රස්තියාදු',
#   'කාරයේක්'],
#  ['පුළුවන්',
#   'එකෙක්',
#   'ඉන්නවනම්',
#   'දේශපාලකයෙක්',
#   'ට',
#   'ඔය',
#   'කොල්ලා',
#   'කරපු',
#   'දේ',
#   'කරලා',
#   'පෙන්නපන්',
#   'එකෙක්',
#   'නැ',
#   'භයටම',
#   'උබලාගෙ',
#   'කොදු',
#   'නැමෙනවා',
#   'එල',
#   'කොල්ලෙක්'],
#  ['මෙයටත්',
#   'වඩා',
#   'වැඩියෙන්',
#   'ඔවුන්',
#   'නිවරදි',
#   'වෙනතෙක්ම',
#   'සමස්ත',
#   'සමාජයම',
#   'මේ',
#   'තත්ත්වයට',
#   'පත්විය',
#   'යුතුයි',
#   'ඒ',
#   'අනුව',
#   'ඔවුන්',
#   'ගේ',
#   'ක්\u200dරියාව',
#   'යුක්ති',
#   'සහගතයි',
#   'ඔවුන්',
#   'දෙදනා',
#   'ආරම්භක්',
#   'දීම',
#   'ගැන',
#   'ස්තුතිවන්ත',
#   'විය',
#   'යුතු',
#   'අතරම',
#   'අපි',
#   'සියල්ලෝම',
#   'ඔවුන්ව',
#   'අනුගමනය',
#   'කල',
#   'යුතුයි',
#   'දේශපාලකයා',
#   'නිවරදි',
#   'වෙන',
#   'තෙක්'],
#  ['මොක්කුද',
#   'බං',
#   'මේ',
#   'අදමයි',
#   'දැක්කේ',
#   'මුංට',
#   'නලුවෝ',
#   'කියලා',
#   'නලුවොන්ට',
#   'කියන්න',
#   'වෙනනමක්',
#   'හදාගනිං',
#   'මේවගේ',
#   'උන්',
#   'ඕන',
#   'තරං',
#   'හොයාගන්න',
#   'පුලුවං',
#   'හතරෙන්',
#   'පස්සේ',
#   'බෝක්කුවක්',
#   'ලගට',
#   'ගියානං'],
#  ['ලංකාවෙි',
#   'දේශපාලනය',
#   'හැම',
#   'වැඩකටම',
#   'සමිබන්ධ',
#   'කර',
#   'ගන්න',
#   'හොද',
#   'නෑ',
#   'ප්\u200dරවීන',
#   'කලාකාරයෙක්',
#   'අතින්',
#   'ඔය',
#   'සමිමානය',
#   'දුන්නනමි',
#   'වටිනව',
#   'කොහොම',
#   'උනත්',
#   'ලංකාවෙි',
#   'දෙශපාලකයින්',
#   'ගැන',
#   'කල',
#   'කිරී',
#   'සිටින',
#   'අවධියක',
#   'පාර්ලිමෙින්තුවෙි',
#   'සිටින',
#   '225',
#   'ජනතාව',
#   'විසින්',
#   'ඔය',
#   'විදිහට',
#   'ප්\u200dරතික්\u200dේෂ්ප',
#   'කරානමි',
#   'හොදයි'],
#  ['හැමෝම',
#   'තම',
#   'තමන්ගේ',
#   'හර්දශාක්කියට',
#   'තට්ටු',
#   'කරලා',
#   'බල්න්න',
#   'ඔනේ',
#   'සෑම',
#   'තැනදිම',
#   'සෑම',
#   'කරුනකදීම',
#   'මේ',
#   'විදියට',
#   'වැඩ',
#   'කරනවාද',
#   'නැත්නම්',
#   'කාටවත්',
#   'රිදවන්න',
#   'වැඩ',
#   'කරනවද',
#   'තීරනය',
#   'ඔබම',
#   'සතුයි'],
#  ['කලාකරුවා',
#   'දේශපාලනේ',
#   'අතින්',
#   'මොන',
#   'මතය',
#   'දැරුවත්',
#   'මේ',
#   'වගේ',
#   'තැනක',
#   'නිහතමානි',
#   'නොවීම',
#   'කනගාටුවට',
#   'කාරනාවක්',
#   'සම්මානයේ',
#   'දක්වපු',
#   'ගෞරවය',
#   'එතැනින්ම',
#   'ඉවරයි'],
#  ['මෙහෙමයි',
#   'ඔය',
#   'කරපුදේ',
#   'ලොකු',
#   'දෙයක්',
#   'නෙවෙයි',
#   'පාට',
#   'පක්ශ',
#   'බේදයකින්',
#   'තොරව',
#   'ඒ',
#   'ලැබුනු',
#   'වරම',
#   'ගන්න',
#   'ඕනෙ',
#   'ඔය',
#   'ගත්ත',
#   'සම්මානයට',
#   'දැන්',
#   'කිදෙන්ක්ගෙන්',
#   'හොද',
#   'නරක',
#   'අහගන්න',
#   'ඇතිද',
#   'මේකයි',
#   'අපි',
#   'අපි',
#   'වෙන්න',
#   'ඕනෙ',
#   'අපිට',
#   'පිට',
#   'මිනිස්සු',
#   'හදන්න',
#   'බැහැ'],
#  ['ඔතන',
#   'වැරැද්ද',
#   'දූශිත',
#   'දේශපාලකයන්ට',
#   'ආරාධනා',
#   'කරපු',
#   'එක',
#   'බව',
#   'ඇත්ත',
#   'ඉතිහාසයේ',
#   'කොහේවත්',
#   'ඔය',
#   'විදියට',
#   'විරෝධත්වය',
#   'පෙන්නල',
#   'නැත්තෙ',
#   'සදාචාර',
#   'සම්පන්න',
#   'සමාජයට',
#   'ගැලපෙන්නෙ',
#   'නැතිනිසා',
#   'වයසින්',
#   'මුහුකුරා',
#   'යනවැයි',
#   'කියන්නෙ',
#   'දැක්ක',
#   'තැන',
#   'හොරාට',
#   'අල්ලගෙන',
#   'තඩිබාන',
#   'එක',
#   'නෙවෙයි',
#   'කලාකාරයො',
#   'තමන්ගෙ',
#   'නිර්මාණ',
#   'තුල',
#   'විරෝධත්වය',
#   'පෙන්නනව',
#   'වගේම',
#   'දේශපාලකයන්ගෙ',
#   'අනුග්\u200dරහය',
#   'තියෙන',
#   'සම්මාන',
#   'උලෙළ',
#   'ප්\u200dරතික්ෂේප',
#   'කරනව',
#   'දියුණු',
#   'සමාජයේ',
#   'ඔය',
#   'පෙනෙන',
#   'රස්තියාදු',
#   'ගතිය',
#   'දේශපාලනයේ',
#   'ඉහළ',
#   'මට්ටමේ',
#   'අනුරයි',
#   'මහින්දයි',
#   'අතරවත්',
#   'නෑ'],
#  ['ඒ',
#   'හින්දා',
#   'කරපු',
#   'නිර්මාණයකට',
#   'කවුරුන්හෝ',
#   'ඇගයීමක්',
#   'කරොත්',
#   'ඒකත්',
#   'නිහතමානීව',
#   'විදගන්න',
#   'ඕනෑ',
#   'මේක',
#   'මේ',
#   'ගම්මන්පිල',
#   'පුද්ගලිකව',
#   'දුන්න',
#   'සම්මානයක්',
#   'නෙමෙයිනේ',
#   'ඊටත්',
#   'මුන්ට',
#   'ඔස්කාර්',
#   'සම්මානේ',
#   'හම්බ',
#   'වුනාය',
#   'ඊටත්',
#   'අපි',
#   'දැකල',
#   'තියෙනවා',
#   'ලංකාවේ',
#   'සම්මාන',
#   'උළෙලවලට',
#   'ඉන්දියාවේ',
#   'කිඹි',
#   'ඇවිත්',
#   'සම්මාන',
#   'දෙනකොට',
#   'උඩදාගෙන',
#   'ගිහින්',
#   'ගන්නවා'],
#  ['මේ',
#   'කරපු',
#   'වැඩේ',
#   'පක්ෂග්\u200dරාහීද',
#   'කියන්න',
#   'දන්නෙ',
#   'ඒදෙන්න',
#   'විතරයි',
#   'හැබැයි',
#   'ලංකාවේ',
#   'පාර්ලිමේන්තුවේ',
#   'දැන්',
#   'ඉන්න',
#   'මහජන',
#   'නියෝජිතයන්',
#   'සියලු',
#   'දෙනා',
#   'ම',
#   'මේ',
#   'විදිහට',
#   'ප්\u200dරතික්ෂේප',
#   'කළ',
#   'යුතුයි',
#   'කියලා',
#   'මම',
#   'හිතනවා',
#   'මොකද',
#   'ඔවුන්',
#   'එක්කෙනෙක්',
#   'වත්',
#   'ලංකාවට',
#   'තියන',
#   'ආදරේ',
#   'නිසා',
#   'එතන',
#   'ඉන්න',
#   'කට්ටිය',
#   'නෙවෙයි',
#   'කියලා',
#   'දැන්',
#   'මේ',
#   'වෙනකොට',
#   'අපිට',
#   'පැහැදිලි',
#   'වෙනවා',
#   'නේද',
#   'බලයට',
#   'කෑදර',
#   'මේවගේ',
#   'දේශපාලුවන්',
#   'සමාජයේ',
#   'මේ',
#   'විදියට',
#   'ප්\u200dරතික්ෂේප',
#   'කළ',
#   'යුතුයි'],
#  ['මොන',
#   'දේශපාලන',
#   'මතවාද',
#   'තිබුනත්',
#   'ඒ',
#   'කරපු',
#   'වැඩේ',
#   'කැතයි',
#   'ඒක',
#   'මනුස්සකමට',
#   'නිගාවක්'],
#  ['ඕවා',
#   'බිබී',
#   'ඉදල',
#   'වැඩක්',
#   'නෑ',
#   'ප්ලීස්',
#   'අපිව',
#   'ආයෙත්',
#   'යටත්',
#   'කරගනිල්ලකෝ'],
#  ['එක',
#   'සුද්දොන්ගේ',
#   'තමා',
#   'අපේ',
#   'කියල',
#   'ඕකේ',
#   'තියෙන්නේ',
#   'කැලණි',
#   'ගගේ',
#   'වතුර',
#   'තමා',
#   'ඉතින්',
#   'මීට',
#   'ලයන්',
#   'බියර්',
#   'සේවකයෙක්'],
#  ['යකෝ',
#   'කසිප්පු',
#   'කිතුල්',
#   'රා',
#   'වගෙ',
#   'ගහනවනම්',
#   'කියපන්',
#   'අපේ',
#   'දේ',
#   'කියලා',
#   'ඕකුන්',
#   'මේ',
#   'රට',
#   'යටත්',
#   'කරගත්ත',
#   'කාලෙත්',
#   'පීප්ප',
#   'ගනන්',
#   'ගෙනල්ලා',
#   'බීවා'],
#  ['අපේ',
#   'උන්',
#   'එක්ක',
#   'උන්ට',
#   'ඒ',
#   'අතින්',
#   'හැරෙන්නවත්',
#   'බෑ',
#   'උන්',
#   'පොඩි',
#   'ටින්',
#   'එකක්',
#   'ගහන්නෙ',
#   'ඒකට',
#   'අපේ',
#   'ටීම්',
#   'එකේ',
#   'උන්',
#   'බෝතල්',
#   'ගහන්නෙ'],
#  ['යකෝ',
#   '1910',
#   'ගංජා',
#   'තහනම්',
#   'කරලා',
#   'ඕකුන්ගේ',
#   'මහ',
#   'එවුන්ම',
#   'තමා',
#   'ඔව්වා',
#   'හදුන්වලා',
#   'දුන්නේ'],
#  ['මෙතන',
#   'ගොඩක්',
#   'අය',
#   'බැනලා',
#   'කොමෙට්',
#   'කරලා',
#   'තියෙනවා',
#   'නමුත්',
#   'කිසි',
#   'කෙනෙකුට',
#   'ර\u2063ටෙ',
#   'උන',
#   'දේ',
#   'අමතක',
#   'වෙලා',
#   'තමයි',
#   'කතා',
#   'කරන්නේ'],
#  ['ගුඩ්',
#   'බායි',
#   'මහින්ද',
#   'උවමනාවක්ක්',
#   'තිබ්නම්',
#   'මහින්දට',
#   'තිබ්බා',
#   'තමන්ගෙ',
#   'හෙංචයියො',
#   'එක',
#   'වචනෙකින්',
#   'හීලෑ',
#   'කරන්න',
#   'එත්',
#   'ඔහු',
#   'එහෙම',
#   'කෙලේ',
#   'නෑ',
#   'ඔහුට',
#   'ඕනෙ',
#   'අවුල',
#   'දිගටම',
#   'තියලා',
#   'රට',
#   'අස්ථාවර',
#   'කරලා',
#   'මිනිස්සු',
#   'මරලා',
#   'හරි',
#   'බලය',
#   'ගන්න',
#   'ඒ',
#   'නිසාම',
#   'ඔහු',
#   'පිරිහනෙ',
#   'බව',
#   'ඔහුට',
#   'තේරෙන්නෙ',
#   'නෑ'],
#  ['හොයලා',
#   'බැලුවනම්',
#   'ඔය',
#   'ඉන්න',
#   'ගොන්',
#   'හැත්තට',
#   'වඩා',
#   'ගොඩක්',
#   'අය',
#   'ඉන්නවා',
#   'රට',
#   'කරන්න',
#   'මේ',
#   'යන',
#   'විදිහට',
#   'කවුද',
#   'එන්න',
#   'කැමති',
#   'පාට',
#   'පක්ෂ',
#   'බලලා',
#   'වැඩක්',
#   'නෑ',
#   'බන්',
#   'දැන්',
#   'ඔකුන්ව',
#   'එලවලා',
#   'දාන්න',
#   'ඔන',
#   'ඔක්කොම',
#   'අපේ',
#   'රටේ',
#   'හොද',
#   'දැනුම',
#   'ඔලුව',
#   'තියෙන',
#   'අය',
#   'රටෙන්',
#   'පිට',
#   'ඉන්නවා',
#   'පිරිසුදු',
#   'දේශපාලනයට',
#   'ඉඩක්',
#   'නැති',
#   'නිසා',
#   'ඒ',
#   'අය',
#   'එන්නේ',
#   'නෑ'],
#  ['පිස්සන්',
#   'කොටුවේ',
#   'ඉන්න',
#   'පිස්සෝ',
#   'හරිම',
#   'සංවරයි',
#   'සොරුන්ගේ',
#   'රජ',
#   'දහන',
#   'මින්',
#   'ඉදිරියට',
#   'තම',
#   'ආරක්ෂාව',
#   'වෙනුවෙන්',
#   'පිහි',
#   'නොව',
#   'පිස්තෝලයක්',
#   'ගෙන',
#   'යාමට',
#   'අවසර',
#   'දුන්නනම්',
#   'හොදායි',
#   'කිහිපදෙනෙක්',
#   'එලොව',
#   'කිහිපදෙනෙක්',
#   'හිරගෙට'],
#  ['ඉස්කෝලෙ',
#   'ගිය',
#   'නැති',
#   'එවුන්',
#   'පාර්ලිමේන්තු',
#   'ගියාම',
#   'ඉස්කෝලෙ',
#   'කාලෙ',
#   'ආතල්',
#   'ටික',
#   'ඒක',
#   'ඇතුලෙදි',
#   'ගන්නවා',
#   'ඒකයි',
#   'සීන්',
#   'එක'],
#  ['එහෙම',
#   'කරලා',
#   'අපි',
#   'ආපහු',
#   'පාර්ලිමේන්තුවට',
#   'යවන්නෙත්',
#   'මුන්',
#   'වගේ',
#   'සෙට්',
#   'එකක්නේ'],
#  ['ඉතින්',
#   'බන්',
#   'උබලනේ',
#   'හෙනට',
#   'මහන්සි',
#   'වෙලා',
#   'එක',
#   'එකාට',
#   'කඩේ',
#   'යන',
#   'ෆොටෝ',
#   'පොස්ට්',
#   'හදන්නේ',
#   'අපි',
#   'කොහොමත්',
#   'ආතල්',
#   'එකේ',
#   'ඒවා',
#   'බලනවා',
#   'විතරනේ',
#   'බලන්',
#   'ගියාම',
#   'පෙජ්',
#   'ඇඩ්මින්',
#   'මහත්වරු',
#   'පව්',
#   'බන්'],
#  ['උන්ට',
#   'රටට',
#   'මොනවා',
#   'උනත්',
#   'කමක්නෑ',
#   'පාර්ලිමේන්තුව',
#   'ඉස්සරහ',
#   'මෝඩ',
#   'මිනිස්සු',
#   'ටිකක්',
#   'ඇවිල්ලා',
#   'දෙපැත්ත',
#   'බෙදිලා',
#   'කෑ',
#   'ගහනවා',
#   'පාර්ලිමේන්තු',
#   'ඇතුලේ',
#   'මුන්',
#   'දෙගොල්ලොම',
#   'එකට',
#   'ජොලියේ',
#   'සැපේ',
#   'ඉන්නවා'],
#  ['විමල්ගේ',
#   'ආදරණිය',
#   'සිරිසේන',
#   'අද',
#   'රාත්\u200dරියේ',
#   'නටන',
#   'පිස්සුව',
#   'නිවැරදිව',
#   'සදහන්කර',
#   'රාත්\u200dරිය',
#   'පුරාවට',
#   'ඔබව',
#   'නැවුම්ව',
#   'තබන',
#   'ව්\u200dයාඝා',
#   'පෙත්තක්',
#   'දිනාගන්න'],
#  ['හිටං',
#   'අගමැති',
#   'මරැ',
#   'කරනවා',
#   'හෂිනි',
#   'මිනිහා',
#   'මරැ',
#   'කරනවා',
#   'මේවා',
#   'දකිද්දී',
#   'අපේ',
#   'වයර්',
#   'මරැ',
#   'වෙනවා',
#   'ආය්යෝ',
#   'ලංකාවට',
#   'වෙච්ච',
#   'දෙයක්'],
#  ['රටේ',
#   'දේවල්',
#   'විකුනං',
#   'කන',
#   'උන්ට',
#   'කඩේ',
#   'යන',
#   'රට',
#   'ගැන',
#   'හැගීමක්',
#   'නැති',
#   'උන්',
#   'තවම',
#   'ඉන්නවා',
#   'කියලා',
#   'පෙන්නුවටත්',
#   'ස්තූතියි',
#   'දැන්',
#   'අපට',
#   'අායේ',
#   'ෆ්\u200dරී',
#   'වයිෆයි',
#   'ලැබෙයි',
#   'නේද'],
#  ['මේ',
#   'වගේ',
#   'රටක',
#   'අධිකරණය',
#   'ගැනත්',
#   'ලොකු',
#   'විශ්වාසයක්',
#   'තියා',
#   'ගන්න',
#   'බෑ',
#   'මොකද',
#   'තීන්දු',
#   'දිලා',
#   'ගෙදර',
#   'ගිහින්',
#   'සමාව',
#   'ඉල්ලන',
#   'අග්\u200dර',
#   'විනිශ්චයකාරයෝ',
#   'ඉන්න',
#   'ආතල්',
#   'රටක්',
#   'මේක'],
#  ['ඉස්සර',
#   'නඩු',
#   'තීන්දු',
#   'තුට්ටුවකට',
#   'ගනන්',
#   'නොගත්ත',
#   'කාලයක්',
#   'තිබ්බා',
#   'පෙට්\u200dරල්',
#   'අඩුකරන්න',
#   'කියලා',
#   'දුන්න',
#   'තීන්දුව',
#   'මේ',
#   'පාර',
#   'ඡන්දය',
#   'එකෙක්ට',
#   'වත්',
#   'දෙන්නේ',
#   'නෑ'],
#  ['අතුරු',
#   'තහනම්',
#   'නියෝගයක්',
#   'යනු',
#   'නඩුව',
#   'විභාග',
#   'කරන',
#   'තෙක්',
#   'ලබා',
#   'දෙන',
#   'තීන්දුවක්',
#   'බව',
#   'ඔබේ',
#   'හය',
#   'හතර',
#   'නොදත්',
#   'දරුවාට',
#   'කියා',
#   'දෙන්න'],
#  ['ඡන්දෙකට',
#   'කලින්',
#   'අපේ',
#   'රටෙත්',
#   'මෙහෙම',
#   'කළා',
#   'නම්',
#   'කොච්චර',
#   'හොඳද',
#   'කතිරය',
#   'ගහන්න',
#   'කළින්',
#   'බලන්න'],
#  ['මෙහෙමනේ', 'අපේ', 'රටේ', 'පොලිසියට', 'ඕවා', 'බෑනේ'],
#  ['මෙහෙම', 'තිබුනොත්', 'මෙහේ', 'මේකත්', 'හොරෙන්', 'කෙලගන', 'යයි'],
#  ['පිස්සෝ', 'දන්නවද', 'ඌ', 'ඉන්නේ', 'අංගොඩද', 'ගෙදරද', 'කියලා'],
#  ['පොලීසිය', 'නිකන්', 'ප්\u200dරභාකරන්', 'අල්ලගෙන', 'වගේ', 'ගැම්ම'],
#  ['සරලවම',
#   'සිරිසේන',
#   'ව්\u200dයවස්ථාවෙන්',
#   'බේරිලා',
#   'පාර්ලිමේන්තුව',
#   'විසිරන',
#   'තැනට',
#   'එනකම්',
#   'ආව',
#   'විදිය',
#   'තමයි',
#   'මේ'],
#  ['නැතුව',
#   'අර',
#   'අන්තිමට',
#   'කලින්',
#   'නියම',
#   'ඩමියක්',
#   'දැම්මේ',
#   'පොලිසියේ',
#   'ඩයල්',
#   'එකක්',
#   'වැටෙන්න'],
#  ['ඉතින්', 'කොහොමද', 'හොරෙක්ව', 'වත්', 'එලවලා', 'අල්ලගන්නෙ'],
#  ['කව්ද',
#   'යකෝ',
#   'වැටෙද්දිම',
#   'විසිල්',
#   'එක',
#   'ගහපු',
#   'එකා',
#   'රගර්',
#   'මැච්',
#   'එකක්',
#   'මතක්',
#   'උනා'],
#  ['ඕකා',
#   'තාම',
#   'පනපිටින්ද',
#   'නැත්තං',
#   'ආයුධ',
#   'පෙන්නන්න',
#   'එක්ක',
#   'ගිහින්වත්ද'],
#  ['පොලිස්සියේ',
#   'එවුන්ට',
#   'බදක',
#   'කිගදිවිම',
#   'පුහුනු',
#   'කල',
#   'එ',
#   'සුදු',
#   'මහත්තයාට',
#   'ස්තුති'],
#  ['මූ',
#   'හැකර්',
#   'කෙනෙක්',
#   'ඒකයි',
#   'ඔච්චර',
#   'තද',
#   'හමුෆ්හාව්ලින්',
#   'ගේමක්',
#   'නැතුව',
#   'බේරිල',
#   'ඇවිත්',
#   'මිශන්',
#   'එක',
#   'ගැහුවෙ'],
#  ['මූව', 'පොහොට්ටුවෙන්', 'පාර්ලිමේන්තු', 'යවමු'],
#  ['එක', 'සුද්දයි', 'මුලු', 'පොලිසියමයි', 'මෙ', 'පාර', 'ඔය', 'පරාදයි', 'දගයො'],
#  ['සුද්දගේ', 'තුනෙන්', 'එක', 'බලය', 'හෙළිවෙලා'],
#  ['සුද්දගෙ', 'තැන', 'ලංකාවේ', 'එකෙක්', 'උනානම්', 'අම්මෝ', 'නේ'],
#  ['ඉතින්', 'කෝමදැ', 'හොරෙක්වත්', 'අල්ලගන්නේ'],
#  ['ඉතින්කොහොමද', 'හොරෙක්වත්', 'අල්ල', 'ගන්නෙ'],
#  ['හෙට', 'ඉදන්', 'කොයි', 'අයියත්', 'මේ', 'අයියට', 'සැලැන්ඩර්', 'මල්ලි'],
#  ['ඇයි',
#   'යකෝ',
#   'පාර්ලිමේන්තුව',
#   'විසුරුවා',
#   'හැරියාම',
#   'මෙච්චර',
#   'බය',
#   'මේ',
#   'වෙලාවෙදි',
#   'ගත්ත',
#   'හොදම',
#   'තිරණය',
#   'තමයි',
#   'මේ',
#   'ගත්තේ',
#   'රනිල්ට',
#   'ඔච්චරම',
#   'මිනිස්සු',
#   'කැමති',
#   'නම්',
#   'ඡන්දයක්',
#   'තියලා',
#   'බලමු'],
#  ['උබල',
#   'නේද',
#   'ජනාධිපති',
#   'කලෙත්',
#   'අම්මෝ',
#   'ඒ',
#   'කාලේ',
#   'උබ',
#   'දීපු',
#   'ටෝක්'],
#  ['මහින්ද',
#   'අරින',
#   'අස්සෙ',
#   'හිටං',
#   'කාරයත්',
#   'පැත්තකින්',
#   'ඇනලා',
#   'ජාතක',
#   'උන',
#   'උං',
#   'නෙ',
#   'මෙච්චර',
#   'කල්',
#   'මහින්දට',
#   'අප්පොච්චි',
#   'කියල',
#   'තියෙන්නෙ',
#   'හෑ',
#   'යකූ',
#   'මේමත්',
#   'සප්ප්\u200dරායිස්'],
#  ['ඒ',
#   'මනුස්සයට',
#   'දරු',
#   'මුණුපුරන්',
#   'ඉන්නවා',
#   'රටක්',
#   'මතු',
#   'පරපුර',
#   'වෙනුවෙන්',
#   'ඉතුරු',
#   'කරන්න',
#   'ඕනී',
#   'හින්දයී',
#   'හරි',
#   'තීරණයක්',
#   'ප්\u200dරමාද',
#   'වී',
#   'හෝ',
#   'ගත්තේ',
#   'එහෙම',
#   'නැති',
#   'උන්ට',
# ...
#   'ආණ්ඩුවටම',
#   'බැන',
#   'බැන',
#   'හත්පොළේ',
#   'ගා',
#   'ගෙන',
#   'වගේ',
#   'හොඳ',
#   'වැඩේ',
#   'කබීර්',
#   'හෂීම්',
#   'සිංහල',
#   'කතා',
#   'කරන්නේ',
#   'ලෝකෙට',
#   'ලොක්කා',
#   'වගේ',
#   'හොර',
#   'තම්බියෝ'],
#  ['එහෙනම්',
#   'රිෂාඩ්',
#   'බද්යුදීන්',
#   'ඇතුලු',
#   'තම්බියෝ',
#   'ටික',
#   'රටින්',
#   'පන්නන්න',
#   'ඕනි'],
#  ['තම්බියෝ',
#   'නිකං',
#   'කියවගෙන',
#   'ඇවිත්',
#   'අල්ලගේ',
#   'හෙලුවැල්ලයි',
#   'ප්\u200dරදර්ශනය',
#   'කරගන්න',
#   'එපා'],
#  ['නව',
#   'සිහල',
#   'උරුමය',
#   'පක්ෂයේ',
#   'අපේක්ෂකයන්',
#   'මෙන්න',
#   'නමට',
#   'සිහල',
#   'උරුමය',
#   'ඉන්නේ',
#   'තම්බියෝ',
#   'කරුණාකර',
#   'අපගේ',
#   'මුල්',
#   'පිටුවට',
#   'පැමිණ'],
#  ['උඹලැ',
#   'බලුමූනු',
#   'අමිත්ගේ',
#   'බණ',
#   'අහල',
#   'අන්න',
#   'තව්හිද්',
#   'ජමා',
#   'සහ',
#   'තම්බි',
#   'අන්තවාදීන්',
#   'සෙට්',
#   'එක',
#   'සෝවාන්',
#   'වෙල',
#   'උඹල',
#   'උන්ව',
#   'හරිමගට',
#   'ගත්ත',
#   'නේ',
#   'අනෙ',
#   'හුකේ',
#   'එකේක',
#   'විකාර',
#   'අවුස්සල',
#   'වීඩියෝ',
#   'දාල',
#   'රට',
#   'ඉන්න',
#   'කොල්ලන්ගෙන්',
#   'සල්ල්ලි',
#   'හිඟාකනෝ',
#   'ඒව',
#   'ගසාකනෝ',
#   'තොපිද්',
#   'දැනුවත්ව',
#   'හෝ',
#   'මෝඩ',
#   'කමට',
#   'ඕ',
#   'ගස්නරින්ට',
#   'කඩේ',
#   'යනව'],
#  ['දහමි',
#   'කතිකාවතක්',
#   'අැතිව්නේ',
#   'කලකට',
#   'පස්සේ',
#   'සිංහල',
#   'අපි',
#   'දහමෙින්',
#   'ඈත්',
#   'කරාම',
#   'මෙි',
#   'හොර',
#   'නඩෙිට',
#   'වාසියිනේ',
#   'එ්කයි',
#   'මෙි',
#   'බත්',
#   'කන',
#   'හරක්',
#   'මොර',
#   'දේන්නේ'],
#  ['ගම්මන්පිල',
#   'දුමින්ද',
#   'පුද්ගලිකව',
#   'උන්',
#   'අකමැති',
#   'චරිත',
#   'වෙන්න',
#   'පුලුවන්',
#   'ඒත්',
#   'මුන්',
#   'පෙන්නුවෙ',
#   'උන්ගෙ',
#   'වීර',
#   'කම',
#   'නෙමෙයි',
#   'ගොබ්බ',
#   'කම',
#   'උන්ට',
#   'කලාකාරයො',
#   'කියනවනම්',
#   'ඒක',
#   'උන්ගෙත්',
#   'ගොබ්බකම',
#   'ඔතන',
#   'රනිල්',
#   'හිටියත්',
#   'අනුර',
#   'හිටියත්',
#   'මහින්ද',
#   'හිටියත්',
#   'නිහතමානීව',
#   'සම්මානෙ',
#   'ගත්තනම්',
#   'අන්න',
#   'ඌ',
#   'කලාකරුවෙක්'],
#  ['ඔලුව',
#   'උදුමමා',
#   'ගත්ත',
#   'පල්',
#   'මෝඩයෙක්',
#   'දේශපාලනඥයන්',
#   'ප්\u200dරතිකේෂ්ප',
#   'කරන්න',
#   'මහජන',
#   'ජන්දෙන්',
#   'එපැයි',
#   'වැදගත්',
#   'වන්නේ',
#   'සම්මානය',
#   'දුන්',
#   'කාරනාව',
#   'මිස',
#   'ලබා',
#   'දෙන',
#   'කෙනා',
#   'නෙවේ',
#   'මෙවැනි',
#   'ගොබ්බයන්',
#   'සමාජයෙන්ම',
#   'ප්\u200dරතිකේෂ්ප',
#   'වනු',
#   'ඇත'],
#  ['මේ',
#   'යෞවන',
#   'සම්මාන',
#   'උළෙල',
#   '2018',
#   'අංකුර',
#   'කලාකරුවන්ට',
#   'තමයි',
#   'සම්මාන',
#   'දෙන්නේ',
#   'ඒ',
#   'හින්දා',
#   'මෙවුන්',
#   'වැඩිය',
#   'ජනප්\u200dරිය',
#   'නැති',
#   'වෙන්න',
#   'පුලුවන්',
#   'මොවුන්ගේ',
#   'දේශපාලන',
#   'මතවාද',
#   'පිළිබඳ',
#   'අදහස්',
#   'දැක්වීමට',
#   'නොහැකි',
#   'යි',
#   '\u2063කොහොම',
#   'උනත්',
#   'අංකුර',
#   'කලාකරුවකු',
#   'සම්මාන',
#   'ලබා',
#   'ගත',
#   'යුත්තේ',
#   'ප්\u200dරවීණ',
#   'කලාකරුවෙක්',
#   'අතින්',
#   'කියන',
#   'එක',
#   'තමයි',
#   'මගේ',
#   'මතය',
#   'නැතුව',
#   'රට',
#   'කන',
#   'බූරු',
#   'දේශපාලඥයන්',
#   'අතින්',
#   'නෙවෙයි'],
#  ['ලංකාවෙ',
#   'මිනිස්සු',
#   'වර්ග',
#   'දෙකක්',
#   'ඉන්නව',
#   'එකක්',
#   'ගොං',
#   'ගොබ්බ',
#   'ගෝත්\u200dරික',
#   'හොරිකඩ',
#   'නිවටයො',
#   'අනික්',
#   'වර්ගෙ',
#   'මේ',
#   'කොල්ලො',
#   'කරපු',
#   'වැඩේට',
#   'එකඟ',
#   'හා',
#   'අගය',
#   'කරන',
#   'උන්'],
#  ['හොදම',
#   'වැඩේ',
#   'කිසිම',
#   'පකේ',
#   'දේශපාලන',
#   'පකයෙක්',
#   'කිසිම',
#   'දේකට',
#   'ආරාදනා',
#   'කරන්න',
#   'හොද',
#   'නෑ',
#   'මේව',
#   'හොද',
#   'වැඩ'],
#  ['ඒ',
#   'මේ',
#   'නලුව',
#   'කව්ද',
#   'බං',
#   'මොකෙන්',
#   'ආපු',
#   'එකෙක්ද',
#   'යකෝ',
#   'ඒ',
#   'මේක',
#   'මේ',
#   'පක්ෂග්\u200dරාහී',
#   'වෙලා',
#   'කරපු',
#   'වැඩක්නෙ',
#   'ඔතන',
#   'යූ',
#   'එන්',
#   'පී',
#   'හරි',
#   'ජේවීපි',
#   'හරි',
#   'හිටියනම්',
#   'ඔව්න්',
#   'ඕක',
#   'ගන්නෙ',
#   'උන්ගෙ',
#   'පුකත්',
#   'ලෙවකාල',
#   'අනේ',
#   'පකේ',
#   'නලුකම',
#   'එතන',
#   'හිටිය',
#   'ශ්\u200dරියන්නල',
#   'වගේ',
#   'අය',
#   'ආදර්ශයට',
#   'ගනියව්',
#   'ඒ',
#   'නිහතමානීකම්',
#   'පුරුදු',
#   'වෙයව්'],
#  ['දේශපාලන',
#   'මතේ',
#   'මොකක්',
#   'උනත්',
#   'තමන්ට',
#   'හිමි',
#   'සම්මානය',
#   'දක්ෂතාවයටයි',
#   'ලැබෙන්නේ',
#   'ඒක',
#   'දෙන්නේ',
#   'මොකාද',
#   'කියලා',
#   'බලන්න',
#   'ඕන',
#   'නෑ',
#   'නිහතමානීකම',
#   'නැති',
#   'ගොබ්බ',
#   'කලාකාරයෝ',
#   'මුන්ට',
#   'අනාගතයක්',
#   'තියෙයිද',
#   'නෙදකිංවත්'],
#  ['හරි',
#   'ලොකු',
#   'දෙයක්',
#   'වගේ',
#   'නූගත්කම',
#   'ප්\u200dරදර්ශනය',
#   'කලා',
#   'ඕක',
#   'ගොන්කම',
#   'එක්ක',
#   'එන',
#   'දෙයක්',
#   'උදේ',
#   'ගංජා',
#   'ගහලා',
#   'හවස',
#   'සම්මානය',
#   'ගන්න',
#   'ඇවිත්',
#   'වගේයි',
#   'පේන්නේ'],
#  ['පඩ',
#   'ශෝ',
#   'සම්මානෙ',
#   'දුන්නෙ',
#   'උන්ගෙ',
#   'හැකියාවක්',
#   'තිබිලා',
#   'මිසක්',
#   'දේශපාලුන්ගෙ',
#   'අල්ලසක්',
#   'විදිහට',
#   'නෙවෙයි',
#   'මේ',
#   'වගෙ',
#   'දැන්',
#   'උන්',
#   'පොරවල්',
#   'ද',
#   'සම්මානෙකට',
#   'නුසුදුසු',
#   'කම',
#   'පෙන්නුවා',
#   'විතරයි'],
#  ['හාල්පාරු',
#   'දේශපාලුවන්ගේ',
#   'අතින්',
#   'ඔය',
#   'වගේ',
#   'වටිනා',
#   'සම්මාන',
#   'ලාබාදීම',
#   'සංවිධායකයන්',
#   'ගන්න',
#   'ගොබ්බ',
#   'තීරණ',
#   'ප්\u200dරවීණ',
#   'කලාකරුවෙක්ගේ',
#   'අතින්',
#   'සම්මාන',
#   'ලබා',
#   'දෙන්න',
#   'කොන්දක්',
#   'නැති',
#   'ගොබ්බ',
#   'සංවිධායකයන්ට',
#   'හොද',
#   'පිලිතුරක්'],
#  ['මෙහෙම',
#   'තමයි',
#   'වෙන්න',
#   'ඔින',
#   'වහල්',
#   'ගතිවලින්',
#   'මිදෙන්න',
#   'බැරි',
#   'බහුතරයක්',
#   'ඉන්නවනේ',
#   'උන්',
#   'හැමවෙලාවෙම',
#   'තණකොළ',
#   'පුන්නක්කු',
#   'දීලා',
#   'කිරිටික',
#   'දොවාගන්නවා'],
#  ['සිංහල',
#   'කියන',
#   'කාලකන්නි',
#   'මෝඩ',
#   'පකයිනෙ',
#   'තොපි',
#   'පොඩ්ඩක්',
#   'කල්පනා',
#   'කරපියව්',
#   'මුන්',
#   'දෙගොල්ලම',
#   'කරන්නෙ',
#   'ඌරගෙ',
#   'මාළු',
#   'ඌරගෙ',
#   'ඇඟේමතියල',
#   'කපනඑකයි',
#   'මහින්දව',
#   'ලොකු',
#   'කරන්න',
#   'කියන',
#   'එක',
#   'නෙමෙයි',
#   'කියන්නෙ',
#   'දැනට',
#   'රනිල්',
#   'සමග',
#   'ඇතිකරගෙන',
#   'තියන',
#   'ගිවිසුම්ටික',
#   'ක්\u200dරියාත්මක',
#   'කරගන්නකම්',
#   'මේ',
#   'දෙගොල්ලම',
#   'රනිල්ව',
#   'උඩින්ම',
#   'තියාගෙන',
#   'ඉන්නෙ',
#   'ඊටපස්සෙ',
#   'බලාගන්න',
#   'පුළුවන්',
#   'මුන්ගෙ',
#   'කෙරුවාවල්ටික',
#   'බලපියව්',
#   'මුන්',
#   'මෙහෙම',
#   'ඉඳගෙන',
#   'ගරහන්නෙ',
#   'අපේම',
#   'සක්කිලිත්',
#   'එක්ක',
#   'එකතුවෙලා',
#   'අපේම',
#   'උන්ට',
#   'නේද',
#   'කියල',
#   'මුන්ට',
#   'තවම',
#   'ලොකු',
#   'බලයක්',
#   'නැතිව',
#   'මෙහෙමනම්',
#   'මුන්ට',
#   'අයිතිවාසිකම්',
#   '\u2063බලතල',
#   'සේරම',
#   'ලැබුනදාට',
#   'ඔය',
#   'මුන්',
#   'එක්ක',
#   'එකතුවෙලා',
#   'ඉන්න',
#   'පොන්නයන්ටත්',
#   'අපිටත්',
#   'මුන්',
#   'බෙදන්නෙ',
#   'එකම',
#   'හැන්දෙන්බව',
#   'මතකතියා',
#   'ගනිල්ල'],
#  ['කුනුහරුප',
#   'වලින්',
#   'කියන්නෙ',
#   'අපේ',
#   'සක්කිළි',
#   'මිනිසුන්ට',
#   'හොදින්',
#   'කිව්වට',
#   'තේරුම්',
#   'ගන්නෙ',
#   'නැති',
#   'නිසයි',
#   'පක්ෂයක්',
#   'නිසා',
#   'ජාතියක්',
#   'විනාස',
#   'කරගන්න',
#   'එපා',
#   'කියන',
#   'එකයි',
#   'කියන්නෙ',
#   'ඒකට',
#   'මහින්ද',
#   'අදාලනෑ',
#   'නමුත්',
#   'දැනට',
#   'ඌතරම්වත්',
#   'අපිගැන',
#   'බලන්න',
#   'වෙන',
#   'එකෙක්',
#   'නැතිනිසයි'],
#  ['උන්ට',
#   'පින',
#   'නෑ',
#   'ගම්මන්පිල',
#   'වගේ',
#   'උත්තමයෙක්',
#   'අතින්',
#   'සම්මානයක්',
#   'ගන්ට',
#   'දුමින්ද',
#   'මහත්තයාගේත්',
#   'හිත',
#   'හොදටෝම',
#   'පෑරෙන්ට',
#   'ඇති'],
#  ['කොච්චර',
#   'ඉහලට',
#   'ගියත්',
#   'මනුස්සකම',
#   'තියෙන්න',
#   'ඔන',
#   'හදවතයි',
#   'ලස්සන',
#   'වෙන්න',
#   'ඕන',
#   'දේශපාලකයො',
#   'කියන්නෙ',
#   'තමන්',
#   'ගැන',
#   'විතරක්',
#   'හිතන',
#   'උන්',
#   'බව',
#   'අැත්ත',
#   'එ්ත්',
#   'මිසුන්',
#   'විදියට',
#   'අපි',
#   'කවුරුත්',
#   'මනුස්සයො',
#   'එ්',
#   'මනුස්ස',
#   'කමටයි',
#   'ගරු',
#   'කරන්න',
#   'ඕන',
#   'ඕය',
#   'මොන',
#   'දේ',
#   'තිබ්බත්',
#   'වැඩක්',
#   'නෑ',
#   'මනුෂීය',
#   'බවක්',
#   'නැත්නම්'],
#  ['මුන්',
#   'මොන',
#   'පුකේ',
#   'නලුවොද',
#   'බං',
#   'යකෝ',
#   'දේශපාලනය',
#   'පැත්තකට',
#   'තියල',
#   'මනුස්සකම',
#   'ගැන',
#   'හිතන්න',
#   'ඕන',
#   'බලපං',
#   'ශ්\u200dරියන්ත',
#   'මහත්තයගෙ',
#   'නිහතමානීකම',
#   'ඒත',
#   'නලුවෙක්',
#   'තමා',
#   'ඔය',
#   'පගරනැට්ටට',
#   'වඩා'],
#  ['කවුරුන්',
#   'වුවද',
#   'අකමැති',
#   'නම්',
#   'කළ',
#   'යුත්තේ',
#   'මෙයයි',
#   'මේ',
#   'දේ',
#   'අපේ',
#   'රටේ',
#   'නොවෙන',
#   'නිසයි',
#   'අපි',
#   'ජාතියක්',
#   'විදියට',
#   'ඇන',
#   'කොටාගනිමින්',
#   'අපිම',
#   'විනාශ',
#   'වෙන්නේ',
#   'අපි',
#   'සුළැගිල්ලේ',
#   'තිින්ත',
#   'ටික',
#   'ගානවෙලාවට',
#   'විතරක්',
#   'වටිනවා',
#   'යැයි',
#   'සිතා',
#   'සිටින',
#   'දේශපාලකයන්',
#   'ඉන්',
#   'අනතුරුව',
#   'අපිව',
#   'බල්ලේකුටවත්',
#   'ගනන්',
#   'ගන්නේ',
#   'නැත'],
#  ['සැබෑ',
#   'කලා',
#   'කරුවා',
#   'දෙවැනි',
#   'වන්නේ',
#   'දෙවියන්ට',
#   'පමණයි',
#   'ඒ',
#   'වචනයේ',
#   'පරිසමාප්ත',
#   'අර්ථයෙන්',
#   'කලාකරුවන්',
#   'නැතුව',
#   'දේශපාලන',
#   'ගැත්තො',
#   'නෙවෙයි',
#   'ඒ',
#   'කියන්නේ',
#   'දෙවියෙක්',
#   'එහෙම',
#   'කලා',
#   'නම්',
#   'මේ',
#   'පොලොව',
#   'සියළු',
#   'නිමැවුම්',
#   'කල',
#   'ඊලඟ',
#   'කෙනා',
#   'වන',
#   'කලාකරුවා',
#   'ජනතාවගේ',
#   'ශ්\u200dරමය',
#   'ධනය',
#   'හූරාගෙන',
#   'කන',
#   'මනී',
#   'මරණ',
#   'දේශපාලුවන්ගේ',
#   'කිලිටි',
#   'අත්වලින්',
#   'සම්මාන',
#   'ලබා',
#   'ගැනීම',
#   'නොකල',
#   'යුතුයි',
#   'නමුත්',
#   'රටට',
#   'ජනතාවට',
#   'යමක්',
#   'කල',
#   'දේශපාලකයෙකු',
#   'ගෙන්',
#   'කලාවට',
#   'යමක්',
#   'කල',
#   'කලාකරුවන්',
#   'සම්මානයක්',
#   'ලබාගනීම',
#   'වරදක්',
#   'නැත',
#   'එහෙත්',
#   'දෙපාර්ශවයේම',
#   'එවැනි',
#   'අය',
#   'කොපමණ',
#   'ඇත්ද',
#   'අඩුවැඩි',
#   'වශයෙන්'],
#  ['සම්මානය',
#   'ගත්ත',
#   'දෙන්න',
#   'කරපු',
#   'දේ',
#   'සීයට',
#   'සීයක්',
#   'හරි',
#   'කියන්න',
#   'බෑ',
#   'නමුත්',
#   'පක්ශ',
#   'විපක්ශ',
#   'සියලු',
#   'දේශපාලකයන්',
#   'තේරුම්',
#   'ගත',
#   'යුතුයි',
#   'දේශපාලකයන්ව',
#   'මිනිස්සු',
#   'කොයිතරම්',
#   'පිලිකුල්',
#   'කරනවද',
#   'කියල'],
#  ['මන්',
#   'මෙයා',
#   'කව්ද',
#   'වත්',
#   'දන්නේ',
#   'නෑ',
#   'කිසිම',
#   'උත්සවයකට',
#   'දේශපාලන',
#   'මී',
#   'හරක්',
#   'එකෙක්',
#   'වත්',
#   'ඔනී',
#   'නෑ',
#   'මට',
#   'නම්',
#   'ඔය',
#   'මිනිස්සු',
#   'පේන්න',
#   'බෑ',
#   'රට',
#   'කනවා'],
#  ['සම්මානයක්',
#   'ලැබෙනවා',
#   'කියන්නෙම',
#   'ජනතාවගේ',
#   'සම්මානයක්',
#   'ප්\u200dරසාදයක්',
#   'ලැබෙනවා',
#   'කියන',
#   'එක',
#   'ඒක',
#   'අතට',
#   'දෙන්න',
#   'කවුරුහරි',
#   'ඉන්න',
#   'ඕන',
#   'ඒකට',
#   'සුදුසු',
#   'ජනතාවගේ',
#   'නියෝජිතයන්',
#   'හැර',
#   'වෙන',
#   'කවුද'],
#  ['කිසිම',
#   'පුතිපත්තියක්',
#   'නැති',
#   'තමන්ට',
#   'යැපෙන්නට',
#   'ඕනම',
#   'ජරා',
#   'බලු',
#   'කතා',
#   'කියන',
#   'දේශපාලකයන්',
#   'කියාගන්න',
#   'අපතය\u200dෝ',
#   'එක්ක',
#   'ලගින',
#   'පුවීන',
#   'යයි',
#   'කියාගන්න',
#   'කලාකරුවන්ටත්',
#   'හොඳ',
#   'පාඩමක්'],
#  ['යකො',
#   'ගොන්',
#   'පොන්නයෝ',
#   'තොට',
#   'සානුකම්පිත',
#   'හේතූන්',
#   'මත',
#   'දුන්',
#   'ලී',
#   'කෑල්ල',
#   'ගන්න',
#   'තෝ',
#   'පුද්ගලයා',
#   'තෝරන්න',
#   'තරම්',
#   'තෝ',
#   'මීට',
#   'කලින්',
#   'ඔවැනි',
#   'අපිට',
#   'අදාළ',
#   'නැති',
#   'ලී',
#   'කෑලි',
#   'කීයක්',
#   'අරන්',
#   'තියෙනවාද'],
#  ['දේශපාලනය',
#   'කියන්නේ',
#   'ගෞරවනීය',
#   'වෘත්තියක්',
#   'අපි',
#   'එයට',
#   'ගරුකල',
#   'යුතුයි',
#   'ඔවුන්',
#   'නොමැතිව',
#   'රටක්',
#   'හෝ',
#   'සමාජයක්',
#   'ඉදිරියට',
#   'යන්න',
#   'විදියක්',
#   'නැහ',
#   'ඇත්තටම',
#   'මේ',
#   'සිද්ධිය',
#   'තුල',
#   'ඇත්තේ',
#   'ඒ',
#   'ගෞරවයනීය',
#   'වෘත්තීය',
#   'ප්\u200dරතික්ශේප',
#   'කිරීමක්',
#   'එය',
#   'එසේ',
#   'සිදුවිය',
#   'යුතුයි',
#   'කියා',
#   'මා',
#   'විස්වාස',
#   'කරන්නේ',
#   'නැහැ',
#   'ඒත්',
#   'දේශපාලනඥයා',
#   'ඔවුන්ගේ',
#   'වපසරිය',
#   'මොකක්ද',
#   'යන්න',
#   'හදුනා',
#   'නොගන්නා',
#   'විට',
#   'මෙය',
#   'මෙසේ',
#   'සිදුවිය',
#   'යුතුයි'],
#  ['කවද',
#   'හරි',
#   'දවසක',
#   'ඒ',
#   'කලාකරුවා',
#   'කියනකෙනාගෙ',
#   'අතින්',
#   'කාට',
#   'හරි',
#   'සම්මානයක්',
#   'දෙන',
#   'වෙලාවකදී',
#   'එය',
#   'ප්\u200dරතික්ෂේප',
#   'කලහොත්',
#   'එදාට',
#   'ඔහු',
#   'කල',
#   'නුසුදුසු',
#   'ක්\u200dරියාව',
#   'අවබෝධ',
#   'වෙනු',
#   'ඇත'],
#  ['හාල්පාරු',
#   'දේශපාලුවන්ගේ',
#   'අතින්',
#   'ඔය',
#   'වගේ',
#   'වටිනා',
#   'සම්මාන',
#   'ලාබාදීම',
#   'සංවිධායකයන්',
#   'ගන්න',
#   'ගොබ්බ',
#   'තීරණ',
#   'ප්\u200dරවීණ',
#   'කලාකරුවෙක්ගේ',
#   'අතින්',
#   'සම්මාන',
#   'ලබා',
#   'දෙන්න',
#   'කොන්දක්',
#   'නැති',
#   'ගොබ්බ',
#   'සංවිධායකයන්ට',
#   'හොද',
#   'පිලිතුරක්'],
#  ['පුකේ',
#   'කලාකරුවෝ',
#   'මිනිස්සුන්ට',
#   'ගරුකරන්න',
#   'බැරි',
#   'කාගෙවත්',
#   'දේශපාලනයක්',
#   'මොකටද',
#   'සම්මානයකට',
#   'පටලවාගන්නෙ',
#   'නූගත්කමයි',
#   'මහන්තත්ත්වෙයි',
#   'පෙන්නන්න',
#   'ගත්ත',
#   'බොළද',
#   'උත්සහයක්',
#   'විතරයි',
#   'හරිම',
#   'ලාමකයි'],
#  ['නියමයි',
#   'ඔවුන්ගේ',
#   'මහන්සියෙන්',
#   'නිර්මාණ',
#   'කරලා',
#   'එකට',
#   'වටිනාකමක්',
#   'වටිනා',
#   'මිනිසුන්ගෙන්',
#   'ලැබෙන්න',
#   'ඔනි',
#   'කොහෙවත්',
#   'ඉන්න',
#   'ජරා',
#   'දුෂිත',
#   'රටටම',
#   'පිලිලයක්',
#   'වුනු',
#   'නරැම',
#   'පාලකයන්',
#   'ගෙන්',
#   'නොවෙ'],
#  ['රනිල්ට',
#   'විරැද්දව',
#   'දේශපාලනය',
#   'රැස්වීම්',
#   'කතා',
#   'පැවැත්වූ',
#   'ජැක්සන්',
#   'ඇන්තනි',
#   'මහතා',
#   'සම්මාන',
#   'උලෙළේදී',
#   'ඇන්තනි',
#   'මහතාට',
#   'සම්මානය',
#   'දුන්නේ',
#   'රනිල්',
#   'එතුමා',
#   'සම්මානය',
#   'ගන්න',
#   'බෑ',
#   'කීවේ',
#   'නැහැ',
#   'ඒතමයි',
#   'ගෙෘරවාන්විත',
#   'කලා',
#   'කරැවන්',
#   'මේ',
#   'මොකෙක්ද',
#   'කලා',
#   'කරැවෝද',
#   'මුන්ට',
#   'කියන්නේ',
#   'ගංජා',
#   'කරැවො',
#   'කියලා'],
#  ['නියමයි',
#   'සහෝ',
#   'කොතනත්',
#   'මෙහෙම',
#   'වෙනවනම්',
#   'අපේ',
#   'හෙට',
#   'දවස',
#   'ලස්සන',
#   'වේවි',
#   'බුකියේ',
#   'දේශපාලනය',
#   'කරන',
#   'නිකමුන්',
#   'බලා',
#   'ගතහොත්',
#   'හොදා'],
#  ['ප්\u200dරවීන',
#   'කලා',
#   'කරුවනුත්',
#   'දේශපාලන',
#   'අතකොලු',
#   'වෙලා',
#   'ඉන්න',
#   'ලංකාවේ',
#   'මේ',
#   'වැඩෙන්',
#   'වෙන්නෙ',
#   'එයාලට',
#   'කලා',
#   'කාරයොත්',
#   'නෑ',
#   'දේශපාලකයෝත්',
#   'නැතිවෙන',
#   'වැඩක්',
#   'මොනව',
#   'උනත්',
#   'ලංකාවේ',
#   'දේශපාලකයන්',
#   'පිලිබඳ',
#   'සමාජ',
#   'මතය',
#   'මේක',
#   'උනත්',
#   'කවුරුත්',
#   'එලියට',
#   'දාන්න',
#   'ඉදිරිපත්',
#   'වෙන්නෑ',
#   'මෙයාල',
#   'ඒක',
#   'කලා',
#   'උන්',
#   'ගොබ්බයෝ',
#   'උනා'],
#  ['නිකන්',
#   'මේ',
#   'කොහෙද',
#   'ඉන්න',
#   'ගෙම්බෝ',
#   'දෙන්නෙක්',
#   'පුම්බන්ට',
#   'හදන්න',
#   'එපා',
#   'කලාකරුවෙක්',
#   'කියන්නේ',
#   'මොකෙක්ද',
#   'කියලවත්',
#   'දන්නේ',
#   'නැති',
#   'චූ',
#   'කොල්ලෝ',
#   'දෙන්නෙක්',
#   'කලාකරුවෙක්',
#   'නිර්මාණයක්',
#   'කරත්',
#   'මේක',
#   'දෙසපලකයට',
#   'මේක',
#   'හිගන්නට',
#   'මේක',
#   'වංශවත්',
#   'එකාට',
#   'කියලා',
#   'තෝරලා',
#   'බේරලා',
#   'නිර්මාණ',
#   'කරන්නේ',
#   'නැ'],
#  ['මේ',
#   'ව\u200d\u200dගේ',
#   'කාලකණ්නි',
#   'ගංජා',
#   'කාරයෝ',
#   'තැනක',
#   'හැසිරෙන්න',
#   'දන්නවද',
#   'මුන්',
#   'කලාකරයොද',
#   'මේ',
#   'වගේ',
#   'කාලකණ්නි',
#   'බල්ලොන්ට',
#   'සම්මාන',
#   'දෙන',
#   'එක',
#   'තිරණය',
#   'කරපු',
#   'ගොන්',
#   'තීරකයෝ',
#   'කවුද'],
#  ['මේ',
#   'දේ',
#   'ඇත්තටම',
#   'මේ',
#   'ගොබ්බයෝ',
#   'කරේ',
#   'රටේ',
#   'පේමස්',
#   'වෙන්න',
#   'මොකද',
#   'මුන්',
#   'දෙන්නම',
#   'හිගන',
#   'කාලාකරැවෝ',
#   'දෙන්නෙක්',
#   'බොර',
#   'දියේ',
#   'මළු',
#   'බානවා',
#   'කියන්නේ',
#   'ඕකට',
#   'රටේ',
#   'බුද්ධිමත්',
#   'ජනතාව',
#   'තොපි',
#   'දෙන්නා',
#   'විනයක්',
#   'නැති',
#   'ගොන්',
#   'ඩබලක්',
#   'කියලා',
#   'තේරැම්',
#   'ගත්තා'],
#  ['ජෙප්පෙක්',
#   'කියන්නෙ',
#   'මොනවගේ',
#   'ගොන්',
#   'ආතල්',
#   'දෙන',
#   'එකෙක්ද',
#   'කියල',
#   'ඈහුවොත්',
#   'කනට',
#   'එකක්',
#   'දීල',
#   'මේක',
#   'පෙන්වපන්'],
#  ['බයිසන්ලාට',
#   'අනුව',
#   'මොවුන්',
#   'ගන්ජා',
#   'කාරයන්',
#   'වේ',
#   'ටොයිසන්ලාට',
#   'අනුව',
#   'මොවුන්',
#   'කොන්ද',
#   'පන',
#   'ඇති',
#   'කොල්ලන්',
#   'වේ',
#   'කමෙන්ට්',
#   'බලනකොට',
#   'තෙරුනේ',
#   'ඈ'],
#  ['දේශපාලකයො',
#   'හදපු',
#   'නෙළුමි',
#   'පොකුනට',
#   'ආවෙ',
#   'ඇයි',
#   'ගෙදරට',
#   'ගෙන්නව',
#   'ගත්තනමි',
#   'ඉවරනේ',
#   'ගෝතයො',
#   'දෙදෙනෙකුගෙ',
#   'පටිට',
#   'ගොන්',
#   'රංගනයක්'],
#  ['උබ',
#   'හිතුවද',
#   'උන්',
#   'රටවල්',
#   'වලට',
#   'යනකොට',
#   'උන්ගේ',
#   'බෝල',
#   'පිති',
#   'අරගෙන',
#   'යනවා',
#   'වගේ',
#   'අරක්කු',
#   'බියරුත්',
#   'උන්ගේ',
#   'රටෙන්',
#   'අරගෙන',
#   'එනවා',
#   'කියලා',
#   'අනේ',
#   'නිකම්',
#   'හිටහන්',
#   'අඩ්මින්'],
#  ['දැන්',
#   'ඉන්න',
#   'ගොඩක්',
#   'උන්',
#   'නම්',
#   'අමු',
#   'කාලකන්නි',
#   'අම්ම',
#   'තාත්ත',
#   'දුක්',
#   'මහන්සියෙන්',
#   'හොයල',
#   'දෙන',
#   'පංති',
#   'සල්ලි',
#   'වලින්',
#   'බොනව',
#   'ගංජ',
#   'ගහනව',
#   'පාරෙ',
#   'යන',
#   'මිනිස්සු',
#   'මරාගෙන',
#   'බයික්',
#   'වල',
#   'පියාබනව',
#   'කරන්න',
#   'පුලුවන්',
#   'බලු',
#   'සක්කිලි',
#   'වැඩ',
#   'ඔක්කෝම',
#   'කරනව',
#   'මේව',
#   'නවත්වන්න',
#   'රටේ',
#   'පාලකයන්ට',
#   'ඕනෙ',
#   'නෑ',
#   'මොකද',
#   'උගත්',
#   'බුද්ඨිමත්',
#   'උන්',
#   'ඉන්න',
#   'රටක',
#   'උන්ට',
#   'රගන්න',
#   'බැහැනෙ',
#   'රටක්',
#   'විනාස',
#   'වෙනව',
#   'කියන්නෙ',
#   'ඕකට'],
#  ['උන්',
#   'ඉස්කෝලෙ',
#   'ගමන',
#   'නවත්තල',
#   'හිගන්නො',
#   'වගෙ',
#   'බහිනව',
#   'පාරට',
#   'දැන්',
#   'කරන්න',
#   'රස්සාවක්',
#   'නෑ',
#   'වීල්',
#   'හයර්',
#   'කරනව',
#   'හොදම',
#   'වැඩේ',
#   'බල්ලො',
#   'මරල',
#   'හරි',
#   'සල්ලි',
#   'හොයන්න',
#   'තමා',
#   'බලුකම්',
#   'කරල',
#   'අන්තිමට',
#   'පොලිස්සියෙන්',
#   'බල්ලො',
#   'වගේ',
#   'වෙඩි',
#   'කාල',
#   'පාරෙම',
#   'මැරෙනව',
#   'ඔන්න',
#   'ජීවිතේ',
#   'ඔන්න',
#   'සිංහල',
#   'රටේ',
#   'ජව',
#   'සම්පන්න',
#   'තාරුණ්\u200dය'],
#  ['අර',
#   'ප්\u200dරභාකරන්',
#   'කියන',
#   'එකා',
#   'ඉන්නකන්',
#   'අහිංසක',
#   'මිනිස්සු',
#   'බොම්බ',
#   'ගහලා',
#   'මැරුවා',
#   'එක',
#   'බොම්බයක්',
#   'මේක',
#   'ඇතුලට',
#   'ගහගන්න',
#   'බැරි',
#   'උනානෙ',
#   'ඕකට',
#   'මුන්',
#   'ටික',
#   'මැරුලා',
#   'යන්න'],
#  ['කරන',
#   'දේවල්',
#   'මුන්ට',
#   'හෙනම',
#   'වදින්න',
#   'ඕනී',
#   'ජනතාවගේ',
#   'සල්ලිවලට',
#   'කරන',
#   'දේවල්',
#   'වලට'],
#  ['රාජපක්ෂ',
#   'කඳවුර',
#   'අද',
#   'පෙන්වූ',
#   'අශීලාචාර',
#   'මෘග',
#   'හැසිරීම',
#   'අනුමත',
#   'කල',
#   'හැක්කේ',
#   'එවැනිම',
#   'අශීලාචාර',
#   'මෘගයන්ට',
#   'පමණි'],
#  ['නුගත්',
#   'හැතිකරෙ',
#   'මරන්න',
#   'පුලුවන්',
#   'නම්',
#   'මරනවා',
#   'මුන්ව',
#   'ගෙන්',
#   'හැතිකරෙ'],
#  ['තෝපිලගේ',
#   'ඇට',
#   'ටික',
#   'වික්කත්',
#   'හරි',
#   'මිලියන',
#   '20',
#   'ගන්න',
#   'බෑ',
#   'පාර්ලිමේන්තුවේ',
#   'දවස',
#   'වියදමට'],
#  ['පොන්න', 'රිලා', 'සක්කිලි', 'හැත්ත', 'වදුරො', 'කුස්සියට', 'පැනලා', 'වගේ'],
#  ['මෙ',
#   'හොරිකඩ',
#   'පොන්නයන්ට',
#   'පොදු',
#   'දෙපල',
#   'විනාශය',
#   'යටතේ',
#   'නඩු',
#   'නැද්ද',
#   'කො',
#   'මෙ',
#   'පොලිස්ස්ස්ස්ස්ස්ස්'],
#  ['තු',
#   'නොදකින්',
#   'කාලකන්නි',
#   'රටේ',
#   'දෙපළ',
#   'තොපෙ',
#   'අම්මා',
#   'තාත්තාගේ',
#   'නෙවෙයි',
#   'පර',
#   'හැත්ත'],
#  ...]

# %%
singlish_tokens_set
# Out:
# [['menna',
#   'ratawal',
#   'menna',
#   'minissu',
#   'ape',
#   'ratawal',
#   'wala',
#   'inna',
#   'jathin',
#   'thunema',
#   'gothrikayo',
#   'tika',
#   'manussayo',
#   'karala',
#   'inna',
#   'wenawa'],
#  ['paduway',
#   'hitahan',
#   'beri',
#   'weda',
#   'nokaran',
#   'bat',
#   'eka',
#   'gaththada',
#   'bole',
#   'elluwada',
#   'oka',
#   'karagena',
#   'inna',
#   'oyala',
#   'desapalanayata',
#   'atha',
#   'daruwan',
#   'therum',
#   'ganna',
#   'nikan',
#   'thiyena',
#   'prrsiddath',
#   'nethi',
#   'karanna',
#   'epa'],
#  ['muth',
#   'kata',
#   'arinne',
#   'anik',
#   'unta',
#   'witharai',
#   'jathiyata',
#   'agamata',
#   'sadda',
#   'na',
#   'endiyawata',
#   'koti',
#   'ganan',
#   'denawa',
#   'ahinsakayant',
#   'ape',
#   'rate',
#   'unta',
#   'mukuth',
#   'na'],
#  ['songs',
#   'kanna',
#   'epa',
#   'buruwo',
#   'kochchara',
#   'lassana',
#   'sindu',
#   'kanna',
#   'epa',
#   'ubalata',
#   'song',
#   'karanna',
#   'barinam',
#   'nikan',
#   'edapan',
#   'thiyana',
#   'ewa',
#   'kanna',
#   'epa'],
#  ['muth',
#   'nanna',
#   'yanne',
#   'kridakayanta',
#   'ground',
#   'walata',
#   'wena',
#   'asadaranakam',
#   'walata',
#   'wachanayak',
#   'eliyata',
#   'danne',
#   'nathi',
#   'aka',
#   'rata',
#   'hadanna',
#   'yanawa',
#   'mahela',
#   'karanam',
#   'api',
#   'akenma',
#   'set'],
#  ['ai',
#   'mahinda',
#   'gen',
#   'polonnaruve',
#   'valikande',
#   'hmbawnaakkara',
#   '1800',
#   'maddida',
#   'sanga',
#   'den',
#   'unp',
#   'yen',
#   'akkara',
#   'kiyak',
#   'onida',
#   'apita',
#   'ogama',
#   'danna',
#   'kaururh',
#   'nane',
#   'dun',
#   'noth',
#   'apith',
#   'dannava',
#   'karan',
#   'naoni',
#   'vada'],
#  ['ජයසූරිය',
#   'mathakada',
#   'ow',
#   'ow',
#   'sanath',
#   'ජයසූරිය',
#   'thama',
#   'eyatath',
#   'wada',
#   'kujitha',
#   'wela',
#   'yannai',
#   'sangata',
#   'wenne'],
#  ['dana', 'reddak', 'sinhalen', 'danna', 'kiyanna', 'meka', 'lankawa'],
#  ['කියන්න',
#   'වැඩ',
#   'හොදනම්',
#   'හදවතින්ම',
#   'සපෝර්ට්',
#   'හැබැයි',
#   'පොහොට්ටුව',
#   'samaga',
#   'නොවී',
#   'u',
#   'n',
#   'p',
#   'nam',
#   'නම්',
#   'හුරේ'],
#  ['president',
#   'wenna',
#   'puluwan',
#   'bauddayekuta',
#   'witharai',
#   'me',
#   'yaka',
#   'croatian'],
#  ['ඔය',
#   'කාරනය',
#   'හරියට',
#   'විග්\u200dරහ',
#   'කරන්න',
#   'ඩුප්ලිකේට්',
#   'මහමෙව්නාවේ',
#   'ඩුප්ලිකේට්',
#   'කල්\u200dයාණ',
#   'මිතුරන්ට',
#   'පුලුවන්',
#   'නම්',
#   'දිව්\u200dය',
#   'ලෝක',
#   'promote',
#   'කරයි\u200d',
#   'ද'],
#  ['aka',
#   'satha',
#   '5k',
#   'wadi',
#   'karanna',
#   'epa',
#   'okunta',
#   'wada',
#   'karanna',
#   'bai',
#   'nam',
#   'job',
#   'eken',
#   'elawanna',
#   'eliye',
#   'job',
#   'nathi',
#   'ewun',
#   'oni',
#   'tharam',
#   'ennawa'],
#  ['kisi', 'quality', 'ekak', 'nathi', 'apatayek'],
#  ['munta', 'chande', 'dena', 'buruwo', 'innawane', 'thawath', 'me', 'rate'],
#  ['thota',
#   'henagapiya',
#   'kadaya',
#   'thilangayawa',
#   'hurathal',
#   'karapan',
#   'esige',
#   'putha'],
#  ['cricket',
#   'kridawa',
#   'kawe',
#   'oi',
#   'thirisana',
#   'oi',
#   'putuwa',
#   'deehan',
#   'sangata',
#   'un',
#   'dawiwaru',
#   'yakooo'],
#  ['kwda',
#   'me',
#   'lat',
#   'roy',
#   'kiyana',
#   'ekaa',
#   'lat',
#   'hoodana',
#   'ekek',
#   'da'],
#  ['ekata', 'ape', 'eka', 'thuuu'],
#  ['dakuna', 'menessuu', 'harema', 'arthmarthakameeeeeeeeeeee'],
#  ['sinhalayo', 'kuhakayo'],
#  ['අපොයි',
#   '2020',
#   'ජනාධිපති',
#   'නෙද',
#   'හුත්තෝ',
#   'උබ',
#   'උබ',
#   'හොදයි',
#   'නගරසභාවේ',
#   'toilet',
#   'සුද්ද',
#   'කරන්න',
#   'හිකුණ්ඨික',
#   'සක්කිලියා'],
#  ['lankawe',
#   'wage',
#   'political',
#   'majarayo',
#   'innakam',
#   'police',
#   'quality',
#   'eka',
#   'wadi',
#   'karanna',
#   'baha'],
#  ['lanka',
#   'we',
#   'inne',
#   'labba',
#   'bahapu',
#   'naki',
#   'police',
#   'karayo',
#   'ne',
#   'bulath',
#   'wite',
#   'kagena',
#   'ahisaka',
#   'bike',
#   'ekak',
#   'nawath',
#   'wala',
#   'ugen',
#   'rs',
#   '500',
#   'aragena',
#   'lami',
#   'ta',
#   'ganun',
#   'ta',
#   'kanna',
#   'dena'],
#  ['kasippu',
#   'karayagen',
#   'ganja',
#   'karayagen',
#   'keeyak',
#   'hari',
#   'aragena',
#   'unge',
#   'bothalayata',
#   'yata',
#   'una',
#   'kisima',
#   'puhunuwak',
#   'nathi',
#   'gon',
#   'harak',
#   'tikak',
#   'ne',
#   'police',
#   'office',
#   'ekak',
#   'paththata',
#   'nikamata',
#   'gihilla',
#   'blapalla',
#   'ali',
#   'wrdi',
#   'walatath',
#   'duwana',
#   'un',
#   'inne',
#   'gam',
#   'walin',
#   'apu',
#   'rilau'],
#  ['ape', 'polisiya', 'atule', 'tmai', 'wadiyenma', 'horu', 'inne'],
#  ['arawa', 'kanno', 'echchari', 'danne', 'policeya', 'gena'],
#  ['තුවක්කු',
#   'පුහුනුව',
#   'දෙන්නෙ',
#   'training',
#   'එකේ',
#   'විතරයි',
#   'ඉලක්කයක්',
#   'අරන්',
#   'වෙඩි',
#   'තියන්න',
#   'කී',
#   'දෙනාද',
#   'දක්ෂ',
#   'නාකි',
#   'පප්පල',
#   'ටික',
#   'ගහල',
#   'පන්නන්න',
#   'ඕන',
#   'ජරාව',
#   'කකා',
#   'ඉන්නන්',
#   'වාලේ',
#   'ඉන්නවට',
#   'අනිත්',
#   'එක',
#   'සාමාන්\u200dය',
#   'මිනිස්සු',
#   'ඉන්න',
#   'තත්වයකදි',
#   'මේ',
#   'විදියට',
#   'වෙඩි',
#   'තැබීම',
#   'අනුමත',
#   'කරන්න',
#   'බැ'],
#  ['පාතාල',
#   'කාරයන්ට',
#   'මනුස්සකමක්',
#   'නැනේ',
#   'මුන්',
#   'බයික්',
#   'වලට',
#   'නගිනකන්',
#   'ඉවසන්න',
#   'තිබුනේ',
#   'නැත්තන්',
#   'තත්වය',
#   'බලල',
#   'stf',
#   'ගෙනන්න',
#   'තිබුනේ',
#   'කොහේද',
#   'ලොක්කො',
#   'දෙන',
#   'අණ',
#   'නේ',
#   'අපරාදෙ',
#   'වටින',
#   'ජීවිතයක්'],
#  ['මන්නම්',
#   'කියන්නෙ',
#   'පොලිසියෙ',
#   'උන්නැහැලා',
#   'ටිකටත්',
#   'stf',
#   'පුහුණුවක්',
#   'අවශයයි',
#   'මොකද',
#   'හොරාට',
#   'පන්න',
#   'ගන්න',
#   'බැ',
#   'මොලෙ',
#   'පාවිච්චි',
#   'කරලා',
#   'හොරා',
#   'කොටු',
#   'කරගන්නෙ',
#   'නැ',
#   'ගොන්',
#   'වැඩ',
#   'ගොඩක්',
#   'තියෙනව'],
#  ['ratakata',
#   'giya',
#   'kalak',
#   'vahane',
#   'dora',
#   'arinna',
#   'ekek',
#   'help',
#   'kare',
#   'ne',
#   'ara',
#   'manussayata',
#   'me',
#   'aparade',
#   'karapu',
#   'un',
#   'tama',
#   'nidalle',
#   'rate',
#   'maha',
#   'un',
#   'ponnayo',
#   'ekai',
#   'me',
#   'serama',
#   'dewal',
#   'okunat',
#   'chance',
#   'denna',
#   'epa',
#   'tatwat'],
#  ['pathali',
#   'para',
#   'haththa',
#   'akekwath',
#   'ethuru',
#   'karanna',
#   'epa',
#   'okunge',
#   'daruwanta',
#   'edala',
#   'hena',
#   'gahanawa',
#   'para',
#   'ballo'],
#  ['ashi',
#   'hashi',
#   'ඔවාට',
#   'දකුණේ',
#   'එකෙක්',
#   'ඒක',
#   'කෙලින්',
#   'කියන්න',
#   'වෙන',
#   'වෙන',
#   'සීන්',
#   'ගැන',
#   'කියල',
#   'මඩ',
#   'ගහන්නෙ',
#   'නැතුව'],
#  ['ahama',
#   'kiyana',
#   'apa',
#   'natara',
#   'kiyann',
#   'apa',
#   'gama',
#   'policya',
#   'wada',
#   'waradagan',
#   'tiyana',
#   'nisai',
#   'minusu',
#   'ahka',
#   'baluwa',
#   'nikaruna',
#   'kollo',
#   'maranawa',
#   'horu',
#   'maragann',
#   'ba',
#   'bayta',
#   'akada',
#   'yahpalan',
#   'ahinsa',
#   'amm',
#   'adanwa',
#   'ada',
#   'puta',
#   'batuwa',
#   'oya',
#   'sakilli',
#   'bollonga',
#   'oluwata',
#   'waditiyala',
#   'danna',
#   'ona'],
#  ['me', 'horu', 'training', 'une', 'koheda'],
#  ['thattayaa',
#   'mokek',
#   'daa',
#   'uuu',
#   'karikii',
#   'karikii',
#   'innee',
#   'pissek',
#   'wagee',
#   'udauu',
#   'karannee',
#   'nathywaa',
#   'mona',
#   'pissek',
#   'daa',
#   'mandaa'],
#  ['maraladanna',
#   'thiyenne',
#   'okunwa',
#   'mathara',
#   'un',
#   'dakune',
#   'kiyala',
#   'kehegahuwata',
#   'bayagullo',
#   'inne'],
#  ['oya',
#   'jatika',
#   'arakahawa',
#   'sambanda',
#   'inna',
#   'uda',
#   'pena',
#   'pena',
#   'kata',
#   'meta',
#   'dodawana',
#   'amatio',
#   'dipan',
#   'polisiata',
#   'hoda',
#   'wepan',
#   'mesinngan',
#   'arun',
#   'ottu',
#   'sellam',
#   'karanawa',
#   'maha',
#   'pare',
#   'hat',
#   'denek',
#   'duwanawa',
#   'lejjai',
#   'dipan',
#   'oya',
#   'pattama',
#   'patalema',
#   'tawa',
#   'ekekuta',
#   'palayan',
#   'paw',
#   'nodi',
#   'gedara'],
#  ['lankawe',
#   'inna',
#   'samahara',
#   'pirimi',
#   'napunsakayo',
#   'ara',
#   'manussayata',
#   'wahane',
#   'dora',
#   'arala',
#   'dennawat',
#   'kenek',
#   'enne',
#   'ne',
#   'mun',
#   'pirimida',
#   'ane',
#   'e',
#   'manussaya',
#   'veerayek',
#   'attatama'],
#  ['meyata',
#   'aydayak',
#   'tibbanam',
#   'aniwa',
#   'dennekwath',
#   'bawanawa',
#   'aprade'],
#  ['hospital',
#   'inna',
#   'ewun',
#   'tikath',
#   'wada',
#   'deela',
#   'maranda',
#   'thiyenne'],
#  ['shit', 'ara', 'ekek', 'dakalat', 'dakke', 'na', 'wage', 'yanawa'],
#  ['waha', 'palane', 'raga', 'tamai', 'oya'],
#  ['ලංකාවේ',
#   'hema',
#   'tanama',
#   'oya',
#   'wage',
#   'tamai',
#   'r',
#   'd',
#   'a',
#   'නිලධාරීන්',
#   'owa',
#   'දකින්නේ',
#   'nati',
#   'එක',
#   'හරිම',
#   'කනගාටුදායක',
#   'අපෙන්',
#   'බඳු',
#   'ගහන',
#   'සල්ලිවලින්',
#   'කරන',
#   'අපරාධ',
#   'henaghanawa',
#   'munta',
#   'tu'],
#  ['ape',
#   'peththeth',
#   'oya',
#   'wede',
#   'mai',
#   'කරන්නේ',
#   'මහින්ද',
#   'මහත්තයා',
#   'නැතිකම',
#   'දැනෙනවා',
#   'hitiyanam',
#   'අපිත්',
#   'ගොඩ'],
#  ['mewata',
#   'loku',
#   'baladarin',
#   'waga',
#   'kiyanna',
#   'ona',
#   'mun',
#   'okkoma',
#   'ekai',
#   'mahajana',
#   'mudal',
#   'nasthi',
#   'karana',
#   'kalakanni',
#   'balu',
#   'heththa'],
#  ['akke', 'aewa', 'loku', 'unge', 'weradi'],
#  ['mun', 'wage', 'kalakanni', 'innakan', 'ratawal', 'diunukarana', 'be'],
#  ['ඒත්',
#   'උඹ',
#   'අර',
#   'හොටු',
#   'පෙරං',
#   'අඬන',
#   'හෙලු',
#   'කෙල්ලොංගෙ',
#   'videosui',
#   'අනික්',
#   'ලබ්බවල්',
#   'වලට',
#   'වඩා',
#   'මේ',
#   'කරපු',
#   'වැඩේනම්',
#   'great',
#   'බං'],
#  ['api',
#   'thathala',
#   'nathuwa',
#   'duk',
#   'wenwa',
#   'me',
#   'kalaknni',
#   'thaththala',
#   'idala',
#   'salakanne'],
#  ['thopi', 'wage', 'lamainta', 'me', 'athmedi', 'hena', 'wadina', 'ona'],
#  ['ngo',
#   'වලින්ද',
#   'එතකොට',
#   'ලංකාවෙ',
#   'නිතිය',
#   'ක්රියාත්මක',
#   'කරන්නෙ',
#   'නොදකිං',
#   'කලකිරෙනවා',
#   'මෙවා',
#   'දැක්කම',
#   'මොනද',
#   'මෙ',
#   'අපෙ',
#   'රටට',
#   'වෙන්නෙ'],
#  ['henama',
#   'gahapiya',
#   'okita',
#   'ngo',
#   'karayanta',
#   'puka',
#   'dipan',
#   'thawath',
#   'wesi',
#   'tho',
#   'marunu',
#   'data',
#   'pansukule',
#   'denneth',
#   'අපේ',
#   'හාමුදුරුවෝ',
#   'mthaka',
#   'thiya',
#   'ganin',
#   'thota',
#   'sapa',
#   'wenawa',
#   'shinhalaya',
#   'gana',
#   'ktha',
#   'krapu',
#   'අපේ',
#   'හාමුදුරුවන්ට',
#   'මෙහෙම',
#   'කරාට'],
#  ['mewata',
#   'katha',
#   'karanna',
#   'wachana',
#   'ne',
#   'hithe',
#   'wairaya',
#   'athi',
#   'karanawata',
#   'wada',
#   'wadath',
#   'hidama',
#   'de',
#   'munta',
#   'swabadahama',
#   'thulin',
#   'lebena',
#   'දඬුවම',
#   'diha',
#   'nihathamaniwa',
#   'balasitimai',
#   'sandya',
#   'kiyana',
#   'wesa',
#   'genita',
#   'hidata',
#   'ninda',
#   'yanawa',
#   'athi',
#   'den'],
#  ['gon',
#   'genita',
#   'saapa',
#   'වේවා',
#   'me',
#   'athmedima',
#   'palisan',
#   'දේවා',
#   'හාමුදුරුවෝ',
#   'namak',
#   'hireta',
#   'yeuwata'],
#  ['hamudurowo',
#   'kiwe',
#   'aththak',
#   'ube',
#   'miniha',
#   'kotiyek',
#   'ltte',
#   'eken',
#   'salli',
#   'gaththa',
#   'oththu',
#   'karayek',
#   'apith',
#   '2020',
#   'passe',
#   'me',
#   'kalakanni',
#   'anduwa',
#   'gedara',
#   'yawala',
#   'sahimakata',
#   'path',
#   'wenawa'],
#  ['oyage',
#   'thawakalika',
#   'sathuta',
#   'uparima',
#   'winda',
#   'ganna',
#   'okata',
#   'windawanna',
#   'weddi',
#   'daraganna',
#   'bari',
#   'wei'],
#  ['cari',
#   'wesi',
#   'me',
#   'cari',
#   'wesige',
#   'puke',
#   'arinna',
#   'one',
#   'miriskudu',
#   'daala',
#   'balu',
#   'wesita',
#   'katu',
#   'kohila',
#   'alayak',
#   'bessuwanam',
#   'kakul',
#   '2ka',
#   'depeththata',
#   'karala',
#   'huththa',
#   'athulata',
#   'me',
#   'huththita',
#   'mita',
#   'wada',
#   'sathutak',
#   'lebei'],
#  ['tho',
#   'ganu',
#   'jatiyatama',
#   'nindawak',
#   'lake',
#   'wadi',
#   'dawasak',
#   'yamaha',
#   'thota',
#   'sapa',
#   'wenawamai'],
#  ['meki',
#   'lankawe',
#   'janadi',
#   'pathinitakda',
#   'budu',
#   'dahama',
#   'winasa',
#   'karana',
#   'hethiriyak',
#   'ne'],
#  ['podi',
#   'daruwo',
#   'dusanaya',
#   'karala',
#   'maranawa',
#   'ewata',
#   'mokuth',
#   'na',
#   'ane',
#   'pau',
#   'apahasa',
#   'neme',
#   'karanna',
#   'thibbe',
#   'kumarihamita',
#   'bella',
#   'mirikala',
#   'maranna'],
#  ['tigae',
#   'miha',
#   'marapuuna',
#   'hiyanna',
#   'amruwak',
#   'na',
#   'katin',
#   'kiyapu',
#   'wacanata',
#   'uda',
#   'painawa',
#   'ubda',
#   'kada',
#   'hari',
#   'dittadamna',
#   'wadaniya',
#   'karumae',
#   'padisan',
#   'danawamai',
#   'budu',
#   'ciwarayanata',
#   'nigaru',
#   'kirimata'],
#  ['oita',
#   'wada',
#   'hinsa',
#   'appa',
#   'rata',
#   'wanawa',
#   'podi',
#   'daruwo',
#   'antha',
#   'karanawa',
#   'apra',
#   'karayo',
#   'koha',
#   'baluwah',
#   'ma',
#   'gani',
#   'matharamma',
#   'sundara',
#   'wasthuwakda',
#   'balla',
#   'giya',
#   'ratak',
#   'apa',
#   'buddha',
#   'cjiwaraya',
#   'gana',
#   'harima',
#   'dukai'],
#  ['to',
#   'wage',
#   'balu',
#   'wesiyek',
#   'wadapu',
#   'toge',
#   'ammage',
#   'to',
#   'wadapu',
#   'tenatath',
#   'henagahannaona'],
#  ['kanthawakata',
#   'hirihara',
#   'kireema',
#   'waradei',
#   'habai',
#   'me',
#   'wage',
#   'kotiyekuge',
#   'geniyekuta',
#   'banna',
#   'newei',
#   'maruwath',
#   'pau',
#   'na'],
#  ['ape',
#   'ratata',
#   'mokadda',
#   'me',
#   'wenne',
#   'mun',
#   'alawanna',
#   'hadamu',
#   'mahindata',
#   'rata',
#   'barademu',
#   'okkoma',
#   'akathuwemu',
#   'me',
#   'sinhalayage',
#   'rata'],
#  ['thambiyelta', 'kiyala', 'hukaganna', 'kiyahan', 'keri', 'wesita'],
#  ['okege', 'sathuta', 'as', 'panapitama', 'padesan', 'denna', 'one'],
#  ['patta',
#   'wesi',
#   'tota',
#   'henama',
#   'gahapan',
#   'totai',
#   'toge',
#   'anduwatai',
#   'lagadima',
#   'redi',
#   'netuwa',
#   'pare',
#   'duwanna',
#   'wei',
#   'edata',
#   'toge',
#   'hinsanayata',
#   'api',
#   'gal',
#   'gahanawa'],
#  ['tho', 'sathutu', 'unaawagema', 'duk', 'wendath', 'wenawa'],
#  ['hotai',
#   'thindu',
#   'karapu',
#   'ekatai',
#   'me',
#   'rajayatai',
#   'henama',
#   'gahapiya'],
#  ['kotinge',
#   'ata',
#   'deka',
#   'suppu',
#   'karapan',
#   'gihin',
#   'cari',
#   'wesi',
#   'me',
#   'wesitanm',
#   'hodak',
#   'sidda',
#   'wenne',
#   'nehe',
#   'hena',
#   'gahapan'],
#  ['huththa', 'lokuda', 'danne', 'neeee'],
#  ['usawiyeth', 'desapalana', 'theendu'],
#  ['balu', 'huttita', 'hana', 'hatama', 'gahapiya'],
#  ['hitan',
#   'magenguti',
#   'kanna',
#   'nethiwa',
#   'oya',
#   'unansewa',
#   'nidahas',
#   'karapan',
#   'hodaekaawage'],
#  ['karumeta', 'gahala', 'akalata', 'haduna', 'wesiyo'],
#  ['ltte',
#   'එකට',
#   'කඩේ',
#   'යන',
#   'ngo',
#   'සල්ලි',
#   'වලට',
#   'රට',
#   'පාවා',
#   'දෙන',
#   'හැත්ත'],
#  ['hora', 'ganayonta', 'kade', 'yana', 'gonnu', 'inna', 'ratak', 'meka'],
#  ['me', 'genige', 'geta', 'gal', 'gahanna', 'lasthiweyalla'],
#  ['puka',
#   'diyan',
#   'noel',
#   'mona',
#   'paiye',
#   'sinduda',
#   'hutto',
#   'me',
#   'සමාජෙට',
#   'හොද',
#   'දෙයක්',
#   'කරපන්'],
#  ['mun', 'rata', 'winasa', 'karalla', 'ewarayi'],
#  ['ponna', 'wasi'],
#  ['aknali', 'goda', 'maruna', 'aka', 'gana', 'api', 'sathutu', 'wenawa'],
#  ['wesa',
#   'genita',
#   'hena',
#   'gahapiya',
#   'rate',
#   'nayakaya',
#   'ponnayek',
#   'unama',
#   'ohoma',
#   'tamai'],
#  ['ako',
#   'ratama',
#   'ltte',
#   'eke',
#   'salli',
#   'walata',
#   'wikka',
#   'munta',
#   'ira',
#   'hada',
#   'payanawaneeee'],
#  ['nadukarayage',
#   'mulu',
#   'engema',
#   'gedidapn',
#   'okage',
#   'paaulama',
#   'hedigeviyan'],
#  ['koti', 'gani', 'shapa', 'wewa', 'ubata'],
#  ['එහෙමද', 'ආස', 'කැරී', 'wecii'],
#  ['makabawilama', 'pala', 'paduru', 'wesi'],
#  ['meeka', 'pada', 'show', 'ekak'],
#  ['thota', 'hena', 'gahapan', 'thoge', 'balu', 'patawuntath', 'balu', 'weesi'],
#  ['henama', 'gahapiya', 'wesa', 'ballita'],
#  ['tope', 'anduwa', 'tiyana', 'an', 'hodai'],
#  ['mekita', 'dan', 'miniha', 'nathuwa', 'aduwak', 'wena', 'ekak', 'ne'],
#  ['sathutu', 'nam', 'puka', 'deepan', 'wesa', 'baduwa'],
#  ['me', 'genige', 'jathae', 'kalwam', 'ekak'],
#  ['yadamin',
#   'benda',
#   'vilangu',
#   'la',
#   'mage',
#   'putha',
#   'regena',
#   'yanna',
#   'idikatu',
#   'weni',
#   'engili',
#   'thala',
#   'dethis',
#   'wadaya',
#   'pamunuwanna',
#   'aluth',
#   'lowak',
#   'gena',
#   'sithima',
#   'danduwam',
#   'dena',
#   'warada',
#   'nam',
#   'kumata',
#   'erata',
#   'adhikaranaya',
#   'neethiya',
#   'saha',
#   'vinisuran'],
#  ['bona',
#   'unta',
#   'bus',
#   'eke',
#   'megala',
#   'gihin',
#   'bol',
#   'gahanna',
#   'thamai',
#   'tiyenne'],
#  ['ponnayo',
#   'danne',
#   'kellek',
#   'aduwa',
#   'gaman',
#   'laga',
#   'inna',
#   'kollekta',
#   'allan',
#   'gahanna',
#   'witharai'],
#  ['ape', 'harak', 'samjeta', 'eka', 'honda', 'adrshyak'],
#  ['tpita', 'pisuda', 'yako', 'man', 'htuwe', 'atta', 'kiyala', 'aiyo'],
#  ['kimbak', 'eduwoth', 'ape', 'untath', 'amma', 'thaththawath', 'penne', 'n'],
#  ['lisan',
#   'nathawa',
#   'yanna',
#   'puluwan',
#   'yako',
#   'api',
#   'dannawa',
#   'oka',
#   'veede',
#   'nattiyak',
#   'kiyala'],
#  ['samanya',
#   'minasata',
#   'danena',
#   'de',
#   'me',
#   'kalakanni',
#   'desapalakayanta',
#   'penne',
#   'nathi',
#   'eka',
#   'thama',
#   'karume'],
#  ['shampoo',
#   'එකක්',
#   'promote',
#   'කරන්න',
#   'දාපු',
#   'ලස්සන',
#   'මුට්ටියක්',
#   'කියලයි',
#   'මටනම්',
#   'හිතෙන්නෙ',
#   'බලපං',
#   'නැද්ද',
#   'කියලා',
#   'තා',
#   'ටික',
#   'දවසකින්'],
#  ['dakune', 'shampoo', 'nadda'],
#  ['muladi',
#   'hinawey',
#   'digatama',
#   'karoth',
#   'devole',
#   'karala',
#   'hoda',
#   'idea',
#   'ekak'],
#  ['hadannanam',
#   'puluvan',
#   'eth',
#   'oka',
#   'reddak',
#   'adan',
#   'dagena',
#   'yanne',
#   'kohomai',
#   'ape',
#   'handuruvane'],
#  ['police', 'yen', 'navatthana', 'ekkak', 'na'],
#  ['mathakane',
#   'kalayak',
#   'ape',
#   'un',
#   'fite',
#   'fan',
#   'ellan',
#   'gihin',
#   'rexona',
#   'market',
#   'kala'],
#  ['pahadili', 'madi', 'visthara', 'karapu', 'hati'],
#  ['me', 'mokkakda', 'bn', 'eka', 'dapuwahama', 'mahasona', 'wagene'],
#  ['ela', 'ela', 'thawa', 'thawath', 'mede', 'wadidinu', 'karanna'],
#  ['game', 'gahapan', 'aiya', 'api', 'gannaw'],
#  ['lankawen',
#   'desapalakayo',
#   'tikak',
#   'yawala',
#   'balamu',
#   'poster',
#   'gahana',
#   'widihata',
#   'thama',
#   'ita',
#   'passe'],
#  ['comments',
#   'බලන්න',
#   'ආපු',
#   'අය',
#   'මෙතනින්',
#   'පොඩි',
#   'like',
#   'එකක්',
#   'ඕනේ',
#   'bro'],
#  ['paadam',
#   'karanawa',
#   'kese',
#   'wethath',
#   'putuwak',
#   'nan',
#   'aniwa',
#   'allagannawa',
#   'mama',
#   'puluwannan',
#   'putu',
#   'tikak',
#   'allala',
#   'business',
#   'line',
#   'ekakuth',
#   'gahagannawa',
#   'shape',
#   'eke'],
#  ['e', 'karpu', 'kathwa', 'nm', 'wedagth', 'm', 'kiuwath', 'oyala'],
#  ['oshadhi', 'adui', 'hama', 'gahapu', 'issek', 'wage'],
#  ['oka', 'light', 'bala', 'bala', 'cheeneta', 'naya', 'gewamu'],
#  ['කෑමකඩත්',
#   'තියෙනවද',
#   'tomorrowland',
#   'වගේද',
#   'festival',
#   'එක',
#   'තව',
#   'hardwell',
#   'mashmellow',
#   'එනවද',
#   'edm',
#   'කරන්න'],
#  ['ඒකටනම්',
#   'දුම්\u200dරිය',
#   'දෙපාර්තුමේන්තුවත්',
#   'වගකියන්න',
#   'ඕන',
#   'කෝච්චිය',
#   'රෑ',
#   'අවසාන',
#   'ට්\u200dරිප්',
#   'එක',
#   'ගිහින්',
#   'ආවහම',
#   'කිසිම',
#   'නඩත්තුවක්',
#   'නැතුව',
#   'ආපහු',
#   'පහුවදා',
#   'උදේට',
#   'එන්ජිම',
#   'අනිත්',
#   'පැත්තට',
#   'අමුනල',
#   'ඇදගෙන',
#   'එනව',
#   'වගේ',
#   'මටනම්',
#   'පේන්නෙ',
#   'ඒකට',
#   'වරදක්',
#   'කියන්නත්',
#   'බෑ',
#   'බං',
#   'හරියට',
#   'maintenance',
#   'කරන්න',
#   'හරියට',
#   'සේවකයො',
#   'ගන්න',
#   'ඕන',
#   'උන්ට',
#   'පඩියක්',
#   'ගෙවන්න',
#   'ඕන',
#   'ඒව',
#   'කොරන්න',
#   'කොහෙඩ',
#   'රටට',
#   'සල්ලි',
#   'රටින්',
#   'ගන්න',
#   'ණය',
#   'අදාර',
#   'ඔක්කොම',
#   'ගිහිනුත්',
#   'මදි',
#   'පාර්ලිමේන්තුව',
#   'නඩත්තු',
#   'කරන්න',
#   'මට',
#   'තේරෙන්නෙ',
#   'නෑ',
#   'කතා',
#   'කරල',
#   'වැඩක්',
#   'නෑ',
#   'මේ',
#   'කෝච්චියෙ',
#   'යන්න',
#   'ටයි',
#   'කරන්න',
#   'එපා',
#   'ප්\u200dරෙන්',
#   'තෙප්පමක්',
#   'හදාගෙන',
#   'හරි',
#   'කමක්',
#   'නෑ',
#   'ජීවත්',
#   'වෙන්න',
#   'පුලුවන්',
#   'රටකට',
#   'පලයල්ල'],
#  ['මේ',
#   'comment',
#   'වල',
#   'තියෙන',
#   'අදහස්',
#   'facebook',
#   'එක',
#   'ඇතුලේම',
#   'පල්',
#   'නොකර',
#   'ස්ටේෂන්',
#   'වලයි',
#   'දුම්රිය',
#   'මැදිරි',
#   'ඇතුලෙයි',
#   'මිනිස්සුන්ට',
#   'දැනෙන',
#   'විදිහට',
#   'display',
#   'කළා',
#   'නම්',
#   'භාෂා',
#   '3න්ම',
#   'පින්තූරත්',
#   'එක්ක',
#   'පොඩි',
#   'වෙනසක්',
#   'හරි',
#   'දකින්න',
#   'පුළුවන්'],
#  ['dubai',
#   'wala',
#   'thiyana',
#   'awaga',
#   'kama',
#   'kana',
#   'ak',
#   'thahanam',
#   'aduma',
#   'tharama',
#   'chuingam',
#   'wath',
#   'kanda',
#   'ba',
#   'aka',
#   'hama',
#   'thama',
#   'camara',
#   'thiyanawa',
#   'lagatama',
#   'avith',
#   'dada',
#   'gahanakn',
#   'danna',
#   'na',
#   'apa',
#   'minissu',
#   'wanas',
#   'karanda',
#   'amarui',
#   'akata',
#   'hodama',
#   'da',
#   'hariyata',
#   'nithi',
#   'hadanda',
#   'ona',
#   'owata',
#   'athokota',
#   'nikamma',
#   'purudu',
#   'wanawa'],
#  ['යන',
#   'එවුන්ටයි',
#   'මේ',
#   'කියන්නේ',
#   'මොන',
#   'තරම්',
#   'options',
#   'අවත්',
#   'කමක්',
#   'නෑ',
#   'එවගේ',
#   'ඒ',
#   'විදිහිට',
#   'ගිහින්',
#   'එක',
#   'පරිස්සමෙන්',
#   'පාවිච්චි',
#   'කරන්න',
#   'අපේ',
#   'දෙවල්',
#   'රැක',
#   'ගන්න'],
#  ['usb',
#   'port',
#   'එකෙ',
#   'චුයින්ගම්',
#   'අලවාවි',
#   'වඩේ',
#   'කාල',
#   'කර්ටන්',
#   'එකේ',
#   'අත',
#   'පිහිදලා',
#   'කම්මැලිකමට',
#   'sheet',
#   'එක',
#   'කුශන්',
#   'කෑලි',
#   'කඩලා',
#   'tv',
#   'එක',
#   'කැඩුන',
#   'කියල',
#   'පොඩි',
#   'අව්ලක්',
#   'හදල',
#   'රෙපයාර්',
#   'කරන',
#   'එඋන්',
#   'ගෙදර',
#   'ගෙනියලා',
#   'fan',
#   'ගලවල',
#   'ටිකට්',
#   'කවුන්ටරෙට',
#   'සෙට්',
#   'කරලා',
#   'ටොයිලට්',
#   'ටික',
#   'වටේට',
#   'ජරා',
#   'කරලා',
#   'අර',
#   'ස්ටෙසමේ',
#   'නවත්තනකොටම',
#   'සුද්ද',
#   'කරන්න',
#   'නගින',
#   'සෙට්',
#   'එකක්',
#   'ඉන්නොනෙ',
#   'බූමිතෙල්',
#   'වැදිච්ච',
#   'ගැරඩි',
#   'වගේ',
#   'cleaners',
#   'ලා',
#   'උන්',
#   'තමයි',
#   'ඕකෙ',
#   'තීන',
#   'කුනු',
#   'පේන',
#   'ටික',
#   'අතුගාල',
#   'අනිත්ව',
#   'ශීටඅස්සට',
#   'තල්ලු',
#   'කරල',
#   'ලොකුම',
#   'සේවය',
#   'කරන්නෙ'],
#  ['mewa',
#   'thiyana',
#   'widiyata',
#   'keedawasak',
#   'thiyaganna',
#   'puluwan',
#   'weida',
#   'ape',
#   'moda',
#   'noogathun',
#   'ekka'],
#  ['wadenam',
#   'hondai',
#   'eth',
#   'ape',
#   'minisunge',
#   'winayath',
#   'ekka',
#   'mewa',
#   'araksha',
#   'karaganida'],
#  ['ape',
#   'ratata',
#   'genna',
#   'ona',
#   'owa',
#   'newe',
#   'hoda',
#   'hadichcha',
#   'silachara',
#   'minissu',
#   'tikak',
#   'dan',
#   'inna',
#   'un',
#   'tikawa',
#   'koheta',
#   'hari',
#   'aduwata',
#   'vikunala',
#   'dala'],
#  ['ehenm',
#   'palaweni',
#   'dawasema',
#   'train',
#   'ride',
#   'ekak',
#   'yanda',
#   'onee',
#   'mokada',
#   'dawas',
#   'deka',
#   'thunak',
#   'giyata',
#   'passe',
#   'owwa',
#   'mukuth',
#   'nee',
#   'ne'],
#  ['hamadama',
#   'ithin',
#   'ahanna',
#   'wenne',
#   'kohen',
#   'hari',
#   'genapu',
#   'ekak',
#   'gana',
#   'thamai',
#   'ape',
#   'rate',
#   'nispadanayak',
#   'kiyala',
#   'ahanna',
#   'wena',
#   'ekak',
#   'naha'],
#  ['indiawen',
#   'genna',
#   'oneda',
#   'oowa',
#   'lankawe',
#   'ennawa',
#   'onnataran',
#   'weddo',
#   'oitawada',
#   'hodata',
#   'haganna',
#   'puluwan',
#   'kutti',
#   'pitin',
#   'ekapara',
#   'gasaganna',
#   'project',
#   'oowa'],
#  ['owa',
#   'ta',
#   'army',
#   'eken',
#   'dala',
#   'arawage',
#   'pissu',
#   'natana',
#   'unge',
#   'kana',
#   'paluwa',
#   'nam',
#   'nikan',
#   'ma',
#   'hadeyi'],
#  ['badulla',
#   'jaffna',
#   'kandy',
#   'yana',
#   'train',
#   'me',
#   'wage',
#   'api',
#   'dawasawala',
#   'hondai',
#   'dan',
#   'kohomada'],
#  ['unp',
#   'ආන්ඩුව',
#   'මොකුත්',
#   'කලේ',
#   'නෑ',
#   'කියන',
#   'එවුන්',
#   'බලා',
#   'ගනිල්ල',
#   'unp',
#   'ආන්ඩුවක්',
#   'පලක්',
#   'නැති',
#   'දේවල්',
#   'වෙනුවෙන',
#   'කවදාවත්',
#   'ලෝකෙට',
#   'රට',
#   'ණයකලේ',
#   'නෑ',
#   'නෙළුම්',
#   'පොකුනු',
#   'නෙළුම්',
#   'පොකුනු',
#   'වෙනුවෙන්',
#   'රට',
#   'ණයකරපු',
#   'සල්ලිවල',
#   'මේ',
#   'වගේ',
#   'දෙයක්',
#   'කලානම්',
#   'කොච්චර',
#   'වටිනවද'],
#  ['සතියයි',
#   'බං',
#   'ඕවා',
#   'ඕවට',
#   'cctv',
#   'camera',
#   'system',
#   'එකක්',
#   'දාන්න',
#   'ඕනෙ'],
#  ['okko', 'keli', 'galawan', 'yanawa', 'ape', 'un'],
#  ['oya',
#   'thathwen',
#   'tyenne',
#   'eka',
#   'dwsai',
#   'ape',
#   'minisunt',
#   'kohed',
#   'owge',
#   'wtinakamak'],
#  ['මේ',
#   'ලංකාවටද',
#   'ඕක',
#   'ගේන්නෙ',
#   'පලවෙනි',
#   'දවසෙම',
#   'ඕකේ',
#   'ෆෑන්',
#   'tv',
#   'ටික',
#   'ගලවන්',
#   'යයි'],
#  ['gothrika',
#   'ratakata',
#   'me',
#   'wage',
#   'dewal',
#   'dunnata',
#   'reka',
#   'ganne',
#   'ne',
#   'kiyala',
#   'sure'],
#  ['ki', 'dawasak', 'ohoma', 'lassanata', 'thiyaida'],
#  ['cctv',
#   'gahala',
#   'genna',
#   'nathnm',
#   'dawsai',
#   'dekaii',
#   'okkoma',
#   'kala',
#   'daweee'],
#  ['ape',
#   'unta',
#   'oke',
#   'yanna',
#   'uganna',
#   'wenawa',
#   'neth',
#   'nam',
#   'kala',
#   'dawi'],
#  ['ape', 'rilawu', 'tika', 'okatath', 'wade', 'deyi'],
#  ['balamu',
#   'mekawath',
#   'hariyata',
#   'thiya',
#   'ganida',
#   'kiyala',
#   'badulle',
#   'train',
#   'eke',
#   'toilat',
#   'eken',
#   'eleyata',
#   'patta',
#   'chu',
#   'gadai'],
#  ['hoda', 'wagayma', 'wanasana', 'ewungayn', 'bayraganna', 'watina', 'badu'],
#  ['raththaran',
#   'newei',
#   'diyamanthi',
#   'hari',
#   'kamak',
#   'na',
#   'ape',
#   'gedara',
#   'chandayaka',
#   'watinakama',
#   'laksha',
#   'dekai'],
#  ['me',
#   'mama',
#   'nemei',
#   'ane',
#   'danne',
#   'nadda',
#   'mata',
#   'naya',
#   'gahala',
#   'mama',
#   'malane',
#   'a',
#   'unata',
#   'balannako',
#   'parcy',
#   'aiyata',
#   'kellek',
#   'akka',
#   'sapak',
#   'ganna',
#   'ona',
#   'unama',
#   'mama',
#   'thamai',
#   'set',
#   'karala',
#   'denne',
#   'parcy',
#   'aiya',
#   'katha',
#   'kaloth',
#   'witharai',
#   'mata',
#   'pana',
#   'anne'],
#  ['mehema',
#   'poster',
#   'gahana',
#   'ekeknam',
#   'raththaran',
#   'ekek',
#   'wenna',
#   'ba'],
#  ['sadu',
#   'sadu',
#   'ochchara',
#   'kal',
#   'pirith',
#   'ahuwa',
#   'theruma',
#   'danan',
#   'hitiye',
#   'na',
#   'aa',
#   'hinda',
#   'sarddawakin',
#   'nm',
#   'neme',
#   'ahuwe',
#   'paliyenui',
#   'sinahalenuii',
#   'dekenma',
#   'kiynakota',
#   'pirithehi',
#   'thiyenawa',
#   'avobathmaka',
#   'bawth',
#   'labenawa',
#   'sraddwth',
#   'wadenawa',
#   'kusalayka',
#   'hitha',
#   'pihitana',
#   'nisa',
#   'aniwryenma',
#   'pirithehi',
#   'anubawa',
#   'labenawamai'],
#  ['ත්\u200dරිපිටකය',
#   'විකුර්ති',
#   'කරලා',
#   'පමණක්',
#   'නෙවි',
#   'කොටස්',
#   'අඩු',
#   'කරලා',
#   'පිරිත්',
#   'කියන්නේ',
#   'ඉංග්\u200dරීසියෙන්',
#   'පල්ලියේ',
#   'ගීතිකා',
#   'ගයන',
#   'විධියට',
#   'ඉංග්\u200dරීසියට',
#   'පරිවර්තනය',
#   'කරලා',
#   'සංගීතිය',
#   'මුසු',
#   'කරලා',
#   'ප්\u200dරතිමා',
#   'කලාව',
#   'එහෙම',
#   'පිටින්ම',
#   'විකුර්ති',
#   'කරලා',
#   'අඩ',
#   'නිරුවත්',
#   'රුප',
#   'අඹල',
#   'මේවා',
#   'මම',
#   'ඇතුළු',
#   'බොහෝ',
#   'පිරිසක්',
#   'විවේචනය',
#   'කරාට',
#   'පස්සේ',
#   'දැන්',
#   'විකුර්ති',
#   'කරලා',
#   'හදපු',
#   'ප්\u200dරතිමා',
#   'නැවත',
#   'හදනවා',
#   'කියල',
#   'ආරංචියි',
#   'ඔබ',
#   'නොදන්නවා',
#   'උනාට',
#   'මම',
#   'ඔය',
#   'හාමුදුරුවන්ගේ',
#   'ngo',
#   'වැඩපිළිවෙල',
#   'ගැන',
#   'මම',
#   'දන්නේ',
#   '1998',
#   'පමණ',
#   'ඉඳල',
#   'ගලිගමුවේ',
#   'ghanadipa',
#   'හාමුදුරුවන්ට',
#   'වස',
#   'දීල',
#   'ඒ',
#   'හාමුදුරුවන්ව',
#   'අපවත්',
#   'කරන්න',
#   'හැදුවේ',
#   'කව්ද',
#   'කියල',
#   'ඒ',
#   'ගලිගමුවේ',
#   'හාමුදුරුවන්ගෙන්ම',
#   'ඇහුවනම්',
#   'දැනගන්න',
#   'තිබුන',
#   'මහාචාර්ය',
#   'ඉඳුරාගාරේ',
#   'ධර්මරතන',
#   'හාමුදුරුවෝ',
#   'බෞධ',
#   'ඝාතක',
#   'කල්ලි',
#   'කියල',
#   'පොතක්',
#   'ලියල',
#   'තියනවා',
#   'අන්න',
#   'ඒ',
#   'පොතේ',
#   'තියනවා',
#   'කිරිබත්ගොඩ',
#   'උන්නාන්සේගේ',
#   'කෙරුවාව',
#   'හොයාගෙන',
#   'කියවන්න',
#   'මම',
#   'මේ',
#   'කරන්නේ',
#   'බොරු',
#   'අපහාසයක්',
#   'නම්',
#   'එකේ',
#   'පාපයේ',
#   'දිග',
#   'පළල',
#   'මම',
#   'හොඳට',
#   'දන්නවා',
#   'නමුත්',
#   'මම',
#   'බය',
#   'නැතුව',
#   'මේ',
#   'චෝදනාව',
#   'කරන්නේ',
#   'මම',
#   'හොඳාකාරවම',
#   'දන්නා',
#   'නිසයි',
#   'මේ',
#   'දේවල්',
#   'පරම',
#   'සත්\u200dයය'],
#  ['pirtiha',
#   'yanu',
#   'manthara',
#   'nowa',
#   'gana',
#   'pihitanna',
#   'sathya',
#   'pamanai',
#   'gana',
#   'pihitanne',
#   'bamuno'],
#  ['kuhaka',
#   'kamin',
#   'kupitha',
#   'uwanta',
#   'theruwan',
#   'saranai',
#   'kalyana',
#   'mithrainwahanselata',
#   'deergau',
#   'wewa'],
#  ['oba',
#   'jothishya',
#   'karana',
#   'kenek',
#   'wenna',
#   'oni',
#   'cover',
#   'foto',
#   'ekata',
#   'anuwa',
#   'nam',
#   'ow',
#   'loku',
#   'swamanin',
#   'wahanse',
#   'wiruddai',
#   'jothishyta',
#   'a',
#   'nisa',
#   'wenna',
#   'athi',
#   'ohoma',
#   'kiwwe'],
#  ['jivite',
#   'nodenima',
#   'amuthuma',
#   'tenakata',
#   'geniyanawa',
#   'sadu',
#   'sadu',
#   'sadu',
#   'ape',
#   'dahama',
#   'api',
#   'rekaganna',
#   'ona'],
#  ['අන්න',
#   'එහෙම',
#   'තමයි',
#   'ඉන්න',
#   'ඕන',
#   'මමත්',
#   'පංසල්',
#   'පල්ලි',
#   'දෙකටම',
#   'යනවා',
#   'ඉස්සර',
#   'ඉඳන්ම',
#   'කාලයක්',
#   'මගේ',
#   'gf',
#   'වෙලා',
#   'හිටියෙ',
#   'කතෝලික',
#   'කෙල්ලෙක්',
#   'ඉතින්',
#   'නිරායාසයෙන්',
#   'මම',
#   'කතෝලික',
#   'පල්ලි',
#   'වල',
#   'නිස්කලංක',
#   'බවට',
#   'ආස',
#   'වුණා',
#   'කෙල්ල',
#   'ගියා',
#   'හැබැයි',
#   'පල්ලි',
#   'වලට',
#   'මම',
#   'තාම',
#   'යනවා'],
#  ['මගේ',
#   'අම්මා',
#   'කතෝලික\u200b',
#   'තාත්තා',
#   'බෞද්ධ\u200b',
#   'මමයි',
#   'මල්ලියි',
#   'දෙන්නම',
#   'බෞතීස්ම',
#   'වෙලා',
#   'නෑ',
#   'ගියේ',
#   'බෞද්ධ',
#   'ඉස්කෝල',
#   'දෙකකට\u200b',
#   'හැබැයි',
#   'දෙන්නම',
#   'පල්ලි',
#   'පන්සල්',
#   'දෙකටම',
#   'ගියා',
#   'මම',
#   'spiritual',
#   'මල්ලි',
#   'නිරාගමික\u200b'],
#  ['kauru',
#   'mona',
#   'widiyata',
#   'dakkath',
#   'meka',
#   'ahagena',
#   'innakota',
#   'me',
#   'palida',
#   'sinhalada',
#   'kiyala',
#   'hithen',
#   'na',
#   'hithata',
#   'pudumakara',
#   'sahalluwak',
#   'danenawa',
#   'aththatama'],
#  ['ඇතැමුන්',
#   'නොදන්නවා',
#   'උනාට',
#   'කිරිබත්ගොඩ',
#   'උන්නාන්සේ',
#   'ත්\u200dරිපිටකය',
#   'විකුර්ති',
#   'කරලා',
#   'පමණක්',
#   'නෙවි',
#   'කොටස්',
#   'අඩු',
#   'කරලා',
#   'පිරිත්',
#   'කියන්නේ',
#   'ඉංග්\u200dරීසියෙන්',
#   'පල්ලියේ',
#   'ගීතිකා',
#   'ගයන',
#   'විධියට',
#   'ඉංග්\u200dරීසියට',
#   'පරිවර්තනය',
#   'කරලා',
#   'සංගීතිය',
#   'මුසු',
#   'කරලා',
#   'ප්\u200dරතිමා',
#   'කලාව',
#   'එහෙම',
#   'පිටින්ම',
#   'විකුර්ති',
#   'කරලා',
#   'අඩ',
#   'නිරුවත්',
#   'රුප',
#   'අඹල',
#   'මේවා',
#   'මම',
#   'ඇතුළු',
#   'බොහෝ',
#   'පිරිසක්',
#   'විවේචනය',
#   'කරාට',
#   'පස්සේ',
#   'දැන්',
#   'විකුර්ති',
#   'කරලා',
#   'හදපු',
#   'ප්\u200dරතිමා',
#   'නැවත',
#   'හදනවා',
#   'කියල',
#   'ආරංචියි',
#   'ඔබ',
#   'කව්රුත්',
#   'නොදන්නවා',
#   'උනාට',
#   'මම',
#   'ඔය',
#   'හාමුදුරුවන්ගේ',
#   'ngo',
#   'වැඩපිළිවෙල',
#   'ගැන',
#   'මම',
#   'දන්නේ',
#   '1998',
#   'පමණ',
#   'ඉඳල',
#   'ගලිගමුවේ',
#   'ghanadipa',
#   'හාමුදුරුවන්ට',
#   'වස',
#   'දීල',
#   'ඒ',
#   'හාමුදුරුවන්ව',
#   'අපවත්',
#   'කරන්න',
#   'හැදුවේ',
#   'කව්ද',
#   'කියල',
#   'ඒ',
#   'ගලිගමුවේ',
#   'හාමුදුරුවන්ගෙන්ම',
#   'ඇහුවනම්',
#   'දැනගන්න',
#   'තිබුන',
#   'මහාචාර්ය',
#   'ඉඳුරාගාරේ',
#   'ධර්මරතන',
#   'හාමුදුරුවෝ',
#   'බෞධ',
#   'ඝාතක',
#   'කල්ලි',
#   'කියල',
#   'පොතක්',
#   'ලියල',
#   'තියනවා',
#   'අන්න',
#   'ඒ',
#   'පොතේ',
#   'තියනවා',
#   'කිරිබත්ගොඩ',
#   'උන්නාන්සේගේ',
#   'කෙරුවාව',
#   'හොයාගෙන',
#   'කියවන්න',
#   'හොඳ',
#   'පොතක්',
#   'මම',
#   'මේ',
#   'කරන්නේ',
#   'බොරු',
#   'අපහාසයක්',
#   'නම්',
#   'එකේ',
#   'පාපයේ',
#   'දිග',
#   'පළල',
#   'මම',
#   'හොඳට',
#   'දන්නවා',
#   'නමුත්',
#   'මම',
#   'බය',
#   'නැතුව',
#   'මේ',
#   'චෝදනාව',
#   'කරන්නේ',
#   'මම',
#   'හොඳාකාරවම',
#   'දන්නා',
#   'නිසයි',
#   'මේ',
#   'දේවල්',
#   'පරම',
#   'සත්\u200dයය'],
#  ['බුදු',
#   'දහම',
#   'අපි',
#   'රැක',
#   'ගමු',
#   'ath',
#   'me',
#   'kamara',
#   'karayata',
#   'pisida',
#   'චූඩාමානි',
#   'කයේ',
#   'udine',
#   'camara',
#   'karanne',
#   'pisso',
#   'inne',
#   'බුදු',
#   'සරණයි'],
#  ['unp',
#   'jvp',
#   'slfp',
#   'slpp',
#   'හෝ',
#   'ඕනෑම',
#   'පක්ෂයක',
#   'හොරු',
#   'හා',
#   'බොරුකාරයන්',
#   'මේ',
#   'විදිහට',
#   'දිගටම',
#   'ප්\u200dරතික්ෂේප',
#   'කළ',
#   'යුතුයි',
#   'අනිත්',
#   'අයටත්',
#   'ඒක',
#   'රුකුලක්',
#   'ආදර්ශයක්',
#   'වේවි',
#   'දේශපාලන',
#   'හොරුන්ට',
#   'එරෙහි',
#   'වෙන්න'],
#  ['උන්',
#   'සම්මාන',
#   'ගන්න',
#   'බෑ',
#   'කියද්දි',
#   'දේශපාලුවෝ',
#   'දෙන්නනම',
#   'අත්පුඩි',
#   'ගැහුවා',
#   'උන්',
#   'එහෙම',
#   'කරේ',
#   'කපටිකමටද',
#   'ලැජ්ජාවෙන්',
#   'බේරෙන්නද',
#   'කියල',
#   'හිතන්න',
#   'අමාරුයි',
#   'නමුත්',
#   'ප්\u200dරතික්ෂේප',
#   'වුනේ',
#   'කවුද',
#   'කියල',
#   'බහුතර',
#   'comments',
#   'වලින්',
#   'පැහැදිලියි'],
#  ['meke',
#   'comment',
#   'dakkahama',
#   'terena',
#   'akama',
#   'de',
#   'tamat',
#   'desapaluwanta',
#   'kade',
#   'yana',
#   'wahallu',
#   'bara',
#   'gaaanak',
#   'ennawa',
#   'kiyana',
#   'ekai'],
#  ['aththatama',
#   'hoday',
#   'school',
#   'ekaka',
#   'sertificates',
#   'dennath',
#   'amathi',
#   'waru',
#   'genwanawa',
#   'e',
#   'amathi',
#   'waru',
#   'e',
#   'lamay',
#   'tharamatawath',
#   'igena',
#   'gena',
#   'na',
#   'kisima',
#   'uthsawayakata',
#   'amathi',
#   'waru',
#   'manthri',
#   'waru',
#   'genna',
#   'ganna',
#   'narakay',
#   'ita',
#   'wada',
#   'hoday',
#   'e',
#   'sahathika',
#   'thamanwa',
#   'bihikarapu',
#   'demawpiyan',
#   'athin',
#   'dena',
#   'eka'],
#  ['politics',
#   'enawanam',
#   'mewa',
#   'vinda',
#   'dara',
#   'ganna',
#   'wenawa',
#   'eken',
#   'gammak',
#   'ena',
#   'bawath',
#   'hada',
#   'ganna',
#   'waradi',
#   'awathawak',
#   'eka'],
#  ['mun',
#   'naluwo',
#   'da',
#   'nattam',
#   'rastiyadu',
#   'kara',
#   'chandi',
#   'da',
#   'oka',
#   'award',
#   '1k',
#   'ganna',
#   'welawak',
#   'nathuwa',
#   'picatin',
#   'karana',
#   'welawak',
#   'newei'],
#  ['news',
#   'newaradi',
#   'karanna',
#   'hadanna',
#   'epa',
#   'organised',
#   'karala',
#   'tibuna',
#   'vidiyata',
#   'wada',
#   'kerrnna',
#   'one',
#   'ehema',
#   'kamati',
#   'nati',
#   'kenek',
#   'innawanam',
#   'samana',
#   'nogena',
#   'inna',
#   'one'],
#  ['prashnayak',
#   'na',
#   'othana',
#   'inna',
#   'deshapalakayin',
#   'dedenath',
#   'ekka',
#   'baladdai',
#   'shriyantha',
#   'mendis',
#   'yanu',
#   'yodhayek',
#   'sriyantha',
#   'laankeeya',
#   'kalaawata',
#   'amila',
#   'sewayak',
#   'kala',
#   'ayeki',
#   'anek',
#   'dedena',
#   'parliment',
#   'gos',
#   'aththe',
#   'ratata',
#   'awashya',
#   'hoda',
#   'prathipaththi',
#   'saadeemata',
#   'namuth',
#   'owun',
#   'hadupu',
#   'eka',
#   'hoda',
#   'prathipaththiyak',
#   'thibeda'],
#  ['kalakarayek',
#   'unama',
#   'meta',
#   'wada',
#   'nihathamai',
#   'wenna',
#   'one',
#   'mun',
#   'tama',
#   'oya',
#   'rasikayontah',
#   'lokuma',
#   'pennane',
#   'desapalane',
#   'wadak',
#   'n',
#   'a',
#   'othenta',
#   'owa',
#   'tama',
#   'moda',
#   'kama',
#   'penwanne'],
#  ['aththtama',
#   'meyala',
#   'ta',
#   'kalakaruwo',
#   'kiyanna',
#   'puluwanda',
#   'niyama',
#   'kalakaruwo',
#   'mehema',
#   'hasirenne',
#   'nah',
#   'kawadawath',
#   'duminda',
#   'gammanpila',
#   'lage',
#   'deshpalana',
#   'gatalu',
#   'athi',
#   'namuth',
#   'apey',
#   'sinhalayan',
#   'vidiyata',
#   'meeta',
#   'wada',
#   'gunagaruka',
#   'wenna',
#   'oney',
#   'oyala',
#   'oya',
#   'pradharshanaya',
#   'kale',
#   'duminda',
#   'ge',
#   'wath',
#   'gammanpila',
#   'gewath',
#   'narakak',
#   'neme',
#   'oyalagema',
#   'pahath',
#   'manasikathwaya',
#   'harima',
#   'kanagatui'],
#  ['methana',
#   'thiyenne',
#   'wenna',
#   'prasnayak',
#   'muu',
#   'ranil',
#   'dunne',
#   'name',
#   'ok',
#   'a',
#   'ganiwi',
#   'muu',
#   'sannasgalage',
#   'golayek',
#   'ganga',
#   'karate',
#   'kiyalath',
#   'hugely',
#   'aya',
#   'kiyanawa',
#   'ai',
#   'desapaluwanta',
#   'aradana',
#   'late'],
#  ['kalaa',
#   'karuvekuta',
#   'sammaanayak',
#   'pirinemiya',
#   'yuththe',
#   'iita',
#   'ihala',
#   'talaye',
#   'kalaavek',
#   'athini'],
#  ['manussakamai',
#   'deshapalanayai',
#   'wenas',
#   'puthiii',
#   'a',
#   'deka',
#   'aduraganna',
#   'beri',
#   'munta',
#   'kawda',
#   'yako',
#   'sammana',
#   'dennee'],
#  ['mamath',
#   'despalkayanta',
#   'kamti',
#   'ne',
#   'namuth',
#   'metana',
#   'despalanya',
#   'gawa',
#   'ganna',
#   'eka',
#   'modakamak',
#   'onwata',
#   'wada',
#   'oluw',
#   'idmawa',
#   'gande',
#   'apa',
#   'meka',
#   'dekahma',
#   'mata',
#   'hitanna',
#   'kalkaruo',
#   'mehara',
#   'මෝඩද',
#   'kiyala'],
#  ['niduk',
#   'nirogi',
#   'suwapiri',
#   'wasarak',
#   'erabena',
#   'subama',
#   'suba',
#   'upandinak',
#   'wewa',
#   'maliya'],
#  ['deshapalanaya',
#   'wenai',
#   'sabawaka',
#   'kuhaka',
#   'kam',
#   'kirieema',
#   'anumatha',
#   'karanna',
#   'ba',
#   'kalawa',
#   'kiyanne',
#   'sundarathwaya',
#   'misak',
#   'kuhaka',
#   'kama',
#   'neme'],
#  ['kondak',
#   'athi',
#   'un',
#   'dennek',
#   'dakka',
#   'sathutui',
#   'aththatama',
#   'me',
#   'uda',
#   'comment',
#   'dala',
#   'thiyana',
#   'godak',
#   'unta',
#   'game',
#   'pol',
#   'gediyak',
#   'kadapu',
#   'horekuta',
#   'gahala',
#   'banala',
#   'erehi',
#   'wenta',
#   'kondak',
#   'thibbata',
#   'me',
#   'wage',
#   'loku',
#   'horunta',
#   'erehi',
#   'wenta',
#   'kondak',
#   'na'],
#  ['මේකෙ',
#   'වරදක්',
#   'පේන්නෙ',
#   'නෑ',
#   'මේ',
#   'වගෙ',
#   'අවස්ථාවලට',
#   'දේශපාලනය',
#   'ගාව',
#   'ගන්න',
#   'හොද',
#   'නෑ',
#   'ඒත්',
#   'මොන',
#   'දේශපාලන',
#   'පක්ෂය',
#   'කින්',
#   'ආවත්',
#   'මේ',
#   'දේ',
#   'මෙහෙම',
#   'කරන්න',
#   'ඕනි',
#   'unp',
#   'jvp',
#   'උන්',
#   'ආව',
#   'කියලත්',
#   'මේ',
#   'විදිහටම',
#   'කරන්න',
#   'ඕනි',
#   'එහෙම',
#   'කරාවිද',
#   'නැද්ද',
#   'කියලා',
#   'දන්නෙ',
#   'කරපු',
#   'උන්',
#   'දෙන්න',
#   'විතරයි'],
#  ['desapaluwo',
#   'uthsawa',
#   'weleta',
#   'awasa',
#   'na',
#   'penawane',
#   'parlimenthuwe',
#   'hati',
#   'in',
#   'thaneketa',
#   'awath',
#   'nagitinna',
#   'epa'],
#  ['mona',
#   'dekarath',
#   'manussayo',
#   'api',
#   'nihathamani',
#   'wenna',
#   'oni',
#   'pali',
#   'ganim',
#   'waire',
#   'pennanna',
#   'yana',
#   'eka',
#   'hari',
#   'katha',
#   'vidihatai',
#   'penne'],
#  ['mahindata',
#   'giyasereth',
#   'kelawune',
#   'mahindage',
#   'golayo',
#   'nisaa',
#   'thamayy'],
#  ['හරි',
#   'ගානක්',
#   'කියපන්',
#   'යකෝ',
#   'එක',
#   'එකා',
#   'නානාප්\u200dරකාර',
#   'ගනන්',
#   'කියනව',
#   'අපිට',
#   'දන්',
#   'වෙලා',
#   'තියෙන්නෙ',
#   'ඕකෙ',
#   'mean',
#   'value',
#   'එක',
#   'ගන්න'],
#  ['aiyooo',
#   'mahinda',
#   'attatama',
#   'lajjai',
#   'oba',
#   'tumawa',
#   'nati',
#   'kala',
#   'golayo',
#   'tika'],
#  ['aehema', 'minissu', 'hitiya', 'nam', 'mun', 'parlimentu', 'yannne', 'broo'],
#  ['sri',
#   'lankan',
#   'cricket',
#   'පිලේ',
#   'පන්දු',
#   'රැකීමේ',
#   'පුහුණුකරු',
#   'තනතුර',
#   'බාරගන්නකම්',
#   'පෙරුම්පුරා',
#   'මග',
#   'බලාහිදිමි',
#   'මම',
#   'ඇයි',
#   'තව',
#   'නාවෙ',
#   'දයා'],
#  ['munta',
#   'pissu',
#   'mun',
#   'me',
#   'nati',
#   'nasthi',
#   'karanne',
#   'ape',
#   'salli',
#   'monatada',
#   'api',
#   'munta',
#   'meva',
#   'karanna',
#   'bale',
#   'denneeeee'],
#  ['badagini',
#   'wela',
#   'harak',
#   'relata',
#   'wal',
#   'miti',
#   '225',
#   'kapala',
#   'gihin',
#   'dahalla',
#   'atakota',
#   'oya',
#   'enaganna',
#   'eka',
#   'nawttaganiivi'],
#  ['නොතිබුණු',
#   'ප්\u200dරශ්නයක්',
#   'ඇති',
#   'කර',
#   'රටෙහි',
#   'උත්තරීතර',
#   'ආයතනය',
#   'ගිනි',
#   'මඩුවක්',
#   'කල',
#   'පුද්ගලයා',
#   'අද',
#   'tv',
#   'එකෙන්',
#   'මෙවා',
#   'බලමින්',
#   'සතුටු',
#   'වෙනවා',
#   'ඇති'],
#  ['me',
#   '225',
#   'dena',
#   'api',
#   'venuven',
#   'karana',
#   'kapaveema',
#   'dakkama',
#   'harima',
#   'duka',
#   'hithenava',
#   'pau',
#   'thamun',
#   'ganavath',
#   'nositha',
#   'gutikagena',
#   'dagalanne',
#   'api',
#   'venuven',
#   'vadakarannane'],
#  ['me',
#   'serama',
#   'hadanne',
#   'me',
#   'ratata',
#   'adareta',
#   'newei',
#   'balayata',
#   'mudalata',
#   'pagawal',
#   'ganna',
#   'rate',
#   'keli',
#   'wikunanna',
#   'rata',
#   'winasa',
#   'karanna',
#   'ratak',
#   'nethi',
#   'karanna',
#   'hadanne'],
#  ['damn',
#   'bugaboos',
#   'wosrt',
#   'government',
#   'busking',
#   'money',
#   'hama',
#   'deyakma',
#   'wena',
#   'ahinsaka',
#   'dupath',
#   'minissunta',
#   'thama',
#   'lankawe',
#   'me',
#   'kalakani',
#   'yakkunta',
#   'occurred',
#   'wath',
#   'nene',
#   'shit',
#   'damn',
#   'koti',
#   'ganan',
#   'billons',
#   'ganan',
#   'waste',
#   'karana',
#   'nugath',
#   'kalakani',
#   'yakku',
#   'podi',
#   'ratak',
#   'development',
#   'karana',
#   'horu',
#   'ralak',
#   'inna',
#   'ona',
#   'kalakani',
#   'yakku',
#   'o',
#   'level',
#   'a',
#   'level',
#   'kiyala',
#   'wath',
#   'pass',
#   'nethi',
#   'budimath',
#   'citizens',
#   'la',
#   'mewage',
#   'musala',
#   'kalakani',
#   'yakku',
#   'inna',
#   'rataka',
#   'inna',
#   'asanethe',
#   'ekai',
#   'guest',
#   'keneck',
#   'ma',
#   'awila',
#   'rate',
#   'situation',
#   'eka',
#   'ahumwa',
#   'nondi',
#   'i',
#   'say',
#   'shit',
#   'kisima',
#   'disciplined',
#   'ethics',
#   'auspicious',
#   'occasion',
#   'ekak',
#   'nethi',
#   'ratak',
#   'ashamed',
#   'people',
#   's'],
#  ['lajjai',
#   'bn',
#   'aththatama',
#   'mewa',
#   'balanakota',
#   'me',
#   'ape',
#   'rate',
#   'palakayone',
#   'itin',
#   'kawada',
#   'goda',
#   'ennada',
#   'me',
#   'rata'],
#  ['me',
#   'ඔක්කෝම',
#   'ඉතින්',
#   'රට',
#   'ජාතිය',
#   'ආගම',
#   'බේරගන්න',
#   'මිසක්',
#   'එයාලගේ',
#   'පුද්ගලික',
#   'waasiyakata',
#   'nemeine',
#   'ban',
#   'borunam',
#   'tv',
#   'balahanko'],
#  ['ane',
#   'mehema',
#   'randuwenawanam',
#   'heta',
#   'parliment',
#   'yanna',
#   'epa',
#   'please',
#   'adarshamath',
#   'wennako',
#   'aduma',
#   'tharame',
#   'lejjai'],
#  ['me',
#   'dagalanne',
#   'janthavata',
#   'sahana',
#   'dennada',
#   'nee',
#   'munge',
#   'blayata',
#   'kaaadara',
#   'kamata',
#   'kageda',
#   'me',
#   'rata',
#   'ayalage',
#   'pawugalika',
#   'buudalayak',
#   'nemai',
#   'needa',
#   'mahajanthavani',
#   'molaya',
#   'kpana',
#   'kra',
#   'danvat',
#   'sudussan',
#   'pamnk',
#   'paliment',
#   'yavanna'],
#  ['ammapa',
#   'shik',
#   'oka',
#   'karannna',
#   'ekek',
#   'nane',
#   'me',
#   'rate',
#   'uwa',
#   'diwiyaloke',
#   'gihin',
#   'niwanuth',
#   'daki',
#   'appa',
#   'e',
#   'karana',
#   'kusalayata',
#   'samana',
#   'karanna',
#   'kusalayak',
#   'thawa',
#   'nathiwai',
#   'me',
#   'loke'],
#  ['ehema',
#   'innawanam',
#   'koitharam',
#   'hodaida',
#   'hamadema',
#   'parliment',
#   'eke',
#   'unata',
#   'nikam',
#   'pitathadi',
#   'yaluwo',
#   'dakimath',
#   'sathutak'],
#  ['අපි',
#   'ඉස්කෝලේ',
#   'යන',
#   'කාලේ',
#   'වාර',
#   'විභාගේ',
#   'කල්',
#   'ගියාමත්',
#   'අද',
#   'jvp',
#   'unp',
#   'අය',
#   'විදින',
#   'තාවකාලික',
#   'සතුට',
#   'වින්දා'],
#  ['nuugath',
#   'sadachara',
#   'kamak',
#   'nethi',
#   'un',
#   'balayata',
#   'apuwahama',
#   'mewage',
#   'dewal',
#   'athi',
#   'wenawa',
#   'upekshawen',
#   'bala',
#   'idimu'],
#  ['sha', 'niyama', 'wadak', 'kalanm', 'hari', 'ape', 'kattiyatath'],
#  ['oyaga',
#   'rail',
#   'mhatayata',
#   'minisu',
#   'chanda',
#   'dunbar',
#   'magma',
#   'koranta',
#   'tame',
#   'nmuth',
#   'it',
#   'a',
#   'klalin',
#   'central',
#   'bank',
#   'akata',
#   'wada',
#   'dunana',
#   'hour',
#   'wanuvan',
#   'horu',
#   'una'],
#  ['and', 'kohoma', 'hari', 'karanawanam', 'onna', 'niyama', 'wadak'],
#  ['මෙක', 'ඇත්තටම', 'උනොත්', 'නම්', 'heart', 'attack', 'hadila', 'mareii'],
#  ['මූ',
#   'ශුවර්',
#   'rugby',
#   'player',
#   'කෙනෙක්',
#   'හරියටම',
#   'බෝල්',
#   'එක',
#   'අරන්',
#   'යන',
#   'විදියටම',
#   'මු',
#   'අනික්',
#   'players',
#   'ලව',
#   'මග',
#   'අැරල',
#   'රින්ගල',
#   'අැවිත්',
#   'ලකුණ',
#   'ගත්ත',
#   'වගේ',
#   'සීන්',
#   'එකක්',
#   'ඒක'],
#  ['sira', 'kathawa', 'ban', 'eka', 'nam'],
#  ['ara', 'miniha', 'oxygen', 'nethuwa', 'merenne'],
#  ['policiye',
#   'un',
#   'hithan',
#   'inne',
#   'ltte',
#   'karayek',
#   'ahu',
#   'una',
#   'kiyala'],
#  ['podikale', 'hora', 'polis', 'den', 'trend', 'ekata', 'ewilla', 'wage'],
#  ['jonah', 'lomu', 'වගේ', 'යකෝ', 'ට්\u200dරයි', 'එක', 'තිබ්බේ'],
#  ['4',
#   'simawata',
#   'giya',
#   'eka',
#   'hatharak',
#   'reka',
#   'genimata',
#   'noheki',
#   'unaa'],
#  ['ara', 'police', 'lokkath', 'rugby', 'gahapu', 'ekek', 'mama', 'hithanne'],
#  ['patta',
#   'try',
#   'eka',
#   'si',
#   'kenekds',
#   'koheda',
#   'kohoma',
#   'hari',
#   'tackle',
#   'kara'],
#  ['suddage', 'athe', 'ruger', 'ball', 'ekak', 'thibbanam', 'maru'],
#  ['munta',
#   'puluwanne',
#   'bila',
#   'yana',
#   'ahinsaka',
#   'minihak',
#   'alla',
#   'ganda',
#   'tama'],
#  ['galu', 'policeyama', 'awwilla', 'yako'],
#  ['admin',
#   'manta',
#   'apith',
#   'kamathi',
#   'nha',
#   'mahindatath',
#   'kamthima',
#   'nha',
#   'unp',
#   'nm',
#   'ponil',
#   'enna',
#   'kn',
#   'katha',
#   'krla',
#   'wdk',
#   'nha',
#   'eth',
#   'lokka',
#   'gaththe',
#   'gnna',
#   'thiyena',
#   'hdma',
#   'thirane'],
#  ['ithin',
#   'hodaine',
#   'karapu',
#   'de',
#   'kage',
#   'unath',
#   'prathipaththi',
#   'weradinam',
#   'me',
#   'tika',
#   'thama',
#   'wenna',
#   'one'],
#  ['kisi',
#   'prasnaya',
#   'nahe',
#   'ape',
#   'rate',
#   'salli',
#   'thiyenawa',
#   'kabasiniya',
#   'karanna',
#   'thawa',
#   'one',
#   'tharam'],
#  ['meeta',
#   'pasu',
#   'lankawe',
#   'chandayak',
#   'awashshmanatha',
#   'mewage',
#   'vihilu',
#   'monaratakawath',
#   'nathuwa',
#   'athi'],
#  ['parliment',
#   'eka',
#   'විසුරුවා',
#   'janathawatama',
#   'oka',
#   'bara',
#   'dunna',
#   'eka',
#   'hodai',
#   'mokada',
#   'parliment',
#   'eke',
#   'inna',
#   'horu',
#   'relamani',
#   'thoranne',
#   'eka',
#   'e',
#   'minissunta',
#   'nodee',
#   'ජනමතයට',
#   'ida',
#   'dunna',
#   'eka',
#   'hodai',
#   'kiyala',
#   'hithnawa'],
#  ['lokaya',
#   'dunu',
#   'wena',
#   'kale',
#   'meyala',
#   'apassata',
#   'yanna',
#   'hadanne',
#   'seegiri',
#   'situwam',
#   'ugayata',
#   'nawata',
#   'yannna',
#   'epa',
#   'pls'],
#  ['බොරුවක්', 'කියලා', 'හිතෙන', 'අය', 'like', 'ekak', 'දාමු'],
#  ['noize',
#   'tv',
#   'උන්',
#   'filt',
#   'ව',
#   'hit',
#   'කරනවා',
#   'කාලෙකට',
#   'උව',
#   'බල්ලට',
#   'දානවා',
#   'මුන්',
#   'මෙ',
#   'ගහන්නෙ',
#   'ගෙමක්',
#   'කියලා',
#   'හිතෙන',
#   'උන්',
#   'ලයික්',
#   'එකක්',
#   'දා',
#   'න්',
#   'මුන්',
#   'හදන්න',
#   'උබලගේ',
#   'ඔලු',
#   'වලට',
#   'උ',
#   'ගැන',
#   'නරක',
#   'අදහසක්',
#   'දාලා',
#   'ආයෙ',
#   'උව',
#   'ගෙනල්ලා',
#   'උ',
#   'හොදයි',
#   'වගෙ',
#   'පෙන්නලා',
#   'උව',
#   'හිට්',
#   'කරන්නයි'],
#  ['munta', 'eka', 'miniyek', 'madi', 'ekai'],
#  ['europe', 'wala', 'inna', 'suddiyo', 'best', 'munta', 'wada'],
#  ['මේ',
#   'වගේ',
#   'කිසි',
#   'වැඩක්',
#   'නැති',
#   'එවුන්',
#   'කරපු',
#   'කිසිම',
#   'වැඩක්',
#   'නැති',
#   'වැඩකට',
#   'trending',
#   'එන්න',
#   'තරම්',
#   'ලංකාවෙ',
#   'මිනිස්සු',
#   'මෝඩ',
#   'ද'],
#  ['මේක',
#   'බලා',
#   'මුන්ට',
#   'ඇන්දුනු',
#   'එවුන්',
#   'මේ',
#   'පැත්තට',
#   'වර',
#   'මුන්',
#   'negative',
#   'promotion',
#   'මචං',
#   'මේ',
#   'කරන්නෙ',
#   'මුන්ට',
#   'ඕනි',
#   'views',
#   'ඒකට',
#   'දැන්',
#   'ලෝකෙ',
#   'ගොඩාක්',
#   'චැනල්',
#   'කාරයෝ',
#   'කරන්නෙ',
#   'negative',
#   'promotions',
#   'අපිත්',
#   'උන්ගෙ',
#   'කුණු',
#   'බලන්ඩ',
#   'බලනවා',
#   'දැන්',
#   'හොද',
#   'දෙයක්',
#   'බලනවට',
#   'වඩා',
#   'කෙනෙක්ගෙ',
#   'නරකක්',
#   'සමාජ',
#   'ගත',
#   'කරන්ඩ',
#   'පට්ටම',
#   'ලේසියි'],
#  ['fill',
#   't',
#   'ගේ',
#   'විඩියෝ',
#   'එක',
#   'පේමස්',
#   'කරන්න',
#   'කරන',
#   'කුමන්ත්\u200dරනයක්',
#   'බන්',
#   'ඕක'],
#  ['monawada',
#   'oii',
#   'mewa',
#   'thamuselath',
#   'views',
#   'ganna',
#   'ona',
#   'jarawak',
#   'danawa',
#   'wadagath',
#   'deyak',
#   'dala',
#   'ratata',
#   'wadak',
#   'athi',
#   'deyak',
#   'karala',
#   'salli',
#   'hoyanawa'],
#  ['මේක',
#   'අනිවාර්යෙන්',
#   'රඟපෑමක්',
#   'වෙන්න',
#   'ඕන',
#   'මොකද',
#   'noize',
#   'tv',
#   'channel',
#   'එකත්',
#   'filti',
#   'ලාගෙ',
#   'ඔබටත්',
#   'ඒක',
#   'තේරුම්',
#   'ගන්න',
#   'පුළුවන්',
#   'නම්',
#   'like',
#   'කරන්න'],
#  ['un',
#   'denatawath',
#   'nathi',
#   'prashnane',
#   'meke',
#   'comment',
#   'karanna',
#   'apu',
#   'unta',
#   'thiyenne'],
#  ['hasini',
#   'kochchara',
#   'samajeta',
#   'hoda',
#   'kiyagena',
#   'awata',
#   'wadak',
#   'na',
#   'badina',
#   'dawase',
#   'wena',
#   'ekek',
#   'ekka',
#   'haadakam',
#   'karanawa',
#   'me',
#   'video',
#   'ekenma',
#   'penawa',
#   'ekita',
#   'salli',
#   'witharai',
#   'wadagath'],
#  ['අනේ',
#   'මුන්ගෙ',
#   'බොරු',
#   'මාර්කටින්',
#   'වලට',
#   'අහු',
#   'වෙන',
#   'ගොබ්බයො',
#   'සෙට්',
#   'එහෙකුත්',
#   'ඉන්නවනේ',
#   'එනිවේ',
#   'iraj',
#   'අයියා',
#   'Buggatiයක්',
#   'වත්',
#   'බස්සයි',
#   'ලගදිම'],
#  ['hari',
#   'medda',
#   'wedasatahane',
#   'filltiwai',
#   'hashiniwai',
#   'vitharak',
#   'genella',
#   'palu',
#   'gedara',
#   'walang',
#   'bindhe',
#   'aei',
#   'aei',
#   'filltita',
#   'viruddawa',
#   'awa',
#   'cumens',
#   'block',
#   'kale',
#   'aei',
#   'oke',
#   'therumada',
#   'hari',
#   'medda',
#   'kiyanne'],
#  ['hasini',
#   'gei',
#   'filt',
#   'gei',
#   'song',
#   'ekak',
#   'yako',
#   'meee',
#   'hammeeee',
#   'marketing',
#   'ting',
#   'ting'],
#  ['සිංහල',
#   'ගායක',
#   'ගායිකාවෝ',
#   'හැමදාම',
#   'නහයෙන්',
#   'අඬන',
#   'නිසා',
#   'මම',
#   'ලේසියෙන්',
#   'අලුත්',
#   'සිංහල',
#   'සිංදු',
#   'අහන්නේ',
#   'නෑ',
#   'ඇහුවත්',
#   'එක',
#   'පාරක්',
#   'අහම්බෙන්',
#   'වගේ',
#   'තමා',
#   'හැබැයි',
#   'මේ',
#   'සිංදුව',
#   'ඕන',
#   'කමින්',
#   'කී',
#   'පාරක්',
#   'ඇහුවද',
#   'මන්දා',
#   'visual',
#   'එකත්',
#   'හොදයි',
#   'ගොඩ',
#   'කාලෙකින්',
#   'අහපු',
#   'හොදම',
#   'සිංදුව',
#   'වගේම',
#   'මේ',
#   'කාලේ',
#   'ආපු',
#   'හොදම',
#   'සිංදුව'],
#  ['meka',
#   'yakooo',
#   'marai',
#   'bn',
#   'umbe',
#   'hakiyawa',
#   'hiniyta',
#   'dena',
#   'kindi',
#   'thama',
#   'pattama'],
#  ['අම්මෝ',
#   'එකටනම්',
#   'හොටුත්',
#   'පැන්නා',
#   'මාවත්',
#   'subscribe',
#   'කරල',
#   'help',
#   'එකක්',
#   'දෙන්න',
#   'පෙන්ස්'],
#  ['අත්තටම',
#   'අදරෙකට',
#   'marry',
#   'කලනම්',
#   'මෙහෙම',
#   'කතා',
#   'කරන්න',
#   'පුලුවන්ද',
#   'මෙ',
#   'මිනිස්සු',
#   'marriage',
#   'එක',
#   'කියන්නෙ',
#   'මොකක්ද',
#   'කියල',
#   'දන්නෙ',
#   'නැ',
#   'හශිනි',
#   'තමනට',
#   'උන',
#   'ලජ්ජාව',
#   'වහගන්න',
#   'විශ්වව',
#   'marry',
#   'කරන්න',
#   'හදල',
#   'තියෙන්නෙ',
#   'ඔයලා',
#   'වගෙ',
#   'ගැනු',
#   'අත්තටම',
#   'ලජ්ජවක්',
#   'marriage',
#   'එක',
#   'කියන්නෙ',
#   'ලොකු',
#   'hotels',
#   'වල',
#   'grand',
#   'wedding',
#   'එකක්',
#   'ගන්න',
#   'එක',
#   'නෙවෙයි',
#   'අදරය',
#   'විශ්වාසය',
#   'එකිනෙකාටතියන',
#   'respect',
#   'එක',
#   'මත',
#   'පවතින',
#   'දෙයක්',
#   'ඔයලගෙ',
#   'තියෙන්නෙ',
#   'හරිම්',
#   'හිස්',
#   'ජීවිත',
#   'බොරු',
#   'ශො',
#   'එක',
#   'විතරයි'],
#  ['ඩෙටා',
#   'කාගෙන',
#   'බලලා',
#   'කමෙන්ට්',
#   'ලයික්',
#   'දාල',
#   'කරලා',
#   'කරෙ',
#   'ලොකු',
#   'පින්',
#   'කමක්',
#   'තැන්ස්',
#   'හැමොටම',
#   'මීට',
#   'ඉරාජ්',
#   'ඇතුලු',
#   'noize',
#   'tv',
#   'සැට්',
#   'එක'],
#  ['විවාහයක්',
#   'කියන්නෙ',
#   'මොකක්ද',
#   'කියලවත්',
#   'දන්නෙ',
#   'නැති',
#   'උන්',
#   'විවාහ',
#   'උනාම',
#   'ඔහොම',
#   'වෙනවා',
#   'ජනප්\u200dරිය',
#   'වෙන්න',
#   'ඇට',
#   'ලේ',
#   'මස්',
#   'විකුණනවා',
#   'නමුත්',
#   'ආදරයේ',
#   'හරි',
#   'අර්ථය',
#   'හොයන්න',
#   'ඔච්චර',
#   'දගලන්නෙ',
#   'නෑ',
#   'ලංකාවේ',
#   'විවාහ',
#   'උත්සවයක්',
#   'හෝ',
#   'engagement',
#   'එකකින්',
#   'දෙන්න',
#   'ඕන',
#   'ආදර්ශය',
#   'ඕක',
#   'නෙමෙයි'],
#  ['kwd',
#   'hutho',
#   'thmge',
#   'kollt',
#   'bainkm',
#   'bln',
#   'inn',
#   'geni',
#   'munt',
#   'benla',
#   'wedk',
#   'ne',
#   'mun',
#   'badu',
#   'gon',
#   'badu',
#   'oya',
#   'eha',
#   'peththe',
#   'inn',
#   'anith',
#   'hiaptuwa',
#   'oka',
#   'isra',
#   'amma',
#   'gena',
#   'sindu',
#   'qwe',
#   'eda',
#   'asewn',
#   'e',
#   'dewl',
#   'ghuwe',
#   'ada',
#   'mu',
#   'ponneyk',
#   'thani',
#   'ponnya',
#   'thwa',
#   'deyk',
#   'oya',
#   'හසිනිගෙ',
#   'wedding',
#   'ekt',
#   'ek',
#   'wedgth',
#   'kiyn',
#   'nluwek',
#   'awd',
#   'ne',
#   'ekn',
#   'hitha',
#   'gnn',
#   'puwnm',
#   'mun',
#   'serm',
#   'badu',
#   'kiyla',
#   'ලංකාවේ',
#   'සංස්කෘතිය',
#   'බල්ලට',
#   'වැටිලා',
#   'munwa',
#   'ෆොම්',
#   'krnn',
#   'epa',
#   'bolw'],
#  ['niraparade',
#   'nasthi',
#   'una',
#   'jeewitha',
#   'vivahaya',
#   'kiyana',
#   'eka',
#   'meyalata',
#   'sellamak',
#   'ada',
#   'banda',
#   'heta',
#   'divorce',
#   'una',
#   'hariyata',
#   'instant',
#   'noodles',
#   'ekak',
#   'wage',
#   'vivahaya',
#   'kiyana',
#   'wachne',
#   'hari',
#   'therumawath',
#   'danne',
#   'na',
#   'meyala',
#   'giya',
#   'athme',
#   'karapu',
#   'pawak',
#   'me',
#   'gewanne',
#   'e',
#   'unata',
#   'eka',
#   'therum',
#   'ganna',
#   'ba',
#   'danma',
#   'meyalata',
#   'thawa',
#   'awrudu',
#   '30k',
#   'yaddi',
#   'therei',
#   'lassana',
#   'pawl',
#   'jeewithayak',
#   'gewannath',
#   'pina',
#   'thiyenna',
#   'ona',
#   'e',
#   'pina',
#   'meyalata',
#   'na',
#   'karmayata',
#   'anuwa',
#   'meyalage',
#   'me',
#   'jeewitheth',
#   'idiri',
#   'jeewithayath',
#   'theeranaya',
#   'wei'],
#  ['මල',
#   'ලතෝනි',
#   'අහල',
#   'අහල',
#   'හෙම්බත්',
#   'වෙලා',
#   'හිටපු',
#   'කලෙක',
#   'මේ',
#   'වගේ',
#   'සුප්පා',
#   'songs',
#   'කරනවට',
#   'ගොඩක්',
#   'තැන්ක්ස්',
#   'බ්\u200dරෝ',
#   'සුබ',
#   'පතනවා',
#   'මම',
#   'මේක',
#   'සිය',
#   'වතාවක්',
#   'විතර',
#   'අහන්න',
#   'ඇති',
#   'සින්දුවක්',
#   'කියන්නේ',
#   'මොකක්ද',
#   'කියල',
#   'කිවොත්',
#   'අනිත්',
#   'නිරුවත',
#   'මාකට්',
#   'කරන',
#   'උන්ටයි',
#   'මල',
#   'ගෙදරක',
#   'වගේ',
#   'ලතෝනි',
#   'තියන',
#   'උන්ටයි',
#   'කනට',
#   'දෙකක්',
#   'ගහල',
#   'සනුකව',
#   'පෙන්නන',
#   'අපිට',
#   'පුළුවන්',
# ...
#   'අපිට',
#   'කවදාවත්',
#   'හොයාගන්න',
#   'බැරි',
#   'ජීවන',
#   'බිස්නස්',
#   'රහස්',
#   'මේ',
#   'පාර',
#   'චතුරයි',
#   'දම්මිකයි',
#   'දෙන්නම්',
#   'කටපාඩම්',
#   'කරගෙන',
#   'ඉන්නේ'],
#  ['දෙන්නම',
#   'විකටයෝ',
#   'තමන්ගේ',
#   'දිග',
#   'පලල',
#   'ගැන',
#   'මෙච්චර',
#   'පුරාජේරු',
#   'දොඩවන්නේ',
#   'ඇතුලත',
#   'හිස්',
#   'මිනිස්සු',
#   'මේ',
#   'ලංකාවට',
#   'වෙලා',
#   'තියෙන',
#   'විනාසේ',
#   'හරස්',
#   'කඩක්',
#   'මහා',
#   'පුරුෂාර්ථ',
#   'මත',
#   'ගොඩ',
#   'නැගෙන',
#   'ලාංකීය',
#   'පවුර්ෂ',
#   'නෑ',
#   'කටින්',
#   'පවුර්ෂ',
#   'හදන්න',
#   'බෑ',
#   'නිකන්',
#   'හිතන්න',
#   'කවදාවත්',
#   'tv',
#   'එකට',
#   'ආපු',
#   'නැති',
#   'උනත්',
#   'උපාලි',
#   'විජේවර්ධන',
#   'ගැනලොකු',
#   'ව්\u200dයාපාරික',
#   'පවුර්ෂයක්',
#   'අපේ',
#   'හිතේ',
#   'තියෙනවා',
#   'දැක්කේ',
#   'වත්',
#   'නැති',
#   'අනගාරික',
#   'ධර්මපාල',
#   'තුමාට',
#   'අපේ',
#   'ලොකු',
#   'ගවුරවයක්',
#   'තියෙනවා',
#   'පක්ෂ',
#   'බේධ',
#   'නැතුව',
#   'ds',
#   'ට',
#   'swrd',
#   'ට',
#   'මිනිස්සු',
#   'ගරු',
#   'කරන්නේ',
#   'නැද්ද',
#   'මගේ',
#   'නත්තල',
#   'දුගියා',
#   'බත්',
#   'කන',
#   'දාය',
#   'කියපු',
#   'පන්සලේ',
#   'පියතුමා',
#   'කියන',
#   'මර්සිලින්',
#   'පිය',
#   'තුමා',
#   'බවුද්ධ',
#   'අපිටත්',
#   'හුඟක්',
#   'ලොකු',
#   'කෙනෙක්'],
#  ['සූර',
#   'සරදියෙල්',
#   'කරපු',
#   'වැඩ',
#   'එක්ක',
#   'හැදුනු',
#   'ප්\u200dරතිරූපයක්',
#   'තියෙනවා',
#   'අර්තර්',
#   'වී',
#   'දියෙස්',
#   'ගේ',
#   'ප්\u200dරතිරුපේ',
#   'හැදුනේ',
#   'කොස්',
#   'ගහ',
#   'අපේ',
#   'වලට',
#   'හුඟක්',
#   'කිට්ටු',
#   'නිසා',
#   'මද්දුම',
#   'බණ්ඩාර',
#   'ගැන',
#   'කිරිබොන',
#   'පොඩි',
#   'උන්',
#   'හිටන්',
#   'දන්නවා',
#   'nm',
#   'පෙරේරා',
#   'db',
#   'ජයතිලක',
#   'කියන',
#   'නම්',
#   'වලට',
#   'හැම',
#   'හදකම',
#   'ඉඩක්',
#   'තියෙනවා',
#   'මහාචාර්ය',
#   'සරච්චන්ද්\u200dර',
#   'හා',
#   'තුනේ',
#   'පන්තියටවිතරක්',
#   'ගිය',
#   'මාර්ටින්',
#   'වික්\u200dරමසිංහ',
#   'නම්',
#   'ඇහුනත්',
#   'මිනිස්සු',
#   'ටිකකට',
#   'නැවතිලා',
#   'බලනවා',
#   'prof',
#   'jb',
#   'carlo',
#   'fonseka',
#   'nalin',
#   'de',
#   'silva',
#   'කිව්වම',
#   'ලංකාවේ',
#   'මහා',
#   'පවුර්ශ',
#   'ඇයි',
#   'මේ',
#   'පොල්කොළ',
#   'ඉටිකොළ',
#   'සිමෙන්ති',
#   'අනාගෙන',
#   'තමාගේම',
#   'පිළිම',
#   'තමන්ම',
#   'අඹන්නේ',
#   'අර',
#   'සමනත්\u200dර',
#   'භද්\u200dර',
#   'පිස්සු',
#   'උන්නාන්සේ',
#   'වගේ',
#   'අර',
#   'හැම',
#   'පෝයටම',
#   'අධෝ',
#   'වාහිනියට',
#   'itn',
#   'වාචාල',
#   'ගොන්',
#   'මඬලාවට',
#   'එන',
#   'අත්තනායක',
#   'ආචාරියා',
#   'වගේ',
#   'සුචරිත',
#   'කම',
#   'දෙකොනෙන්',
#   'බේරෙනවා'],
#  ['ඒක',
#   'මකන්න',
#   'න්\u200dයෂ්ටික',
#   'බෝම්බ',
#   'දැම්මත්',
#   'බෑ',
#   'මේ',
#   'එයාගේ',
#   '5',
#   'දිව්\u200dයඥානෙන්',
#   'පේන',
#   'දේවල්',
#   'අපිට',
#   'මොකටද',
#   'පුන',
#   'පුනා',
#   'කියන්නේ',
#   'මේවා',
#   'ගොන්',
#   'image',
#   'building',
#   'consultant',
#   'ලගේ',
#   'දිරච්ච',
#   'ලනු',
#   'හැබැයි',
#   'මෙයාගේ',
#   '5',
#   'මොලේ',
#   'පාවිච්චි',
#   'කරපු',
#   'එක',
#   'නම්',
#   'ඇත්ත',
#   'මොකද',
#   'අනෙක්',
#   '95',
#   'මහින්දගේ',
#   'කලුසල්ලි',
#   'හොර',
#   'මොලේ',
#   'මහින්ද',
#   'තමයි',
#   'වටේ',
#   'ඉන්න',
#   'උන්ට',
#   'අල්ලන',
#   'බැරි',
#   'විදියට',
#   'හොරාකන්න',
#   'පුරුදු',
#   'කරේ',
#   'මේ',
#   'වගේ',
#   'තැන්',
#   'වලට',
#   'ගැලපෙන',
#   'කියමන්',
#   'දෙක',
#   'තුනක්',
#   'මතක්',
#   'වෙනවා',
#   'ගැමියෝ',
#   'කියන',
#   'ඔන්න',
#   'කනෝ',
#   'පිනුම්',
#   'කිව්වලු'],
#  ['ඒ',
#   'වගේම',
#   'සිංහල',
#   'සමාජේ',
#   'තව',
#   'කියමනක්',
#   'තියෙනවා',
#   'හොරාගේ',
#   'අම්මගෙන්',
#   'පේන',
#   'ඇහීම',
#   'වගේ',
#   'මේ',
#   'කියමන්',
#   'දෙකෙන්ම',
#   'පොතකින්',
#   'කියන්න',
#   'බැරි',
#   'තරම්',
#   'මනෝ',
#   'රූප',
#   'අපතුල',
#   'මැවෙනවා',
#   'හැමදාම',
#   'ලංකාවේ',
#   'අපි',
#   'tv',
#   'එක',
#   'ළඟ',
#   'වාඩිවෙලා',
#   'තක්කඩි',
#   'පල්',
#   'හොරු',
#   'විසි',
#   'තිස්දාහක',
#   'කනා',
#   'පිනුම්',
#   'බල',
#   'බලා',
#   'උන්ගේ',
#   'දෙමවුපියන්ගෙන්ම',
#   'හොරා',
#   'ගැන',
#   'පේන',
#   'අහ',
#   'අහ',
#   'ඉන්න',
#   'ගොන්',
#   'රැලක්',
#   'වෙලා'],
#  ['president',
#   'wenna',
#   'one',
#   'na',
#   'policy',
#   'maker',
#   'kenek',
#   'karala',
#   'rata',
#   'diunu',
#   'karana',
#   'wada',
#   'tika',
#   'meyata',
#   'dunna',
#   'nam',
#   'sahena',
#   'deyak',
#   'karai'],
#  ['අපෝ',
#   'ධම්මික',
#   'ලොක්කා',
#   'චාටර්නේ',
#   'මේ',
#   'මොනවද',
#   'කියන්නේ',
#   'ai',
#   'ගැන',
#   'සිගිති',
#   'කථා',
#   'නේ',
#   'කියන්නේ'],
#  ['macahn',
#   'chathura',
#   'uba',
#   'program',
#   'eka',
#   'handle',
#   'karana',
#   'widiha',
#   'patta',
#   'harima',
#   'lassanai',
#   'jaya',
#   'weewa'],
#  ['I’m',
#   'a',
#   'muslim',
#   'ඒත්',
#   'මං',
#   'ආදරෙයි',
#   'මගේ',
#   'රටට',
#   'පණ',
#   'වගේ',
#   'මම',
#   'කවදාවත්',
#   'හිතල',
#   'නෑ',
#   'මම',
#   'මුස්ලිම්',
#   'උඹ',
#   'බෞධ්ද',
#   'අරෑ',
#   'හින්දු',
#   'ක්\u200dරිස්තියානි',
#   'කියලා',
#   'මට',
#   'නම්',
#   'කිසිම',
#   'ජාති',
#   'බේදයක්',
#   'නැහැ',
#   'අපේ',
#   'family',
#   'එකෙත්',
#   'කවුරැත්',
#   'එහෙම',
#   'නෑ',
#   'මම',
#   'අදහන',
#   'දෑ',
#   'මට',
#   'උඹ',
#   'අදහන',
#   'දෑ',
#   'උඹට',
#   'අපි',
#   'කවුරැත්',
#   'ඕව',
#   'ප්\u200dරශ්ණයක්',
#   'කරගන්න',
#   'ඕන',
#   'නෑ',
#   'මොකද',
#   'අපි',
#   'ඔක්කොම',
#   'එකයි',
#   'අපි',
#   'හැමෝම',
#   'එක',
#   'රටක',
#   'ජිවත්',
#   'වෙන්නේ',
#   'මමනම්',
#   'කියන්නේ',
#   'ලංකාවේ',
#   'ඉපදුන',
#   'මමත්',
#   'සිංහල',
#   'මගේ',
#   'ඇඟෙත්',
#   'දුවන්නේ',
#   'සිංහලේ'],
#  ['ආගම්',
#   'කුළ',
#   'භේද',
#   'අපි',
#   'කවුරැත්',
#   'ප්\u200dරශ්ණයක්',
#   'කරගන්න',
#   'ඕන',
#   'නෑ',
#   'අපි',
#   'ඔක්කොම',
#   'එකයි',
#   'අන්න',
#   'ඒක',
#   'කවුරැ',
#   'කවුරැත්',
#   'හිතට',
#   'ගත්තනම්',
#   'අපිත්',
#   'දිවුනු',
#   'වෙලා',
#   'රටත්',
#   'දිවුනු',
#   'වෙලා',
#   'පුංචි',
#   'එංගලන්තයක්',
#   'කරන්න',
#   'පුලුවන්',
#   'වැරදි',
#   'දෙයක්',
#   'කිවුවනම්',
#   'sorry'],
#  ['බුදු',
#   'අම්මො',
#   'කී',
#   'පාරක්නම්',
#   'ඇවිල්ලා',
#   'බැලුවද',
#   'full',
#   'episode',
#   'එක',
#   'දාලද',
#   'කියලා'],
#  ['එක', 'තත්පරයක්වත්', 'forward', 'කරන්නෙ', 'නැතුව', 'බලපු', 'video', 'එකක්'],
#  ['මොන',
#   'ලබ්බක්ද',
#   'යකෝ',
#   'තේරුමක්',
#   'ඇති',
#   'video',
#   'එකක්',
#   'කරපන්',
#   'ඉරාජ්',
#   'වගේ',
#   'වෙන්න',
#   'ගිහින්',
#   'තියන',
#   'තැනත්',
#   'නැති',
#   'කර',
#   'ගන්න',
#   'එපා'],
#  ['පොන්න',
#   'වැඩ',
#   'කරන්න',
#   'එපා',
#   'ඉරාජ්',
#   'අයියේ',
#   'dr',
#   'abdul',
#   'm',
#   'b',
#   'b',
#   's',
#   'saitn',
#   'sri',
#   'lanka',
#   'කෙලින්ම',
#   'saitm',
#   'කියලා',
#   'ගහපන්කෝ',
#   'පොන්න',
#   'වැඩ',
#   'කරන්නේ',
#   'නැතුව',
#   'සිංදුව',
#   'මෙලෝ',
#   'රහක්',
#   'නෑ',
#   'music',
#   'කලාට',
#   'කමක්',
#   'නෑ',
#   'කඩේ',
#   'යන්න',
#   'එපා'],
#  ['raj',
#   'ane',
#   'uba',
#   'wage',
#   'gon',
#   'harakek',
#   'hari',
#   'video',
#   'ekak',
#   'karapan',
#   'kisima',
#   'therumak',
#   'na',
#   'thaththath',
#   'casino',
#   'eke',
#   'kali',
#   'ekka',
#   'athal',
#   'gananwa',
#   'uba',
#   'namalge',
#   'hotu',
#   'kali',
#   'gahanawa',
#   'ewa',
#   'gahala',
#   'karana',
#   'video',
#   'thama',
#   'me',
#   'bhudda',
#   'sasane',
#   'kana',
#   'ekekuth',
#   'dagena',
#   'karana',
#   'gon',
#   'wada',
#   'ethi',
#   'bn',
#   'harajek',
#   'unata',
#   'eka',
#   'pennanna',
#   'epa'],
#  ['මචං',
#   'iraj',
#   'උබ',
#   'දක්ෂ',
#   'marketing',
#   'පොරක්',
#   'ඒත්',
#   'ආගමට',
#   'ජාතියට',
#   'නිග්\u200dරහ',
#   'කරන්න',
#   'එපා',
#   'උබට',
#   'ජාතියක්',
#   'ජන්මයක්',
#   'නැති',
#   'එකට',
#   'සමස්ත',
#   'ජාතියටම',
#   'ආගමට',
#   'මේ',
#   'වගේ',
#   'කරන්න',
#   'එපා',
#   'සමන්ත්\u200dර',
#   'බද්ඳා',
#   'කියන්නේ',
#   'දේව',
#   'දත්ත',
#   'කෙනෙක්',
#   'උබට',
#   'ටිකිරි',
#   'මොලයක්',
#   'හරි',
#   'තියෙනවනන්',
#   'දහම්',
#   'පාසලකට',
#   'ගිහින්',
#   'තියෙනවනන්',
#   'රහතන්',
#   'වහන්සේ',
#   'කෙනෙක්',
#   'කියන්නෙ',
#   'කොයි',
#   'වගේ',
#   'පුද්ගලයෙක්ද',
#   'කියන',
#   'එක',
#   'දැන',
#   'ගනිවී',
#   'මේ',
#   'වගේ',
#   'රග',
#   'පාන',
#   'නලුවෝ',
#   'උබලටම',
#   'තමා',
#   'හොද',
#   'උබට',
#   'මේ',
#   'කරන',
#   'දේවල්',
#   'වලට',
#   'මේ',
#   'අත්මයේ',
#   'දීම',
#   'පලිසන්',
#   'දෙනවා'],
#  ['balan',
#   'giyama',
#   'meya',
#   'piumita',
#   'wada',
#   'gonek',
#   'ne',
#   'he',
#   'he',
#   'he'],
#  ['fill',
#   't',
#   'එක්ක',
#   'ගහපු',
#   'වීඩියෝ',
#   'එක',
#   'දැක්කම',
#   'උබේ',
#   'තාත්තට',
#   'පාරෙ',
#   'බැහැලා',
#   'යන්න',
#   'පුලුවන්ද'],
#  ['පට්ට',
#   'බඩු',
#   'මේව',
#   'පාරෙ',
#   'යද්දි',
#   'ගල්',
#   'ගහන්න',
#   'ඕන',
#   'වැරදි',
#   'කරල',
#   'කොච්චර',
#   'හංගන්න',
#   'හැදුවත්',
#   'බෑ',
#   'ගොන්',
#   'වේසියේ',
#   'උඹලගෙ',
#   'ජීවිත',
#   'වලට',
#   'උඹල',
#   'respect',
#   'කරන්',
#   'නැත්නම්',
#   'වැරදි',
#   'ලෝකෙන්',
#   'හංගල',
#   'අනිත්',
#   'මිනිස්සුන්ගෙ',
#   'ගෞරවය',
#   'දිනා',
#   'ගන්න',
#   'උඹලට',
#   'බෑ'],
#  ['main',
#   'sponsor',
#   'manager',
#   'එක්ක',
#   'හුකලා',
#   'තමයි',
#   'videos',
#   'වලට',
#   'එන්නෙ',
#   'නැතුව',
#   'උබල',
#   'නිකං',
#   'එන්නේ',
#   'නෑනේ',
#   'මිනිස්සු',
#   'දන්නවා',
#   'බං',
#   'උඹලා',
#   'ගැන',
#   'කොච්චර',
#   'පොෂ්',
#   'වෙන්න',
#   'හැදුවත්',
#   'වැඩක්',
#   'නෑ'],
#  ['lankawe',
#   'inna',
#   'අලුත්',
#   'නළුනිළි',
#   'යන්ට',
#   'kiyanna',
#   'wachana',
#   'na',
#   'gon',
#   'part',
#   'මේවාට',
#   'danawa'],
#  ['me',
#   'minissunta',
#   'onnathi',
#   'deyak',
#   'na',
#   'kath',
#   'ekka',
#   'hitiyath',
#   'moko'],
#  ['එකි',
#   'අරුට',
#   'කියලා',
#   'ඇරගේන',
#   'දැන්',
#   'එනවා',
#   'so',
#   'so',
#   'kiyann',
#   'අනේ',
#   'පවු',
#   'dan',
#   'oyaaa',
#   'kohomath',
#   'baduwe',
#   'wela',
#   'inne',
#   'aiyooooooo',
#   'salli'],
#  ['hashini',
#   'comments',
#   'dana',
#   'ayatath',
#   'podi',
#   'chance',
#   'ekak',
#   'denna',
#   'berida',
#   'nikan',
#   'lampuwa',
#   'allanna',
#   'wage'],
#  ['mudukku',
#   'wala',
#   'heduna',
#   'awn',
#   'thama',
#   'me',
#   'widiyata',
#   'hesirenne',
#   'kisima',
#   'wili',
#   'lejjawak',
#   'nethi',
#   'wesaganan',
#   'wahinakota',
#   'hena',
#   'gahanna',
#   'one',
#   'munta',
#   'lankawa',
#   'winasa',
#   'karanawata'],
#  ['මේ',
#   'comment',
#   'එකට',
#   'like',
#   'එකක්',
#   'නොදා',
#   'ඔයගොල්ලෝ',
#   'සතුටින්',
#   'ඉන්න',
#   'හොදේ'],
#  ['wooowwww',
#   'teledrama',
#   'එක',
#   'කොහොම',
#   'වුනත්',
#   'සිංදුව',
#   'නම්',
#   'මාරම',
#   'ලස්සනයි',
#   'ගයමු',
#   'දවසක',
#   'ජිවිතේ',
#   'තාලේ'],
#  ['ane',
#   'aththamai',
#   'meke',
#   'ad',
#   'kara',
#   'akkai',
#   'අයියය්',
#   'harima',
#   'lassanai'],
#  ['pramoth',
#   'ganearachchi',
#   'ඔයාට',
#   'වැරදුනේ',
#   'na',
#   'දෙරණ',
#   'ඔයාව',
#   'අමතක',
#   'කළේ',
#   'na',
#   'නේද'],
#  ['music', 'එක', 'වගේම', 'කතාවත්', 'ලස්සනයි', 'කියලා', 'හිතනවා'],
#  ['niyama',
#   'kathawa',
#   'lawan',
#   'aiya',
#   'niyamata',
#   'acting',
#   'karanawa',
#   'superb'],
#  ['lassani', 'godakkkk', 'man', 'asai', 'e', 'song', 'ekata'],
#  ['මමත්',
#   'dream',
#   'star',
#   'yanna',
#   'hithan',
#   'hitiye',
#   'ath',
#   'mata',
#   'රඟපාන්න',
#   'bee',
#   'a',
#   'nisa',
#   'adahasa',
#   'wenas',
#   'kla'],
#  ['me',
#   'teledrama',
#   'eka',
#   'harima',
#   'lassanai',
#   'meka',
#   'jiwita',
#   'kalayatama',
#   'thiyannawam'],
#  ['pttt', 'broo', 'අපි', 'ආසාවෙන්', 'බලන', 'කතාවක්', 'සුපිරි'],
#  ['meke',
#   'inna',
#   'chuty',
#   'babage',
#   'team',
#   'eke',
#   'mahatha',
#   'ayyage',
#   'name',
#   'eka',
#   'mokakda',
#   'bolaa',
#   'maama',
#   'kiyana',
#   'kenage'],
#  ['ඇප්',
#   'එක',
#   'රිලීස්',
#   'වුනේ',
#   'පෙබරවාරි',
#   '13',
#   'හැබැයි',
#   'රැල්ලට',
#   'යන්න',
#   'කලින්',
#   'account',
#   'එකක්',
#   'හදා',
#   'ගන්න',
#   'බොරු',
#   'බොරු',
#   'කියල',
#   'ඉන්නෙ',
#   'නැතිව',
#   'පොඩ්ඩක්',
#   'ට්\u200dරයි',
#   'කරන්න'],
#  ['මේකේ',
#   'btc',
#   'හොයන්නයි',
#   'තියෙන්නේ',
#   'දැනට',
#   'නම්',
#   'invite',
#   'කරල',
#   'රෙෆරල්',
#   'කරන',
#   'එකට',
#   'තමයි',
#   'ගෙවන්නේ',
#   'එහෙම',
#   'හොයන',
#   'gems',
#   'පැය',
#   'දොලහෙන්',
#   'දොලහට',
#   'වගේ',
#   'එකතු',
#   'කරන්න',
#   'දෙනවා'],
#  ['ඊට',
#   'පස්සේ',
#   'ලංකාවේ',
#   'වෙලාවෙන්',
#   'නම්',
#   'රෑ',
#   '7',
#   '30ට',
#   'gems',
#   'btc',
#   'වලට',
#   'exchange',
#   'වෙනවා',
#   'මෙයාලා',
#   'කියන්නෙ',
#   'එක්කෙනෙක්ට',
#   '20',
#   'වගේ',
#   'දෙන්න',
#   'බලාපොරොත්තු',
#   'වෙනව',
#   'කියල'],
#  ['මේ',
#   'ලින්ක්',
#   'එකෙන්',
#   'රෙජිස්ටර්',
#   'වෙන්න',
#   'gems',
#   '10000ක්',
#   'හම්බ',
#   'වෙයි',
#   'ඒ',
#   'වගේම',
#   'ඩොලර්',
#   'මිලියනයක්',
#   'දින්න',
#   'චාන්ස්',
#   'එකකුත්',
#   'ලැබේබී'],
#  ['මුලින්ම',
#   'මේ',
#   'ලින්ක්',
#   'එකෙන්',
#   'ගියාම',
#   'login',
#   'with',
#   'google',
#   'දෙන්න',
#   'ඊට',
#   'පස්සේ',
#   'gmail',
#   'එකක්',
#   'දීලා',
#   'පර්මිසන්',
#   'වගයක්',
#   'allow',
#   'කරන්න',
#   'ඉල්ලයි',
#   'ඒක',
#   'කරන්න'],
#  ['ඊට',
#   'පස්සෙ',
#   'play',
#   'store',
#   'එකට',
#   'යයි',
#   'ඇප්',
#   'එක',
#   'අරන්',
#   'ඕපන්',
#   'කලාට',
#   'පස්සේ',
#   'google',
#   'account',
#   'පෙන්නයි',
#   'කලින්',
#   'දුන්න',
#   'email',
#   'address',
#   'එකේ',
#   'account',
#   'එක',
#   'select',
#   'කරන්න',
#   'ඊට',
#   'පස්සේ',
#   'ලොග්',
#   'වෙන්න'],
#  ['මේ',
#   'ඇප්',
#   'එක',
#   'නම්',
#   'කොලෝන්',
#   'කරන්න',
#   'එකවුන්ට්',
#   'දෙකක්',
#   'හදන්න',
#   'එහෙම',
#   'යන්න',
#   'එපා',
#   'බෑන්',
#   'කරාවී',
#   'ඒක',
#   'දන්නව',
#   'ඇති',
#   'පිවොට්',
#   'එකෙන්',
#   'බෑන්',
#   'උන',
#   'කට්ටිය',
#   'එහෙම',
#   'උනොත්',
#   'ආයේ',
#   'හදන',
#   'හදන',
#   'account',
#   'එක',
#   'බෑන්',
#   'වෙයි',
#   'ඔන්න',
#   'කලින්ම',
#   'කීවා'],
#  ['marai',
#   'a',
#   'kathawa',
#   'harima',
#   'lassanai',
#   'mn',
#   'godak',
#   'aasai',
#   'mechchara',
#   'dawasakata',
#   'balapu',
#   'lassanama',
#   'kathawa',
#   'hamadama',
#   'balanawa',
#   'aththatama',
#   'eka',
#   'dawasak',
#   'balala',
#   'digatama',
#   'balanna',
#   'hitha',
#   'gaththa',
#   'wow'],
#  ['යනගමන්', 'subscribe', 'පාරක්', 'දාගෙන', 'යනවද', 'කට්ටිය'],
#  ['සිංදුව', 'ලස්සනයි', 'අයියේ', 'good', 'luck'],
#  ['me', 'drama', 'ekath', 'episodes', '1000', 'k', 'withra', 'yaida'],
#  ['t',
#   'ඇහෙනකොට',
#   'අහගෙන',
#   'ඉන්න',
#   'ආස',
#   'හිතෙන',
#   'සින්දුවක්',
#   'අහලම',
#   'බලන්න'],
#  ['me', 'gaani', 'atthatama', 'සිංහල', 'dannema', 'nadda'],
#  ['mona',
#   'hari',
#   'aulak',
#   'thiyanawa',
#   'kella',
#   'balapan',
#   'ubata',
#   'weradila',
#   'muge',
#   'wayasa',
#   'tikak'],
#  ['gon', 'huththiyek'],
#  ['පිස්සු',
#   'හුත්තිලා',
#   'මුන්',
#   'වගේ',
#   'උන්',
#   'නිසා',
#   'හොඳ',
#   'කෙල්ලන්වත්',
#   'දූෂණය',
#   'කරන්න',
#   'නාකි',
#   'ඉතිං',
#   'දුවනවා',
#   'කියපන්කෝ',
#   'මේ',
#   'මෙයාව',
#   'sponsor',
#   'කරන්න',
#   'එතකොට',
#   'තව',
#   'ඔයිට',
#   'වඩා',
#   'නාකි',
#   'උන්ටත්',
#   'ඔහොම',
#   'බදාගෙන',
#   'ඉන්න',
#   'පුළුවන්',
#   'අනේ',
#   'පව්',
#   'sponsor',
#   'කරලා',
#   'විතරයිනෙ',
#   'අනෙ',
#   'අම්මේ',
#   'උඹල',
#   'වගේ',
#   'උනුත්',
#   'පලයල්ලකො',
#   'පාර්ලිමේන්තුවට'],
#  ['aththatama',
#   'mama',
#   'video',
#   'eka',
#   'baluwe',
#   'na',
#   'mulinama',
#   'kare',
#   'comments',
#   'tika',
#   'kiyawanna',
#   'awa',
#   'maru',
#   'jolly',
#   'appa',
#   'mewa',
#   'kiyawanakota'],
#  ['gon', 'badu', 'form', 'karanna', 'epa'],
#  ['yes',
#   'so',
#   'but',
#   'ammage',
#   'redda',
#   'pala',
#   'belli',
#   'konakata',
#   'dannttn',
#   'waren',
#   'kiyala',
#   'denna'],
#  ['ane',
#   'ithin',
#   'adagenama',
#   'nagena',
#   'paw',
#   'apppa',
#   'lejjawe',
#   'vachana',
#   'tepalenava'],
#  ['ammpa', 'me', 'wesiyont', 'lajja', 'nane'],
#  ['video',
#   'aka',
#   'karannath',
#   'hambela',
#   'thiyanne',
#   'room',
#   'akakk',
#   'ada',
#   'uda',
#   'edan',
#   'video',
#   'aka',
#   'karala',
#   'thiyanna',
#   'wadagath',
#   'ganulamayak',
#   'sponsor',
#   'akka',
#   'room',
#   'aka',
#   'thaniyama',
#   'video',
#   'akak',
#   'karaida'],
#  ['lankawe',
#   'dan',
#   'badui',
#   'horui',
#   'minimaruwoi',
#   'mankolla',
#   'karayoi',
#   'tamai',
#   'inne',
#   'dan'],
#  ['sinhalen', 'kiyapan', 'ganiye', 'therenne', 'na'],
#  ['meunta', 'monawat', 'danna', 'ma', 'nadda'],
#  ['gon', 'gahak', 'so', 'but', 'so', 'but', 'onada', 'bn', 'e'],
#  ['monoda', 'bn', 'me', 'inglish', 'ane', 'huke'],
#  ['paw',
#   'bn',
#   'meki',
#   'mama',
#   'hithanne',
#   'nevedikawak',
#   'wenna',
#   'hadanne',
#   'aru',
#   'ba',
#   'ba',
#   'ba',
#   'gana',
#   'wa',
#   'meki',
#   'kiyanawa',
#   'golden',
#   'wards',
#   'lu',
#   'thopi',
#   'jathaka',
#   'kelata',
#   'wada',
#   'hodai',
#   'yako',
#   'us',
#   'mahath',
#   'keranna',
#   'kerapu',
#   'viyadamen',
#   'pol',
#   'waththak',
#   'wawa',
#   'nawa',
#   'nondi',
#   'nathuwa',
#   'vikunagena',
#   'kanna',
#   'puluwan'],
#  ['ubala', 'thama', 'dawasakatat', 'ganu', 'p', 'hina', 'ithin', 'mewata'],
#  ['mun', 'okkom', 'badu', 'boruwata', 'baila', 'gahanawa'],
#  ['ow', 'ow', 'matath', 'therune', 'purtugisi', 'basawa', 'wage', 'thamai'],
#  ['nodanna', 'english', 'katharanna', 'gihing', 'redi', 'galaunada', 'manda'],
#  ['adoooo',
#   'anna',
#   'u',
#   'france',
#   'walinda',
#   'kohedooo',
#   'kata',
#   'kara',
#   'grade',
#   '8',
#   'walata',
#   'iskole',
#   'gihin',
#   'nathi',
#   'wesiyo',
#   'moddeling',
#   'chuttak',
#   'kalama',
#   'hithanne',
#   'ane',
#   'eki',
#   'thama',
#   'queen',
#   'elizebeth',
#   'kiyala'],
#  ['huththata',
#   'english',
#   'aava',
#   'neththang',
#   'sinhalen',
#   'katha',
#   'karapan',
#   'huththo'],
#  ['aiyooo', 'ratakat', 'giya', 'kala'],
#  ['adeeh',
#   'ayeth',
#   'gihin',
#   'live',
#   'ma',
#   'awith',
#   'ada',
#   'udama',
#   'balapan',
#   'konedeth',
#   'awl',
#   'mekige'],
#  ['daenina',
#   'kata',
#   'karagaena',
#   'ewara',
#   'wela',
#   'apeta',
#   'baila',
#   'gahanawa',
#   'aiyo',
#   'salile'],
#  ['amu', 'wesiyak'],
#  ['lajjawai',
#   'aththai',
#   'waha',
#   'ganna',
#   'klchchara',
#   'vidio',
#   'dammath',
#   'boru',
#   'kiwwat',
#   'wadak',
#   'nh',
#   'hasini',
#   'paw',
#   'oya'],
#  ['wow',
#   'pattama',
#   'lassana',
#   'tele',
#   'drama',
#   'ekak',
#   'derana',
#   'hemadama',
#   'aluth',
#   'wedak',
#   'karanawata',
#   'thanks',
#   'ගයමූ',
#   'දවසක',
#   'ජීවිතේ',
#   'තාලේ'],
#  ['meke',
#   'inna',
#   'sudu',
#   'aiya',
#   'shoi',
#   'ane',
#   'eyawa',
#   'contact',
#   'krala',
#   'dennako'],
#  ...]

# %%
percent_sinhala = (len(sinhala_tokens_set)/len(cleaned_tokens))*100
print("Percentage of sinhala tweets:", percent_sinhala)

percent_singlish = (len(singlish_tokens_set)/len(cleaned_tokens))*100
print("Percentage of singlish tweets:", percent_singlish)
# Out:
# Percentage of sinhala tweets: 57.99999999999999
# Percentage of singlish tweets: 42.0

# %%
# find indexes of sinhala and singlish to create 2 datasets
sinhala_indexes = []
singlish_indexes = []
for index, row in df.iterrows():
    sentence = row['cleaned_phrase']
    tokens = tokenize(sentence)
    if(isSinglish(tokens)):
        singlish_indexes.append(index)
    else:
        sinhala_indexes.append(index)

# %%
# writing to CSV files
sinhala_df = df.ix[sinhala_indexes]
singlish_df = df.ix[singlish_indexes]

sinhala_df.to_csv("sinhala_dataset.csv")
singlish_df.to_csv("singlish_dataset.csv")
# Out:
# /home/sidathm/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# /home/sidathm/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# - **cleaned_tokens** list contains the all generated tokens after applying the preprocessing and tokenizing steps
# - **sinhala_tokens_set** list contains the all sinhala tweets
# - **singlish_tokens_set** list contains the all singlish tweets
# - **sinhala_df** dataframe is the dataset of only sinhala tweets
# - **singlish_df** dataframe is the dataset of singlish tweets

# %% [markdown]
# ### Answer (b)
#
# Any pre-text explaining the code below...

# %%
# Insert code for part (b)

# %% [markdown]
# Any post-text explaining the result obtained...

# %% [markdown]
# ### Answer (c)
#
# Any pre-text explaining the code below...

# %%
# Insert code for part (c)

# %% [markdown]
# Any post-text explaining the result obtained...

# %% [markdown]
# ### Answer (d)
#
# Any pre-text explaining the code below...

# %%
# Insert code for part (d)

# %% [markdown]
# Any post-text explaining the result obtained...

# %% [markdown]
# ### Answer (e)
#
# Any pre-text explaining the code below...

# %%
# Insert code for part (e)

# %% [markdown]
# Any post-text explaining the result obtained...

# %% [markdown]
# ### Answer (f)
#
# Any pre-text explaining the code below...

# %%
# Insert code for part (f)

# %% [markdown]
# Any post-text explaining the result obtained...

# %% [markdown]
# ### Answer (g)
#
# Insert text description for this part here
